# %%
import spacy
import de_core_news_sm
nlp = de_core_news_sm.load()
from spacy.matcher import Matcher
from charsplit import Splitter
import string
splitter = Splitter()
import pandas as pd
import jellyfish
import random

# %%
def clear_special_characters(s1, s2):
    invalidcharacters = set(string.punctuation)
    if any(char in invalidcharacters for char in s1):
        s1_ = s1.lower().translate(str.maketrans('', '', string.punctuation))
    else:
        s1_ = s1
    if any(char in invalidcharacters for char in s2):
        s2_ = s2.lower().translate(str.maketrans('', '', string.punctuation))
    else:
        s2_ = s2
    return s1_, s2_

# %%
def stop_words_handling(term):
    splitted_term = term.split()
    stop_words = set(["for", "and", "of", "in", "&", "via", "be"])
    
    if splitted_term[0] in stop_words:
        stop_words = stop_words - set([splitted_term[0]])
                
    for sw in stop_words:
        while sw in splitted_term:
            splitted_term.remove(sw)
    sanitized_term = " ".join([w for w in splitted_term]) 
        
    return sanitized_term

# %%
def check_initial_letters(a, t):
    initial_letters_of_tokens_of_t = ''.join([c[0] for c in t.split()])
    if initial_letters_of_tokens_of_t == a or initial_letters_of_tokens_of_t.upper() == a:
        return True

# %%
def check_length_consistency(a, t):
    length_consistency = False
    if len(t.split()) <= len(a):
        length_consistency = True
    return length_consistency

# %%
def check_order(a, t):
    abbv_reversed = a.lower()[::-1]
    term_reversed = t.lower()[::-1]
    len_of_term = len(t)
    
    pos_memory = 0
    pos_memory_list = []
    order_matching_string_rev = ""
    
    for j, char_from_abbv in enumerate(abbv_reversed):
        if j == len(abbv_reversed) - 1:
            if char_from_abbv == term_reversed[-1]:
                order_matching_string_rev = order_matching_string_rev + char_from_abbv
                pos_memory_list.append(0)
        else:
            for i, char_from_term in enumerate(term_reversed[pos_memory:]):
                if char_from_abbv == char_from_term:
                    order_matching_string_rev = order_matching_string_rev + char_from_abbv
                    pos_memory = pos_memory + i + 1
                    pos_memory_list.append(len_of_term - pos_memory)
                    break
                
    if order_matching_string_rev == abbv_reversed:
        return True, pos_memory_list[::-1]
    else:
        return False, []

# %%
check_order("XMPP", "xtensibxle Messaging and Presence Protocol")
# Out:
# (True, [0, 11, 25, 34])

# %%
def check_distribution_of_matching_characters(pos_of_chars_list, t):
    term_intervals = []
    len_of_term = len(t)
    i = 0
    while i < len_of_term:
        sublist = []
        j = i
        while j < len_of_term and t[j] != " ":
            sublist.append(j)
            j = j+ 1
        i = j+1
        term_intervals.append(sublist)
        
    splitted_term = t.split()      
    
    containment_list = []
    for i, interval in enumerate(term_intervals):
        contanment_sublist = []
        for pos in pos_of_chars_list:
            if (pos in interval) and (splitted_term[i][0] == t[pos]):
                contanment_sublist.append(0)
            elif pos in interval:
                contanment_sublist.append(interval.index(pos))
        if len(contanment_sublist) == 0:
            contanment_sublist.append(-1)
        containment_list.append(contanment_sublist)
    
    result_of_distribution_check = False
    if len(containment_list) <= 1:
        result_of_distribution_check = True
    elif len (containment_list) >= 2:
        non_zero_count = 0
        for sublist in containment_list[1:]:
            if len(sublist) == 1 and 0 not in sublist:
                non_zero_count += 1
        if non_zero_count == 0:
            result_of_distribution_check = True
    
    return result_of_distribution_check

# %%
def base_algo(abbv, term):
    valid_order, pos_of_chars_list = check_order(abbv, term)
    return valid_order

# %%
def match_rating_comparison(a, term):
    if jellyfish.match_rating_comparison(a, term):
        return 1
    elif not jellyfish.match_rating_comparison(a, term):
        return 0

# %%
def check_wether_abbv_is_proper_short_form_of_term(abbv, term):
    if (abbv[0].lower() == term[0].lower()):
        
        
        ###################################### Step (a) ##########################################
        # check wether initial letters of tokens in t match with the letters in abbreviation
        if check_initial_letters(abbv, term):
            return True
        
        
        
        ###################################### Step (b) ########################################
        # clean abbreviation and term from special characters and stopwords
        sanitized_abbv, sanitized_term = clear_special_characters(abbv, term) 
        sanitized_term_without_stopswords = stop_words_handling(sanitized_term)
        sanitized_term_without_stopswords_splitted  = sanitized_term_wo_stopswords.split()
        
        # check wether initial letters of tokens in t' match with the letters in a'
        if check_initial_letters(sanitized_abbv, sanitized_term_without_stopswords):
            return True
        
        
        ###################################### Step (c) ##########################################
        # Sequential call of the methods that check and compare lengths, order and distribution of characters
        length_consistency = check_length_consistency(sanitized_abbv, sanitized_term_without_stopswords)
        order, pos_of_chars_list = check_order(sanitized_abbv, sanitized_term_without_stopswords)
        distribution = check_distribution_of_matching_characters(pos_of_chars_list, sanitized_term_without_stopswords)


        if length_consistency and order and distribution:
            return True
        else:
            return False

        ################################## in case nothing matches #################################
    else:
        return False

# %%
data = pd.read_csv('abbr_db.CSV', names=['abbr', 'long_forms'], sep=';', encoding='utf8')
abbr = list(data['abbr'].values)
long_forms = list(data['long_forms'].values)

# %%
def calc_fn(algo):
    FN = 0
    for i, abb in enumerate(abbr):
        if not algo(abb, long_forms[i]):
            print("\"" + abb + "\", " + "\"" + long_forms[i] + "\"")
            print("##################################")
            FN += 1
    return str(FN) + " FALSE NEGATIVES. Pairs that could not be detected out of " + str(len(abbr)) + " given pairs"

# %%
def calc_fp(algo):
    count_of_false_examples = 0
    FP = 0
    for i, abb in enumerate(abbr):
        len_ = len(abbr)
        for j in range (i, len_):
            if abb != abbr[j]:
                count_of_false_examples += 1
                if algo(abb, long_forms[j]):
                    print("\"" + abb + "\", " + "\"" + long_forms[j] + "\"")
                    FP +=1
    return str(FP) + " FALSE POSITIVE detections out of " +  str(count_of_false_examples) + " created false examples"

# %%
a = calc_fp(base_algo)
print(a)
# Out:
# "AA", "Advanced Audio Coding"
# "AA", "autmoatic acoustic management"
# "AA", "Auto Area Segmentation"
# "AA", "as a service"
# "AA", "Atanasoff-Berry Computer"
# "AA", "abnormabl end"
# "AA", "Advanced BIOS"
# "AA", "AdBlock Plus"
# "AA", "anonymous coward"
# "AA", "Asheron's Call"
# "AA", "alternating current"
# "AA", "account"
# "AA", "access control entry"
# "AA", "acknowledgment"
# "AA", "access control list"
# "AA", "Association for Computing Machinery"
# "AA", "Advanced Configuration and Power Interface"
# "AA", "annual compliance report"
# "AA", "actual cell rate"
# "AA", "attenuation crosstalk ratio"
# "AA", "absolute cell reference"
# "AA", "access control system"
# "AA", "Active Directory"
# "AA", "Apple Desktop Bus"
# "AA", "Android Debug Bridge"
# "AA", "analog-to-digital"
# "AA", "ActiveX Data Object"
# "AA", "adaptive delta pulse code modulation"
# "AA", "analog display service interface"
# "AA", "Active Directory Service Interface"
# "AA", "asymmetric digital subscriber line"
# "AA", "ADSTAR Distributed Storage Management"
# "AA", "automatic exposure"
# "AA", "After Effects"
# "AA", "auto exposure lock"
# "AA", "Advanced Encryption Standard"
# "AA", "Autofocus"
# "AA", "accelerated graphics port"
# "AA", "Advanced Host Controller Interface"
# "AA", "artificial intelligence"
# "AA", "Apple, IBM and Motorola"
# "AA", "AOL Instant Messenger"
# "AA", "Artificial Intelligent Markup Language"
# "AA", "AGP in-line memory module"
# "AA", "All-in-One"
# "AA", "advanced interactive executive"
# "AA", "Asynchronous JavaScript and XML"
# "AA", "also known as"
# "AA", "algorithmic language"
# "AA", "alphabet"
# "AA", "arithmetic logic unit"
# "AA", "ante meridiem"
# "AA", "amplitude modulation"
# "AA", "ask me anything"
# "AA", "active-matrix organic light-emitting diode"
# "AA", "ampere"
# "AA", "Automatic Number Identification"
# "AA", "American National Standards Institute"
# "AA", "auto operator"
# "AA", "aspect-oriented programming"
# "AA", "Android Open Source Project"
# "AA", "application programming interface"
# "AA", "Advanced Programmable Interrupt Controller"
# "AA", "Automatic Private Internet Protocol Addressing"
# "AA", "Android package file"
# "AA", "advanced power management"
# "AA", "application"
# "AA", "advanced persistent threat"
# "AA", "advanced packaging tool"
# "AA", "advanced processing unit"
# "AA", "accelerated processing unit"
# "AA", "augmented reality"
# "AA", "Attached Resource Computer network"
# "AA", "address record"
# "AA", "argument"
# "AA", "Address Resolution Protocol"
# "AA", "address and routing parameter area"
# "AA", "Advanced Research Projects Agency"
# "AA", "Advanced Research Projects Agency Network"
# "AA", "automatic repeat request"
# "AA", "autonomous system"
# "AA", "Application System/400"
# "AA", "as soon as possible"
# "AA", "American Standard Code for Information Interchange"
# "AA", "American Society of Mechanical Engineers"
# "AA", "autonomous sensory meridian response"
# "AA", "autonomous system number"
# "AA", "abstract syntax number one"
# "AA", "answer set programming"
# "AA", "authorized service provider"
# "AA", "application service provider"
# "AA", "Active Server Pages"
# "AA", "advanced SCSI programming interface"
# "AA", "automatic speech recognition"
# "AA", "automated system recovery "
# "AA", "advanced technology"
# "AA", "Advanced Technology Attachment"
# "AA", "AT Attachment Packet Interface"
# "AA", "advanced transfer cache"
# "AA", "above the fold"
# "AA", "automated teller machine"
# "AA", "at the moment"
# "AA", "ascynchronous transfer mode"
# "AA", "Adaptive Transform Acoustic Coding"
# "AA", "Advanced Technology eXtended"
# "AA", "arithmetic unit"
# "AA", "Attachment Unit Interface"
# "AA", "acceptable use policy"
# "AA", "automobile"
# "AA", "autonomous"
# "AA", "automatic"
# "AA", "avatar"
# "AA", "aperture value"
# "AA", "antivirus"
# "AA", "Advanced Video Coding"
# "AA", "Audio Video Interleaved"
# "AA", "automatic voice response"
# "AA", "automatic voice recognition"
# "AA", "automatic voltage regulator"
# "AA", "Amazon Web Services"
# "AA", "Adobe Flash"
# "AA", "are you there?"
# "AAC", "autmoatic acoustic management"
# "AAC", "as a service"
# "AAC", "Atanasoff-Berry Computer"
# "AAC", "Advanced BIOS"
# "AAC", "AdBlock Plus"
# "AAC", "anonymous coward"
# "AAC", "Asheron's Call"
# "AAC", "alternating current"
# "AAC", "account"
# "AAC", "access control entry"
# "AAC", "acknowledgment"
# "AAC", "access control list"
# "AAC", "Association for Computing Machinery"
# "AAC", "Advanced Configuration and Power Interface"
# "AAC", "annual compliance report"
# "AAC", "actual cell rate"
# "AAC", "attenuation crosstalk ratio"
# "AAC", "absolute cell reference"
# "AAC", "access control system"
# "AAC", "Active Directory"
# "AAC", "ActiveX Data Object"
# "AAC", "adaptive delta pulse code modulation"
# "AAC", "analog display service interface"
# "AAC", "Active Directory Service Interface"
# "AAC", "asymmetric digital subscriber line"
# "AAC", "automatic exposure"
# "AAC", "After Effects"
# "AAC", "auto exposure lock"
# "AAC", "Advanced Encryption Standard"
# "AAC", "Autofocus"
# "AAC", "accelerated graphics port"
# "AAC", "Advanced Host Controller Interface"
# "AAC", "artificial intelligence"
# "AAC", "Artificial Intelligent Markup Language"
# "AAC", "advanced interactive executive"
# "AAC", "Asynchronous JavaScript and XML"
# "AAC", "algorithmic language"
# "AAC", "arithmetic logic unit"
# "AAC", "active-matrix organic light-emitting diode"
# "AAC", "Automatic Number Identification"
# "AAC", "American National Standards Institute"
# "AAC", "aspect-oriented programming"
# "AAC", "Android Open Source Project"
# "AAC", "application programming interface"
# "AAC", "Advanced Programmable Interrupt Controller"
# "AAC", "Automatic Private Internet Protocol Addressing"
# "AAC", "Android package file"
# "AAC", "advanced power management"
# "AAC", "application"
# "AAC", "advanced persistent threat"
# "AAC", "advanced packaging tool"
# "AAC", "advanced processing unit"
# "AAC", "accelerated processing unit"
# "AAC", "Attached Resource Computer network"
# "AAC", "address record"
# "AAC", "Address Resolution Protocol"
# "AAC", "Advanced Research Projects Agency"
# "AAC", "Advanced Research Projects Agency Network"
# "AAC", "automatic repeat request"
# "AAC", "Application System/400"
# "AAC", "American Standard Code for Information Interchange"
# "AAC", "American Society of Mechanical Engineers"
# "AAC", "abstract syntax number one"
# "AAC", "authorized service provider"
# "AAC", "application service provider"
# "AAC", "Active Server Pages"
# "AAC", "advanced SCSI programming interface"
# "AAC", "automatic speech recognition"
# "AAC", "automated system recovery "
# "AAC", "advanced technology"
# "AAC", "Advanced Technology Attachment"
# "AAC", "AT Attachment Packet Interface"
# "AAC", "advanced transfer cache"
# "AAC", "automated teller machine"
# "AAC", "ascynchronous transfer mode"
# "AAC", "Adaptive Transform Acoustic Coding"
# "AAC", "Advanced Technology eXtended"
# "AAC", "arithmetic unit"
# "AAC", "Attachment Unit Interface"
# "AAC", "acceptable use policy"
# "AAC", "automatic"
# "AAC", "Advanced Video Coding"
# "AAC", "automatic voice response"
# "AAC", "automatic voice recognition"
# "AAC", "automatic voltage regulator"
# "AAC", "Amazon Web Services"
# "AAM", "Auto Area Segmentation"
# "AAM", "Atanasoff-Berry Computer"
# "AAM", "abnormabl end"
# "AAM", "anonymous coward"
# "AAM", "acknowledgment"
# "AAM", "Association for Computing Machinery"
# "AAM", "annual compliance report"
# "AAM", "access control system"
# "AAM", "adaptive delta pulse code modulation"
# "AAM", "asymmetric digital subscriber line"
# "AAM", "ADSTAR Distributed Storage Management"
# "AAM", "automatic exposure"
# "AAM", "Apple, IBM and Motorola"
# "AAM", "AOL Instant Messenger"
# "AAM", "Artificial Intelligent Markup Language"
# "AAM", "AGP in-line memory module"
# "AAM", "Asynchronous JavaScript and XML"
# "AAM", "algorithmic language"
# "AAM", "arithmetic logic unit"
# "AAM", "ante meridiem"
# "AAM", "amplitude modulation"
# "AAM", "ask me anything"
# "AAM", "active-matrix organic light-emitting diode"
# "AAM", "ampere"
# "AAM", "Automatic Number Identification"
# "AAM", "American National Standards Institute"
# "AAM", "aspect-oriented programming"
# "AAM", "application programming interface"
# "AAM", "Advanced Programmable Interrupt Controller"
# "AAM", "Automatic Private Internet Protocol Addressing"
# "AAM", "advanced power management"
# "AAM", "augmented reality"
# "AAM", "Attached Resource Computer network"
# "AAM", "argument"
# "AAM", "address and routing parameter area"
# "AAM", "automatic repeat request"
# "AAM", "autonomous system"
# "AAM", "Application System/400"
# "AAM", "American Standard Code for Information Interchange"
# "AAM", "American Society of Mechanical Engineers"
# "AAM", "autonomous sensory meridian response"
# "AAM", "autonomous system number"
# "AAM", "abstract syntax number one"
# "AAM", "answer set programming"
# "AAM", "advanced SCSI programming interface"
# "AAM", "automatic speech recognition"
# "AAM", "automated system recovery "
# "AAM", "Advanced Technology Attachment"
# "AAM", "AT Attachment Packet Interface"
# "AAM", "automated teller machine"
# "AAM", "at the moment"
# "AAM", "ascynchronous transfer mode"
# "AAM", "Adaptive Transform Acoustic Coding"
# "AAM", "arithmetic unit"
# "AAM", "Attachment Unit Interface"
# "AAM", "automobile"
# "AAM", "autonomous"
# "AAM", "automatic"
# "AAM", "automatic voice response"
# "AAM", "automatic voice recognition"
# "AAM", "automatic voltage regulator"
# "AAM", "Amazon Web Services"
# "AAS", "Atanasoff-Berry Computer"
# "AAS", "Advanced BIOS"
# "AAS", "AdBlock Plus"
# "AAS", "anonymous coward"
# "AAS", "Asheron's Call"
# "AAS", "access control entry"
# "AAS", "access control list"
# "AAS", "Association for Computing Machinery"
# "AAS", "attenuation crosstalk ratio"
# "AAS", "absolute cell reference"
# "AAS", "access control system"
# "AAS", "Apple Desktop Bus"
# "AAS", "adaptive delta pulse code modulation"
# "AAS", "analog display service interface"
# "AAS", "Active Directory Service Interface"
# "AAS", "asymmetric digital subscriber line"
# "AAS", "ADSTAR Distributed Storage Management"
# "AAS", "automatic exposure"
# "AAS", "After Effects"
# "AAS", "auto exposure lock"
# "AAS", "Advanced Encryption Standard"
# "AAS", "Autofocus"
# "AAS", "accelerated graphics port"
# "AAS", "Advanced Host Controller Interface"
# "AAS", "AOL Instant Messenger"
# "AAS", "Asynchronous JavaScript and XML"
# "AAS", "also known as"
# "AAS", "ask me anything"
# "AAS", "American National Standards Institute"
# "AAS", "aspect-oriented programming"
# "AAS", "Android Open Source Project"
# "AAS", "Automatic Private Internet Protocol Addressing"
# "AAS", "advanced persistent threat"
# "AAS", "advanced processing unit"
# "AAS", "accelerated processing unit"
# "AAS", "Attached Resource Computer network"
# "AAS", "address record"
# "AAS", "Address Resolution Protocol"
# "AAS", "address and routing parameter area"
# "AAS", "Advanced Research Projects Agency"
# "AAS", "Advanced Research Projects Agency Network"
# "AAS", "automatic repeat request"
# "AAS", "autonomous system"
# "AAS", "Application System/400"
# "AAS", "as soon as possible"
# "AAS", "American Standard Code for Information Interchange"
# "AAS", "American Society of Mechanical Engineers"
# "AAS", "autonomous sensory meridian response"
# "AAS", "autonomous system number"
# "AAS", "abstract syntax number one"
# "AAS", "answer set programming"
# "AAS", "authorized service provider"
# "AAS", "application service provider"
# "AAS", "Active Server Pages"
# "AAS", "advanced SCSI programming interface"
# "AAS", "automatic speech recognition"
# "AAS", "automated system recovery "
# "AAS", "advanced transfer cache"
# "AAS", "ascynchronous transfer mode"
# "AAS", "Adaptive Transform Acoustic Coding"
# "AAS", "acceptable use policy"
# "AAS", "autonomous"
# "AAS", "antivirus"
# "AAS", "automatic voice response"
# "AAS", "Amazon Web Services"
# "AAS", "Adobe Flash"
# "AAS", "Atanasoff-Berry Computer"
# "AAS", "Advanced BIOS"
# "AAS", "AdBlock Plus"
# "AAS", "anonymous coward"
# "AAS", "Asheron's Call"
# "AAS", "access control entry"
# "AAS", "access control list"
# "AAS", "Association for Computing Machinery"
# "AAS", "attenuation crosstalk ratio"
# "AAS", "absolute cell reference"
# "AAS", "access control system"
# "AAS", "Apple Desktop Bus"
# "AAS", "adaptive delta pulse code modulation"
# "AAS", "analog display service interface"
# "AAS", "Active Directory Service Interface"
# "AAS", "asymmetric digital subscriber line"
# "AAS", "ADSTAR Distributed Storage Management"
# "AAS", "automatic exposure"
# "AAS", "After Effects"
# "AAS", "auto exposure lock"
# "AAS", "Advanced Encryption Standard"
# "AAS", "Autofocus"
# "AAS", "accelerated graphics port"
# "AAS", "Advanced Host Controller Interface"
# "AAS", "AOL Instant Messenger"
# "AAS", "Asynchronous JavaScript and XML"
# "AAS", "also known as"
# "AAS", "ask me anything"
# "AAS", "American National Standards Institute"
# "AAS", "aspect-oriented programming"
# "AAS", "Android Open Source Project"
# "AAS", "Automatic Private Internet Protocol Addressing"
# "AAS", "advanced persistent threat"
# "AAS", "advanced processing unit"
# "AAS", "accelerated processing unit"
# "AAS", "Attached Resource Computer network"
# "AAS", "address record"
# "AAS", "Address Resolution Protocol"
# "AAS", "address and routing parameter area"
# "AAS", "Advanced Research Projects Agency"
# "AAS", "Advanced Research Projects Agency Network"
# "AAS", "automatic repeat request"
# "AAS", "autonomous system"
# "AAS", "Application System/400"
# "AAS", "as soon as possible"
# "AAS", "American Standard Code for Information Interchange"
# "AAS", "American Society of Mechanical Engineers"
# "AAS", "autonomous sensory meridian response"
# "AAS", "autonomous system number"
# "AAS", "abstract syntax number one"
# "AAS", "answer set programming"
# "AAS", "authorized service provider"
# "AAS", "application service provider"
# "AAS", "Active Server Pages"
# "AAS", "advanced SCSI programming interface"
# "AAS", "automatic speech recognition"
# "AAS", "automated system recovery "
# "AAS", "advanced transfer cache"
# "AAS", "ascynchronous transfer mode"
# "AAS", "Adaptive Transform Acoustic Coding"
# "AAS", "acceptable use policy"
# "AAS", "autonomous"
# "AAS", "antivirus"
# "AAS", "automatic voice response"
# "AAS", "Amazon Web Services"
# "AAS", "Adobe Flash"
# "ABC", "AdBlock Plus"
# "ABC", "absolute cell reference"
# "ABC", "ActiveX Data Object"
# "ABC", "asymmetric digital subscriber line"
# "ABC", "Automatic Number Identification"
# "ABC", "Advanced Programmable Interrupt Controller"
# "ABC", "abstract syntax number one"
# "ABC", "acceptable use policy"
# "ABC", "Amazon Web Services"
# "ABP", "Advanced Programmable Interrupt Controller"
# "ABP", "acceptable use policy"
# "AC", "account"
# "AC", "access control entry"
# "AC", "acknowledgment"
# "AC", "access control list"
# "AC", "Association for Computing Machinery"
# "AC", "Advanced Configuration and Power Interface"
# "AC", "annual compliance report"
# "AC", "actual cell rate"
# "AC", "attenuation crosstalk ratio"
# "AC", "absolute cell reference"
# "AC", "access control system"
# "AC", "Active Directory"
# "AC", "ActiveX Data Object"
# "AC", "adaptive delta pulse code modulation"
# "AC", "analog display service interface"
# "AC", "Active Directory Service Interface"
# "AC", "asymmetric digital subscriber line"
# "AC", "automatic exposure"
# "AC", "After Effects"
# "AC", "auto exposure lock"
# "AC", "Advanced Encryption Standard"
# "AC", "Autofocus"
# "AC", "accelerated graphics port"
# "AC", "Advanced Host Controller Interface"
# "AC", "artificial intelligence"
# "AC", "Artificial Intelligent Markup Language"
# "AC", "advanced interactive executive"
# "AC", "Asynchronous JavaScript and XML"
# "AC", "algorithmic language"
# "AC", "arithmetic logic unit"
# "AC", "active-matrix organic light-emitting diode"
# "AC", "Automatic Number Identification"
# "AC", "American National Standards Institute"
# "AC", "aspect-oriented programming"
# "AC", "Android Open Source Project"
# "AC", "application programming interface"
# "AC", "Advanced Programmable Interrupt Controller"
# "AC", "Automatic Private Internet Protocol Addressing"
# "AC", "Android package file"
# "AC", "advanced power management"
# "AC", "application"
# "AC", "advanced persistent threat"
# "AC", "advanced packaging tool"
# "AC", "advanced processing unit"
# "AC", "accelerated processing unit"
# "AC", "Attached Resource Computer network"
# "AC", "address record"
# "AC", "Address Resolution Protocol"
# "AC", "Advanced Research Projects Agency"
# "AC", "Advanced Research Projects Agency Network"
# "AC", "automatic repeat request"
# "AC", "Application System/400"
# "AC", "American Standard Code for Information Interchange"
# "AC", "American Society of Mechanical Engineers"
# "AC", "abstract syntax number one"
# "AC", "authorized service provider"
# "AC", "application service provider"
# "AC", "Active Server Pages"
# "AC", "advanced SCSI programming interface"
# "AC", "automatic speech recognition"
# "AC", "automated system recovery "
# "AC", "advanced technology"
# "AC", "Advanced Technology Attachment"
# "AC", "AT Attachment Packet Interface"
# "AC", "advanced transfer cache"
# "AC", "automated teller machine"
# "AC", "ascynchronous transfer mode"
# "AC", "Adaptive Transform Acoustic Coding"
# "AC", "Advanced Technology eXtended"
# "AC", "arithmetic unit"
# "AC", "Attachment Unit Interface"
# "AC", "acceptable use policy"
# "AC", "automatic"
# "AC", "Advanced Video Coding"
# "AC", "automatic voice response"
# "AC", "automatic voice recognition"
# "AC", "automatic voltage regulator"
# "AC", "Amazon Web Services"
# "AC", "account"
# "AC", "access control entry"
# "AC", "acknowledgment"
# "AC", "access control list"
# "AC", "Association for Computing Machinery"
# "AC", "Advanced Configuration and Power Interface"
# "AC", "annual compliance report"
# "AC", "actual cell rate"
# "AC", "attenuation crosstalk ratio"
# "AC", "absolute cell reference"
# "AC", "access control system"
# "AC", "Active Directory"
# "AC", "ActiveX Data Object"
# "AC", "adaptive delta pulse code modulation"
# "AC", "analog display service interface"
# "AC", "Active Directory Service Interface"
# "AC", "asymmetric digital subscriber line"
# "AC", "automatic exposure"
# "AC", "After Effects"
# "AC", "auto exposure lock"
# "AC", "Advanced Encryption Standard"
# "AC", "Autofocus"
# "AC", "accelerated graphics port"
# "AC", "Advanced Host Controller Interface"
# "AC", "artificial intelligence"
# "AC", "Artificial Intelligent Markup Language"
# "AC", "advanced interactive executive"
# "AC", "Asynchronous JavaScript and XML"
# "AC", "algorithmic language"
# "AC", "arithmetic logic unit"
# "AC", "active-matrix organic light-emitting diode"
# "AC", "Automatic Number Identification"
# "AC", "American National Standards Institute"
# "AC", "aspect-oriented programming"
# "AC", "Android Open Source Project"
# "AC", "application programming interface"
# "AC", "Advanced Programmable Interrupt Controller"
# "AC", "Automatic Private Internet Protocol Addressing"
# "AC", "Android package file"
# "AC", "advanced power management"
# "AC", "application"
# "AC", "advanced persistent threat"
# "AC", "advanced packaging tool"
# "AC", "advanced processing unit"
# "AC", "accelerated processing unit"
# "AC", "Attached Resource Computer network"
# "AC", "address record"
# "AC", "Address Resolution Protocol"
# "AC", "Advanced Research Projects Agency"
# "AC", "Advanced Research Projects Agency Network"
# "AC", "automatic repeat request"
# "AC", "Application System/400"
# "AC", "American Standard Code for Information Interchange"
# "AC", "American Society of Mechanical Engineers"
# "AC", "abstract syntax number one"
# "AC", "authorized service provider"
# "AC", "application service provider"
# "AC", "Active Server Pages"
# "AC", "advanced SCSI programming interface"
# "AC", "automatic speech recognition"
# "AC", "automated system recovery "
# "AC", "advanced technology"
# "AC", "Advanced Technology Attachment"
# "AC", "AT Attachment Packet Interface"
# "AC", "advanced transfer cache"
# "AC", "automated teller machine"
# "AC", "ascynchronous transfer mode"
# "AC", "Adaptive Transform Acoustic Coding"
# "AC", "Advanced Technology eXtended"
# "AC", "arithmetic unit"
# "AC", "Attachment Unit Interface"
# "AC", "acceptable use policy"
# "AC", "automatic"
# "AC", "Advanced Video Coding"
# "AC", "automatic voice response"
# "AC", "automatic voice recognition"
# "AC", "automatic voltage regulator"
# "AC", "Amazon Web Services"
# "AC", "account"
# "AC", "access control entry"
# "AC", "acknowledgment"
# "AC", "access control list"
# "AC", "Association for Computing Machinery"
# "AC", "Advanced Configuration and Power Interface"
# "AC", "annual compliance report"
# "AC", "actual cell rate"
# "AC", "attenuation crosstalk ratio"
# "AC", "absolute cell reference"
# "AC", "access control system"
# "AC", "Active Directory"
# "AC", "ActiveX Data Object"
# "AC", "adaptive delta pulse code modulation"
# "AC", "analog display service interface"
# "AC", "Active Directory Service Interface"
# "AC", "asymmetric digital subscriber line"
# "AC", "automatic exposure"
# "AC", "After Effects"
# "AC", "auto exposure lock"
# "AC", "Advanced Encryption Standard"
# "AC", "Autofocus"
# "AC", "accelerated graphics port"
# "AC", "Advanced Host Controller Interface"
# "AC", "artificial intelligence"
# "AC", "Artificial Intelligent Markup Language"
# "AC", "advanced interactive executive"
# "AC", "Asynchronous JavaScript and XML"
# "AC", "algorithmic language"
# "AC", "arithmetic logic unit"
# "AC", "active-matrix organic light-emitting diode"
# "AC", "Automatic Number Identification"
# "AC", "American National Standards Institute"
# "AC", "aspect-oriented programming"
# "AC", "Android Open Source Project"
# "AC", "application programming interface"
# "AC", "Advanced Programmable Interrupt Controller"
# "AC", "Automatic Private Internet Protocol Addressing"
# "AC", "Android package file"
# "AC", "advanced power management"
# "AC", "application"
# "AC", "advanced persistent threat"
# "AC", "advanced packaging tool"
# "AC", "advanced processing unit"
# "AC", "accelerated processing unit"
# "AC", "Attached Resource Computer network"
# "AC", "address record"
# "AC", "Address Resolution Protocol"
# "AC", "Advanced Research Projects Agency"
# "AC", "Advanced Research Projects Agency Network"
# "AC", "automatic repeat request"
# "AC", "Application System/400"
# "AC", "American Standard Code for Information Interchange"
# "AC", "American Society of Mechanical Engineers"
# "AC", "abstract syntax number one"
# "AC", "authorized service provider"
# "AC", "application service provider"
# "AC", "Active Server Pages"
# "AC", "advanced SCSI programming interface"
# "AC", "automatic speech recognition"
# "AC", "automated system recovery "
# "AC", "advanced technology"
# "AC", "Advanced Technology Attachment"
# "AC", "AT Attachment Packet Interface"
# "AC", "advanced transfer cache"
# "AC", "automated teller machine"
# "AC", "ascynchronous transfer mode"
# "AC", "Adaptive Transform Acoustic Coding"
# "AC", "Advanced Technology eXtended"
# "AC", "arithmetic unit"
# "AC", "Attachment Unit Interface"
# "AC", "acceptable use policy"
# "AC", "automatic"
# "AC", "Advanced Video Coding"
# "AC", "automatic voice response"
# "AC", "automatic voice recognition"
# "AC", "automatic voltage regulator"
# "AC", "Amazon Web Services"
# "ACCT", "access control entry"
# "ACCT", "access control list"
# "ACCT", "Association for Computing Machinery"
# "ACCT", "Advanced Configuration and Power Interface"
# "ACCT", "annual compliance report"
# "ACCT", "actual cell rate"
# "ACCT", "access control system"
# "ACCT", "Active Directory"
# "ACCT", "ActiveX Data Object"
# "ACCT", "Active Directory Service Interface"
# "ACCT", "Advanced Encryption Standard"
# "ACCT", "accelerated graphics port"
# "ACCT", "Advanced Host Controller Interface"
# "ACCT", "advanced interactive executive"
# "ACCT", "Asynchronous JavaScript and XML"
# "ACCT", "arithmetic logic unit"
# "ACCT", "active-matrix organic light-emitting diode"
# "ACCT", "Automatic Number Identification"
# "ACCT", "Android Open Source Project"
# "ACCT", "Advanced Programmable Interrupt Controller"
# "ACCT", "advanced packaging tool"
# "ACCT", "advanced processing unit"
# "ACCT", "accelerated processing unit"
# "ACCT", "Attached Resource Computer network"
# "ACCT", "Advanced Research Projects Agency"
# "ACCT", "Advanced Research Projects Agency Network"
# "ACCT", "American Standard Code for Information Interchange"
# "ACCT", "American Society of Mechanical Engineers"
# "ACCT", "advanced SCSI programming interface"
# "ACCT", "automatic speech recognition"
# "ACCT", "Advanced Technology Attachment"
# "ACCT", "AT Attachment Packet Interface"
# "ACCT", "ascynchronous transfer mode"
# "ACCT", "Advanced Technology eXtended"
# "ACCT", "acceptable use policy"
# "ACCT", "automatic voice recognition"
# "ACE", "acknowledgment"
# "ACE", "access control list"
# "ACE", "Association for Computing Machinery"
# "ACE", "Advanced Configuration and Power Interface"
# "ACE", "annual compliance report"
# "ACE", "actual cell rate"
# "ACE", "absolute cell reference"
# "ACE", "access control system"
# "ACE", "Active Directory"
# "ACE", "ActiveX Data Object"
# "ACE", "adaptive delta pulse code modulation"
# "ACE", "analog display service interface"
# "ACE", "Active Directory Service Interface"
# "ACE", "asymmetric digital subscriber line"
# "ACE", "automatic exposure"
# "ACE", "Advanced Encryption Standard"
# "ACE", "accelerated graphics port"
# "ACE", "Advanced Host Controller Interface"
# "ACE", "artificial intelligence"
# "ACE", "Artificial Intelligent Markup Language"
# "ACE", "advanced interactive executive"
# "ACE", "algorithmic language"
# "ACE", "active-matrix organic light-emitting diode"
# "ACE", "Automatic Number Identification"
# "ACE", "American National Standards Institute"
# "ACE", "aspect-oriented programming"
# "ACE", "Android Open Source Project"
# "ACE", "application programming interface"
# "ACE", "Advanced Programmable Interrupt Controller"
# "ACE", "Automatic Private Internet Protocol Addressing"
# "ACE", "Android package file"
# "ACE", "advanced power management"
# "ACE", "advanced persistent threat"
# "ACE", "advanced packaging tool"
# "ACE", "advanced processing unit"
# "ACE", "accelerated processing unit"
# "ACE", "Attached Resource Computer network"
# "ACE", "Advanced Research Projects Agency"
# "ACE", "Advanced Research Projects Agency Network"
# "ACE", "automatic repeat request"
# "ACE", "Application System/400"
# "ACE", "American Standard Code for Information Interchange"
# "ACE", "American Society of Mechanical Engineers"
# "ACE", "abstract syntax number one"
# "ACE", "authorized service provider"
# "ACE", "application service provider"
# "ACE", "Active Server Pages"
# "ACE", "advanced SCSI programming interface"
# "ACE", "automatic speech recognition"
# "ACE", "automated system recovery "
# "ACE", "advanced technology"
# "ACE", "Advanced Technology Attachment"
# "ACE", "AT Attachment Packet Interface"
# "ACE", "advanced transfer cache"
# "ACE", "automated teller machine"
# "ACE", "ascynchronous transfer mode"
# "ACE", "Advanced Technology eXtended"
# "ACE", "Attachment Unit Interface"
# "ACE", "acceptable use policy"
# "ACE", "Advanced Video Coding"
# "ACE", "automatic voice response"
# "ACE", "automatic voice recognition"
# "ACE", "automatic voltage regulator"
# "ACE", "Amazon Web Services"
# "Ack", "attenuation crosstalk ratio"
# "Ack", "auto exposure lock"
# "Ack", "Artificial Intelligent Markup Language"
# "Ack", "Android package file"
# "Ack", "advanced packaging tool"
# "Ack", "Attached Resource Computer network"
# "Ack", "Advanced Research Projects Agency Network"
# "Ack", "AT Attachment Packet Interface"
# "ACL", "annual compliance report"
# "ACL", "actual cell rate"
# "ACL", "attenuation crosstalk ratio"
# "ACL", "absolute cell reference"
# "ACL", "access control system"
# "ACL", "adaptive delta pulse code modulation"
# "ACL", "asymmetric digital subscriber line"
# "ACL", "accelerated graphics port"
# "ACL", "Advanced Host Controller Interface"
# "ACL", "artificial intelligence"
# "ACL", "Artificial Intelligent Markup Language"
# "ACL", "Asynchronous JavaScript and XML"
# "ACL", "algorithmic language"
# "ACL", "arithmetic logic unit"
# "ACL", "active-matrix organic light-emitting diode"
# "ACL", "American National Standards Institute"
# "ACL", "Advanced Programmable Interrupt Controller"
# "ACL", "Automatic Private Internet Protocol Addressing"
# "ACL", "Android package file"
# "ACL", "advanced packaging tool"
# "ACL", "accelerated processing unit"
# "ACL", "Address Resolution Protocol"
# "ACL", "American Society of Mechanical Engineers"
# "ACL", "advanced technology"
# "ACL", "Advanced Technology Attachment"
# "ACL", "Advanced Technology eXtended"
# "ACL", "acceptable use policy"
# "ACL", "automatic voltage regulator"
# "ACM", "annual compliance report"
# "ACM", "access control system"
# "ACM", "adaptive delta pulse code modulation"
# "ACM", "Artificial Intelligent Markup Language"
# "ACM", "Asynchronous JavaScript and XML"
# "ACM", "active-matrix organic light-emitting diode"
# "ACM", "Automatic Number Identification"
# "ACM", "aspect-oriented programming"
# "ACM", "application programming interface"
# "ACM", "Advanced Programmable Interrupt Controller"
# "ACM", "advanced power management"
# "ACM", "Attached Resource Computer network"
# "ACM", "Application System/400"
# "ACM", "American Standard Code for Information Interchange"
# "ACM", "American Society of Mechanical Engineers"
# "ACM", "abstract syntax number one"
# "ACM", "advanced SCSI programming interface"
# "ACM", "Advanced Technology Attachment"
# "ACM", "AT Attachment Packet Interface"
# "ACM", "ascynchronous transfer mode"
# "ACM", "Attachment Unit Interface"
# "ACPI", "annual compliance report"
# "ACPI", "Advanced Encryption Standard"
# "ACPI", "accelerated graphics port"
# "ACPI", "aspect-oriented programming"
# "ACPI", "application programming interface"
# "ACPI", "Advanced Programmable Interrupt Controller"
# "ACPI", "Automatic Private Internet Protocol Addressing"
# "ACPI", "advanced persistent threat"
# "ACPI", "advanced packaging tool"
# "ACPI", "advanced processing unit"
# "ACPI", "accelerated processing unit"
# "ACPI", "authorized service provider"
# "ACPI", "application service provider"
# "ACPI", "advanced SCSI programming interface"
# "ACPI", "automatic speech recognition"
# "ACPI", "AT Attachment Packet Interface"
# "ACPI", "acceptable use policy"
# "ACR", "access control system"
# "ACR", "Active Directory"
# "ACR", "analog display service interface"
# "ACR", "Active Directory Service Interface"
# "ACR", "asymmetric digital subscriber line"
# "ACR", "automatic exposure"
# "ACR", "Advanced Encryption Standard"
# "ACR", "accelerated graphics port"
# "ACR", "Advanced Host Controller Interface"
# "ACR", "Artificial Intelligent Markup Language"
# "ACR", "advanced interactive executive"
# "ACR", "Asynchronous JavaScript and XML"
# "ACR", "active-matrix organic light-emitting diode"
# "ACR", "Automatic Number Identification"
# "ACR", "American National Standards Institute"
# "ACR", "aspect-oriented programming"
# "ACR", "Android Open Source Project"
# "ACR", "application programming interface"
# "ACR", "Advanced Programmable Interrupt Controller"
# "ACR", "Automatic Private Internet Protocol Addressing"
# "ACR", "advanced power management"
# "ACR", "advanced persistent threat"
# "ACR", "advanced processing unit"
# "ACR", "accelerated processing unit"
# "ACR", "Attached Resource Computer network"
# "ACR", "address record"
# "ACR", "Advanced Research Projects Agency"
# "ACR", "Advanced Research Projects Agency Network"
# "ACR", "automatic repeat request"
# "ACR", "American Standard Code for Information Interchange"
# "ACR", "American Society of Mechanical Engineers"
# "ACR", "abstract syntax number one"
# "ACR", "authorized service provider"
# "ACR", "application service provider"
# "ACR", "Active Server Pages"
# "ACR", "advanced SCSI programming interface"
# "ACR", "automatic speech recognition"
# "ACR", "automated system recovery "
# "ACR", "AT Attachment Packet Interface"
# "ACR", "advanced transfer cache"
# "ACR", "ascynchronous transfer mode"
# "ACR", "Attachment Unit Interface"
# "ACR", "automatic voice response"
# "ACR", "automatic voice recognition"
# "ACR", "automatic voltage regulator"
# "ACR", "access control system"
# "ACR", "Active Directory"
# "ACR", "analog display service interface"
# "ACR", "Active Directory Service Interface"
# "ACR", "asymmetric digital subscriber line"
# "ACR", "automatic exposure"
# "ACR", "Advanced Encryption Standard"
# "ACR", "accelerated graphics port"
# "ACR", "Advanced Host Controller Interface"
# "ACR", "Artificial Intelligent Markup Language"
# "ACR", "advanced interactive executive"
# "ACR", "Asynchronous JavaScript and XML"
# "ACR", "active-matrix organic light-emitting diode"
# "ACR", "Automatic Number Identification"
# "ACR", "American National Standards Institute"
# "ACR", "aspect-oriented programming"
# "ACR", "Android Open Source Project"
# "ACR", "application programming interface"
# "ACR", "Advanced Programmable Interrupt Controller"
# "ACR", "Automatic Private Internet Protocol Addressing"
# "ACR", "advanced power management"
# "ACR", "advanced persistent threat"
# "ACR", "advanced processing unit"
# "ACR", "accelerated processing unit"
# "ACR", "Attached Resource Computer network"
# "ACR", "address record"
# "ACR", "Advanced Research Projects Agency"
# "ACR", "Advanced Research Projects Agency Network"
# "ACR", "automatic repeat request"
# "ACR", "American Standard Code for Information Interchange"
# "ACR", "American Society of Mechanical Engineers"
# "ACR", "abstract syntax number one"
# "ACR", "authorized service provider"
# "ACR", "application service provider"
# "ACR", "Active Server Pages"
# "ACR", "advanced SCSI programming interface"
# "ACR", "automatic speech recognition"
# "ACR", "automated system recovery "
# "ACR", "AT Attachment Packet Interface"
# "ACR", "advanced transfer cache"
# "ACR", "ascynchronous transfer mode"
# "ACR", "Attachment Unit Interface"
# "ACR", "automatic voice response"
# "ACR", "automatic voice recognition"
# "ACR", "automatic voltage regulator"
# "ACR", "access control system"
# "ACR", "Active Directory"
# "ACR", "analog display service interface"
# "ACR", "Active Directory Service Interface"
# "ACR", "asymmetric digital subscriber line"
# "ACR", "automatic exposure"
# "ACR", "Advanced Encryption Standard"
# "ACR", "accelerated graphics port"
# "ACR", "Advanced Host Controller Interface"
# "ACR", "Artificial Intelligent Markup Language"
# "ACR", "advanced interactive executive"
# "ACR", "Asynchronous JavaScript and XML"
# "ACR", "active-matrix organic light-emitting diode"
# "ACR", "Automatic Number Identification"
# "ACR", "American National Standards Institute"
# "ACR", "aspect-oriented programming"
# "ACR", "Android Open Source Project"
# "ACR", "application programming interface"
# "ACR", "Advanced Programmable Interrupt Controller"
# "ACR", "Automatic Private Internet Protocol Addressing"
# "ACR", "advanced power management"
# "ACR", "advanced persistent threat"
# "ACR", "advanced processing unit"
# "ACR", "accelerated processing unit"
# "ACR", "Attached Resource Computer network"
# "ACR", "address record"
# "ACR", "Advanced Research Projects Agency"
# "ACR", "Advanced Research Projects Agency Network"
# "ACR", "automatic repeat request"
# "ACR", "American Standard Code for Information Interchange"
# "ACR", "American Society of Mechanical Engineers"
# "ACR", "abstract syntax number one"
# "ACR", "authorized service provider"
# "ACR", "application service provider"
# "ACR", "Active Server Pages"
# "ACR", "advanced SCSI programming interface"
# "ACR", "automatic speech recognition"
# "ACR", "automated system recovery "
# "ACR", "AT Attachment Packet Interface"
# "ACR", "advanced transfer cache"
# "ACR", "ascynchronous transfer mode"
# "ACR", "Attachment Unit Interface"
# "ACR", "automatic voice response"
# "ACR", "automatic voice recognition"
# "ACR", "automatic voltage regulator"
# "ACR", "access control system"
# "ACR", "Active Directory"
# "ACR", "analog display service interface"
# "ACR", "Active Directory Service Interface"
# "ACR", "asymmetric digital subscriber line"
# "ACR", "automatic exposure"
# "ACR", "Advanced Encryption Standard"
# "ACR", "accelerated graphics port"
# "ACR", "Advanced Host Controller Interface"
# "ACR", "Artificial Intelligent Markup Language"
# "ACR", "advanced interactive executive"
# "ACR", "Asynchronous JavaScript and XML"
# "ACR", "active-matrix organic light-emitting diode"
# "ACR", "Automatic Number Identification"
# "ACR", "American National Standards Institute"
# "ACR", "aspect-oriented programming"
# "ACR", "Android Open Source Project"
# "ACR", "application programming interface"
# "ACR", "Advanced Programmable Interrupt Controller"
# "ACR", "Automatic Private Internet Protocol Addressing"
# "ACR", "advanced power management"
# "ACR", "advanced persistent threat"
# "ACR", "advanced processing unit"
# "ACR", "accelerated processing unit"
# "ACR", "Attached Resource Computer network"
# "ACR", "address record"
# "ACR", "Advanced Research Projects Agency"
# "ACR", "Advanced Research Projects Agency Network"
# "ACR", "automatic repeat request"
# "ACR", "American Standard Code for Information Interchange"
# "ACR", "American Society of Mechanical Engineers"
# "ACR", "abstract syntax number one"
# "ACR", "authorized service provider"
# "ACR", "application service provider"
# "ACR", "Active Server Pages"
# "ACR", "advanced SCSI programming interface"
# "ACR", "automatic speech recognition"
# "ACR", "automated system recovery "
# "ACR", "AT Attachment Packet Interface"
# "ACR", "advanced transfer cache"
# "ACR", "ascynchronous transfer mode"
# "ACR", "Attachment Unit Interface"
# "ACR", "automatic voice response"
# "ACR", "automatic voice recognition"
# "ACR", "automatic voltage regulator"
# "ACS", "Active Directory Service Interface"
# "ACS", "asymmetric digital subscriber line"
# "ACS", "automatic exposure"
# "ACS", "After Effects"
# "ACS", "Advanced Encryption Standard"
# "ACS", "Autofocus"
# "ACS", "accelerated graphics port"
# "ACS", "Advanced Host Controller Interface"
# "ACS", "Asynchronous JavaScript and XML"
# "ACS", "American National Standards Institute"
# "ACS", "Automatic Private Internet Protocol Addressing"
# "ACS", "advanced persistent threat"
# "ACS", "advanced processing unit"
# "ACS", "accelerated processing unit"
# "ACS", "Attached Resource Computer network"
# "ACS", "Advanced Research Projects Agency"
# "ACS", "Advanced Research Projects Agency Network"
# "ACS", "automatic repeat request"
# "ACS", "Application System/400"
# "ACS", "American Standard Code for Information Interchange"
# "ACS", "American Society of Mechanical Engineers"
# "ACS", "abstract syntax number one"
# "ACS", "application service provider"
# "ACS", "Active Server Pages"
# "ACS", "advanced SCSI programming interface"
# "ACS", "automatic speech recognition"
# "ACS", "advanced transfer cache"
# "ACS", "ascynchronous transfer mode"
# "ACS", "Adaptive Transform Acoustic Coding"
# "ACS", "acceptable use policy"
# "ACS", "automatic voice response"
# "ACS", "Amazon Web Services"
# "AD", "Apple Desktop Bus"
# "AD", "Android Debug Bridge"
# "AD", "analog-to-digital"
# "AD", "ActiveX Data Object"
# "AD", "adaptive delta pulse code modulation"
# "AD", "analog display service interface"
# "AD", "Active Directory Service Interface"
# "AD", "asymmetric digital subscriber line"
# "AD", "ADSTAR Distributed Storage Management"
# "AD", "Advanced Encryption Standard"
# "AD", "accelerated graphics port"
# "AD", "Advanced Host Controller Interface"
# "AD", "Apple, IBM and Motorola"
# "AD", "AGP in-line memory module"
# "AD", "advanced interactive executive"
# "AD", "Asynchronous JavaScript and XML"
# "AD", "ante meridiem"
# "AD", "amplitude modulation"
# "AD", "active-matrix organic light-emitting diode"
# "AD", "Automatic Number Identification"
# "AD", "American National Standards Institute"
# "AD", "aspect-oriented programming"
# "AD", "Android Open Source Project"
# "AD", "Advanced Programmable Interrupt Controller"
# "AD", "Automatic Private Internet Protocol Addressing"
# "AD", "Android package file"
# "AD", "advanced power management"
# "AD", "advanced persistent threat"
# "AD", "advanced packaging tool"
# "AD", "advanced processing unit"
# "AD", "accelerated processing unit"
# "AD", "augmented reality"
# "AD", "Attached Resource Computer network"
# "AD", "address record"
# "AD", "Address Resolution Protocol"
# "AD", "address and routing parameter area"
# "AD", "Advanced Research Projects Agency"
# "AD", "Advanced Research Projects Agency Network"
# "AD", "American Standard Code for Information Interchange"
# "AD", "autonomous sensory meridian response"
# "AD", "authorized service provider"
# "AD", "application service provider"
# "AD", "advanced SCSI programming interface"
# "AD", "automated system recovery "
# "AD", "advanced technology"
# "AD", "Advanced Technology Attachment"
# "AD", "advanced transfer cache"
# "AD", "above the fold"
# "AD", "automated teller machine"
# "AD", "ascynchronous transfer mode"
# "AD", "Adaptive Transform Acoustic Coding"
# "AD", "Advanced Technology eXtended"
# "AD", "Advanced Video Coding"
# "AD", "Audio Video Interleaved"
# "AD", "Adobe Flash"
# "ADB", "ActiveX Data Object"
# "ADB", "asymmetric digital subscriber line"
# "ADB", "ADSTAR Distributed Storage Management"
# "ADB", "Advanced Programmable Interrupt Controller"
# "ADB", "Adobe Flash"
# "ADB", "ActiveX Data Object"
# "ADB", "asymmetric digital subscriber line"
# "ADB", "ADSTAR Distributed Storage Management"
# "ADB", "Advanced Programmable Interrupt Controller"
# "ADB", "Adobe Flash"
# "ADC", "ActiveX Data Object"
# "ADC", "adaptive delta pulse code modulation"
# "ADC", "analog display service interface"
# "ADC", "Active Directory Service Interface"
# "ADC", "asymmetric digital subscriber line"
# "ADC", "Advanced Encryption Standard"
# "ADC", "accelerated graphics port"
# "ADC", "Advanced Host Controller Interface"
# "ADC", "advanced interactive executive"
# "ADC", "Automatic Number Identification"
# "ADC", "Android Open Source Project"
# "ADC", "Advanced Programmable Interrupt Controller"
# "ADC", "Android package file"
# "ADC", "advanced power management"
# "ADC", "advanced persistent threat"
# "ADC", "advanced packaging tool"
# "ADC", "advanced processing unit"
# "ADC", "accelerated processing unit"
# "ADC", "Attached Resource Computer network"
# "ADC", "address record"
# "ADC", "Address Resolution Protocol"
# "ADC", "Advanced Research Projects Agency"
# "ADC", "Advanced Research Projects Agency Network"
# "ADC", "American Standard Code for Information Interchange"
# "ADC", "authorized service provider"
# "ADC", "advanced SCSI programming interface"
# "ADC", "automated system recovery "
# "ADC", "advanced technology"
# "ADC", "Advanced Technology Attachment"
# "ADC", "advanced transfer cache"
# "ADC", "automated teller machine"
# "ADC", "Adaptive Transform Acoustic Coding"
# "ADC", "Advanced Technology eXtended"
# "ADC", "Advanced Video Coding"
# "ADO", "adaptive delta pulse code modulation"
# "ADO", "Active Directory Service Interface"
# "ADO", "ADSTAR Distributed Storage Management"
# "ADO", "Advanced Encryption Standard"
# "ADO", "accelerated graphics port"
# "ADO", "Advanced Host Controller Interface"
# "ADO", "Apple, IBM and Motorola"
# "ADO", "amplitude modulation"
# "ADO", "active-matrix organic light-emitting diode"
# "ADO", "Automatic Number Identification"
# "ADO", "aspect-oriented programming"
# "ADO", "Android Open Source Project"
# "ADO", "Advanced Programmable Interrupt Controller"
# "ADO", "Android package file"
# "ADO", "advanced power management"
# "ADO", "advanced packaging tool"
# "ADO", "advanced processing unit"
# "ADO", "accelerated processing unit"
# "ADO", "Attached Resource Computer network"
# "ADO", "address record"
# "ADO", "Address Resolution Protocol"
# "ADO", "address and routing parameter area"
# "ADO", "Advanced Research Projects Agency"
# "ADO", "Advanced Research Projects Agency Network"
# "ADO", "American Standard Code for Information Interchange"
# "ADO", "autonomous sensory meridian response"
# "ADO", "authorized service provider"
# "ADO", "advanced SCSI programming interface"
# "ADO", "automated system recovery "
# "ADO", "advanced technology"
# "ADO", "Advanced Technology Attachment"
# "ADO", "Adaptive Transform Acoustic Coding"
# "ADO", "Advanced Technology eXtended"
# "ADO", "Advanced Video Coding"
# "ADO", "Audio Video Interleaved"
# "ADO", "Adobe Flash"
# "ADSI", "asymmetric digital subscriber line"
# "ADSI", "ADSTAR Distributed Storage Management"
# "ADSI", "Advanced Host Controller Interface"
# "ADSI", "American National Standards Institute"
# "ADSI", "Automatic Private Internet Protocol Addressing"
# "ADSI", "advanced persistent threat"
# "ADSI", "advanced processing unit"
# "ADSI", "accelerated processing unit"
# "ADSI", "Address Resolution Protocol"
# "ADSI", "address and routing parameter area"
# "ADSI", "authorized service provider"
# "ADSI", "advanced SCSI programming interface"
# "ADSI", "Adaptive Transform Acoustic Coding"
# "ADSI", "asymmetric digital subscriber line"
# "ADSI", "ADSTAR Distributed Storage Management"
# "ADSI", "Advanced Host Controller Interface"
# "ADSI", "American National Standards Institute"
# "ADSI", "Automatic Private Internet Protocol Addressing"
# "ADSI", "advanced persistent threat"
# "ADSI", "advanced processing unit"
# "ADSI", "accelerated processing unit"
# "ADSI", "Address Resolution Protocol"
# "ADSI", "address and routing parameter area"
# "ADSI", "authorized service provider"
# "ADSI", "advanced SCSI programming interface"
# "ADSI", "Adaptive Transform Acoustic Coding"
# "ADSL", "Advanced Host Controller Interface"
# "ADSL", "Address Resolution Protocol"
# "ADSM", "Attached Resource Computer network"
# "ADSM", "address and routing parameter area"
# "ADSM", "advanced SCSI programming interface"
# "ADSM", "automated system recovery "
# "ADSM", "Adaptive Transform Acoustic Coding"
# "AE", "auto exposure lock"
# "AE", "Advanced Encryption Standard"
# "AE", "accelerated graphics port"
# "AE", "Advanced Host Controller Interface"
# "AE", "artificial intelligence"
# "AE", "Apple, IBM and Motorola"
# "AE", "AOL Instant Messenger"
# "AE", "Artificial Intelligent Markup Language"
# "AE", "AGP in-line memory module"
# "AE", "All-in-One"
# "AE", "advanced interactive executive"
# "AE", "algorithmic language"
# "AE", "alphabet"
# "AE", "arithmetic logic unit"
# "AE", "ante meridiem"
# "AE", "amplitude modulation"
# "AE", "ask me anything"
# "AE", "active-matrix organic light-emitting diode"
# "AE", "ampere"
# "AE", "Automatic Number Identification"
# "AE", "American National Standards Institute"
# "AE", "auto operator"
# "AE", "aspect-oriented programming"
# "AE", "Android Open Source Project"
# "AE", "application programming interface"
# "AE", "Advanced Programmable Interrupt Controller"
# "AE", "Automatic Private Internet Protocol Addressing"
# "AE", "Android package file"
# "AE", "advanced power management"
# "AE", "advanced persistent threat"
# "AE", "advanced packaging tool"
# "AE", "advanced processing unit"
# "AE", "accelerated processing unit"
# "AE", "augmented reality"
# "AE", "Attached Resource Computer network"
# "AE", "address record"
# "AE", "argument"
# "AE", "Address Resolution Protocol"
# "AE", "address and routing parameter area"
# "AE", "Advanced Research Projects Agency"
# "AE", "Advanced Research Projects Agency Network"
# "AE", "automatic repeat request"
# "AE", "autonomous system"
# "AE", "Application System/400"
# "AE", "as soon as possible"
# "AE", "American Standard Code for Information Interchange"
# "AE", "American Society of Mechanical Engineers"
# "AE", "autonomous sensory meridian response"
# "AE", "autonomous system number"
# "AE", "abstract syntax number one"
# "AE", "answer set programming"
# "AE", "authorized service provider"
# "AE", "application service provider"
# "AE", "Active Server Pages"
# "AE", "advanced SCSI programming interface"
# "AE", "automatic speech recognition"
# "AE", "automated system recovery "
# "AE", "advanced technology"
# "AE", "Advanced Technology Attachment"
# "AE", "AT Attachment Packet Interface"
# "AE", "advanced transfer cache"
# "AE", "above the fold"
# "AE", "automated teller machine"
# "AE", "at the moment"
# "AE", "ascynchronous transfer mode"
# "AE", "Adaptive Transform Acoustic Coding"
# "AE", "Advanced Technology eXtended"
# "AE", "arithmetic unit"
# "AE", "Attachment Unit Interface"
# "AE", "acceptable use policy"
# "AE", "automobile"
# "AE", "aperture value"
# "AE", "Advanced Video Coding"
# "AE", "Audio Video Interleaved"
# "AE", "automatic voice response"
# "AE", "automatic voice recognition"
# "AE", "automatic voltage regulator"
# "AE", "Amazon Web Services"
# "AE", "Adobe Flash"
# "AE", "are you there?"
# "AE", "auto exposure lock"
# "AE", "Advanced Encryption Standard"
# "AE", "accelerated graphics port"
# "AE", "Advanced Host Controller Interface"
# "AE", "artificial intelligence"
# "AE", "Apple, IBM and Motorola"
# "AE", "AOL Instant Messenger"
# "AE", "Artificial Intelligent Markup Language"
# "AE", "AGP in-line memory module"
# "AE", "All-in-One"
# "AE", "advanced interactive executive"
# "AE", "algorithmic language"
# "AE", "alphabet"
# "AE", "arithmetic logic unit"
# "AE", "ante meridiem"
# "AE", "amplitude modulation"
# "AE", "ask me anything"
# "AE", "active-matrix organic light-emitting diode"
# "AE", "ampere"
# "AE", "Automatic Number Identification"
# "AE", "American National Standards Institute"
# "AE", "auto operator"
# "AE", "aspect-oriented programming"
# "AE", "Android Open Source Project"
# "AE", "application programming interface"
# "AE", "Advanced Programmable Interrupt Controller"
# "AE", "Automatic Private Internet Protocol Addressing"
# "AE", "Android package file"
# "AE", "advanced power management"
# "AE", "advanced persistent threat"
# "AE", "advanced packaging tool"
# "AE", "advanced processing unit"
# "AE", "accelerated processing unit"
# ...
# "VC", "very high frequency"
# "VC", "virtual local area network"
# "VC", "Vesa Local Bus"
# "VC", "Vesa Local Bus"
# "VC", "very-large-scale integration"
# "VC", "voicemail"
# "VC", "virtual machine"
# "VC", "Versa Module Eurocard bus"
# "VC", "Virtual Machine Manager"
# "VC", "Virtual Machine Monitor"
# "VC", "voicemail system"
# "VC", "Virtual Network Computing"
# "VC", "Voice over Internet Protocol"
# "VC", "video random access memory"
# "VC", "valve-regulated lead-acid"
# "VC", "virtual storage access method"
# "VC", "Video Coding Experts Group"
# "VC", "Visual Coding Experts Group"
# "VC", "virtual circuit identifier"
# "VC", "virtual control program interface"
# "VC", "video cassette recorder"
# "VC", "voltage direct current"
# "VC", "virtual device driver, virtual disk drive"
# "VC", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "VC", "Video Electronics Standard Association"
# "VC", "Video Graphics Array"
# "VC", "Video Graphics Adapter"
# "VC", "VHSIC Hardware Description Language "
# "VC", "very high frequency"
# "VC", "virtual local area network"
# "VC", "Vesa Local Bus"
# "VC", "Vesa Local Bus"
# "VC", "very-large-scale integration"
# "VC", "voicemail"
# "VC", "virtual machine"
# "VC", "Versa Module Eurocard bus"
# "VC", "Virtual Machine Manager"
# "VC", "Virtual Machine Monitor"
# "VC", "voicemail system"
# "VC", "Virtual Network Computing"
# "VC", "Voice over Internet Protocol"
# "VC", "video random access memory"
# "VC", "valve-regulated lead-acid"
# "VC", "virtual storage access method"
# "VCEG", "VHSIC Hardware Description Language "
# "VCEG", "very-large-scale integration"
# "VCEG", "Virtual Machine Manager"
# "VCEG", "VHSIC Hardware Description Language "
# "VCEG", "very-large-scale integration"
# "VCEG", "Virtual Machine Manager"
# "VCI", "virtual control program interface"
# "VCI", "virtual device driver, virtual disk drive"
# "VCI", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "VCI", "Video Electronics Standard Association"
# "VCI", "VHSIC Hardware Description Language "
# "VCI", "very-large-scale integration"
# "VCI", "voicemail"
# "VCI", "virtual machine"
# "VCI", "Virtual Machine Manager"
# "VCI", "Virtual Machine Monitor"
# "VCI", "voicemail system"
# "VCI", "Virtual Network Computing"
# "VCI", "Voice over Internet Protocol"
# "VCI", "valve-regulated lead-acid"
# "VCPI", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "VCPI", "VHSIC Hardware Description Language "
# "VCPI", "Virtual Network Computing"
# "VCR", "voltage direct current"
# "VCR", "virtual device driver, virtual disk drive"
# "VCR", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "VCR", "Video Electronics Standard Association"
# "VCR", "Video Graphics Array"
# "VCR", "Video Graphics Adapter"
# "VCR", "VHSIC Hardware Description Language "
# "VCR", "virtual local area network"
# "VCR", "very-large-scale integration"
# "VCR", "Versa Module Eurocard bus"
# "VCR", "Virtual Machine Manager"
# "VCR", "Virtual Machine Monitor"
# "VCR", "Voice over Internet Protocol"
# "VCR", "video random access memory"
# "VDC", "virtual device driver, virtual disk drive"
# "VDC", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "VDC", "Video Electronics Standard Association"
# "VDC", "Video Graphics Array"
# "VDC", "Video Graphics Adapter"
# "VDC", "VHSIC Hardware Description Language "
# "VDC", "Versa Module Eurocard bus"
# "VDC", "video random access memory"
# "VDC", "valve-regulated lead-acid"
# "VDD", "very high data rate DSL"
# "VDD", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "VDD", "Video Electronics Standard Association"
# "VDD", "Video Graphics Adapter"
# "VDD", "VHSIC Hardware Description Language "
# "VDD", "Vendor Independent Messaging"
# "VDD", "Versa Module Eurocard bus"
# "VDD", "video on demand"
# "VDD", "video random access memory"
# "VDD", "valve-regulated lead-acid"
# "VDSL", "visual display unit"
# "VDSL", "VHSIC Hardware Description Language "
# "VDU", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "VDU", "VHSIC Hardware Description Language "
# "VDU", "Versa Module Eurocard bus"
# "VDU", "voltage regulator module"
# "VDU", "Virtual Reality Modeling Language"
# "Ver", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# "Ver", "Video Electronics Standard Association"
# "Ver", "Video Graphics Array"
# "Ver", "Video Graphics Adapter"
# "Ver", "VHSIC Hardware Description Language "
# "Ver", "very high frequency"
# "Ver", "Vendor Independent Messaging"
# "Ver", "very important person"
# "Ver", "virtual local area network"
# "Ver", "very-large-scale integration"
# "Ver", "virtual memory"
# "Ver", "Versa Module Eurocard bus"
# "Ver", "Virtual Machine Manager"
# "Ver", "Virtual Machine Monitor"
# "Ver", "virtual memory system"
# "Ver", "Virtual Network Computing"
# "Ver", "Voice over Internet Protocol"
# "Ver", "virtual private network"
# "Ver", "virtual private server"
# "Ver", "video random access memory"
# "Ver", "valve-regulated lead-acid"
# "Ver", "voltage regulator module"
# "Ver", "versus"
# "Ver", "Virtual YouTuber"
# "Veronica", "Video Electronics Standard Association"
# "VESA", "Video Graphics Array"
# "VESA", "Video Graphics Adapter"
# "VESA", "VHSIC Hardware Description Language "
# "VESA", "Vendor Independent Messaging"
# "VESA", "Vesa Local Bus"
# "VESA", "Vesa Local Bus"
# "VESA", "very-large-scale integration"
# "VESA", "Versa Module Eurocard bus"
# "VGA", "VHSIC Hardware Description Language "
# "VGA", "very-large-scale integration"
# "VGA", "valve-regulated lead-acid"
# "VGA", "voltage regulator module"
# "VGA", "Virtual Reality Modeling Language"
# "VGA", "virtual storage access method"
# "VGA", "VHSIC Hardware Description Language "
# "VGA", "very-large-scale integration"
# "VGA", "valve-regulated lead-acid"
# "VGA", "voltage regulator module"
# "VGA", "Virtual Reality Modeling Language"
# "VGA", "virtual storage access method"
# "Vhost", "Video Home System"
# "VIM", "very important person"
# "VIM", "voicemail"
# "VIM", "virtual memory"
# "VIM", "virtual machine"
# "VIM", "Virtual Machine Manager"
# "VIM", "Virtual Machine Monitor"
# "VIM", "virtual memory system"
# "VIM", "voicemail system"
# "VIM", "Virtual Network Computing"
# "VIM", "video on demand"
# "VIM", "video random access memory"
# "VIM", "Virtual Reality Modeling Language"
# "VIM", "virtual storage access method"
# "VIP", "Virtual Network Computing"
# "VIP", "Voice over Internet Protocol"
# "VIP", "virtual private network"
# "VIP", "virtual private server"
# "VLAN", "VideoLAN"
# "VLAN", "very-large-scale integration"
# "VLAN", "virtual machine"
# "VLAN", "Virtual Machine Manager"
# "VLAN", "Virtual Machine Monitor"
# "VLAN", "virtual private network"
# "VLAN", "Virtual Reality Modeling Language"
# "VLB", "Vesa Local Bus"
# "VLB", "Versa Module Eurocard bus"
# "VLB", "Virtual YouTuber"
# "VL Bus", "Versa Module Eurocard bus"
# "VLC", "very-large-scale integration"
# "VLC", "virtual machine"
# "VLC", "Versa Module Eurocard bus"
# "VLC", "Virtual Machine Manager"
# "VLC", "Virtual Machine Monitor"
# "VLC", "Virtual Network Computing"
# "VLC", "valve-regulated lead-acid"
# "VLC", "virtual storage access method"
# "VLSI", "Visual Studio"
# "VM", "Versa Module Eurocard bus"
# "VM", "Virtual Machine Manager"
# "VM", "Virtual Machine Monitor"
# "VM", "virtual memory system"
# "VM", "voicemail system"
# "VM", "Virtual Network Computing"
# "VM", "video on demand"
# "VM", "video random access memory"
# "VM", "voltage regulator module"
# "VM", "Virtual Reality Modeling Language"
# "VM", "virtual storage access method"
# "VM", "Versa Module Eurocard bus"
# "VM", "Virtual Machine Manager"
# "VM", "Virtual Machine Monitor"
# "VM", "virtual memory system"
# "VM", "voicemail system"
# "VM", "Virtual Network Computing"
# "VM", "video on demand"
# "VM", "video random access memory"
# "VM", "voltage regulator module"
# "VM", "Virtual Reality Modeling Language"
# "VM", "virtual storage access method"
# "VM", "Versa Module Eurocard bus"
# "VM", "Virtual Machine Manager"
# "VM", "Virtual Machine Monitor"
# "VM", "virtual memory system"
# "VM", "voicemail system"
# "VM", "Virtual Network Computing"
# "VM", "video on demand"
# "VM", "video random access memory"
# "VM", "voltage regulator module"
# "VM", "Virtual Reality Modeling Language"
# "VM", "virtual storage access method"
# "VMM", "virtual memory system"
# "VMM", "voicemail system"
# "VMM", "video random access memory"
# "VMM", "virtual memory system"
# "VMM", "voicemail system"
# "VMM", "video random access memory"
# "VMS", "video random access memory"
# "VMS", "video random access memory"
# "VNC", "Voice over Internet Protocol"
# "VNC", "video random access memory"
# "VOD", "video random access memory"
# "VOD", "voltage regulator module"
# "VOD", "Virtual Reality Modeling Language"
# "VOD", "virtual storage access method"
# "VoMM", "video random access memory"
# "VR", "video random access memory"
# "VR", "valve-regulated lead-acid"
# "VR", "voltage regulator module"
# "VR", "Virtual Reality Modeling Language"
# "VR", "versus"
# "VR", "virtual storage access method"
# "VR", "Virtual YouTuber"
# "VRAM", "voltage regulator module"
# "VRAM", "Virtual Reality Modeling Language"
# "VRAM", "virtual storage access method"
# "VRLA", "voltage regulator module"
# "VRLA", "Virtual Reality Modeling Language"
# "VRLA", "virtual storage access method"
# "VRM", "Virtual Reality Modeling Language"
# "VRM", "virtual storage access method"
# "Vs", "virtual storage access method"
# "Vs", "virtual storage access method"
# "W", "World Wide Web Consortium"
# "W", "Wide Area Information Server"
# "W", "wide area network"
# "W", "wireless access point"
# "W", "Warning, Advice and Reporting Point"
# "W", "Web-based Enterprise Management"
# "W", "Wideband Code Division Multiple Access"
# "W", "Windows Connect Now"
# "W", "working draft"
# "W", "working directory"
# "W", "Western Digital"
# "W", "Window Driver Foundation"
# "W", "web application"
# "W", "Wired Equivalent Privacy"
# "W", "Wired for Management"
# "W", "Windows File Protection"
# "W", "Windows Genuine Advantage"
# "W", "Worldwide Interoperability for Microwave Access"
# "W", "Windows Pre-install Environment"
# "W", "Windows socket"
# "W", "wireless Internet service provider"
# "W", "Windows metafile format"
# "W", "Windows Management Instrumentation"
# "W", "Website META Language"
# "W", "Wireless Markup Language"
# "W", "Wake-on-LAN"
# "W", "word of the day"
# "W", "World of Warcraft"
# "W", "Windows on Windows"
# "W", "WordPress"
# "W", "word processor"
# "W", "write pre-comp"
# "W", "word processing competency"
# "W", "Wide Quad Extended Graphics Array"
# "W", "Windows RAM"
# "W", "Widescreen Super eXtended Graphics Array"
# "W", "what the hell"
# "W", "World Wide Web"
# "W", "what you see is what you get"
# "W", "what you see is what you print"
# "WAIS", "Web-based Enterprise Management"
# "WAIS", "Wideband Code Division Multiple Access"
# "WAIS", "Worldwide Interoperability for Microwave Access"
# "WAIS", "Windows Management Instrumentation"
# "WAIS", "Wide Quad Extended Graphics Array"
# "WAIS", "Widescreen Super eXtended Graphics Array"
# "WAIS", "what you see is what you get"
# "WAIS", "what you see is what you print"
# "WAN", "wireless access point"
# "WAN", "Warning, Advice and Reporting Point"
# "WAN", "Web-based Enterprise Management"
# "WAN", "Wideband Code Division Multiple Access"
# "WAN", "Window Driver Foundation"
# "WAN", "web application"
# "WAN", "Wired Equivalent Privacy"
# "WAN", "Wired for Management"
# "WAN", "Windows Genuine Advantage"
# "WAN", "Windows Pre-install Environment"
# "WAN", "Windows Management Instrumentation"
# "WAN", "Website META Language"
# "WAN", "Wireless Markup Language"
# "WAN", "Wake-on-LAN"
# "WAN", "Wide Quad Extended Graphics Array"
# "WAN", "what you see is what you print"
# "WAP", "Warning, Advice and Reporting Point"
# "WAP", "Web-based Enterprise Management"
# "WAP", "Wideband Code Division Multiple Access"
# "WAP", "web application"
# "WAP", "Wired Equivalent Privacy"
# "WAP", "Wireless Markup Language"
# "WAP", "Wide Quad Extended Graphics Array"
# "WAP", "Widescreen Super eXtended Graphics Array"
# "WAP", "what you see is what you print"
# "WARP", "Web-based Enterprise Management"
# "WARP", "Wireless Markup Language"
# "WARP", "Wide Quad Extended Graphics Array"
# "WBEM", "Wideband Code Division Multiple Access"
# "WBEM", "Website META Language"
# "WCN", "web application"
# "WCN", "Windows File Protection"
# "WCN", "word processing competency"
# "WCN", "Widescreen Super eXtended Graphics Array"
# "WD", "Window Driver Foundation"
# "WD", "Wired Equivalent Privacy"
# "WD", "Wired for Management"
# "WD", "Windows File Protection"
# "WD", "Windows Genuine Advantage"
# "WD", "Worldwide Interoperability for Microwave Access"
# "WD", "Windows Pre-install Environment"
# "WD", "Windows socket"
# "WD", "wireless Internet service provider"
# "WD", "Windows metafile format"
# "WD", "Windows Management Instrumentation"
# "WD", "word of the day"
# "WD", "World of Warcraft"
# "WD", "Windows on Windows"
# "WD", "WordPress"
# "WD", "word processor"
# "WD", "word processing competency"
# "WD", "Wide Quad Extended Graphics Array"
# "WD", "Windows RAM"
# "WD", "Widescreen Super eXtended Graphics Array"
# "WD", "World Wide Web"
# "WD", "Window Driver Foundation"
# "WD", "Wired Equivalent Privacy"
# "WD", "Wired for Management"
# "WD", "Windows File Protection"
# "WD", "Windows Genuine Advantage"
# "WD", "Worldwide Interoperability for Microwave Access"
# "WD", "Windows Pre-install Environment"
# "WD", "Windows socket"
# "WD", "wireless Internet service provider"
# "WD", "Windows metafile format"
# "WD", "Windows Management Instrumentation"
# "WD", "word of the day"
# "WD", "World of Warcraft"
# "WD", "Windows on Windows"
# "WD", "WordPress"
# "WD", "word processor"
# "WD", "word processing competency"
# "WD", "Wide Quad Extended Graphics Array"
# "WD", "Windows RAM"
# "WD", "Widescreen Super eXtended Graphics Array"
# "WD", "World Wide Web"
# "WD", "Window Driver Foundation"
# "WD", "Wired Equivalent Privacy"
# "WD", "Wired for Management"
# "WD", "Windows File Protection"
# "WD", "Windows Genuine Advantage"
# "WD", "Worldwide Interoperability for Microwave Access"
# "WD", "Windows Pre-install Environment"
# "WD", "Windows socket"
# "WD", "wireless Internet service provider"
# "WD", "Windows metafile format"
# "WD", "Windows Management Instrumentation"
# "WD", "word of the day"
# "WD", "World of Warcraft"
# "WD", "Windows on Windows"
# "WD", "WordPress"
# "WD", "word processor"
# "WD", "word processing competency"
# "WD", "Wide Quad Extended Graphics Array"
# "WD", "Windows RAM"
# "WD", "Widescreen Super eXtended Graphics Array"
# "WD", "World Wide Web"
# "WDF", "Wired for Management"
# "WDF", "Windows File Protection"
# "WDF", "Worldwide Interoperability for Microwave Access"
# "WDF", "Windows metafile format"
# "WDF", "word of the day"
# "WDF", "World of Warcraft"
# "WEP", "Windows File Protection"
# "WEP", "Worldwide Interoperability for Microwave Access"
# "WEP", "wireless Internet service provider"
# "WEP", "Wireless Markup Language"
# "WEP", "write pre-comp"
# "WEP", "word processing competency"
# "WEP", "Wide Quad Extended Graphics Array"
# "WEP", "Widescreen Super eXtended Graphics Array"
# "WEP", "what you see is what you print"
# "WFM", "Worldwide Interoperability for Microwave Access"
# "WFM", "Windows metafile format"
# "WGA", "Windows Management Instrumentation"
# "WGA", "Website META Language"
# "WGA", "Wireless Markup Language"
# "WGA", "Wide Quad Extended Graphics Array"
# "WGA", "Widescreen Super eXtended Graphics Array"
# "WISP", "Wireless Markup Language"
# "WISP", "Widescreen Super eXtended Graphics Array"
# "WISP", "what you see is what you print"
# "WOL", "World of Warcraft"
# "WOL", "World Wide Web"
# "WOW", "Windows RAM"
# "WOW", "World Wide Web"
# "WOW", "what you see is what you get"
# "WOW", "what you see is what you print"
# "WOW", "Windows RAM"
# "WOW", "World Wide Web"
# "WOW", "what you see is what you get"
# "WOW", "what you see is what you print"
# "WP", "write pre-comp"
# "WP", "word processing competency"
# "WP", "Wide Quad Extended Graphics Array"
# "WP", "Widescreen Super eXtended Graphics Array"
# "WP", "what you see is what you print"
# "WP", "write pre-comp"
# "WP", "word processing competency"
# "WP", "Wide Quad Extended Graphics Array"
# "WP", "Widescreen Super eXtended Graphics Array"
# "WP", "what you see is what you print"
# "WTH", "what you see is what you get"
# "WTH", "what you see is what you print"
# "WWW", "what you see is what you get"
# "WWW", "what you see is what you print"
# "X", "X Window System"
# "X", "XP mode"
# 23744 FALSE POSITIVE detections out of 1695149 created false examples

# %%
b = calc_fn(base_algo)
print(b)
# Out:
# "ADC", "analog-to-digital"
# ##################################
# "ASN.1", "abstract syntax number one"
# ##################################
# "B2B", "business-to-business"
# ##################################
# "B2B", "business-to-consumer"
# ##################################
# "BDF", "Glyph Bitmap Distribution Format"
# ##################################
# "Bi-di", "bidirectional"
# ##################################
# "CDA", "compact audio disc"
# ##################################
# "CD-i", "Compact Disc Interactive"
# ##################################
# "CD-R", "Compact Disc Recordable"
# ##################################
# "CD-ROM", "Compact Disc Read-Only Memory"
# ##################################
# "CD-RW", "Compact Disc Re-Writable"
# ##################################
# "CD-WO", "Compact Disc Write Once"
# ##################################
# "CLCC", "ceramic leadless lead carrier"
# ##################################
# "Code", "source code"
# ##################################
# "Coil", "electromagnetic coil"
# ##################################
# "CPM", "cost per thousand"
# ##################################
# "CPTM", "cost per targeted thousand"
# ##################################
# "C-RIMM", "continuity RIMM"
# ##################################
# "D2D", "disk-to-disk"
# ##################################
# "DART", "Microsoft Diagnostics and Recovery Toolset"
# ##################################
# "DDR2", "double data rate two"
# ##################################
# "DDR3", "double data rate three"
# ##################################
# "DDR4", "double data rate four"
# ##################################
# "DFMC", "direct methanol fuel cell"
# ##################################
# "D/L", "download"
# ##################################
# "Drop", "malware dropper"
# ##################################
# "DTX", "discontinuous transmission"
# ##################################
# "E-911", "Enhanced 911"
# ##################################
# "EAP-FAST", "Flexible Authentication via Secure Tunneling"
# ##################################
# "E-book", "electronic book"
# ##################################
# "E-learning", "electronic learning"
# ##################################
# "E-mail", "electronic mail"
# ##################################
# "ETA-I", "Electronic Technicians Association International"
# ##################################
# "FC-PGA", "flip-chip pin grid array"
# ##################################
# "Flash", "Adobe Flash"
# ##################################
# "G+", "Google Plus"
# ##################################
# "G2G", "government to government"
# ##################################
# "GIGO", "&quot;garbage in, garbage out&quot;"
# ##################################
# "Gram", "Instagram"
# ##################################
# "HD-ROM", "high-density read-only memory"
# ##################################
# "Hi-res", "high resolution"
# ##################################
# "HP-UX", "Hewlett Packard UniX"
# ##################################
# "IA-32", "Intel Architecture 32"
# ##################################
# "IA-64", "Intel Architecture 64"
# ##################################
# "kb / kbit", "kilobit"
# ##################################
# "kilo", "one thousand"
# ##################################
# "L2P", "learn to play"
# ##################################
# "LED monitor", "light-emitting diode"
# ##################################
# "Lo-res / low-res", "low-resolution"
# ##################################
# "M-", "meta key"
# ##################################
# "MBAM", "Malwarebytes"
# ##################################
# "Model no.", "model number"
# ##################################
# "MS-DOS", "Microsoft Disk Operating System"
# ##################################
# "MSN", "The Microsoft Network"
# ##################################
# "NLS", "online system"
# ##################################
# "NO-OP", "no operatation"
# ##################################
# "P2W", "pay-to-win"
# ##################################
# "PC-DOS", "Personal Computer Disk operating system"
# ##################################
# "PCI-X", "Peripheral Component Interconnect Extended"
# ##################################
# "P-code", "pseudocode"
# ##################################
# "P-code", "packed code"
# ##################################
# "PHP", "Hypertext Preprocessor"
# ##################################
# "PII", "Pentium 2"
# ##################################
# "Plus", "Microsoft Plus!"
# ##################################
# "P-machine", "pseudomachine"
# ##################################
# "PRISM", "Synchronization"
# ##################################
# "PRISM", "Planning Tool for Resource Integration,  and Management"
# ##################################
# "PTY", "pseudoterminal"
# ##################################
# "Q&A", "questions and answers"
# ##################################
# "Rec.", "receive"
# ##################################
# "RUT", "are you there?"
# ##################################
# "RXD", "received data"
# ##################################
# "S2R", "send to receive"
# ##################################
# "Serial no.", "serial number"
# ##################################
# "Servlet", "Java servlet"
# ##################################
# "Sexp or sexpr", "s-expression"
# ##################################
# "SFX", "sound effects"
# ##################################
# "SFX", "special effects"
# ##################################
# "Slotket", "socket adapter"
# ##################################
# "SO-DIMM", "small outline dual in-line memory module"
# ##################################
# "S/PDIF", "Sony and Phillips Digital Interconnect Format"
# ##################################
# "S-Video", "Super Video"
# ##################################
# "SXGA+", "Super XGA Plus"
# ##################################
# "T&amp;L", "transform, clipping, and lighting"
# ##################################
# "TP-PMD", "Twisted-Pair Physical Medium Dependant"
# ##################################
# "Transistor", "transfer resistance"
# ##################################
# "TXD", "trasmit data"
# ##################################
# "Uarch", "microarchitecture"
# ##################################
# "U/L", "upload"
# ##################################
# "UTC", "Coordinated Universal Time"
# ##################################
# "VBScript", "Microsoft Visual Basic Scripting Edition"
# ##################################
# "VLC", "VideoLAN"
# ##################################
# "VoMM", "eVade o' Matic Module"
# ##################################
# "W3C", "World Wide Web Consortium"
# ##################################
# "WiMAX", "Worldwide Interoperability for Microwave Access"
# ##################################
# "X11", "X Window System"
# ##################################
# "XDF", "extended density format"
# ##################################
# "XGA", "Extended Graphics Array"
# ##################################
# "XHTML", "Extensible Hypertext markup Language"
# ##################################
# "XML", "Extensible Markup Language"
# ##################################
# "XMPP", "Extensible Messaging and Presence Protocol"
# ##################################
# "XMS", "extended memory specification"
# ##################################
# "XSL", "Extensible Stylesheet Language"
# ##################################
# "XSLT", "Extensible Stylesheet Language Transformations"
# ##################################
# "XSS", "cross-site scripting"
# ##################################
# "XT", "extended technology"
# ##################################
# 106 FALSE NEGATIVES. Pairs that could not be detected out of 1842 given pairs

# %%
a = calc_fp(check_wether_abbv_is_proper_short_form_of_term)
print(a)
# Out:
# "AA", "account"
# "AA", "acknowledgment"
# "AA", "analog-to-digital"
# "AA", "Autofocus"
# "AA", "All-in-One"
# "AA", "alphabet"
# "AA", "ampere"
# "AA", "application"
# "AA", "argument"
# "AA", "automobile"
# "AA", "autonomous"
# "AA", "automatic"
# "AA", "avatar"
# "AA", "antivirus"
# "AAC", "Atanasoff-Berry Computer"
# "AAC", "anonymous coward"
# "AAC", "Asheron's Call"
# "AAC", "alternating current"
# "AAC", "account"
# "AAC", "acknowledgment"
# "AAC", "Autofocus"
# "AAC", "application"
# "AAC", "automatic"
# "AAM", "acknowledgment"
# "AAM", "ante meridiem"
# "AAM", "amplitude modulation"
# "AAM", "ampere"
# "AAM", "aspect-oriented programming"
# "AAM", "argument"
# "AAM", "automobile"
# "AAM", "autonomous"
# "AAM", "automatic"
# "AAS", "Autofocus"
# "AAS", "autonomous system"
# "AAS", "Application System/400"
# "AAS", "autonomous"
# "AAS", "antivirus"
# "AAS", "Adobe Flash"
# "AAS", "Autofocus"
# "AAS", "autonomous system"
# "AAS", "Application System/400"
# "AAS", "autonomous"
# "AAS", "antivirus"
# "AAS", "Adobe Flash"
# "AC", "account"
# "AC", "acknowledgment"
# "AC", "Autofocus"
# "AC", "application"
# "AC", "automatic"
# "AC", "account"
# "AC", "acknowledgment"
# "AC", "Autofocus"
# "AC", "application"
# "AC", "automatic"
# "AC", "account"
# "AC", "acknowledgment"
# "AC", "Autofocus"
# "AC", "application"
# "AC", "automatic"
# "ACCT", "Active Directory"
# "ACE", "acknowledgment"
# "ACE", "automatic exposure"
# "ACE", "artificial intelligence"
# "ACL", "algorithmic language"
# "ACL", "advanced technology"
# "ACPI", "aspect-oriented programming"
# "ACPI", "application programming interface"
# "ACR", "Active Directory"
# "ACR", "address record"
# "ACR", "Active Directory"
# "ACR", "address record"
# "ACR", "Active Directory"
# "ACR", "address record"
# "ACR", "Active Directory"
# "ACR", "address record"
# "ACS", "After Effects"
# "ACS", "Autofocus"
# "ACS", "Application System/400"
# "AD", "analog-to-digital"
# "ADO", "amplitude modulation"
# "AE", "All-in-One"
# "AE", "alphabet"
# "AE", "ampere"
# "AE", "argument"
# "AE", "automobile"
# "AE", "All-in-One"
# "AE", "alphabet"
# "AE", "ampere"
# "AE", "argument"
# "AE", "automobile"
# "AF", "Adobe Flash"
# "AI", "All-in-One"
# "AI", "application"
# "AI", "automobile"
# "AI", "automatic"
# "AI", "antivirus"
# "AIM", "ante meridiem"
# "AIM", "amplitude modulation"
# "AIM", "ante meridiem"
# "AIM", "amplitude modulation"
# "AIML", "algorithmic language"
# "AIML", "amplitude modulation"
# "AIMM", "aspect-oriented programming"
# "AIO", "amplitude modulation"
# "AIO", "application"
# "ALU", "aperture value"
# "AM", "ampere"
# "AM", "argument"
# "AM", "automobile"
# "AM", "autonomous"
# "AM", "automatic"
# "AM", "ampere"
# "AM", "argument"
# "AM", "automobile"
# "AM", "autonomous"
# "AM", "automatic"
# "AMA", "automatic"
# "ANI", "arithmetic unit"
# "ANI", "antivirus"
# "AOSP", "authorized service provider"
# "AOSP", "application service provider"
# "API", "application"
# "APIC", "application"
# "AR", "address record"
# "AR", "argument"
# "AR", "avatar"
# "AR", "antivirus"
# "AS", "Application System/400"
# "AS", "autonomous"
# "AS", "antivirus"
# "ASCII", "automatic speech recognition"
# "ASME", "autonomous system number"
# "ASMR", "autonomous system number"
# "ASMR", "automated system recovery "
# "AT", "automobile"
# "AT", "autonomous"
# "AT", "automatic"
# "AT", "avatar"
# "AT", "antivirus"
# "ATA", "automatic"
# "ATA", "avatar"
# "ATC", "automatic"
# "ATM", "automobile"
# "ATM", "autonomous"
# "ATM", "automatic"
# "ATM", "automobile"
# "ATM", "autonomous"
# "ATM", "automatic"
# "ATM", "automobile"
# "ATM", "autonomous"
# "ATM", "automatic"
# "AU", "automobile"
# "AU", "autonomous"
# "AU", "automatic"
# "AU", "antivirus"
# "AUI", "automobile"
# "AUI", "automatic"
# "BAE", "Battlefield"
# "BAE", "battleground"
# "BAE", "bad game"
# "BAE", "beginning of message"
# "BAE", "bill of materials"
# "BAE", "broadband-over-powerline"
# "Basic", "BinarySynchronous Communications"
# "BAT", "bidirectional isolation"
# "BAT", "Battlefield"
# "BAT", "battleground"
# "BAT", "BinarySynchronous Communications"
# "BAT", "bill of materials"
# "BB", "Battlefield"
# "BB", "battleground"
# "BB", "background"
# "BB", "bidirectional"
# "BB", "biography"
# "BB", "Boolean"
# "BB", "broadband-over-powerline"
# "BB", "back-side bus"
# "BB", "bitcoin"
# "BBS", "back-side bus"
# "BBS", "back-side bus"
# "BBS", "back-side bus"
# "BC", "background"
# "BC", "bidirectional"
# "BC", "BinarySynchronous Communications"
# "BC", "bitcoin"
# "BCC", "BinarySynchronous Communications"
# "BCC", "Bayonet Neill-Concelman"
# "BCD", "background"
# "BD", "Battlefield"
# "BD", "battleground"
# "BD", "background"
# "BD", "bidirectional"
# "BD", "binary digit"
# "BD", "broadband-over-powerline"
# "BDC", "bidirectional"
# "BDI", "bidirectional"
# "BDI", "binary digit"
# "BDI", "beginning of medium"
# "BDI", "broadband-over-powerline"
# "BDO", "bidirectional"
# "BDO", "broadband-over-powerline"
# "BER", "battleground"
# "BER", "bill of materials"
# "BER", "broadband-over-powerline"
# "BER", "bridge router"
# "BER", "battleground"
# "BER", "bill of materials"
# "BER", "broadband-over-powerline"
# "BER", "bridge router"
# "BERT", "bridge router"
# "BERT", "bridge router"
# "BG", "biography"
# "BG", "biography"
# "BG", "biography"
# "BG", "biography"
# "BGA", "biography"
# "BGP", "biography"
# "Bi-di", "binary digit"
# "Bi-di", "bold, italic, underline"
# "Bi-di", "beginning of medium"
# "BIND", "binary digit"
# "BIND", "bold, italic, underline"
# "BIO", "BinarySynchronous Communications"
# "BIO", "Bayonet Neill-Concelman"
# "BIO", "bitcoin"
# "BIOS", "BinarySynchronous Communications"
# "BISYNC", "Binary Synchronous Communications"
# "Bit", "bitcoin"
# "BIU", "beginning of medium"
# "BO", "Boolean"
# "BO", "broadband-over-powerline"
# "BO", "bitcoin"
# "Bool", "broadband-over-powerline"
# "bps", "bytes per second"
# "Br", "bridge router"
# "C", "CapsLock"
# "C", "CapsLock"
# "C", "counterclockwise"
# "C", "certified"
# "C", "certification"
# "C", "certified"
# "C", "certificate"
# "C", "CompactFlash"
# "C", "character"
# "C", "cylinder-head-sector"
# "C", "comp.os.linux.announce"
# "C", "conference"
# "C", "confidence"
# "C", "console"
# "C", "cryptography"
# "C", "counter-strike"
# "CA", "CapsLock"
# "CA", "CapsLock"
# "CA", "certification"
# "CA", "certificate"
# "CA", "CompactFlash"
# "CA", "character"
# "CA", "cylinder-head-sector"
# "CA", "Certificate of Authenticity"
# "CA", "comp.os.linux.announce"
# "CA", "cryptography"
# "Cab", "Current Mailbox"
# "CAD", "charge-coupled device"
# "CAD", "compact disc"
# "CAD", "change directory"
# "CAD", "compact audio disc"
# "CAD", "change directory"
# "CAD", "cylinder-head-sector"
# "CAP", "CapsLock"
# "CAP", "CapsLock"
# "CAP", "Challenge-Handshake Authentication Protocol"
# "CAP", "cryptography"
# "CAPS", "CapsLock"
# "CAPS", "characters per second"
# "CAS", "call-control signaling "
# "CAS", "CompactFlash"
# "CAS", "cylinder-head-sector"
# "CAS", "cable select"
# "CAS", "comma-separated values"
# "CAS", "call-control signaling "
# "CAS", "CompactFlash"
# "CAS", "cylinder-head-sector"
# "CAS", "cable select"
# "CAS", "comma-separated values"
# "CASC", "compact disc"
# "CASC", "compact audio disc"
# "CASC", "cylinder-head-sector"
# "CASC", "cable select"
# "CAT", "Community Access Television"
# "CAT", "Cable TV "
# "CAT", "computer-based training"
# "CAT", "cellular telephone"
# "CAT", "certification"
# "CAT", "certificate"
# "CAT", "CompactFlash"
# "CAT", "character"
# "CAT", "cylinder-head-sector"
# "CAT", "computer-mediated communication"
# "CAT", "Certificate of Authenticity"
# "CAT", "click-through rate"
# "CAT", "change teletype"
# "CATV", "comma-separated values"
# "CATV", "comma-separated values"
# "CC", "counterclockwise"
# "CC", "certified"
# "CC", "certification"
# "CC", "certified"
# "CC", "certificate"
# "CC", "CompactFlash"
# "CC", "character"
# "CC", "cylinder-head-sector"
# "CC", "computer-mediated communication"
# "CC", "comp.os.linux.announce"
# "CC", "conference"
# "CC", "confidence"
# "CC", "console"
# "CC", "cryptography"
# "CC", "counter-strike"
# "CC", "counterclockwise"
# "CC", "certified"
# "CC", "certification"
# "CC", "certified"
# "CC", "certificate"
# "CC", "CompactFlash"
# "CC", "character"
# "CC", "cylinder-head-sector"
# "CC", "computer-mediated communication"
# "CC", "comp.os.linux.announce"
# "CC", "conference"
# "CC", "confidence"
# "CC", "console"
# "CC", "cryptography"
# "CC", "counter-strike"
# "CC", "counterclockwise"
# "CC", "certified"
# "CC", "certification"
# "CC", "certified"
# "CC", "certificate"
# "CC", "CompactFlash"
# "CC", "character"
# "CC", "cylinder-head-sector"
# "CC", "computer-mediated communication"
# "CC", "comp.os.linux.announce"
# "CC", "conference"
# "CC", "confidence"
# "CC", "console"
# "CC", "cryptography"
# "CC", "counter-strike"
# "CC", "counterclockwise"
# "CC", "certified"
# "CC", "certification"
# "CC", "certified"
# "CC", "certificate"
# "CC", "CompactFlash"
# "CC", "character"
# "CC", "cylinder-head-sector"
# "CC", "computer-mediated communication"
# "CC", "comp.os.linux.announce"
# "CC", "conference"
# "CC", "confidence"
# "CC", "console"
# "CC", "cryptography"
# "CC", "counter-strike"
# "CCC", "counterclockwise"
# "CCC", "certification"
# "CCC", "certificate"
# "CCC", "CompactFlash"
# "CCC", "character"
# "CCC", "cylinder-head-sector"
# "CCC", "computer-mediated communication"
# "CCC", "comp.os.linux.announce"
# "CCC", "conference"
# "CCC", "confidence"
# "CCC", "computer science"
# "CCD", "compact disc"
# "CCD", "change directory"
# "CCD", "Consumer DSL"
# "CCD", "certified"
# "CCD", "certified"
# "CCD", "change directory"
# "CCD", "cylinder-head-sector"
# "CCD", "Compression / Decompression"
# "CCD", "COmpression / DECompression"
# "CCD", "confidence"
# "CCD", "core dump"
# "CCDE", "change directory"
# "CCDE", "change directory"
# "CCDE", "cylinder-head-sector"
# "CCDE", "Compression / Decompression"
# "CCDE", "COmpression / DECompression"
# "CCDE", "Computer Dealers' Exhibition"
# "CCDE", "confidence"
# "CCFL", "CompactFlash"
# "CCIE", "counterclockwise"
# "CCIE", "change directory"
# "CCIE", "certified"
# "CCIE", "certified"
# "CCIE", "certificate"
# "CCIE", "computer-generated imagery"
# "CCIE", "change directory"
# "CCIE", "cylinder-head-sector"
# "CCIE", "command-line interface"
# "CCIE", "central office"
# "CCIE", "close of business"
# "CCIE", "comp.os.linux.announce"
# "CCIE", "confidence"
# "CCIE", "customer service"
# "CCIE", "computer science"
# "CCIE", "counter-strike"
# "CCITT", "closed circuit television"
# "CCITT", "Certificate of Authenticity"
# "CCNA", "call-control signaling "
# "CCNA", "Communication Decency Act"
# "CCNA", "cylinder-head-sector"
# "CCNA", "command-line interface"
# "CCNA", "computer-mediated communication"
# "CCNA", "comp.os.linux.announce"
# "CCNP", "Challenge-Handshake Authentication Protocol"
# "CCNP", "client-to-client protocol"
# "CCS", "counterclockwise"
# "CCS", "CompactFlash"
# "CCS", "cylinder-head-sector"
# "CCS", "Compression / Decompression"
# "CCS", "COmpression / DECompression"
# "CCS", "comp.os.linux.announce"
# "CCS", "console"
# "CCS", "customer service"
# "CCS", "computer science"
# "CCS", "counter-strike"
# "CCS", "cable select"
# "CCS", "code segment"
# "CCS", "cross-site scripting"
# "CCS", "counterclockwise"
# "CCS", "CompactFlash"
# "CCS", "cylinder-head-sector"
# "CCS", "Compression / Decompression"
# "CCS", "COmpression / DECompression"
# "CCS", "comp.os.linux.announce"
# "CCS", "console"
# "CCS", "customer service"
# "CCS", "computer science"
# "CCS", "counter-strike"
# "CCS", "cable select"
# "CCS", "code segment"
# "CCS", "cross-site scripting"
# "CCTV", "comma-separated values"
# "CD", "Consumer DSL"
# "CD", "certified"
# "CD", "certified"
# "CD", "change directory"
# "CD", "cylinder-head-sector"
# "CD", "Compression / Decompression"
# "CD", "COmpression / DECompression"
# "CD", "confidence"
# "CD", "core dump"
# "CD", "Consumer DSL"
# "CD", "certified"
# "CD", "certified"
# "CD", "change directory"
# "CD", "cylinder-head-sector"
# "CD", "Compression / Decompression"
# "CD", "COmpression / DECompression"
# "CD", "confidence"
# "CD", "core dump"
# "CDA", "cylinder-head-sector"
# "CDA", "cylinder-head-sector"
# "CDDA", "compact disc database"
# "CDDA", "Compact Disc Recordable"
# "CDDA", "CD-ROM extended architecture"
# "CDDB", "Compact Disc Recordable"
# "CDE", "change directory"
# "CDE", "cylinder-head-sector"
# "CDE", "Compression / Decompression"
# "CDE", "COmpression / DECompression"
# "CDE", "Computer Dealers' Exhibition"
# "CDE", "confidence"
# "CDfs", "CD-R file system"
# "CD-i", "consumer edition"
# "CD-i", "compact edition"
# "CD-i", "collector's edition"
# "CD-i", "computer-generated imagery"
# "CD-i", "change directory"
# "CD-i", "command-line interface"
# "CD-i", "Compression / Decompression"
# "CD-i", "COmpression / DECompression"
# "CDMA", "computer-generated imagery"
# "CDMA", "computer-mediated communication"
# "CDN", "consumer edition"
# "CDN", "compact edition"
# "CDN", "collector's edition"
# "CDN", "Compression / Decompression"
# "CDN", "COmpression / DECompression"
# "CDN", "confidence"
# "CDN", "consumer edition"
# "CDN", "compact edition"
# "CDN", "collector's edition"
# "CDN", "Compression / Decompression"
# "CDN", "COmpression / DECompression"
# "CDN", "confidence"
# "CDP", "Compression / Decompression"
# "CDP", "COmpression / DECompression"
# "CDP", "core dump"
# "CDP", "Compression / Decompression"
# "CDP", "COmpression / DECompression"
# "CDP", "core dump"
# "CDP", "Compression / Decompression"
# "CDP", "COmpression / DECompression"
# "CDP", "core dump"
# "CDP", "Compression / Decompression"
# "CDP", "COmpression / DECompression"
# "CDP", "core dump"
# "CDP", "Compression / Decompression"
# "CDP", "COmpression / DECompression"
# "CDP", "core dump"
# "CDP", "Compression / Decompression"
# "CDP", "COmpression / DECompression"
# "CDP", "core dump"
# "CD-R", "Compact Disc Re-Writable"
# "CD-R", "change directory"
# "CD-R", "cylinder-head-sector"
# "CD-R", "Compression / Decompression"
# "CD-R", "COmpression / DECompression"
# "CE", "certified"
# "CE", "certification"
# "CE", "certified"
# "CE", "certificate"
# "CE", "character"
# "CE", "cylinder-head-sector"
# "CE", "comp.os.linux.announce"
# "CE", "conference"
# "CE", "confidence"
# "CE", "console"
# "CE", "counter-strike"
# "CE", "certified"
# "CE", "certification"
# "CE", "certified"
# "CE", "certificate"
# "CE", "character"
# "CE", "cylinder-head-sector"
# "CE", "comp.os.linux.announce"
# "CE", "conference"
# "CE", "confidence"
# "CE", "console"
# "CE", "counter-strike"
# "CE", "certified"
# "CE", "certification"
# "CE", "certified"
# "CE", "certificate"
# "CE", "character"
# "CE", "cylinder-head-sector"
# "CE", "comp.os.linux.announce"
# "CE", "conference"
# "CE", "confidence"
# "CE", "console"
# "CE", "counter-strike"
# "CE", "certified"
# "CE", "certification"
# "CE", "certified"
# "CE", "certificate"
# "CE", "character"
# "CE", "cylinder-head-sector"
# "CE", "comp.os.linux.announce"
# "CE", "conference"
# "CE", "confidence"
# "CE", "console"
# "CE", "counter-strike"
# "CentOS", "connectionless network service"
# "CentOS", "complementary metal-oxide semiconductor"
# "CEO", "certification"
# "CEO", "change directory"
# "CEO", "cylinder-head-sector"
# "CEO", "central office"
# "CEO", "Compression / Decompression"
# "CEO", "COmpression / DECompression"
# "CERN", "certification"
# "CERN", "Compression / Decompression"
# "CERN", "COmpression / DECompression"
# "CERN", "conference"
# "CERN", "carriage return"
# "CERN", "cross-site scripting"
# "CERT", "certification"
# "CERT", "certified"
# "CERT", "certificate"
# "CERT", "change directory"
# "CERT", "cylinder-head-sector"
# "CERT", "cost per thousand"
# "CERT", "carriage return"
# "CERT", "cathode ray tube"
# "CERT", "counter-strike"
# "CERT", "Computer Service Technician"
# "CERT", "client-to-client protocol"
# "CERT", "Coordinated Universal Time"
# "CERT", "Coordinated Universal Time"
# "CERT", "cross-site scripting"
# "CERT", "certification"
# "CERT", "certified"
# "CERT", "certificate"
# "CERT", "change directory"
# "CERT", "cylinder-head-sector"
# "CERT", "cost per thousand"
# "CERT", "carriage return"
# "CERT", "cathode ray tube"
# "CERT", "counter-strike"
# "CERT", "Computer Service Technician"
# "CERT", "client-to-client protocol"
# "CERT", "Coordinated Universal Time"
# "CERT", "Coordinated Universal Time"
# "CERT", "cross-site scripting"
# "Cert", "change directory"
# "Cert", "cylinder-head-sector"
# "Cert", "cost per thousand"
# "Cert", "carriage return"
# "Cert", "cathode ray tube"
# "Cert", "counter-strike"
# "Cert", "Computer Service Technician"
# "Cert", "client-to-client protocol"
# "Cert", "Coordinated Universal Time"
# "Cert", "Coordinated Universal Time"
# "Cert", "cross-site scripting"
# "Cert", "change directory"
# "Cert", "cylinder-head-sector"
# "Cert", "cost per thousand"
# "Cert", "carriage return"
# "Cert", "cathode ray tube"
# "Cert", "counter-strike"
# "Cert", "Computer Service Technician"
# "Cert", "client-to-client protocol"
# "Cert", "Coordinated Universal Time"
# "Cert", "Coordinated Universal Time"
# "Cert", "cross-site scripting"
# "Cert", "change directory"
# "Cert", "cylinder-head-sector"
# "Cert", "cost per thousand"
# "Cert", "carriage return"
# "Cert", "cathode ray tube"
# "Cert", "counter-strike"
# "Cert", "Computer Service Technician"
# "Cert", "client-to-client protocol"
# "Cert", "Coordinated Universal Time"
# "Cert", "Coordinated Universal Time"
# "Cert", "cross-site scripting"
# "CES", "cylinder-head-sector"
# "CES", "close of business"
# "CES", "Compression / Decompression"
# "CES", "COmpression / DECompression"
# "CES", "customer service"
# "CES", "computer science"
# "CES", "counter-strike"
# "CES", "cable select"
# "CES", "code segment"
# "CES", "comma-separated values"
# "CES", "cross-site scripting"
# "CF", "conference"
# "CF", "confidence"
# "CGA", "cryptography"
# "CH", "character"
# "CH", "cylinder-head-sector"
# "CH", "compact HTML"
# "CH", "cryptography"
# "CH", "character"
# "CH", "cylinder-head-sector"
# "CH", "compact HTML"
# "CH", "cryptography"
# "Char", "cylinder-head-sector"
# "CIDR", "Compression / Decompression"
# "CIDR", "COmpression / DECompression"
# "CIM", "continuity RIMM"
# "CIR", "command-line interface"
# "CIR", "carriage return"
# "CIR", "continuity RIMM"
# "CIR", "click-through rate"
# "CISC", "cross-site scripting"
# "CISSP", "chirp spread spectrum"
# "CLI", "class ID"
# "CLI", "comp.os.linux.announce"
# "CLNS", "close of business"
# "CLOS", "complementary metal-oxide semiconductor"
# "CLR", "click-through rate"
# "CLUT", "control unit"
# "CMA", "computer-mediated communication"
# "CMA", "comp.os.linux.announce"
# "CMA", "Current Mailbox"
# "CMC", "comp.os.linux.announce"
# "CMOS", "Compression / Decompression"
# "CMOS", "COmpression / DECompression"
# "CMOS", "comp.os.linux.announce"
# "CMS", "Compression / Decompression"
# "CMS", "COmpression / DECompression"
# "CMS", "comp.os.linux.announce"
# "CMS", "customer service"
# "CMS", "computer science"
# "CNCT", "Certificate of Authenticity"
# "CNE", "close of business"
# "CNE", "comp.os.linux.announce"
# "CNE", "conference"
# "CNE", "confidence"
# "CNE", "console"
# "CNE", "computer science"
# "CNE", "counter-strike"
# "CNR", "conference"
# "CNR", "continuity RIMM"
# "CNR", "counter-strike"
# "CNST", "counter-strike"
# "CNST", "Coordinated Universal Time"
# "CNST", "Coordinated Universal Time"
# "CO", "comp.os.linux.announce"
# "CO", "conference"
# "CO", "confidence"
# "CO", "console"
# "CO", "cryptography"
# "CO", "counter-strike"
# "COA", "comp.os.linux.announce"
# "COA", "cryptography"
# "COAST", "Certificate Revocation List"
# "COBOL", "Component Object Model"
# "Code", "Compression / Decompression"
# "Code", "COmpression / DECompression"
# "Code", "Computer Dealers' Exhibition"
# "Code", "confidence"
# "Codec", "confidence"
# "Codec", "confidence"
# "Coil", "Combined Programming Language"
# "Coil", "Certificate Revocation List"
# "Con", "counter-strike"
# "Con", "counter-strike"
# "Con", "counter-strike"
# "Core", "customer service"
# "Core", "counter-strike"
# "Core", "click-through rate"
# "CPA", "cryptography"
# "CPA", "cryptography"
# "CPAN", "Combined Programming Language"
# "CPAN", "cost per thousand"
# "CPC", "client-to-client protocol"
# "CPGA", "Combined Programming Language"
# "CPGA", "cryptography"
# "CPI", "cross-site scripting"
# "CPL", "client-to-client protocol"
# "CPS", "computer science"
# "CR", "continuity RIMM"
# "CR", "cryptography"
# "CR", "counter-strike"
# "CR", "click-through rate"
# "CRC", "customer service"
# "CRC", "client-to-client protocol"
# "CREN", "customer relationship management"
# "CREN", "computer science"
# "C-RIMM", "customer relationship management"
# "CRL", "client-to-client protocol"
# "CRM", "Current Mailbox"
# "CRT", "cryptography"
# "CRT", "counter-strike"
# "CRT", "client-to-client protocol"
# "CRT", "click-through rate"
# "CRT", "cross-site scripting"
# "CS", "cross-site scripting"
# "CS", "cross-site scripting"
# "CS", "cross-site scripting"
# "CS", "cross-site scripting"
# "CS", "cross-site scripting"
# "CSS", "cross-site scripting"
# "CSS", "cross-site scripting"
# "CSS", "cross-site scripting"
# "CSS", "cross-site scripting"
# "CST", "cross-site scripting"
# "CTCP", "cross-site scripting"
# "CTS", "cross-site scripting"
# "CUT", "Coordinated Universal Time"
# "D", "disk-to-disk"
# "D", "database"
# "D", "disconnect"
# "D", "download"
# "D", "download"
# "D", "deathmatch"
# "D", "DisplayPort"
# "DAC", "domain controller"
# "DAC", "data center"
# "DAC", "downloadable content"
# "DAC", "deathmatch"
# "DAC", "DirectX diagnostics"
# "DAC", "domain controller"
# "DAC", "data center"
# "DAC", "downloadable content"
# "DAC", "deathmatch"
# "DAC", "DirectX diagnostics"
# "DACL", "domain controller"
# "DACL", "dynamic-link library"
# "DAE", "database"
# "DAE", "Device Manager"
# "DAE", "direct message"
# "DARPA", "Data Encryption Algorithm"
# "DART", "Disk Anti-Shock Protection"
# "DART", "digital audio workstation"
# "DART", "database administrator"
# "DART", "dial-on-demand routing"
# "DART", "digital linear tape"
# "DART", "DisplayPort"
# "DART", "data request"
# "DART", "Disk Anti-Shock Protection"
# "DART", "digital audio workstation"
# "DART", "database administrator"
# "DART", "dial-on-demand routing"
# "DART", "digital linear tape"
# "DART", "DisplayPort"
# "DART", "data request"
# "DART", "Disk Anti-Shock Protection"
# "DART", "digital audio workstation"
# "DART", "database administrator"
# "DART", "dial-on-demand routing"
# "DART", "digital linear tape"
# "DART", "DisplayPort"
# "DART", "data request"
# "DASP", "digital signal processor"
# "DASP", "digital signal processor"
# "DASP", "digital signal processor"
# "DAT", "database"
# "DAT", "database analyst"
# "DAT", "decibels adjust"
# "DAT", "database administrator"
# "DAT", "deathmatch"
# "DAT", "Double-precision floating-point"
# "DAT", "DisplayPort"
# "DAT", "DirectX diagnostics"
# "DBA", "dynamic-link library"
# "DBA", "dynamic-link library"
# "DBA", "dynamic-link library"
# "DBA", "dynamic-link library"
# "DBAN", "Double-precision floating-point"
# "DC", "Direct Client-to-Client"
# "DC", "downloadable content"
# "DC", "deathmatch"
# "DC", "Direct Client-to-Client"
# "DC", "downloadable content"
# "DC", "deathmatch"
# "DC", "Direct Client-to-Client"
# "DC", "downloadable content"
# "DC", "deathmatch"
# "DC", "Direct Client-to-Client"
# "DC", "downloadable content"
# "DC", "deathmatch"
# "DCE", "disc jockey"
# "DCE", "downloadable content"
# "DCE", "denial of service"
# "DCE", "disc jockey"
# "DCE", "downloadable content"
# "DCE", "denial of service"
# "DCE", "disc jockey"
# "DCE", "downloadable content"
# "DCE", "denial of service"
# "DCE", "disc jockey"
# "DCE", "downloadable content"
# "DCE", "denial of service"
# "DCOM", "Do Communications Over Mobile"
# "DD", "dynamic DNS"
# "DD", "download"
# "DD", "download"
# "DD", "deathmatch"
# "DD", "Department of Defense"
# "DD", "DisplayPort"
# "DD", "DirectX diagnostics"
# "DDE", "deathmatch"
# "DDE", "Department of Defense"
# "DDL", "download"
# "DDL", "download"
# "DDL", "dynamic-link library"
# "DDL", "DisplayPort"
# "DDNS", "Distributed Denial of Service"
# "DDNS", "Department of Defense"
# "DDNS", "denial of service"
# "DDNS", "discontinuous transmission"
# "DDNS", "DirectX diagnostics"
# "DDO", "download"
# "DDO", "download"
# "DDO", "DisplayPort"
# "DDO", "DirectX diagnostics"
# "DDO", "download"
# "DDO", "download"
# "DDO", "DisplayPort"
# "DDO", "DirectX diagnostics"
# "DDoS", "disk operating system"
# "DDoS", "DirectX diagnostics"
# "DDP", "DisplayPort"
# "DDR", "DisplayPort"
# "DDR", "data request"
# "DDR", "DisplayPort"
# "DDR", "data request"
# "DDS", "Department of Defense"
# "DDS", "denial of service"
# "DDS", "DisplayPort"
# "DDS", "drive select"
# "DDS", "DirectX diagnostics"
# "DEA", "deathmatch"
# "DEA", "direct message"
# "DEC", "downloadable content"
# "DEC", "deathmatch"
# "DEC", "denial of service"
# "DEC", "drive select"
# "DES", "direct message"
# "DES", "Department of Defense"
# "DES", "denial of service"
# "DES", "data request"
# "DES", "drive select"
# "DID", "DirectX diagnostics"
# "DIF", "Double-precision floating-point"
# "DIME", "Device Manager"
# "DIME", "direct message"
# "DIP", "Double-precision floating-point"
# "DIP", "DisplayPort"
# "DL", "download"
# "DL", "dynamic-link library"
# "DL", "DisplayPort"
# "D/L", "dynamic-link library"
# "D/L", "DisplayPort"
# "DLA", "dynamic-link library"
# "DLA", "Double-precision floating-point"
# "DLA", "DisplayPort"
# "DLC", "drive select"
# "DLC", "drive select"
# "DLC", "drive select"
# "DLP", "Double-precision floating-point"
# "DLP", "DisplayPort"
# "DLP", "Double-precision floating-point"
# "DLP", "DisplayPort"
# "DLP", "Double-precision floating-point"
# "DLP", "DisplayPort"
# "DLP", "Double-precision floating-point"
# "DLP", "DisplayPort"
# "DLT", "Double-precision floating-point"
# "DLT", "DisplayPort"
# "DLT", "drive select"
# "DMAR", "Data Terminal Ready"
# "DMI", "discontinuous transmission"
# "DNS", "Department of Defense"
# "DNS", "denial of service"
# "DNS", "discontinuous transmission"
# "DNS", "DirectX diagnostics"
# "DOA", "Double-precision floating-point"
# "DOD", "double word"
# "DoS", "disk operating system"
# "DoS", "DirectX diagnostics"
# "DOS", "DirectX diagnostics"
# "DoT", "Double-precision floating-point"
# "DoT", "DisplayPort"
# "DoT", "discontinuous transmission"
# "DoT", "DirectX diagnostics"
# "Dpkg", "Dial-Up Networking"
# "DRAM", "digital rights management"
# "DRAM", "discontinuous transmission"
# "DRM", "discontinuous transmission"
# "DSAP", "drive secondary present"
# "DSAP", "digital signal processor"
# "DSO", "discontinuous transmission"
# "DSS", "discontinuous transmission"
# "DSS", "DirectX diagnostics"
# "DSS", "discontinuous transmission"
# "DSS", "DirectX diagnostics"
# "DTR", "discontinuous transmission"
# "DTR", "Dial-Up Networking"
# "DTS", "discontinuous transmission"
# "DTS", "DirectX diagnostics"
# "DTS", "discontinuous transmission"
# "DTS", "DirectX diagnostics"
# "DTS", "discontinuous transmission"
# "DTS", "DirectX diagnostics"
# "DUST", "device under test"
# "E", "emphasized"
# "E", "end-of-file"
# "E", "End-of-Line"
# "E", "end-of-message"
# "E", "end-of-page"
# "E", "End-of-Transmission"
# "E", "equalizer"
# "E", "EverQuest"
# "E", "equals"
# "E", "End-of-Text"
# "E", "evaluate"
# "EA", "emphasized"
# "EA", "end-of-message"
# "EA", "end-of-page"
# "EA", "End-of-Transmission"
# "EA", "equalizer"
# "EA", "equals"
# "EA", "evaluate"
# "EAI", "electronic learning"
# "EAI", "emphasized"
# "EAI", "electronic mail"
# "EAI", "enhanced metafile"
# "EAI", "electromagnetic interference"
# "EAI", "End-of-Transmission"
# "EAI", "electronic publication"
# "EAI", "equalizer"
# "EAPROM", "Erasable Programmable Read-Only Memory"
# "ECC", "extended cylinder-head-sector"
# "ECDSA", "electronic design automation"
# "ECDSA", "electroluminescent display"
# "ECDSA", "electrostatic discharge"
# "ECMA", "electronic mail"
# "ECMA", "enhanced metafile"
# "ECP", "encapsulated PostScript"
# "ECP", "electronic publication"
# "EDA", "electroluminescent display"
# "EDA", "end-of-message"
# "EDA", "end-of-page"
# "EDA", "End-of-Transmission"
# "EDA", "electrostatic discharge"
# "EDI", "Extended ISA"
# "EDI", "electroluminescent display"
# "EDI", "end-of-file"
# "EDI", "End-of-Line"
# "EDI", "End-of-Transmission"
# "EDI", "electrostatic discharge"
# "EDO", "end-of-file"
# "EDO", "End-of-Line"
# "EDO", "end-of-message"
# "EDO", "end-of-page"
# "EDO", "End-of-Transmission"
# "EDO", "End-of-Text"
# "EDO", "Evolution-Data Only"
# "EDO", "Evolution-Data Optimized"
# "EDP", "electroluminescent display"
# "EDP", "end-of-page"
# "EDSAC", "Electronic Industries Alliance"
# "EDSAC", "Enhanced Serial Interface"
# "EEPROM", "Erasable Programmable Read-Only Memory"
# "EFI", "enhanced metafile"
# "EFI", "end-of-file"
# "EFI", "End-of-Line"
# "EFI", "End-of-Transmission"
# "EFS", "end-of-message"
# "EFS", "End-of-Transmission"
# "EGA", "Extended Graphics Array"
# "EIA", "Extended ISA"
# "EIA", "electroluminescent display"
# "EIA", "electronic publication"
# "EIA", "electrostatic discharge"
# "EIDE", "electrostatic discharge"
# "EISA", "electroluminescent display"
# "EISA", "electrostatic discharge"
# "EISA", "End-User License Agreement"
# "EISA", "electroluminescent display"
# "EISA", "electrostatic discharge"
# "EISA", "End-User License Agreement"
# "ELD", "electrostatic discharge"
# "ELF", "electromotive force"
# "EM", "electronic mail"
# "EM", "enhanced metafile"
# "EM", "expanded-memory manager"
# "EM", "end-of-message"
# "EM", "End-of-Transmission"
# "E-mail", "enhanced metafile"
# "EMI", "End-of-Transmission"
# "EMI", "Evolution-Data Optimized"
# "EMS", "end-of-message"
# "EMS", "End-of-Transmission"
# "EMS", "extended memory specification"
# "EMS", "end-of-message"
# "EMS", "End-of-Transmission"
# "EMS", "extended memory specification"
# "EOF", "End-of-Line"
# "EOF", "end-of-message"
# "EOF", "end-of-page"
# "EOF", "End-of-Transmission"
# "EOF", "End-of-Text"
# "EOL", "Evolution-Data Only"
# "EOL", "extended technology"
# "EOM", "End-of-Transmission"
# "EOM", "Evolution-Data Optimized"
# "EOP", "end of topic"
# "EOP", "encapsulated PostScript"
# "EOP", "electronic publication"
# "EOP", "Evolution-Data Optimized"
# "EOT", "encapsulated PostScript"
# "EOT", "End-of-Text"
# "EOT", "Evolution-Data Optimized"
# "EOT", "encapsulated PostScript"
# "EOT", "End-of-Text"
# "EOT", "Evolution-Data Optimized"
# "EPD", "Evolution-Data Optimized"
# "EPIC", "electronic publication"
# "EPP", "encapsulated PostScript"
# "ESA", "electrostatic discharge"
# "ESCD", "electrostatic discharge"
# "F", "favorite"
# "F", "facebook"
# "F", "feature"
# "F", "Firefox"
# "F", "fixed-point"
# "F", "floating-point"
# "F", "function"
# "F", "FrontPage"
# "FAD", "fast forward"
# "Famicom", "Federal Communications Commission"
# "FAST", "format and restore"
# "FAST", "Formula Translation"
# "FAT", "favorite"
# "FAT", "feature"
# "FAT", "floating-point"
# "FAT", "frequency modulation"
# "FAT", "Formula Translation"
# "FAU", "feature"
# "FAU", "floating-point unit"
# "FAU", "field-replacable unit"
# "FB", "front-side bus"
# "FD", "fixed-point"
# "Feat", "frequency modulation"
# "FF", "fixed-point"
# "FF", "floating-point"
# "FF", "function"
# "FF", "FrontPage"
# "FF", "fixed-point"
# "FF", "floating-point"
# "FF", "function"
# "FF", "FrontPage"
# "FF", "fixed-point"
# "FF", "floating-point"
# "FF", "function"
# "FF", "FrontPage"
# "FF", "fixed-point"
# "FF", "floating-point"
# "FF", "function"
# "FF", "FrontPage"
# "FFA", "floating-point"
# "FFA", "FrontPage"
# "FFS", "file system"
# "Fn", "FrontPage"
# "FPU", "field-replacable unit"
# "FR", "Ferroelectric RAM"
# "G+", "GeForce"
# "G+", "Gigahertz"
# "GA", "Gallium Arsenide"
# "GA", "Gigahertz"
# "GaAs", "game masters"
# "GCC", "General Electric"
# "GCR", "General Electric"
# "GE", "GeForce"
# "GE", "Gigahertz"
# "GEM", "golden masters"
# "GEM", "game masters"
# "GEM", "Google Mail"
# "GM", "Google Mail"
# "GM", "Google Mail"
# "GM", "Google Mail"
# "GM", "Google Mail"
# "GM", "Google Mail"
# "GPT", "GIMP toolkit"
# "GT", "GIMP toolkit"
# "GUI", "globally unique identifier"
# "H", "high-definition"
# "H", "high-density"
# "H", "Hewlett-Packard"
# "H", "high-quality"
# "H", "Hyper-Threading"
# "H", "HyperTransport"
# "H", "hardware"
# "H", "Hertz"
# "HAL", "high-quality"
# "HAN", "high-level language"
# "HAN", "high-performance addressing"
# "HAN", "Horizontal Synchronization"
# "HAN", "Hyper-Threading"
# "HAN", "HyperTransport"
# "HCI", "Horizontal Synchronization"
# "HD", "Hewlett-Packard"
# "HD", "Hyper-Threading"
# "HD", "hardware"
# "HD", "Hewlett-Packard"
# "HD", "Hyper-Threading"
# "HD", "hardware"
# "HD", "Hewlett-Packard"
# "HD", "Hyper-Threading"
# "HD", "hardware"
# "HDD", "high-performance addressing"
# "HES", "high resolution"
# "HES", "high-performance addressing"
# "HES", "Human Resources"
# "HES", "HyperTransport"
# "HES", "Hypertext Preprocessor"
# "HFC", "Hypertext reference"
# "HFS", "high-performance file system"
# "HGA", "high-level language"
# "HGA", "high-memory area"
# "HGA", "high-performance addressing"
# "HGA", "high-quality"
# "Hi-res", "high-performance addressing"
# "HIT", "high-quality"
# "HIT", "Horizontal Synchronization"
# "HMA", "high-performance addressing"
# "HoT", "Horizontal Synchronization"
# "HoT", "HyperTransport"
# "HP", "Hyper-Threading"
# "HP", "HyperTransport"
# "HP", "Hypertext Preprocessor"
# "HPA", "Hyper-Threading"
# "HPA", "HyperTransport"
# "HPD", "Hyper-Threading"
# "HR", "Hypertext reference"
# "HR", "Hyper-Threading"
# "HR", "HyperTransport"
# "HR", "hardware"
# "HR", "Hertz"
# "HT", "Hertz"
# "HT", "Hertz"
# "HTPC", "Hypertext Transfer Protocol"
# "HTPC", "Hypertext Preprocessor"
# "IAB", "image stabilization"
# "IAC", "interpupillary distance"
# "IAC", "interpupillary distance"
# "IAD", "incorporated"
# "IAD", "interpupillary distance"
# "IAD", "infrared"
# "IANA", "integrated communications adapter"
# "IANA", "Image-Enabled Netware"
# "IANA", "Industry Standard Architecture"
# "IAP", "interblock gap"
# "IAP", "intellectual property"
# "IAP", "interrecord gap"
# "ICA", "incorporated"
# "ICA", "interprocess communication"
# "ICA", "incorporated"
# "ICA", "interprocess communication"
# "Icacl", "information and communications technology"
# "ICANN", "International Telecommunication Union"
# "ICCCM", "International Electrotechnical Commision"
# "ICMP", "Intel comparative microprocessor performance"
# "ICO", "interactive fiction"
# "ICO", "incorporated"
# "ICO", "input/output controller"
# "ICO", "Internet Protocol"
# "ICO", "ingress protection"
# "ICO", "interprocess communication"
# "ICO", "information technology"
# "ICO", "interactive fiction"
# "ICO", "incorporated"
# "ICO", "input/output controller"
# "ICO", "Internet Protocol"
# "ICO", "ingress protection"
# "ICO", "interprocess communication"
# "ICO", "information technology"
# "ICRA", "incorporated"
# "ICS", "Information Services"
# "ICT", "interactive fiction"
# "ICT", "incorporated"
# "ICT", "input/output controller"
# "ICT", "ingress protection"
# "ICT", "interprocess communication"
# "ICT", "interactive fiction"
# "ICT", "incorporated"
# "ICT", "input/output controller"
# "ICT", "ingress protection"
# "ICT", "interprocess communication"
# "ICU", "interprocess communication"
# "ICU", "interprocess communication"
# "ICU", "interprocess communication"
# "ICU", "interprocess communication"
# "IDC", "interpupillary distance"
# "IDE", "index node"
# "IDE", "interpupillary distance"
# "IDE", "Intensity-Red-Green-Blue"
# "IDE", "index node"
# "IDE", "interpupillary distance"
# "IDE", "Intensity-Red-Green-Blue"
# "IDEA", "Image-Enabled Netware"
# "IDS", "interpupillary distance"
# "IE", "incorporated"
# "IE", "integer"
# "IE", "interrupt"
# "IE", "infrared"
# "IE", "Intensity-Red-Green-Blue"
# "IEC", "ingress protection"
# "IEC", "interprocess communication"
# "IEC", "Information Services"
# "IEC", "information technology"
# "IEEE", "Image-Enabled Netware"
# "IEEE", "instant messenger"
# "IEEE", "Intensity-Red-Green-Blue"
# "IEEE", "interrupt request"
# "IEN", "instant messaging"
# "IEN", "instant messenger"
# "IEN", "index node"
# "IEN", "ingress protection"
# "IEN", "Intensity-Red-Green-Blue"
# "IEN", "information technology"
# "IEN", "instant messaging"
# "IEN", "instant messenger"
# "IEN", "index node"
# "IEN", "ingress protection"
# "IEN", "Intensity-Red-Green-Blue"
# "IEN", "information technology"
# "IEN", "instant messaging"
# "IEN", "instant messenger"
# "IEN", "index node"
# "IEN", "ingress protection"
# "IEN", "Intensity-Red-Green-Blue"
# "IEN", "information technology"
# "IETF", "interactive fiction"
# "IF", "information"
# "IF", "infrared"
# "IGES", "image stabilization"
# "IGP", "ingress protection"
# "IGP", "interrecord gap"
# "IIL", "information retrieval"
# "IIL", "Intensity-Red-Green-Blue"
# "IIL", "image stabilization"
# "IIS", "Input/Output Supervisor"
# "IIS", "interpupillary distance"
# "IIS", "Intensity-Red-Green-Blue"
# "IIS", "Information Services"
# "IIS", "image stabilization"
# "IM", "information"
# "IM", "information"
# "IM", "information"
# "IMEI", "information retrieval"
# "IMEI", "Information Services"
# "IMSI", "Information Services"
# "IMSI", "image stabilization"
# "INC", "input/output controller"
# "INC", "interprocess communication"
# "INC", "interpupillary distance"
# "Inetd", "Intensity-Red-Green-Blue"
# "Inode", "Information Technology eXtended"
# "Int", "interrupt"
# "Int", "input/output"
# "Int", "input/output controller"
# "Int", "interprocess communication"
# "Int", "Intensity-Red-Green-Blue"
# "Int", "information technology"
# "INTR", "input/output controller"
# "INTR", "information retrieval"
# "INTR", "Intensity-Red-Green-Blue"
# "INTR", "interrupt request"
# "IOC", "Internet Protocol"
# "IOC", "ingress protection"
# "IOC", "interprocess communication"
# "IOCCC", "interprocess communication"
# "IOPS", "Input/Output Supervisor"
# "IOPS", "Internetworking operating system"
# "IOPS", "intrusion prevention system"
# "IOS", "IP over Satellite"
# "IOS", "International Organization for Standardization"
# "IOS", "IP over Satellite"
# "IOS", "International Organization for Standardization"
# "IPng", "Ingress Protection Rating"
# "IPOS", "intrusion prevention system"
# "IPOS", "Internet Protocol security"
# "IPOS", "intrusion prevention system"
# "IPOS", "Internet Protocol security"
# "IPS", "Internet Protocol security"
# "IPTO", "Internet Protocol television"
# "IR", "Intensity-Red-Green-Blue"
# "IR", "in real-life"
# "IR", "interrupt request"
# "IR", "Intensity-Red-Green-Blue"
# "IR", "in real-life"
# "IR", "interrupt request"
# "IRC", "Information Services"
# "IrDA", "Industry Standard Architecture"
# "IRG", "Intensity-Red-Green-Blue"
# "Java EE", "Java servlet"
# "JRE", "Java servlet"
# "JSR", "Java servlet"
# "K", "kilobit"
# "K", "kilohertz"
# "K", "kibibyte"
# "K", "kibibit"
# "KB", "kibibyte"
# "KB", "kibibit"
# "KiB", "kibibit"
# "LAME", "loss of frame"
# "Laser", "location-based service"
# "Laser", "laserdisc"
# "Laser", "least significant character"
# "Laser", "Layered Service Provider"
# "Laser", "Local user"
# "LC", "laserdisc"
# "LD", "light-emitting diode"
# "LD", "light-emitting diode"
# "LD", "Loadhigh"
# "LD", "level of detail"
# "LE", "lithium-polymer"
# "LE", "low-resolution"
# "LE", "letter-quality"
# "LE", "Long-Term Evolution"
# "LE", "level"
# "LED", "light-emitting diode"
# "LED", "line feed"
# "LED", "level of detail"
# "LF", "loss of frame"
# "LFG", "Life's Good"
# "LFM", "loss of frame"
# "LG", "Loadhigh"
# "LGA", "Loss of signal"
# "LGPL", "long play"
# "LH", "lithium-ion"
# "LH", "lithium-polymer"
# "Li-ion", "limited liability company"
# "LIPS", "List Processing"
# "LIPS", "Library Programs Service"
# "LIPS", "List Processing"
# "LIPS", "Library Programs Service"
# "Lisp", "link state packet"
# "LNP", "long play"
# "LU", "Local user"
# "Lzone", "Landing Zone"
# "m", "Macintosh"
# "m", "macroinstruction"
# "m", "manual"
# "m", "maximize"
# "m", "maximum"
# "m", "motherboard"
# "m", "megabit"
# "m", "megabyte"
# "m", "Malwarebytes"
# "m", "megacycle"
# "m", "memorandum"
# "m", "megaflop"
# "m", "megahertz"
# "m", "mebibit"
# "m", "mebibyte"
# "m", "minimum"
# "m", "MultiMediaCard"
# "m", "modulo"
# "m", "modulator/demodulator"
# "m", "metal-oxide-semiconductor"
# "m", "Microsoft"
# "m", "millisecond"
# "m", "microarchitecture"
# "M-", "Macintosh"
# "M-", "macroinstruction"
# "M-", "manual"
# "M-", "maximize"
# "M-", "maximum"
# "M-", "motherboard"
# "M-", "megabit"
# "M-", "megabyte"
# "M-", "Malwarebytes"
# "M-", "megacycle"
# "M-", "memorandum"
# "M-", "megaflop"
# "M-", "megahertz"
# "M-", "mebibit"
# "M-", "mebibyte"
# "M-", "minimum"
# "M-", "MultiMediaCard"
# "M-", "modulo"
# "M-", "modulator/demodulator"
# "M-", "metal-oxide-semiconductor"
# "M-", "Microsoft"
# "M-", "millisecond"
# "M-", "microarchitecture"
# "MAC", "macroinstruction"
# "MAC", "Matrix code"
# "MAC", "megacycle"
# "MAC", "multiple-document interface"
# "MAC", "multi-factor authentication"
# "MAC", "man-in-the-middle attack"
# "MAC", "MultiMediaCard"
# "MAC", "metal-oxide-semiconductor"
# "MAC", "Microsoft Diagnostics"
# "MAC", "multi-user interface"
# "MAC", "microarchitecture"
# "MAC", "macroinstruction"
# "MAC", "Matrix code"
# "MAC", "megacycle"
# "MAC", "multiple-document interface"
# "MAC", "multi-factor authentication"
# "MAC", "man-in-the-middle attack"
# "MAC", "MultiMediaCard"
# "MAC", "metal-oxide-semiconductor"
# "MAC", "Microsoft Diagnostics"
# "MAC", "multi-user interface"
# "MAC", "microarchitecture"
# "MAE", "maximize"
# "MAE", "megabyte"
# "MAE", "Malwarebytes"
# "MAE", "megacycle"
# "MAE", "multiple-document interface"
# "MAE", "multi-factor authentication"
# "MAE", "megahertz"
# "MAE", "mail in rebate"
# "MAE", "MultiMedia eXtension"
# "MAE", "modulator/demodulator"
# "MAE", "metal-oxide-semiconductor"
# "MAE", "multi-user interface"
# "MAE", "microarchitecture"
# "mAH", "multi-factor authentication"
# "mAH", "megahertz"
# "mAH", "microarchitecture"
# "MAN", "Managed Beans"
# "MAN", "memorandum"
# "MAN", "multi-factor authentication"
# "MAN", "Mozilla Foundation"
# "MAN", "metal-oxide-semiconductor"
# "MAN", "Microsoft Diagnostics"
# "MAPI", "message passing interface"
# "MAPS", "megabits per second"
# "MAPS", "megabytes per second"
# "MAR", "matrix laboratory"
# "MAR", "motherboard"
# "MAR", "Malwarebytes"
# "MAR", "megahertz"
# "MAR", "mail in rebate"
# "MAR", "MultiMediaCard"
# "MAR", "modulator/demodulator"
# "MAR", "metal-oxide-semiconductor"
# "MAR", "microarchitecture"
# "MAU", "maximum"
# "MAU", "memorandum"
# "MAU", "multi-factor authentication"
# "MAU", "modulator/demodulator"
# "MAU", "metal-oxide-semiconductor"
# "MAU", "microarchitecture"
# "Max", "metal-oxide-semiconductor"
# "Max", "metal-oxide-semiconductor"
# "mb", "megabit"
# "mb", "megabyte"
# "mb", "Malwarebytes"
# "mb", "Managed Beans"
# "mb", "mebibit"
# "mb", "mebibyte"
# "mb", "mobile blog"
# "Mb", "megabyte"
# "Mb", "Malwarebytes"
# "Mb", "Managed Beans"
# "Mb", "mebibit"
# "Mb", "mebibyte"
# "Mb", "mobile blog"
# "MB", "Malwarebytes"
# "MB", "Managed Beans"
# "MB", "mebibit"
# "MB", "mebibyte"
# "MB", "mobile blog"
# "MBAM", "Multibank DRAM"
# "MBean", "mobile identification number"
# "MBL", "mobile blog"
# "Mbps", "megabytes per second"
# "MBR", "model number"
# "MC", "MultiMediaCard"
# "MC", "metal-oxide-semiconductor"
# "MC", "Microsoft"
# "MC", "millisecond"
# "MC", "microarchitecture"
# "MCA", "multi-factor authentication"
# "MCA", "MultiMediaCard"
# "MCA", "microarchitecture"
# "MCSE", "magneto-optical diskette"
# "MCSE", "Microsoft Cluster Server"
# "MDA", "Multibank DRAM"
# "MDA", "man-in-the-middle attack"
# "MDA", "MultiMediaCard"
# "MDA", "modulator/demodulator"
# "MDA", "Mozilla Foundation"
# "MDA", "Microsoft Diagnostics"
# "MDC", "make directory"
# "MDC", "MultiMediaCard"
# "MDC", "metal-oxide-semiconductor"
# "MDC", "Microsoft Diagnostics"
# "MDI", "make directory"
# "MDI", "MultiMediaCard"
# "MDI", "magneto-optical diskette"
# "MDI", "Mozilla Foundation"
# "MDI", "metal-oxide-semiconductor"
# "MDI", "Microsoft Diagnostics"
# "Memo", "multiple-input, multiple-output"
# "Memo", "modulator/demodulator"
# "Memo", "metal-oxide-semiconductor"
# "MFA", "Mozilla Foundation"
# "MFA", "multi-user interface"
# "MFP", "Microsoft Plus!"
# "MFT", "Mozilla Foundation"
# "MFT", "Microsoft"
# "Mget", "megahertz"
# "Mget", "magneto-optical diskette"
# "Mib", "mebibyte"
# "Mib", "management information base"
# "Mib", "mobile blog"
# "MiB", "management information base"
# "MiB", "mobile blog"
# "MIB", "mobile blog"
# "MICR", "make directory"
# "MICR", "MultiMediaCard"
# "MICR", "metal-oxide-semiconductor"
# "MICR", "Microsoft"
# "MICR", "microarchitecture"
# "MIDI", "MultiMediaCard"
# "MIDI", "magneto-optical diskette"
# "MIDI", "Mozilla Foundation"
# "MIDI", "metal-oxide-semiconductor"
# "MIDI", "Microsoft Diagnostics"
# "MIME", "multiple-input, multiple-output"
# "MIME", "mobile identification number"
# "MIME", "MultiMediaCard"
# "MIME", "MultiMedia eXtension"
# "MIMO", "metal-oxide-semiconductor"
# "Min", "mobile identification number"
# "Min", "MultiMedia eXtension"
# "Min", "Mozilla Foundation"
# "Min", "metal-oxide-semiconductor"
# "Min", "millisecond"
# "Min", "Microsoft Diagnostics"
# "Min", "multi-user interface"
# "MIN", "MultiMedia eXtension"
# "MIN", "Mozilla Foundation"
# "MIN", "metal-oxide-semiconductor"
# "MIN", "millisecond"
# "MIN", "Microsoft Diagnostics"
# "MIN", "multi-user interface"
# "MIPS", "Microsoft Plus!"
# "MIR", "make directory"
# "MIR", "MultiMediaCard"
# "MIR", "metal-oxide-semiconductor"
# "MIR", "Microsoft"
# "MIR", "multi-user interface"
# "MIR", "microarchitecture"
# "MIS", "magneto-optical diskette"
# "MIS", "metal-oxide-semiconductor"
# "MIS", "Microsoft"
# "MIS", "millisecond"
# "MIS", "Microsoft Diagnostics"
# "MIT", "make directory"
# "MIT", "magneto-optical diskette"
# "MIT", "metal-oxide-semiconductor"
# "MIT", "Microsoft"
# "MIT", "Microsoft Diagnostics"
# "MIT", "multi-user interface"
# "MIT", "MultiUser Talk"
# "MIT", "microarchitecture"
# "MMC", "metal-oxide-semiconductor"
# "MMC", "Microsoft"
# "MMC", "millisecond"
# "MMC", "microarchitecture"
# "MMC", "metal-oxide-semiconductor"
# "MMC", "Microsoft"
# "MMC", "millisecond"
# "MMC", "microarchitecture"
# "MMI", "metal-oxide-semiconductor"
# "MMI", "Microsoft"
# "MMI", "millisecond"
# "MMI", "multi-user interface"
# "MMI", "microarchitecture"
# "MMS", "metal-oxide-semiconductor"
# "MMS", "Microsoft"
# "MMS", "memory stick"
# "MMS", "millisecond"
# "MMU", "modulo"
# "MMU", "modulator/demodulator"
# "MMU", "metal-oxide-semiconductor"
# "MMU", "microarchitecture"
# "MMX", "metal-oxide-semiconductor"
# "Mod", "modulator/demodulator"
# "Mod", "magneto-optical diskette"
# "Mod", "Mozilla Foundation"
# "Mod", "metal-oxide-semiconductor"
# "Mod", "millisecond"
# "Mod", "Microsoft Diagnostics"
# "Model no.", "metal-oxide semiconductor field-effect transistor"
# "Model no.", "Microsoft Developer Network"
# "Modem", "metal-oxide-semiconductor"
# "MO diskette", "Microsoft Disk Operating System"
# "MOS", "Microsoft"
# "MOS", "memory stick"
# "MOS", "Microsoft Diagnostics"
# "MOTD", "Microsoft Diagnostics"
# "MPLS", "Microsoft Plus!"
# "MPP", "multiple put"
# "MRP", "Microsoft Plus!"
# "MRU", "microarchitecture"
# "MSC", "Microsoft Diagnostics"
# "MSCS", "Microsoft Diagnostics"
# "MSD", "multi-user dungeon"
# "MSD", "multi-user dungeon"
# "MSDN", "multi-user dungeon"
# "MSP", "Microsoft Plus!"
# "MTA", "multi-user interface"
# "MTA", "MultiUser Talk"
# "MTU", "microarchitecture"
# "NAS", "nanosecond"
# "NAS", "nanosecond"
# "NAT", "non-disclosure agreement"
# "NAT", "non-destructive readout"
# "NAT", "non-destructive readout"
# "NAT", "near-field communication"
# "NAT", "near letter-quality"
# "NAT", "nanometer"
# "NAT", "no operatation"
# "NAT", "non-printing character"
# "NAT", "non-playable character"
# "NCP", "non-impact printer"
# "NCP", "NP-Complete"
# "NCP", "non-impact printer"
# "NCP", "NP-Complete"
# "NCSA", "non-disclosure agreement"
# "NCSC", "Nippon Electronics Company"
# "NDR", "non-destructive readout"
# "NDR", "nickel-metal hydride"
# "NDR", "NT loader"
# "NDR", "non-destructive readout"
# "NDR", "nickel-metal hydride"
# "NDR", "NT loader"
# "NDR", "non-destructive readout"
# "NDR", "nickel-metal hydride"
# "NDR", "NT loader"
# "ne", "network"
# "ne", "newsgroup"
# "ne", "nanometer"
# "ne", "NP-Complete"
# "ne", "non-return-to-zero"
# "ne", "nanosecond"
# "ne", "noteworthy"
# "ne", "number"
# "NEC", "near-field communication"
# "NEC", "non-playable character"
# "NEC", "nanosecond"
# "Net", "near letter-quality"
# "Net", "nanometer"
# "Net", "nonmaskable interrupt"
# "Net", "no operatation"
# "Net", "NP-Complete"
# "Net", "non-return-to-zero"
# "Net", "noteworthy"
# "NFS", "NTFS file system"
# "NIC", "non-printing character"
# "NIP", "nonmaskable interrupt"
# "NIT", "near letter-quality"
# "NIT", "nonmaskable interrupt"
# "nm", "NP-Complete"
# "nm", "number"
# "NN", "Not-Or"
# "NN", "NP-Complete"
# "NN", "non-return-to-zero"
# "NN", "nanosecond"
# "NN", "noteworthy"
# "NN", "number"
# "NNTP", "Network Time Protocol"
# "NOR", "non-return-to-zero"
# "NOR", "NT loader"
# "NOR", "noteworthy"
# "NOS", "nanosecond"
# "OA", "operator"
# "OA", "operation"
# "OCR", "OverDrive Processor"
# "OCTAVE", "object-based storage device"
# "OCTAVE", "Open-Source Initiative"
# "ODI", "object identifier"
# "ODI", "on-screen display"
# "ODP", "object-oriented programming"
# "ODP", "on-screen display"
# "ODPR", "object-oriented programming"
# "OEM", "operating system"
# "OEM", "overtype mode"
# "OIN", "object-oriented programming"
# "OIN", "opinion"
# "OIN", "operation"
# "OIN", "Open-Source Initiative"
# "OLE", "one-time programmable"
# "OO", "out of office"
# "OO", "operator"
# "OO", "opinion"
# "OO", "overpowered"
# "OO", "operation"
# "OO", "OR operator"
# "OOF", "open-source software"
# "OOP", "operator"
# "OOP", "opinion"
# "OOP", "original poster"
# "OOP", "overpowered"
# "OOP", "operation"
# "OOP", "OR operator"
# "OOP", "one-time password"
# "OOP", "one-time programmable"
# "OP", "one-time password"
# "OP", "one-time programmable"
# "OP", "one-time password"
# "OP", "one-time programmable"
# "OP", "one-time password"
# "OP", "one-time programmable"
# "OP", "one-time password"
# "OP", "one-time programmable"
# "OP", "one-time password"
# "OP", "one-time programmable"
# "OS", "open-source software"
# "OSD", "one-time password"
# "OSD", "one-time password"
# "OSD", "one-time password"
# "OSF", "open-source software"
# "OSS", "one-time password"
# "PaaS", "packet assembler/disassembler"
# "PaaS", "PlayerUnknown's Battlegrounds"
# "PAD", "page down"
# "PAD", "print formatted"
# "PAD", "PlayerUnknown's Battlegrounds"
# "PAD", "password"
# "PAD", "password"
# "PAE", "parameter"
# "PAE", "petabyte"
# "PAE", "page-description layer"
# "PAE", "preventive maintenance"
# "PAE", "Presentation Manager"
# "PAE", "personal message"
# "PAE", "power management"
# "PAE", "private message"
# "PAE", "pseudomachine"
# "PAE", "Proof-of-Stake"
# "PAE", "press release"
# "PAE", "Pagerank"
# "PAE", "print formatted"
# ...
# "PPP", "PlayStation Portable"
# "PPPoE", "Photoshop Document"
# "PPPoE", "PlayStation Portable"
# "PPS", "power supply"
# "PPS", "PowerShell"
# "PPS", "print screen"
# "PPS", "Personal System/2"
# "PPS", "Personal Store"
# "PPS", "pseudoterminal slave"
# "PPS", "pseudoterminal"
# "PPS", "password"
# "PPS", "password"
# "PP", "PowerPoint"
# "PP", "Pagerank"
# "PP", "printer"
# "PP", "PowerShell"
# "PP", "PlayStation Portable"
# "PP", "pseudoterminal"
# "PP", "password"
# "PP", "password"
# "PP", "pixel"
# "PPT", "printer"
# "PPT", "PlayStation Portable"
# "PPT", "pseudoterminal"
# "PPTP", "PlayStation Portable"
# "PR", "Parameter RAM"
# "PR", "printer"
# "PR", "PowerShell"
# "PR", "pseudoterminal"
# "PR", "password"
# "PR", "password"
# "PR", "Parameter RAM"
# "PR", "printer"
# "PR", "PowerShell"
# "PR", "pseudoterminal"
# "PR", "password"
# "PR", "password"
# "PRAM", "Private Message"
# "PRAM", "programmable read-only memory"
# "PRN", "print screen"
# "PRN", "pseudoterminal"
# "PRN", "PlayerUnknown's Battlegrounds"
# "Proglog", "Programming in Logic"
# "PS", "Personal System/2"
# "PS", "Personal Store"
# "PS", "pseudoterminal slave"
# "PS", "pseudoterminal"
# "PS", "password"
# "PS", "password"
# "PS", "Personal System/2"
# "PS", "Personal Store"
# "PS", "pseudoterminal slave"
# "PS", "pseudoterminal"
# "PS", "password"
# "PS", "password"
# "PS", "Personal System/2"
# "PS", "Personal Store"
# "PS", "pseudoterminal slave"
# "PS", "pseudoterminal"
# "PS", "password"
# "PS", "password"
# "PS/2", "PlayStation 2"
# "PSAT", "Pacific Standard Time"
# "PSAT", "PlayerUnknown's Battlegrounds"
# "PSD", "pseudoterminal"
# "PSD", "password"
# "PSD", "password"
# "PSR", "Personal Store"
# "PSR", "pseudoterminal"
# "PSR", "password"
# "PSR", "password"
# "PST", "pseudoterminal"
# "PST", "pseudoterminal"
# "PST", "pseudoterminal"
# "PSTN", "pseudoterminal"
# "PSTN", "PlayerUnknown's Battlegrounds"
# "PSU", "pseudoterminal"
# "PSU", "physical unit"
# "PTR", "pseudoterminal"
# "PTR", "PlayerUnknown's Battlegrounds"
# "PTS", "PlayerUnknown's Battlegrounds"
# "PW", "password"
# "Q&A", "quality assurance"
# "Q&A", "questions and answers"
# "QA", "questions and answers"
# "QIC", "quality of service"
# "RAD", "rate-adaptive DSL"
# "RAD", "run commands"
# "RAD", "release candidate"
# "RAD", "Recommended Standard-449"
# "RADSL", "row address select"
# "RAID", "release candidate"
# "RAM", "read-only memory"
# "RAM", "real-time"
# "RAR", "remark"
# "RAR", "Recommended Standard-449"
# "RAS", "run commands"
# "RAS", "release"
# "RAS", "real-time strategy"
# "RAS", "run commands"
# "RAS", "release"
# "RAS", "real-time strategy"
# "RAS", "run commands"
# "RAS", "release"
# "RAS", "real-time strategy"
# "RAS", "run commands"
# "RAS", "release"
# "RAS", "real-time strategy"
# "RAT", "release candidate"
# "RAT", "request for information"
# "RAT", "read-only terminal"
# "RAT", "real-time"
# "RAT", "real-time strategy"
# "RAT", "received data"
# "RBL", "red-green-blue"
# "RC", "receive"
# "RC", "Record"
# "RC", "Request for Comments"
# "RC", "real-time clock"
# "RC", "receive"
# "RC", "Record"
# "RC", "Request for Comments"
# "RC", "real-time clock"
# "RC", "receive"
# "RC", "Record"
# "RC", "Request for Comments"
# "RC", "real-time clock"
# "RC", "receive"
# "RC", "Record"
# "RC", "Request for Comments"
# "RC", "real-time clock"
# "RCE", "receive"
# "RCE", "Request for Comments"
# "RCE", "receive"
# "RCE", "Request for Comments"
# "RCE", "receive"
# "RCE", "Request for Comments"
# "RCS", "Request for Comments"
# "RCS", "Recommended Standard-449"
# "RDBMS", "report distribution management system"
# "RDF", "radio frequency"
# "Rec.", "Record"
# "Rec.", "radio frequency"
# "Rec.", "Request for Comments"
# "Rec.", "run-length encoding"
# "Rec.", "real-time clock"
# "REC", "radio frequency"
# "REC", "Request for Comments"
# "REC", "run-length encoding"
# "REC", "real-time clock"
# "Rel", "read-eval-print loop"
# "Rel", "red-green-blue"
# "Rel", "real-life"
# "Rel", "read-only terminal"
# "Rel", "real-time"
# "REM", "read-only memory"
# "REM", "read-only terminal"
# "REM", "real-time"
# "RF", "real-life"
# "RFI", "radio frequency identification"
# "RFI", "radio frequency identification"
# "RFID", "radio frequency shielding"
# "RIAA", "received data"
# "RL", "real-time"
# "RLE", "run-length limited encoding"
# "RLE", "real-time"
# "RMA", "read-only terminal"
# "RMS", "Recommended Standard-449"
# "RMS", "real-time strategy"
# "RRAS", "Real-time Operating System"
# "RRAS", "real-time strategy"
# "RRD", "Recommended Standard-449"
# "RRD", "received data"
# "RSAT", "real-time strategy"
# "RSAT", "real-time strategy"
# "RTOS", "Request to Send"
# "RTR", "real-time strategy"
# "SaaS", "Standalone Server"
# "SaaS", "Serial Attached SCSI"
# "SaaS", "system management server"
# "SaaS", "storage management subsystem"
# "SACD", "sealed lead-acid"
# "SACD", "SmartMedia card"
# "SAN", "serial number"
# "SAN", "simulation"
# "SAN", "service-level agreement"
# "SAN", "specification"
# "SAN", "small-scale integration"
# "SAN", "system generation"
# "SANE", "search engine"
# "SANE", "serial number"
# "SANE", "signal interrupt"
# "SANE", "Signals Intelligence"
# "SANE", "small-scale integration"
# "SAS", "subnetwork mask"
# "SAS", "subnetwork mask"
# "SATA", "self-extracting archive"
# "SATA", "start of authority"
# "SATA", "small-scale integration"
# "SATAN", "small-scale integration"
# "SATAN", "software test plan"
# "SBE", "serial number"
# "SC", "SmartMedia card"
# "SC", "source code"
# "SC", "specification"
# "SC", "subscript"
# "SC", "superscript"
# "SC", "synchronize"
# "SC", "synchronize"
# "SC", "SmartMedia card"
# "SC", "source code"
# "SC", "specification"
# "SC", "subscript"
# "SC", "superscript"
# "SC", "synchronize"
# "SC", "synchronize"
# "SC", "SmartMedia card"
# "SC", "source code"
# "SC", "specification"
# "SC", "subscript"
# "SC", "superscript"
# "SC", "synchronize"
# "SC", "synchronize"
# "SCA", "self-extracting archive"
# "SCA", "service-level agreement"
# "SCA", "socket adapter"
# "SCA", "SmartMedia card"
# "SCA", "service-oriented architecture"
# "SCA", "specification"
# "SCC", "service-oriented architecture"
# "SCC", "source code"
# "SCC", "specification"
# "SCSI", "symmetric multiprocessing"
# "SCSI", "service set identifier"
# "SD", "synchronous DRAM"
# "SD", "symmetrical DSL"
# "SD", "speech-generating device"
# "SD", "solid-state drive"
# "SD", "Suspend-to-RAM"
# "SD", "synchronous DRAM"
# "SD", "symmetrical DSL"
# "SD", "speech-generating device"
# "SD", "solid-state drive"
# "SD", "Suspend-to-RAM"
# "SD", "synchronous DRAM"
# "SD", "symmetrical DSL"
# "SD", "speech-generating device"
# "SD", "solid-state drive"
# "SD", "Suspend-to-RAM"
# "SD", "synchronous DRAM"
# "SD", "symmetrical DSL"
# "SD", "speech-generating device"
# "SD", "solid-state drive"
# "SD", "Suspend-to-RAM"
# "SDLC", "sealed lead-acid"
# "SDLC", "sealed lead-acid"
# "SDRAM", "Suspend-to-RAM"
# "SE", "s-expression"
# "SE", "sound effects"
# "SE", "special effects"
# "SE", "signature"
# "SE", "Solitaire"
# "SE", "spelling"
# "SE", "specification"
# "SE", "Suspend-to-RAM"
# "SE", "superscript"
# "SE", "software"
# "SE", "synchronize"
# "SE", "synchronize"
# "SE", "synthesizer"
# "SE", "s-expression"
# "SE", "sound effects"
# "SE", "special effects"
# "SE", "signature"
# "SE", "Solitaire"
# "SE", "spelling"
# "SE", "specification"
# "SE", "Suspend-to-RAM"
# "SE", "superscript"
# "SE", "software"
# "SE", "synchronize"
# "SE", "synchronize"
# "SE", "synthesizer"
# "SEA", "service-level agreement"
# "SEA", "sealed lead-acid"
# "SEA", "socket adapter"
# "SEA", "service-oriented architecture"
# "SEA", "super operator"
# "SEA", "specification"
# "SEA", "small-scale integration"
# "SEA", "solid-state relay"
# "SEA", "supertwisted nematic"
# "SEA", "Suspend-to-RAM"
# "SEA", "system generation"
# "SEA", "system operator"
# "SECC", "service-oriented architecture"
# "SECC", "specification"
# "SEO", "s-expression"
# "SEO", "Surface-mount Technology"
# "SEO", "super operator"
# "SEO", "specification"
# "SEO", "small-scale integration"
# "SEO", "Suspend-to-RAM"
# "SEO", "Super Video"
# "SEO", "system generation"
# "SEO", "system operator"
# "SERP", "signal interrupt"
# "SERP", "storage service provider"
# "SERP", "superscript"
# "Servlet", "service-level agreement"
# "SETI", "System Management Interrupt"
# "SETI", "symmetric multiprocessing"
# "SETI", "specification"
# "SETI", "system packet interface"
# "SETI", "small-scale integration"
# "SETI", "supertwisted nematic"
# "SETI", "system generation"
# "Setuid", "set user ID"
# "SFF", "sound effects"
# "SFF", "special effects"
# "SFTP", "software test plan"
# "SFTP", "software test plan"
# "SFW", "software"
# "SGML", "systems programming language"
# "Sig", "Signals Intelligence"
# "Sig", "symmetric multiprocessing"
# "Sig", "spelling"
# "Sig", "small-scale integration"
# "Sim", "symmetric multiprocessing"
# "SIO", "symmetric multiprocessing"
# "SIO", "specification"
# "SIO", "small-scale integration"
# "SIO", "Super Video"
# "SIO", "system generation"
# "SIP", "symmetric multiprocessing"
# "SIP", "standard input"
# "SIP", "subscript"
# "SIP", "superscript"
# "SLA", "Solitaire"
# "SLA", "solid-state relay"
# "SLA", "Solitaire"
# "SLA", "solid-state relay"
# "SLI", "secure login"
# "SLI", "symmetric multiprocessing"
# "SLI", "Solitaire"
# "SLI", "spelling"
# "SLI", "small-scale integration"
# "SLIP", "symmetric multiprocessing"
# "SLSI", "symmetric multiprocessing"
# "SLSI", "small-scale integration"
# "SMAR", "SmartMedia card"
# "SMAR", "System Management RAM"
# "SMAR", "system operator"
# "SMART", "System Management Interrupt"
# "SMART", "small-scale integration"
# "SMB", "System Management Bus"
# "SMB", "spam blogs"
# "SMB", "System Management Bus"
# "SMB", "spam blogs"
# "SMB", "System Management Bus"
# "SMB", "spam blogs"
# "SMI", "symmetric multiprocessing"
# "SMI", "small-scale integration"
# "SMI", "supertwisted nematic"
# "SMI", "symmetric multiprocessing"
# "SMI", "small-scale integration"
# "SMI", "supertwisted nematic"
# "SMIL", "systems programming language"
# "SMM", "symmetric multiprocessing"
# "SMS", "subnetwork mask"
# "SMS", "subnetwork mask"
# "SMS", "subnetwork mask"
# "SMT", "supertwisted nematic"
# "SNA", "service-oriented architecture"
# "SNA", "small-scale integration"
# "SNA", "supertwisted nematic"
# "SNA", "Suspend-to-RAM"
# "SNA", "system generation"
# "SOA", "Solitaire"
# "SOA", "super operator"
# "SOA", "Suspend-to-RAM"
# "SOA", "software"
# "SOA", "system operator"
# "SOA", "Solitaire"
# "SOA", "super operator"
# "SOA", "Suspend-to-RAM"
# "SOA", "software"
# "SOA", "system operator"
# "SoC", "source code"
# "SOI", "Solitaire"
# "SOI", "synchronize"
# "SOI", "synchronize"
# "SONET", "Spam over Internet Telephony"
# "SOP", "system operator"
# "SP", "specification"
# "SP", "Suspend-to-RAM"
# "SP", "subscript"
# "SP", "superscript"
# "SPARC", "system packet interface"
# "SPARC", "serial peripheral interface"
# "SPD", "Suspend-to-RAM"
# "Spec", "system packet interface"
# "Spec", "serial peripheral interface"
# "Spec", "supertwisted nematic"
# "Spec", "superscript"
# "SPI", "superscript"
# "SPI", "superscript"
# "SPI", "superscript"
# "Spit", "superscript"
# "Spool", "Synchronous Transport Module"
# "SPP", "superscript"
# "SPS", "superscript"
# "SRAM", "Synchronous Transport Module"
# "SRAM", "Suspend-to-RAM"
# "SS", "Suspend-to-RAM"
# "SS", "subscript"
# "SS", "superscript"
# "SS", "software"
# "SS", "synchronize"
# "SS", "synchronize"
# "SS", "synthesizer"
# "SSD", "Suspend-to-RAM"
# "SSE", "Suspend-to-RAM"
# "SSE", "superscript"
# "SSE", "software"
# "SSE", "synchronize"
# "SSE", "synchronize"
# "SSE", "synthesizer"
# "SSEM", "supertwisted nematic"
# "SSEM", "Suspend-to-RAM"
# "SSEM", "subnetwork mask"
# "SSI", "service set identifier"
# "SSI", "standard input"
# "SSI", "subscript"
# "SSI", "superscript"
# "SSI", "synchronize"
# "SSI", "synchronize"
# "SSI", "synthesizer"
# "SSID", "storage service provider"
# "SSID", "Super Video"
# "SSL", "system log"
# "SSL", "system log"
# "SSP", "Suspend-to-RAM"
# "SSP", "subscript"
# "SSP", "superscript"
# "SSR", "Suspend-to-RAM"
# "SSR", "subscript"
# "SSR", "superscript"
# "SSR", "software"
# "SSR", "synchronize"
# "SSR", "synchronize"
# "SSR", "synthesizer"
# "SSR", "system request"
# "SSTP", "software test plan"
# "SSTP", "shielded twisted pair"
# "SSTP", "Spanning Tree Protocol"
# "STM", "Suspend-to-RAM"
# "STM", "subnetwork mask"
# "STN", "system generation"
# "STR", "software"
# "STR", "synthesizer"
# "STR", "system operator"
# "STR", "system request"
# "STS", "synthesizer"
# "SUID", "Super Video"
# "SYN", "synchronize"
# "SYN", "synthesizer"
# "TA", "Tantalum"
# "TA", "tape archive"
# "TA", "Titanium"
# "TA", "trademark"
# "TA", "terminate-and-stay-resident"
# "Ta", "tape archive"
# "Ta", "Titanium"
# "Ta", "trademark"
# "Ta", "terminate-and-stay-resident"
# "TAPI", "thread-level parallelism"
# "TAPI", "tracks per inch"
# "TAR", "thread-level parallelism"
# "TAR", "trademark"
# "TAR", "technical report"
# "TAR", "transfer resistance"
# "TAR", "terminate-and-stay-resident"
# "TCO", "technology"
# "TD", "team deathmatch"
# "TD", "top-level domain"
# "TD", "trademark"
# "TD", "terminate-and-stay-resident"
# "TD", "trasmit data"
# "TDD", "terminate-and-stay-resident"
# "TDM", "top-level domain"
# "TDM", "trademark"
# "TDP", "thread-level parallelism"
# "Tech", "text-to-speech"
# "TERA", "thread-level parallelism"
# "TERA", "transfer resistance"
# "TERA", "terminate-and-stay-resident"
# "TET", "texture element"
# "TET", "Textas Instruments"
# "TET", "twisted nematic"
# "TET", "technical report"
# "TET", "transfer resistance"
# "TET", "terminate-and-stay-resident"
# "TET", "Turing test"
# "TET", "text-to-speech"
# "TET", "teletypewriter"
# "TET", "teletype"
# "TH", "text-to-speech"
# "Ti", "toolkit"
# "Ti", "terminate-and-stay-resident"
# "Ti", "teletypewriter"
# "Ti", "television"
# "Ti", "toolkit"
# "Ti", "terminate-and-stay-resident"
# "Ti", "teletypewriter"
# "Ti", "television"
# "Ti", "toolkit"
# "Ti", "terminate-and-stay-resident"
# "Ti", "teletypewriter"
# "Ti", "television"
# "Tk", "trademark"
# "TLP", "teletypewriter"
# "TLP", "teletype"
# "TLS", "television"
# "TM", "terminate-and-stay-resident"
# "TN", "terminate-and-stay-resident"
# "TN", "television"
# "TOPS", "tape operating system"
# "Tor", "technical report"
# "TOS", "text-to-speech"
# "TOS", "text-to-speech"
# "TOS", "text-to-speech"
# "TOS", "text-to-speech"
# "TPI", "teletypewriter"
# "TR", "transfer resistance"
# "TR", "terminate-and-stay-resident"
# "TR", "teletypewriter"
# "TRS", "terminate-and-stay-resident"
# "TT", "text-to-speech"
# "TT", "teletypewriter"
# "TT", "teletype"
# "TT", "television"
# "TTL", "teletypewriter"
# "TTL", "teletype"
# "TTL", "television"
# "TTS", "television"
# "UA", "uppercase"
# "UA", "upload"
# "UA", "upload"
# "UA", "ultraviolet"
# "UAC", "user interface"
# "UAC", "Universal Automatic Computer"
# "UCE", "user interface"
# "UCE", "Unix-to-Unix encode"
# "UCE", "user experience"
# "UDID", "unidirectional DSL"
# "UI", "uplink"
# "UI", "ultraviolet"
# "U/L", "uplink"
# "U/L", "upload"
# "U/L", "unordered list"
# "U/L", "ultraviolet"
# "UL", "ultraviolet"
# "UL", "ultraviolet"
# "UL", "ultraviolet"
# "UPC", "user experience"
# "UPI", "user experience"
# "URC", "user experience"
# "URI", "ultraviolet"
# "URI", "user experience"
# "URL", "ultraviolet"
# "URN", "user experience"
# "USR", "Universal Synchronous Receiver-Transmitter"
# "UT", "ultraviolet"
# "VA", "Valve Anti-Cheat"
# "VA", "VideoLAN"
# "VA", "voicemail"
# "VAC", "Visual Basic"
# "VAC", "virtual circuit"
# "VAC", "virtual machine"
# "VAC", "valve-regulated lead-acid"
# "VADSL", "value-added reseller"
# "VAN", "VideoLAN"
# "VAN", "very-large-scale integration"
# "VAN", "virtual machine"
# "VAR", "virtual reality"
# "VB", "variable bitrate"
# "VBR", "Virtual YouTuber"
# "VC", "voicemail"
# "VC", "voicemail"
# "VC", "voicemail"
# "VC", "voicemail"
# "VCEG", "very-large-scale integration"
# "VCEG", "very-large-scale integration"
# "VCI", "very-large-scale integration"
# "VCI", "voicemail"
# "VCI", "virtual machine"
# "VCI", "valve-regulated lead-acid"
# "VDC", "valve-regulated lead-acid"
# "VDD", "valve-regulated lead-acid"
# "Ver", "very-large-scale integration"
# "Ver", "virtual memory"
# "Ver", "versus"
# "Ver", "Virtual YouTuber"
# "VGA", "very-large-scale integration"
# "VGA", "very-large-scale integration"
# "Vhost", "Video Home System"
# "VIM", "voicemail"
# "VIM", "virtual memory"
# "VIM", "virtual machine"
# "VLAN", "VideoLAN"
# "VLAN", "very-large-scale integration"
# "VLAN", "virtual machine"
# "VLB", "Vesa Local Bus"
# "VLC", "valve-regulated lead-acid"
# "VLSI", "Visual Studio"
# "VR", "versus"
# "VRAM", "voltage regulator module"
# "W", "Wake-on-LAN"
# "W", "WordPress"
# "WAN", "web application"
# "WAN", "Wired for Management"
# "WAN", "Wake-on-LAN"
# "WAP", "web application"
# "WCN", "web application"
# "WD", "WordPress"
# "WD", "WordPress"
# "WD", "WordPress"
# "WEP", "write pre-comp"
# "WP", "write pre-comp"
# "WP", "write pre-comp"
# 2632 FALSE POSITIVE detections out of 1695149 created false examples

# %%
b = calc_fn(check_wether_abbv_is_proper_short_form_of_term)
print(b)
# Out:
# "ADC", "analog-to-digital"
# ##################################
# "AIX", "advanced interactive executive"
# ##################################
# "APK", "Android package file"
# ##################################
# "ARCnet", "Attached Resource Computer network"
# ##################################
# "ARPANET", "Advanced Research Projects Agency Network"
# ##################################
# "ARQ", "automatic repeat request"
# ##################################
# "ASN.1", "abstract syntax number one"
# ##################################
# "ATX", "Advanced Technology eXtended"
# ##################################
# "B2B", "business-to-business"
# ##################################
# "B2B", "business-to-consumer"
# ##################################
# "Basic", "Beginners All-purpose Symbolic Instruction Code"
# ##################################
# "BDF", "Glyph Bitmap Distribution Format"
# ##################################
# "Br", "Break key"
# ##################################
# "BTX", "Balanced Technology eXtended"
# ##################################
# "Cab", "Cabinet file"
# ##################################
# "CAPTCHA", "Completely Automated Public Turing test to tell Computers and Humans Apart"
# ##################################
# "CCITT", "Comit Consultatif International Tlphonique et Tlgraphique"
# ##################################
# "CDA", "compact audio disc"
# ##################################
# "CD-i", "Compact Disc Interactive"
# ##################################
# "CD-R", "Compact Disc Recordable"
# ##################################
# "CD-ROM XA", "CD-ROM extended architecture"
# ##################################
# "CentOS", "Community Enterprise Operating System"
# ##################################
# "CERN", "Conseil Europeen pour la Recherche Nuclaire"
# ##################################
# "CLCC", "ceramic leadless lead carrier"
# ##################################
# "CMYK", "cyan magenta yellow black"
# ##################################
# "Code", "source code"
# ##################################
# "Coil", "electromagnetic coil"
# ##################################
# "CompTIA", "Computer Technology Industry Association"
# ##################################
# "Core", "core dump"
# ##################################
# "CPM", "cost per thousand"
# ##################################
# "CPTM", "cost per targeted thousand"
# ##################################
# "Ctrl", "Control key"
# ##################################
# "D2D", "disk-to-disk"
# ##################################
# "DART", "Microsoft Diagnostics and Recovery Toolset"
# ##################################
# "DDR2", "double data rate two"
# ##################################
# "DDR3", "double data rate three"
# ##################################
# "DDR4", "double data rate four"
# ##################################
# "DFMC", "direct methanol fuel cell"
# ##################################
# "DIVX", "digital video express"
# ##################################
# "DoS", "denial of service"
# ##################################
# "Double", "Double-precision floating-point"
# ##################################
# "Dpkg", "Debian package manager"
# ##################################
# "Drop", "malware dropper"
# ##################################
# "DTX", "discontinuous transmission"
# ##################################
# "DUST", "did you see that"
# ##################################
# "EAP-FAST", "Flexible Authentication via Secure Tunneling"
# ##################################
# "Eb / EB", "Exabit / Exabyte"
# ##################################
# "ETA-I", "Electronic Technicians Association International"
# ##################################
# "exFAT", "Extended File Allocation Table"
# ##################################
# "FCIP", "Fibre Channel over IP"
# ##################################
# "Flash", "Adobe Flash"
# ##################################
# "FNR", "format and restore"
# ##################################
# "FSO", "free-space optical communication"
# ##################################
# "G+", "Google Plus"
# ##################################
# "G2G", "government to government"
# ##################################
# "Gb / GB", "gigabit / gigabyte"
# ##################################
# "GCHQ", "Government Communications Headquarters"
# ##################################
# "Gib / GiB", "gibibit / gibibyte"
# ##################################
# "GIGO", "&quot;garbage in, garbage out&quot;"
# ##################################
# "Goat", "greatest of all time"
# ##################################
# "Gram", "Instagram"
# ##################################
# "GSM", "Global System for Mobile communication"
# ##################################
# "GT", "Greenwich Mean Time"
# ##################################
# "HEIF", "High Efficiency Image File format"
# ##################################
# "Huh", "Have you heard"
# ##################################
# "IDSL", "integrated services digital network digital subscriber line"
# ##################################
# "INCITS", "International Committee for Information Technology Standards"
# ##################################
# "Inetd", "Internet service daemon"
# ##################################
# "IPX/SPX", "Internetwork Packet Exchange/Sequenced Packet Exchange"
# ##################################
# "IrDA", "Infrared Data Association"
# ##################################
# "ISO", "International Organization for Standardization"
# ##################################
# "ITX", "Information Technology eXtended"
# ##################################
# "Java EE", "Java Platform, Enterprise Edition"
# ##################################
# "JDBC", "Java Database Connectivity"
# ##################################
# "JHTML", "Java within HTML"
# ##################################
# "JSON", "JavaScript Object Notation"
# ##################################
# "JSR", "jump to subroutine"
# ##################################
# "kb / kbit", "kilobit"
# ##################################
# "kilo", "one thousand"
# ##################################
# "L2", "level 2 cache"
# ##################################
# "L2P", "learn to play"
# ##################################
# "LAME", "LAME ain't an MP3 encoder"
# ##################################
# "Laser", "light amplification by stimulated emission of radiation"
# ##################################
# "LE", "Less than or Equal to"
# ##################################
# "LED monitor", "light-emitting diode"
# ##################################
# "Lo-res / low-res", "low-resolution"
# ##################################
# "LPX", "Low Profile eXtension"
# ##################################
# "M-", "meta key"
# ##################################
# "Matrix", "Matrix code"
# ##################################
# "MBAM", "Malwarebytes"
# ##################################
# "MDBMS", "Multidimensional Database Management System"
# ##################################
# "MMX", "MultiMedia eXtension"
# ##################################
# "Model no.", "model number"
# ##################################
# "MPLS", "Multiprotocol Label Switching"
# ##################################
# "MS-DOS", "Microsoft Disk Operating System"
# ##################################
# "MSN", "The Microsoft Network"
# ##################################
# "Mutex", "mutual exclusion object"
# ##################################
# "MX record", "Mail eXchange record"
# ##################################
# "NDR", "non-active, dormant, to be removed"
# ##################################
# "NetBEUI", "NetBIOS Enhanced User Interface"
# ##################################
# "Nimrod", "National Institute Machine Radiating On Downs"
# ##################################
# "NLS", "online system"
# ##################################
# "NLX", "New Low Profile Extended"
# ##################################
# "ODBC", "Open Database Connectivity"
# ##################################
# "OO", "object-oriented or OpenOffice"
# ##################################
# "Open", "open source"
# ##################################
# "OR", "OR operator"
# ##################################
# "OVR", "overtype mode"
# ##################################
# "P2W", "pay-to-win"
# ##################################
# "PATA", "Parallel AT Attachment"
# ##################################
# "PBX", "private branch exchange"
# ##################################
# "PBX", "private branch extension"
# ##################################
# "PCIe", "PCI Express"
# ##################################
# "PCI-X", "Peripheral Component Interconnect Extended"
# ##################################
# "PHP", "Hypertext Preprocessor"
# ##################################
# "PII", "Pentium 2"
# ##################################
# "Plus", "Microsoft Plus!"
# ##################################
# "PnP", "Plug and Play"
# ##################################
# "POSIX", "Portable operating system interface for Unix"
# ##################################
# "PRISM", "Synchronization"
# ##################################
# "PRISM", "Planning Tool for Resource Integration,  and Management"
# ##################################
# "PSoC", "programmable system on a chip"
# ##################################
# "PTY", "pseudoterminal"
# ##################################
# "PXE", "preboot execution environment"
# ##################################
# "PXI", "PCI extensions for instrumentation"
# ##################################
# "QoS", "quality of service"
# ##################################
# "QSXGA", "Quad Super Extended Graphics Array"
# ##################################
# "ReFS", "Resilient File System"
# ##################################
# "RPM", "Red Hat Package Manager"
# ##################################
# "RUT", "are you there?"
# ##################################
# "RXD", "received data"
# ##################################
# "S2R", "send to receive"
# ##################################
# "SATA", "Serial AT Attachment"
# ##################################
# "SDHC card", "Secure Digital High Capacity card"
# ##################################
# "Serial no.", "serial number"
# ##################################
# "Servlet", "Java servlet"
# ##################################
# "SETI", "Search for Extraterrestrial Intelligence"
# ##################################
# "Setuid", "set user ID on execution"
# ##################################
# "Sexp or sexpr", "s-expression"
# ##################################
# "SFX", "sound effects"
# ##################################
# "SFX", "special effects"
# ##################################
# "SIM card", "Subscriber Identity Module card"
# ##################################
# "Slotket", "socket adapter"
# ##################################
# "SMBus", "System Management Bus"
# ##################################
# "SMRAM", "System Management RAM"
# ##################################
# "SoC", "system on a chip"
# ##################################
# "S/PDIF", "Sony and Phillips Digital Interconnect Format"
# ##################################
# "SPIM", "spam over instant message"
# ##################################
# "Spit", "Spam over Internet Telephony"
# ##################################
# "SS", "screenshot, South Sudan"
# ##################################
# "Subnet", "subnetwork mask"
# ##################################
# "SXGA", "Super Extended Graphics Array"
# ##################################
# "SXGA+", "Super XGA Plus"
# ##################################
# "TDD", "telecommunications device for the deaf"
# ##################################
# "T&amp;L", "transform, clipping, and lighting"
# ##################################
# "Tor", "The Onion Router"
# ##################################
# "TOS", "terms of use"
# ##################################
# "Transistor", "transfer resistance"
# ##################################
# "TXD", "trasmit data"
# ##################################
# "Uarch", "microarchitecture"
# ##################################
# "UNIVAC", "Universal Automatic Computer"
# ##################################
# "UPnP", "Universal Plug and Play"
# ##################################
# "UTC", "Coordinated Universal Time"
# ##################################
# "UTP", "unshielded twisted pair cable"
# ##################################
# "UX", "user experience"
# ##################################
# "UXGA", "Ultra Extended Graphics Array"
# ##################################
# "VADSL", "very high bit rate asymmetric digital subscriber line"
# ##################################
# "VBScript", "Microsoft Visual Basic Scripting Edition"
# ##################################
# "VDD", "virtual device driver, virtual disk drive"
# ##################################
# "VDSL", "very high data rate DSL"
# ##################################
# "Veronica", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# ##################################
# "VL Bus", "Vesa Local Bus"
# ##################################
# "VLC", "VideoLAN"
# ##################################
# "VoMM", "eVade o' Matic Module"
# ##################################
# "W3C", "World Wide Web Consortium"
# ##################################
# "WBEM", "Web-based Enterprise Management"
# ##################################
# "WiMAX", "Worldwide Interoperability for Microwave Access"
# ##################################
# "WQXGA", "Wide Quad Extended Graphics Array"
# ##################################
# "WSXGA", "Widescreen Super eXtended Graphics Array"
# ##################################
# "X", "X Window System"
# ##################################
# "X11", "X Window System"
# ##################################
# "XDF", "extended density format"
# ##################################
# "XGA", "Extended Graphics Array"
# ##################################
# "XHTML", "Extensible Hypertext markup Language"
# ##################################
# "XML", "Extensible Markup Language"
# ##################################
# "XMPP", "Extensible Messaging and Presence Protocol"
# ##################################
# "XMS", "extended memory specification"
# ##################################
# "XSL", "Extensible Stylesheet Language"
# ##################################
# "XSLT", "Extensible Stylesheet Language Transformations"
# ##################################
# "XSS", "cross-site scripting"
# ##################################
# "XT", "extended technology"
# ##################################
# 191 FALSE NEGATIVES. Pairs that could not be detected out of 1842 given pairs

# %%
a = calc_fp(match_rating_comparison)
print(a)
# Out:
# "AAC", "account"
# "AAC", "icon"
# "AAC", "receive"
# "AAM", "ampere"
# "AAM", "maximum"
# "AAM", "minimum"
# "AAM", "Titanium"
# "AAS", "Celsius"
# "AAS", "release"
# "AAS", "user"
# "AAS", "versus"
# "AAS", "Celsius"
# "AAS", "release"
# "AAS", "user"
# "AAS", "versus"
# "ABC", "automobile"
# "ABC", "automatic"
# "ABC", "kibibit"
# "ABC", "mebibit"
# "ABC", "Tebi"
# "Abend", "Advanced BIOS"
# "Abend", "account"
# "Abend", "absolute cell reference"
# "Abend", "ampere"
# "Abend", "as soon as possible"
# "Abend", "autonomous system number"
# "Abend", "above the fold"
# "Abend", "Advanced Technology eXtended"
# "Abend", "autonomous"
# "Abend", "avatar"
# "Abend", "broadband"
# "Abend", "class ID"
# "Abend", "source code"
# "Abend", "download"
# "Abend", "download"
# "Abend", "Gigabits per second"
# "Abend", "kibibyte"
# "Abend", "line feed"
# "Abend", "memorandum"
# "Abend", "mebibyte"
# "Abend", "NOT NULL"
# "Abend", "nanosecond"
# "Abend", "Record"
# "Abend", "source code"
# "Abend", "table data"
# "Abend", "table head"
# "Abend", "upload"
# "Abend", "upload"
# "Abend", "XP mode"
# "ABIOS", "Autofocus"
# "ABIOS", "automobile"
# "ABIOS", "autonomous"
# "ABIOS", "Celsius"
# "ABIOS", "database"
# "ABIOS", "kibibit"
# "ABIOS", "mebibit"
# "ABIOS", "release"
# "ABIOS", "Tebi"
# "ABIOS", "versus"
# "ABP", "ampere"
# "ABP", "automobile"
# "ABP", "kibibit"
# "ABP", "mebibit"
# "ABP", "page up"
# "ABP", "Tebi"
# "AC", "account"
# "AC", "icon"
# "AC", "receive"
# "AC", "account"
# "AC", "icon"
# "AC", "receive"
# "AC", "account"
# "AC", "icon"
# "AC", "receive"
# "ACCT", "Autofocus"
# "ACCT", "avatar"
# "ACCT", "Baby AT"
# "ACCT", "icon"
# "ACCT", "kibibit"
# "ACCT", "mebibit"
# "ACCT", "object"
# "ACCT", "picture"
# "ACCT", "receive"
# "ACCT", "received data"
# "ACE", "icon"
# "ACE", "receive"
# "Ack", "Autofocus"
# "Ack", "facebook"
# "Ack", "icon"
# "Ack", "receive"
# "ACL", "Autofocus"
# "ACL", "automobile"
# "ACL", "icon"
# "ACL", "Local user"
# "ACL", "level"
# "ACL", "milli"
# "ACL", "manual"
# "ACL", "modulo"
# "ACL", "pixel"
# "ACL", "receive"
# "ACL", "voicemail"
# "ACM", "Autofocus"
# "ACM", "automobile"
# "ACM", "automatic"
# "ACM", "icon"
# "ACM", "maximum"
# "ACM", "minimum"
# "ACM", "receive"
# "ACM", "Titanium"
# "ACM", "voicemail"
# "ACPI", "Autofocus"
# "ACPI", "ampere"
# "ACPI", "icon"
# "ACPI", "page up"
# "ACPI", "receive"
# "ACR", "Autofocus"
# "ACR", "ampere"
# "ACR", "avatar"
# "ACR", "feature"
# "ACR", "GeForce"
# "ACR", "icon"
# "ACR", "Local user"
# "ACR", "picture"
# "ACR", "receive"
# "ACR", "Record"
# "ACR", "user"
# "ACR", "Autofocus"
# "ACR", "ampere"
# "ACR", "avatar"
# "ACR", "feature"
# "ACR", "GeForce"
# "ACR", "icon"
# "ACR", "Local user"
# "ACR", "picture"
# "ACR", "receive"
# "ACR", "Record"
# "ACR", "user"
# "ACR", "Autofocus"
# "ACR", "ampere"
# "ACR", "avatar"
# "ACR", "feature"
# "ACR", "GeForce"
# "ACR", "icon"
# "ACR", "Local user"
# "ACR", "picture"
# "ACR", "receive"
# "ACR", "Record"
# "ACR", "user"
# "ACR", "Autofocus"
# "ACR", "ampere"
# "ACR", "avatar"
# "ACR", "feature"
# "ACR", "GeForce"
# "ACR", "icon"
# "ACR", "Local user"
# "ACR", "picture"
# "ACR", "receive"
# "ACR", "Record"
# "ACR", "user"
# "ACS", "Autofocus"
# "ACS", "autonomous"
# "ACS", "Celsius"
# "ACS", "In Any Case"
# "ACS", "icon"
# "ACS", "lowercase"
# "ACS", "receive"
# "ACS", "release"
# "ACS", "uppercase"
# "ACS", "versus"
# "AD", "modulo"
# "ADB", "modulo"
# "ADB", "Tebi"
# "ADB", "modulo"
# "ADB", "Tebi"
# "ADC", "automatic"
# "ADC", "source code"
# "ADC", "modulo"
# "ADC", "nanosecond"
# "ADC", "source code"
# "ADO", "modulo"
# "ADPCM", "Autofocus"
# "ADPCM", "advanced interactive executive"
# "ADPCM", "ampere"
# "ADPCM", "Android Open Source Project"
# "ADPCM", "address record"
# "ADPCM", "Address Resolution Protocol"
# "ADPCM", "Advanced Research Projects Agency"
# "ADPCM", "advanced transfer cache"
# "ADPCM", "Adaptive Transform Acoustic Coding"
# "ADPCM", "acceptable use policy"
# "ADPCM", "bad game"
# "ADPCM", "leadless chip carrier"
# "ADPCM", "line printer daemon"
# "ADPCM", "write pre-comp"
# "ADSI", "Autofocus"
# "ADSI", "autonomous"
# "ADSI", "Celsius"
# "ADSI", "class ID"
# "ADSI", "modulo"
# "ADSI", "release"
# "ADSI", "set user ID"
# "ADSI", "versus"
# "ADSI", "Autofocus"
# "ADSI", "autonomous"
# "ADSI", "Celsius"
# "ADSI", "class ID"
# "ADSI", "modulo"
# "ADSI", "release"
# "ADSI", "set user ID"
# "ADSI", "versus"
# "ADSL", "ADSTAR Distributed Storage Management"
# "ADSL", "ampere"
# "ADSL", "advanced packaging tool"
# "ADSL", "Address Resolution Protocol"
# "ADSL", "advanced technology"
# "ADSL", "automobile"
# "ADSL", "avatar"
# "ADSL", "Audio Video Interleaved"
# "ADSL", "bad game"
# "ADSL", "Celsius"
# "ADSL", "Code Division Multiple Access"
# "ADSL", "class ID"
# "ADSL", "console"
# "ADSL", "Adobe Flash"
# "ADSL", "Google Plus"
# "ADSL", "Google Mail"
# "ADSL", "modulo"
# "ADSL", "not equal"
# "ADSL", "NOT NULL"
# "ADSL", "rate-adaptive DSL"
# "ADSL", "release"
# "ADSL", "symmetrical DSL"
# "ADSL", "top of file"
# "ADSL", "Trusted Platform Module"
# "ADSL", "unidirectional DSL"
# "ADSL", "very high data rate DSL"
# "ADSL", "Version"
# "ADSL", "VideoLAN"
# "ADSL", "voicemail"
# "ADSL", "width"
# "ADSL", "Wideband Code Division Multiple Access"
# "ADSM", "AGP in-line memory module"
# "ADSM", "ampere"
# "ADSM", "advanced power management"
# "ADSM", "address and routing parameter area"
# "ADSM", "answer set programming"
# "ADSM", "Advanced Technology Attachment"
# "ADSM", "autonomous"
# "ADSM", "avatar"
# "ADSM", "bad game"
# "ADSM", "class ID"
# "ADSM", "console"
# "ADSM", "core dump"
# "ADSM", "code segment"
# "ADSM", "Adobe Flash"
# "ADSM", "K Desktop Environment"
# "ADSM", "Version"
# "ADSM", "VideoLAN"
# "ADSM", "width"
# "AE lock", "Autofocus"
# "AE lock", "ampere"
# "AE lock", "Attached Resource Computer network"
# "AE lock", "acceptable use policy"
# "AE lock", "avatar"
# "AE lock", "BIOS pattern block"
# "AE lock", "bitcoin"
# "AE lock", "CapsLock"
# "AE lock", "CapsLock"
# "AE lock", "class ID"
# "AE lock", "cyan magenta yellow black"
# "AE lock", "source code"
# "AE lock", "cost per click"
# "AE lock", "electronic book"
# "AE lock", "facebook"
# "AE lock", "file system check"
# "AE lock", "Google Mail"
# "AE lock", "half OP"
# "AE lock", "kilobit"
# "AE lock", "kilobit"
# "AE lock", "pay per click"
# "AE lock", "remark"
# "AE lock", "real-time clock"
# "AE lock", "server message block"
# "AE lock", "Solitaire"
# "AE lock", "source code"
# "AE lock", "toolkit"
# "AE lock", "uplink"
# "AE lock", "upper memory block"
# "AES", "Celsius"
# "AES", "release"
# "AES", "user"
# "AES", "versus"
# "AGP", "ampere"
# "AGP", "megaflop"
# "AGP", "page up"
# "AHCI", "automatic"
# "AIM", "ampere"
# "AIM", "maximum"
# "AIM", "minimum"
# "AIM", "Titanium"
# "AIM", "ampere"
# "AIM", "maximum"
# "AIM", "minimum"
# "AIM", "Titanium"
# "AIML", "ampere"
# "AIML", "automobile"
# "AIML", "autonomous"
# "AIML", "Google Mail"
# "AIML", "level"
# "AIML", "milli"
# "AIML", "manual"
# "AIML", "modulo"
# "AIML", "pixel"
# "AIML", "simulation"
# "AIML", "voicemail"
# "AIMM", "ampere"
# "AIMM", "maximum"
# "AIMM", "minimum"
# "AIMM", "Titanium"
# "AIX", "maximum"
# "AIX", "pixel"
# "ALGOL", "ampere"
# "ALGOL", "automobile"
# "ALGOL", "avatar"
# "ALGOL", "bad game"
# "ALGOL", "call-control signaling "
# "ALGOL", "class ID"
# "ALGOL", "console"
# "ALGOL", "Flexible Authentication via Secure Tunneling"
# "ALGOL", "Flexible Authentication via Secure Tunneling"
# "ALGOL", "Google Plus"
# "ALGOL", "Google Mail"
# "ALGOL", "half OP"
# "ALGOL", "kilobit"
# "ALGOL", "kilobit"
# "ALGOL", "not equal"
# "ALGOL", "not gonna lie"
# "ALGOL", "NOT NULL"
# "ALGOL", "real-life"
# "ALGOL", "Solitaire"
# "ALGOL", "toolkit"
# "ALGOL", "top of file"
# "ALGOL", "voicemail"
# "Alpha", "ampere"
# "Alpha", "avatar"
# "Alpha", "C compiler"
# "Alpha", "class ID"
# "Alpha", "depth"
# "Alpha", "Adobe Flash"
# "Alpha", "Google Plus"
# "Alpha", "Google Mail"
# "Alpha", "half OP"
# "Alpha", "kilobit"
# "Alpha", "kilobit"
# "Alpha", "Solitaire"
# "Alpha", "table head"
# "Alpha", "toolkit"
# "Alpha", "width"
# "ALU", "Boolean"
# "ALU", "Celsius"
# "ALU", "level"
# "ALU", "milli"
# "ALU", "manual"
# "ALU", "modulo"
# "ALU", "pixel"
# "ALU", "release"
# "AM", "ampere"
# "AM", "maximum"
# "AM", "minimum"
# "AM", "Titanium"
# "AM", "ampere"
# "AM", "maximum"
# "AM", "minimum"
# "AM", "Titanium"
# "AMA", "ampere"
# "AMA", "maximum"
# "AMA", "minimum"
# "AMA", "Titanium"
# "AMOLED", "ampere"
# "AMOLED", "above the fold"
# "AMOLED", "automobile"
# "AMOLED", "automatic"
# "AMOLED", "avatar"
# "AMOLED", "C compiler"
# "AMOLED", "compact disc digital audio"
# "AMOLED", "Compact Disc Recordable"
# "AMOLED", "class ID"
# "AMOLED", "source code"
# "AMOLED", "download"
# "AMOLED", "download"
# "AMOLED", "demilitarized zone"
# "AMOLED", "equals"
# "AMOLED", "evaluate"
# "AMOLED", "form feed"
# "AMOLED", "initial program load"
# "AMOLED", "line feed"
# "AMOLED", "modulo"
# "AMOLED", "nanometer"
# "AMOLED", "NT loader"
# "AMOLED", "number"
# "AMOLED", "Power LED"
# "AMOLED", "Record"
# "AMOLED", "remark"
# "AMOLED", "Small Business Edition"
# "AMOLED", "simulation"
# "AMOLED", "source code"
# "AMOLED", "table data"
# "AMOLED", "table head"
# "AMOLED", "upload"
# "AMOLED", "upload"
# "AMOLED", "VideoLAN"
# "AMOLED", "XP mode"
# "Amp", "autonomous"
# "Amp", "C compiler"
# "Amp", "core dump"
# "Amp", "hit me up"
# "Amp", "page up"
# "ANI", "Boolean"
# "ANI", "icon"
# "ANI", "manual"
# "ANI", "minimum"
# "ANI", "opinion"
# "ANI", "Titanium"
# "ANSI", "autonomous"
# "ANSI", "Celsius"
# "ANSI", "console"
# "ANSI", "In Any Case"
# "ANSI", "manual"
# "ANSI", "minimum"
# "ANSI", "release"
# "ANSI", "Titanium"
# "ANSI", "Version"
# "ANSI", "versus"
# "AOP", "opinion"
# "AOP", "page up"
# "AOP", "opinion"
# "AOP", "page up"
# "AOSP", "Google Plus"
# "AOSP", "page up"
# "AOSP", "user"
# "API", "opinion"
# "API", "page up"
# "APIC", "automatic"
# "APIC", "opinion"
# "APIPA", "opinion"
# "APIPA", "page up"
# "APK", "opinion"
# "APK", "uplink"
# "APM", "automobile"
# "APM", "automatic"
# "APM", "hit me up"
# "APM", "maximum"
# "APM", "minimum"
# "APM", "opinion"
# "APM", "Titanium"
# "APM", "XP mode"
# "App", "opinion"
# "App", "page up"
# "APT", "avatar"
# "APT", "Baby AT"
# "APT", "depth"
# "APT", "kibibit"
# "APT", "mebibit"
# "APT", "opinion"
# "APT", "teletype"
# "APT", "avatar"
# "APT", "Baby AT"
# "APT", "depth"
# "APT", "kibibit"
# "APT", "mebibit"
# "APT", "opinion"
# "APT", "teletype"
# "APU", "opinion"
# "APU", "page up"
# "APU", "opinion"
# "APU", "page up"
# "AR", "avatar"
# "AR", "Core 2"
# "AR", "feature"
# "AR", "user"
# "AR", "versus"
# "ARCnet", "address record"
# "ARCnet", "argument"
# "ARCnet", "address and routing parameter area"
# "ARCnet", "Advanced Research Projects Agency"
# "ARCnet", "American Standard Code for Information Interchange"
# "ARCnet", "American Society of Mechanical Engineers"
# "ARCnet", "automatic speech recognition"
# "ARCnet", "Advanced Technology Attachment"
# "ARCnet", "AT Attachment Packet Interface"
# "ARCnet", "at the moment"
# "ARCnet", "ascynchronous transfer mode"
# "ARCnet", "arithmetic unit"
# "ARCnet", "Attachment Unit Interface"
# "ARCnet", "automatic voice recognition"
# "ARCnet", "BIOS boot specification"
# "ARCnet", "bidirectional isolation"
# "ARCnet", "Bridge Protocol Data Unit"
# "ARCnet", "bitcoin"
# "ARCnet", "Certificate Authority Security Council"
# "ARCnet", "continuous data protection"
# "ARCnet", "collector's edition"
# "ARCnet", "certification"
# "ARCnet", "cubic feet per minute"
# "ARCnet", "character"
# "ARCnet", "computer-mediated communication"
# "ARCnet", "Certified Network Computer Technician"
# "ARCnet", "Certified Network Systems Technician"
# "ARCnet", "Certificate of Authenticity"
# "ARCnet", "source code"
# "ARCnet", "Computer Technology Industry Association"
# "ARCnet", "Children's Online Privacy Protection Act"
# "ARCnet", "California Online Privacy Protection Act"
# "ARCnet", "cost per action"
# "ARCnet", "characters per inch"
# "ARCnet", "characters per second"
# "ARCnet", "carrier sense multiple access/collision detection"
# "ARCnet", "Channel Service Unit/Data Service Unit"
# "ARCnet", "call to action"
# "ARCnet", "digital audio extraction"
# "ARCnet", "Disk Anti-Shock Protection"
# "ARCnet", "Drive Active Slave Present"
# "ARCnet", "data center"
# "ARCnet", "disconnect"
# "ARCnet", "direct current"
# "ARCnet", "Direct Client-to-Client"
# "ARCnet", "data circuit-terminating equipment"
# "ARCnet", "data communication equipment"
# "ARCnet", "direct inward dialing"
# "ARCnet", "Directory Interchange Format"
# "ARCnet", "direct Internet message encapsulation"
# "ARCnet", "drive secondary present"
# "ARCnet", "data terminating equipment"
# "ARCnet", "data terminal equipment"
# "ARCnet", "Electronic Arts"
# "ARCnet", "European Computer Manufacturers Association"
# "ARCnet", "electronic design automation"
# "ARCnet", "electronic data interchange-Internet integration"
# "ARCnet", "electronic learning"
# "ARCnet", "electromagnetic interference"
# "ARCnet", "expanded memory specification"
# "ARCnet", "Electronic Privacy Information Center"
# "ARCnet", "encapsulated PostScript"
# "ARCnet", "electronic publication"
# "ARCnet", "Entertainment Software Association"
# "ARCnet", "enhanced virus protection"
# "ARCnet", "fahrenheit"
# "ARCnet", "file allocation unit"
# "ARCnet", "fractal image format"
# "ARCnet", "frequency modulation"
# "ARCnet", "Freedom of Information Act"
# "ARCnet", "fear of missing out"
# "ARCnet", "Formula Translation"
# "ARCnet", "frames per second"
# "ARCnet", "free-space optical communication"
# "ARCnet", "for your information"
# "ARCnet", "government to government"
# "ARCnet", "GNU Compiler Collection"
# "ARCnet", "General Data Protection Regulation"
# "ARCnet", "general public license"
# "ARCnet", "graphic pages per minute"
# "ARCnet", "graphics processing unit"
# "ARCnet", "Global System for Mobile communication"
# "ARCnet", "Greenwich Mean Time"
# "ARCnet", "gross words a minute"
# "ARCnet", "High-bandwidth Digital Content Protection"
# "ARCnet", "hierarchical file system"
# "ARCnet", "Hercules graphics adapter"
# "ARCnet", "Horizontal Synchronization"
# "ARCnet", "Internet Content Rating Association"
# "ARCnet", "interactive fiction"
# "ARCnet", "Initial Graphics Exchange Specification"
# "ARCnet", "incorporated"
# "ARCnet", "ingress protection"
# "ARCnet", "interprocess communication"
# "ARCnet", "Infrared Data Association"
# "ARCnet", "Information System Audit and Control Association"
# "ARCnet", "Image and Scanner Interface Specification"
# "ARCnet", "International Telecommunication Union"
# "ARCnet", "Java Runtime Environment"
# "ARCnet", "Lesser General Public License"
# "ARCnet", "Linear Inferences Per Second"
# "ARCnet", "line replaceable unit"
# "ARCnet", "logic unit"
# "ARCnet", "macroinstruction"
# "ARCnet", "Metropolitan Area Ethernet"
# "ARCnet", "media access unit"
# "ARCnet", "Micro Channel Architecture"
# "ARCnet", "multi-factor authentication"
# "ARCnet", "memory management unit"
# "ARCnet", "network driver interface specification"
# "ARCnet", "New Economic Movement"
# "ARCnet", "near-field communication"
# "ARCnet", "nanosecond"
# "ARCnet", "office automation"
# "ARCnet", "operationally critical threat, asset, and vulnerability evaluation"
# "ARCnet", "OverDrive Processor Replacement"
# "ARCnet", "original equipment manufacturer"
# "ARCnet", "Open Systems Interconnection"
# "ARCnet", "Parallel AT Attachment"
# "ARCnet", "Peripheral Component Interconnect"
# "ARCnet", "Personal Computer Memory Card International Association"
# "ARCnet", "personal digital assistant"
# "ARCnet", "protocol data unit"
# "ARCnet", "Personal Electronic Transactor"
# "ARCnet", "Professional Golf Association"
# "ARCnet", "Platform for Internet Content Selection"
# "ARCnet", "product identification"
# "ARCnet", "personally identifiable information"
# "ARCnet", "personal information management"
# "ARCnet", "Protocol Independent Multicast"
# "ARCnet", "power management"
# "ARCnet", "Power over Ethernet"
# "ARCnet", "Privacy Policy Statement"
# "ARCnet", "PowerPoint"
# "ARCnet", "PowerPoint"
# "ARCnet", "power supply unit"
# "ARCnet", "progressive web application"
# "ARCnet", "preboot execution environment"
# "ARCnet", "quadrature amplitude modulation"
# "ARCnet", "remote connection"
# "ARCnet", "Remote Code Execution"
# "ARCnet", "radio frequency identification"
# "ARCnet", "return materials authorization"
# "ARCnet", "Recreational Software Advisory Council"
# "ARCnet", "Really Simple Syndication"
# "ARCnet", "Serial AT Attachment"
# "ARCnet", "service data unit"
# "ARCnet", "search engine"
# "ARCnet", "search engine optimization"
# "ARCnet", "Search for Extraterrestrial Intelligence"
# "ARCnet", "set user ID on execution"
# "ARCnet", "service-level agreement"
# "ARCnet", "super-large scale integration"
# "ARCnet", "source memory address register"
# "ARCnet", "service-oriented architecture"
# "ARCnet", "source code"
# "ARCnet", "Serial Presence Detection"
# "ARCnet", "specification"
# "ARCnet", "stateful packet inspection"
# "ARCnet", "Source Service Access Point"
# "ARCnet", "tracks per inch"
# "ARCnet", "terminate-and-stay-resident"
# "ARCnet", "user agent"
# "ARCnet", "microarchitecture"
# "ARCnet", "user-defined function"
# "ARCnet", "user-defined font"
# "ARCnet", "Unique Device Identification"
# "ARCnet", "User State Migration Tool"
# "ARCnet", "Unicode Transformation Format"
# "ARCnet", "Microsoft Visual Basic Scripting Edition"
# "ARCnet", "Version"
# "ARCnet", "Video Electronics Standard Association"
# "ARCnet", "very high frequency"
# "ARCnet", "very-large-scale integration"
# "ARCnet", "Virtual Machine Monitor"
# "ARCnet", "wireless access point"
# "ARCnet", "Warning, Advice and Reporting Point"
# "ARCnet", "web application"
# "ARCnet", "Wired for Management"
# "ARCnet", "Windows File Protection"
# "ARCnet", "word processing competency"
# "ARCnet", "extended memory specification"
# "A record", "American Society of Mechanical Engineers"
# "A record", "authorized service provider"
# "A record", "application service provider"
# "A record", "AT Attachment Packet Interface"
# "A record", "advanced transfer cache"
# "A record", "ascynchronous transfer mode"
# "A record", "arithmetic unit"
# "A record", "Attachment Unit Interface"
# "A record", "avatar"
# "A record", "aperture value"
# "A record", "bidirectional override"
# "A record", "certified"
# "A record", "certified"
# "A record", "source code"
# "A record", "characters per second"
# "A record", "direct current"
# "A record", "Directory Interchange Format"
# "A record", "drive letter access"
# "A record", "Direct Memory Access Control"
# "A record", "Data Terminal Ready"
# "A record", "form feed"
# "A record", "free for all"
# "A record", "fractal image format"
# "A record", "Federal Information Processing Standards"
# "A record", "Free Lossless Audio Codec"
# "A record", "for nerds by nerds"
# "A record", "frames per second"
# "A record", "Ferroelectric RAM"
# "A record", "great Internet mersenne prime search"
# "A record", "GRand Unified Bootloader"
# "A record", "hard drive"
# "A record", "incorporated"
# "A record", "infrared"
# "A record", "LAME ain't an MP3 encoder"
# "A record", "Linear Inferences Per Second"
# "A record", "Layered Service Provider"
# "A record", "master boot record"
# "A record", "MultiMediaCard"
# "A record", "Mail eXchange record"
# "A record", "network interface card"
# "A record", "nanosecond"
# "A record", "overpowered"
# "A record", "operations research"
# "A record", "printed circuit board"
# "A record", "picture"
# "A record", "print screen"
# "A record", "Problem Steps Recorder"
# "A record", "personal video recorder"
# "A record", "password"
# "A record", "password"
# "A record", "quarter-inch cartridge"
# "A record", "Record"
# "A record", "are you there?"
# "A record", "Secure Digital High Capacity card"
# "A record", "Subscriber Identity Module card"
# "A record", "SmartMedia card"
# "A record", "source code"
# "A record", "storage service provider"
# "A record", "set user ID"
# "A record", "Urchin Tracking Module"
# "A record", "virtual circuit"
# "A record", "video cassette recorder"
# "A record", "wireless Internet service provider"
# "Arg", "Core 2"
# "Arg", "versus"
# "ARP", "Core 2"
# "ARP", "C compiler"
# "ARP", "core dump"
# "ARP", "page up"
# "ARP", "versus"
# "ARPA", "Core 2"
# "ARPA", "C compiler"
# "ARPA", "core dump"
# "ARPA", "page up"
# "ARPA", "versus"
# "ARPA", "Core 2"
# "ARPA", "C compiler"
# "ARPA", "core dump"
# "ARPA", "page up"
# "ARPA", "versus"
# "ARPANET", "American Standard Code for Information Interchange"
# "ARPANET", "American Society of Mechanical Engineers"
# "ARPANET", "autonomous sensory meridian response"
# "ARPANET", "automatic speech recognition"
# "ARPANET", "Advanced Technology Attachment"
# "ARPANET", "at the moment"
# "ARPANET", "Adaptive Transform Acoustic Coding"
# "ARPANET", "arithmetic unit"
# "ARPANET", "automatic voice response"
# "ARPANET", "automatic voice recognition"
# "ARPANET", "bidirectional isolation"
# "ARPANET", "Bridge Protocol Data Unit"
# "ARPANET", "computer-based training"
# "ARPANET", "compact edition"
# "ARPANET", "certification"
# "ARPANET", "Color Graphics Adapter"
# "ARPANET", "computer-mediated communication"
# "ARPANET", "Computer Dealers' Exhibition"
# "ARPANET", "Computer Technology Industry Association"
# "ARPANET", "Corporation for Research and Educational Networking"
# "ARPANET", "carrier sense multiple access/collision detection"
# "ARPANET", "Drive Active Slave Present"
# "ARPANET", "direct current"
# "ARPANET", "Direct Client-to-Client"
# "ARPANET", "direct Internet message encapsulation"
# "ARPANET", "Double-precision floating-point"
# "ARPANET", "Destination Service Access Point"
# "ARPANET", "drive secondary present"
# "ARPANET", "data terminating equipment"
# "ARPANET", "data terminal equipment"
# "ARPANET", "European Computer Manufacturers Association"
# "ARPANET", "expanded memory specification"
# "ARPANET", "fahrenheit"
# "ARPANET", "fixed-point"
# "ARPANET", "floating-point"
# "ARPANET", "frequency modulation"
# "ARPANET", "Freedom of Information Act"
# "ARPANET", "fear of missing out"
# "ARPANET", "Formula Translation"
# "ARPANET", "free-space optical communication"
# "ARPANET", "for your information"
# "ARPANET", "government to government"
# "ARPANET", "group code recording"
# "ARPANET", "graphics double data rate"
# "ARPANET", "General Data Protection Regulation"
# "ARPANET", "Graphics Environment Manager"
# "ARPANET", "Geographic Information System"
# "ARPANET", "Graphical Kernel System"
# "ARPANET", "Group Policy Object"
# "ARPANET", "graphic pages per minute"
# "ARPANET", "graphics processing unit"
# "ARPANET", "Greenwich Mean Time"
# "ARPANET", "gross words a minute"
# "ARPANET", "Hercules graphics adapter"
# "ARPANET", "Hypertext reference"
# "ARPANET", "Horizontal Synchronization"
# "ARPANET", "Java Platform, Enterprise Edition"
# "ARPANET", "Java Runtime Environment"
# "ARPANET", "jump to subroutine"
# "ARPANET", "line replaceable unit"
# "ARPANET", "logic unit"
# "ARPANET", "macroinstruction"
# "ARPANET", "Metropolitan Area Ethernet"
# "ARPANET", "memory management unit"
# "ARPANET", "near-field communication"
# "ARPANET", "Network Service Access Point"
# "ARPANET", "operationally critical threat, asset, and vulnerability evaluation"
# "ARPANET", "OverDrive Processor Replacement"
# "ARPANET", "OR operator"
# "ARPANET", "Occupational Safety and Health Administration"
# "ARPANET", "Parallel AT Attachment"
# "ARPANET", "personal computer"
# "ARPANET", "Peripheral Component Interconnect"
# "ARPANET", "Peripheral Component Interconnect Extended"
# "ARPANET", "Personal Computer Memory Card International Association"
# "ARPANET", "personal digital assistant"
# "ARPANET", "protocol data unit"
# "ARPANET", "Professional Golf Association"
# "ARPANET", "Professional Graphics Adapter"
# "ARPANET", "problem in chair not in computer"
# "ARPANET", "product identification"
# "ARPANET", "personally identifiable information"
# "ARPANET", "personal information management"
# "ARPANET", "power management"
# "ARPANET", "Power over Ethernet"
# "ARPANET", "Privacy Policy Statement"
# "ARPANET", "PowerPoint"
# "ARPANET", "PowerPoint"
# "ARPANET", "power supply unit"
# "ARPANET", "progressive web application"
# "ARPANET", "preboot execution environment"
# "ARPANET", "quadrature amplitude modulation"
# "ARPANET", "return materials authorization"
# "ARPANET", "Serial AT Attachment"
# "ARPANET", "service data unit"
# "ARPANET", "search engine optimization"
# "ARPANET", "service-level agreement"
# "ARPANET", "super-large scale integration"
# "ARPANET", "Serial Presence Detection"
# "ARPANET", "Source Service Access Point"
# "ARPANET", "standard input"
# "ARPANET", "terminal adapter"
# "ARPANET", "terminate-and-stay-resident"
# "ARPANET", "user agent"
# "ARPANET", "user-defined function"
# "ARPANET", "user-defined font"
# "ARPANET", "User State Migration Tool"
# "ARPANET", "unique selling point"
# "ARPANET", "Microsoft Visual Basic Scripting Edition"
# "ARPANET", "Version"
# "ARPANET", "very-large-scale integration"
# "ARPANET", "Virtual Machine Monitor"
# "ARPANET", "wireless access point"
# "ARPANET", "Warning, Advice and Reporting Point"
# "ARPANET", "web application"
# "ARPANET", "Wired for Management"
# "ARQ", "Core 2"
# "ARQ", "versus"
# "AS", "Celsius"
# "AS", "release"
# "AS", "user"
# "AS", "versus"
# "ASAP", "Google Plus"
# "ASAP", "page up"
# "ASAP", "user"
# "ASCII", "automatic"
# "ASCII", "nanosecond"
# "ASCII", "user"
# "ASME", "automobile"
# "ASME", "automatic"
# "ASME", "loss of frame"
# "ASME", "maximum"
# "ASME", "minimum"
# "ASME", "Titanium"
# "ASME", "user"
# "ASMR", "ascynchronous transfer mode"
# "ASMR", "automobile"
# "ASMR", "autonomous"
# "ASMR", "automatic"
# "ASMR", "avatar"
# "ASMR", "automatic voltage regulator"
# "ASMR", "business-to-consumer"
# "ASMR", "Google Mail"
# "ASMR", "hit me up"
# "ASMR", "loss of frame"
# "ASMR", "maximize"
# "ASMR", "nanometer"
# "ASMR", "Not-Or"
# "ASMR", "number"
# "ASMR", "parameter"
# "ASMR", "picture"
# "ASMR", "post meridiem"
# "ASMR", "password"
# "ASMR", "password"
# "ASMR", "Solitaire"
# "ASMR", "set user ID"
# "ASMR", "user"
# "ASMR", "voicemail"
# "ASMR", "XP mode"
# "ASN", "autonomous"
# "ASN", "Boolean"
# "ASN", "icon"
# "ASN", "opinion"
# "ASN", "television"
# "ASN", "user"
# "ASN", "Version"
# "ASN.1", "autonomous"
# "ASP", "Google Plus"
# "ASP", "page up"
# "ASP", "user"
# "ASP", "Google Plus"
# "ASP", "page up"
# "ASP", "user"
# "ASP", "Google Plus"
# "ASP", "page up"
# "ASP", "user"
# "ASP", "Google Plus"
# "ASP", "page up"
# "ASP", "user"
# "ASPI", "Google Plus"
# "ASPI", "page up"
# "ASPI", "user"
# "ASR", "avatar"
# "ASR", "feature"
# "ASR", "lowercase"
# "ASR", "Local user"
# "ASR", "uppercase"
# "ASR", "user"
# "ASR", "avatar"
# "ASR", "feature"
# "ASR", "lowercase"
# "ASR", "Local user"
# "ASR", "uppercase"
# "ASR", "user"
# "AT", "Baby AT"
# "AT", "feature"
# "AT", "kibibit"
# "AT", "mebibit"
# "ATA", "Baby AT"
# "ATA", "feature"
# "ATA", "kibibit"
# "ATA", "mebibit"
# "ATAPI", "automobile"
# "ATAPI", "autonomous"
# "ATAPI", "automatic"
# "ATAPI", "avatar"
# "ATAPI", "feature"
# "ATAPI", "hit me up"
# "ATAPI", "page up"
# "ATC", "automobile"
# "ATC", "autonomous"
# "ATC", "automatic"
# "ATC", "avatar"
# "ATC", "bitcoin"
# "ATC", "feature"
# "ATC", "logic unit"
# "ATC", "out of office"
# "ATF", "automobile"
# "ATF", "autonomous"
# "ATF", "automatic"
# "ATF", "avatar"
# "ATF", "feature"
# "ATF", "out of office"
# "ATM", "automobile"
# "ATM", "autonomous"
# "ATM", "automatic"
# "ATM", "avatar"
# "ATM", "feature"
# "ATM", "hit me up"
# "ATM", "maximum"
# "ATM", "minimum"
# "ATM", "real-time"
# "ATM", "Titanium"
# "ATM", "automobile"
# "ATM", "autonomous"
# "ATM", "automatic"
# "ATM", "avatar"
# "ATM", "feature"
# "ATM", "hit me up"
# "ATM", "maximum"
# "ATM", "minimum"
# "ATM", "real-time"
# "ATM", "Titanium"
# "ATM", "automobile"
# "ATM", "autonomous"
# "ATM", "automatic"
# "ATM", "avatar"
# "ATM", "feature"
# "ATM", "hit me up"
# "ATM", "maximum"
# "ATM", "minimum"
# "ATM", "real-time"
# "ATM", "Titanium"
# "ATRAC", "Attachment Unit Interface"
# "ATRAC", "automobile"
# "ATRAC", "autonomous"
# "ATRAC", "automatic"
# "ATRAC", "avatar"
# "ATRAC", "bit error rate"
# "ATRAC", "big grin"
# "ATRAC", "bitcoin"
# "ATRAC", "CD-ROM extended architecture"
# "ATRAC", "cylinder-head-sector"
# "ATRAC", "complementary metal-oxide semiconductor"
# "ATRAC", "database"
# "ATRAC", "extended cylinder-head-sector"
# "ATRAC", "Extended Industry Standard Architecture"
# "ATRAC", "favorite"
# "ATRAC", "feature"
# "ATRAC", "GeForce"
# "ATRAC", "Gigahertz"
# "ATRAC", "hit me up"
# "ATRAC", "independent computing architecture"
# "ATRAC", "Intel Hub Architecture"
# "ATRAC", "Industry Standard Architecture"
# "ATRAC", "lowercase"
# "ATRAC", "least significant character"
# "ATRAC", "meta key"
# "ATRAC", "metal-oxide-semiconductor"
# "ATRAC", "Motion Picture Association of America"
# "ATRAC", "Most Significant Character"
# "ATRAC", "not equal"
# "ATRAC", "network"
# "ATRAC", "National Information Infrastructure"
# "ATRAC", "NOT NULL"
# "ATRAC", "no operatation"
# "ATRAC", "Not-Or"
# "ATRAC", "non-printing character"
# "ATRAC", "non-playable character"
# "ATRAC", "original equipment manufacturer"
# "ATRAC", "out of office"
# "ATRAC", "operator"
# "ATRAC", "operation"
# "ATRAC", "petabit"
# "ATRAC", "Personal Electronic Transactor"
# "ATRAC", "Record"
# "ATRAC", "remark"
# "ATRAC", "retweet"
# "ATRAC", "small form factor"
# "ATRAC", "safe high-voltage connector"
# "ATRAC", "Systems Network Architecture"
# "ATRAC", "service-oriented architecture"
# "ATRAC", "Scalar Processor Architecture"
# "ATRAC", "supertwisted nematic"
# "ATRAC", "set user ID"
# "ATRAC", "Texas Instruments Graphics Architecture"
# "ATRAC", "uppercase"
# "ATRAC", "Uniform Resource Locator"
# "ATX", "automobile"
# "ATX", "autonomous"
# "ATX", "automatic"
# "ATX", "avatar"
# "ATX", "feature"
# "AUP", "opinion"
# "AUP", "page up"
# "Auto", "Baby AT"
# "Auto", "feature"
# "Auto", "kibibit"
# "Auto", "mebibit"
# "Auto", "Baby AT"
# "Auto", "feature"
# "Auto", "kibibit"
# "Auto", "mebibit"
# "Auto", "Baby AT"
# "Auto", "feature"
# "Auto", "kibibit"
# "Auto", "mebibit"
# "AV", "level"
# "AV", "receive"
# "AV", "level"
# "AV", "receive"
# "AV", "level"
# "AV", "receive"
# "AVC", "level"
# "AVI", "level"
# "AVI", "receive"
# "AVR", "favorite"
# "AVR", "feature"
# "AVR", "level"
# "AVR", "user"
# "AVR", "favorite"
# "AVR", "feature"
# "AVR", "level"
# "AVR", "user"
# "AVR", "favorite"
# "AVR", "feature"
# "AVR", "level"
# "AVR", "user"
# "AWS", "Celsius"
# "AWS", "lowercase"
# "AWS", "release"
# "AWS", "versus"
# "B2B", "Baby AT"
# "B2B", "Boolean"
# "B2B", "Tebi"
# "B2B", "Baby AT"
# "B2B", "Boolean"
# "B2B", "Tebi"
# "Basic", "Baby AT"
# "Basic", "Boolean"
# "Basic", "bitcoin"
# "Basic", "nanosecond"
# "Basic", "user"
# "BAT", "bit error rate"
# "BAT", "Boolean"
# "BAT", "bitcoin"
# "BAT", "feature"
# "BAT", "kibibit"
# "BAT", "mebibit"
# "BBS", "Boolean"
# "BBS", "Celsius"
# "BBS", "release"
# "BBS", "user"
# "BBS", "versus"
# "BBS", "Boolean"
# "BBS", "Celsius"
# "BBS", "release"
# "BBS", "user"
# "BBS", "versus"
# "BBS", "Boolean"
# "BBS", "Celsius"
# "BBS", "release"
# "BBS", "user"
# "BBS", "versus"
# "BC", "Boolean"
# "BC", "icon"
# "BC", "receive"
# "BCC", "Boolean"
# "BCC", "icon"
# "BCC", "receive"
# "BCD", "Boolean"
# "BCD", "bitcoin"
# "BCD", "source code"
# "BCD", "icon"
# "BCD", "receive"
# "BCD", "Record"
# "BCD", "source code"
# "BCP", "Boolean"
# "BCP", "bitcoin"
# "BCP", "icon"
# "BCP", "page up"
# "BCP", "receive"
# "BCPL", "bit error rate"
# "BCPL", "big grin"
# "BCPL", "bad game"
# "BCPL", "BIOS pattern block"
# "BCPL", "Break key"
# "BCPL", "bitcoin"
# "BCPL", "C compiler"
# "BCPL", "console"
# "BCPL", "facebook"
# "BCPL", "Google Plus"
# "BCPL", "Google Mail"
# "BCPL", "Hypertext Transfer Protocol"
# "BCPL", "megaflop"
# "BCPL", "not equal"
# "BCPL", "NOT NULL"
# "BCPL", "picture"
# "BCPL", "Record"
# "BCPL", "Simple Mail Transfer Protocol"
# "BCPL", "Simple Network Management Protocol"
# "BCPL", "Simple Object Access Protocol"
# "BCPL", "top of file"
# "BCPL", "voicemail"
# "BD", "bad game"
# "BD", "Boolean"
# "BD", "modulo"
# "BDC", "bad game"
# "BDC", "Boolean"
# "BDC", "bitcoin"
# "BDC", "source code"
# "BDC", "modulo"
# "BDC", "nanosecond"
# "BDC", "source code"
# "BDF", "bad game"
# "BDF", "Boolean"
# "BDF", "infrared"
# "BDF", "line feed"
# "BDF", "modulo"
# "BDI", "bad game"
# "BDI", "Boolean"
# "BDI", "modulo"
# "BDO", "bad game"
# "BDO", "Boolean"
# "BDO", "modulo"
# "BEDO DRAM", "bit error rate"
# "BEDO DRAM", "big grin"
# "BEDO DRAM", "bad game"
# "BEDO DRAM", "ball grid array"
# "BEDO DRAM", "bidirectional"
# "BEDO DRAM", "beginning of medium"
# "BEDO DRAM", "Break key"
# "BEDO DRAM", "bitcoin"
# "BEDO DRAM", "core dump"
# "BEDO DRAM", "favorite"
# "BEDO DRAM", "Federal Communications Commission"
# "BEDO DRAM", "Federal Trade Commission"
# "BEDO DRAM", "GeForce"
# "BEDO DRAM", "hard drive"
# "BEDO DRAM", "loss of frame"
# "BEDO DRAM", "Multibank DRAM"
# "BEDO DRAM", "model number"
# "BEDO DRAM", "Record"
# "BEDO DRAM", "remark"
# "BEDO DRAM", "synchronous DRAM"
# "BEDO DRAM", "VideoLAN"
# "BEDO DRAM", "video random access memory"
# "BEDO DRAM", "width"
# "BER", "Boolean"
# "BER", "Break key"
# "BER", "Core 2"
# "BER", "feature"
# "BER", "user"
# "BER", "versus"
# "BER", "Boolean"
# "BER", "Break key"
# "BER", "Core 2"
# "BER", "feature"
# "BER", "user"
# "BER", "versus"
# "BERT", "big grin"
# "BERT", "Boolean"
# "BERT", "Break key"
# "BERT", "Core 2"
# "BERT", "certified"
# "BERT", "certified"
# "BERT", "favorite"
# "BERT", "Hertz"
# "BERT", "integer"
# "BERT", "kibibit"
# "BERT", "mebibit"
# "BERT", "nanometer"
# "BERT", "picture"
# "BERT", "Solitaire"
# "BERT", "software"
# "BERT", "versus"
# "BERT", "big grin"
# "BERT", "Boolean"
# "BERT", "Break key"
# "BERT", "Core 2"
# "BERT", "certified"
# "BERT", "certified"
# "BERT", "favorite"
# "BERT", "Hertz"
# "BERT", "integer"
# "BERT", "kibibit"
# "BERT", "mebibit"
# "BERT", "nanometer"
# "BERT", "picture"
# "BERT", "Solitaire"
# "BERT", "software"
# "BERT", "versus"
# "BF", "Boolean"
# "BG", "Boolean"
# "BG", "page up"
# "BG", "Boolean"
# "BG", "page up"
# "BG", "Boolean"
# "BG", "page up"
# "BG", "Boolean"
# "BG", "page up"
# "BGA", "Boolean"
# "BGA", "page up"
# "BGMP", "biography"
# "BGMP", "Break key"
# "BGMP", "bitcoin"
# "BGMP", "core dump"
# "BGMP", "Google Mail"
# "BGMP", "GNU zip"
# "BGMP", "height"
# "BGMP", "hit me up"
# "BGMP", "half OP"
# "BGMP", "maximize"
# "BGMP", "megabit"
# "BGMP", "megaflop"
# "BGMP", "page up"
# "BGMP", "voicemail"
# "BGMP", "XP mode"
# "BGP", "Boolean"
# "BGP", "megaflop"
# "BGP", "page up"
# "BHO", "Boolean"
# "Bi-di", "Boolean"
# "BIND", "Boolean"
# "BIND", "infrared"
# "BIND", "line feed"
# "BIND", "manual"
# "BIND", "minimum"
# "BIND", "nanosecond"
# "BIND", "page down"
# "BIND", "Titanium"
# "BIOS", "Boolean"
# "BIOS", "Celsius"
# "BIOS", "release"
# "BIOS", "user"
# "BIOS", "versus"
# "BISYNC", "BIOS pattern block"
# "BISYNC", "bits per second"
# "BISYNC", "biphase shift keying"
# "BISYNC", "basic rate interface"
# "BISYNC", "bitcoin"
# "BISYNC", "Defense Advanced Research Projects Agency"
# "BISYNC", "disconnect"
# "BISYNC", "dots per inch"
# "BISYNC", "extremely low frequency"
# "BISYNC", "instructions per cycle"
# "BISYNC", "lines per inch"
# "BISYNC", "nanosecond"
# "BISYNC", "Physical Address Extension"
# "BISYNC", "radio frequency"
# "BISYNC", "systems development life cycle"
# "BISYNC", "Trusted Computer Platform Alliance"
# "BISYNC", "user experience"
# "BISYNC", "visual display unit"
# "BISYNC", "very high frequency"
# "BISYNC", "word processing competency"
# "Bit", "Boolean"
# "Bit", "bitcoin"
# "Bit", "feature"
# "Bit", "kibibit"
# "Bit", "mebibit"
# "BITNET", "Boolean"
# "BITNET", "bits per second"
# "BITNET", "Break key"
# "BITNET", "bitcoin"
# "BITNET", "Balanced Technology eXtended"
# "BITNET", "database"
# "BITNET", "data circuit-terminating equipment"
# "BITNET", "data communication equipment"
# "BITNET", "Data Encryption Algorithm"
# "BITNET", "downloadable content"
# "BITNET", "data terminating equipment"
# "BITNET", "data terminal equipment"
# "BITNET", "evaluate"
# "BITNET", "favorite"
# "BITNET", "function"
# "BITNET", "height"
# "BITNET", "hit me up"
# "BITNET", "kilobit"
# "BITNET", "kilobit"
# "BITNET", "kibibyte"
# "BITNET", "logic unit"
# "BITNET", "meta key"
# "BITNET", "Metropolitan Area Ethernet"
# "BITNET", "megabit"
# "BITNET", "mebibyte"
# "BITNET", "National Center for Supercomputing Applications"
# "BITNET", "not equal"
# "BITNET", "not gonna lie"
# "BITNET", "NOT NULL"
# "BITNET", "no operatation"
# "BITNET", "Not-Or"
# "BITNET", "Network Service Access Point"
# "BITNET", "National Television System Committee"
# "BITNET", "out of office"
# "BITNET", "operation"
# "BITNET", "petabit"
# "BITNET", "petabyte"
# "BITNET", "printer"
# "BITNET", "Routing Information Protocol"
# "BITNET", "retweet"
# "BITNET", "Standard Apple Numeric Environment"
# "BITNET", "signature"
# "BITNET", "simulation"
# "BITNET", "Standard Parallel Port"
# "BITNET", "standard input"
# "BITNET", "toolkit"
# "BITNET", "Turing test"
# "BNC", "Boolean"
# "BNC", "bitcoin"
# "BNC", "function"
# "BNC", "manual"
# "BNC", "minimum"
# "BNC", "Titanium"
# "BOFH", "Boolean"
# "BOINC", "Boolean"
# "BOINC", "bitcoin"
# "BOINC", "function"
# "BOINC", "manual"
# "BOINC", "minimum"
# "BOINC", "Titanium"
# "BOM", "Boolean"
# "BOM", "maximum"
# "BOM", "minimum"
# "BOM", "Titanium"
# "BOM", "Boolean"
# "BOM", "maximum"
# "BOM", "minimum"
# "BOM", "Titanium"
# "BOM", "Boolean"
# "BOM", "maximum"
# "BOM", "minimum"
# "BOM", "Titanium"
# "BOM", "Boolean"
# "BOM", "maximum"
# "BOM", "minimum"
# "BOM", "Titanium"
# "Bool", "Celsius"
# "Bool", "level"
# "Bool", "milli"
# "Bool", "manual"
# "Bool", "modulo"
# "Bool", "pixel"
# "Bool", "release"
# "BPB", "opinion"
# "BPB", "Tebi"
# "BPDU", "core dump"
# "BPDU", "opinion"
# "BPDU", "Super Video"
# "BPDU", "upload"
# "BPDU", "upload"
# "BPDU", "XP mode"
# "BPL", "level"
# "BPL", "milli"
# "BPL", "manual"
# "BPL", "modulo"
# "BPL", "opinion"
# "BPL", "pixel"
# "BPL", "spelling"
# "BPL", "top of file"
# "BPL", "upload"
# "BPL", "uplink"
# "BPL", "upload"
# "bps", "Celsius"
# "bps", "opinion"
# "bps", "release"
# "bps", "uppercase"
# "bps", "versus"
# "Bps", "Celsius"
# "Bps", "opinion"
# "Bps", "release"
# "Bps", "uppercase"
# "Bps", "versus"
# "BPSK", "Break key"
# "BPSK", "bitcoin"
# "BPSK", "CapsLock"
# "BPSK", "CapsLock"
# "BPSK", "class ID"
# "BPSK", "console"
# "BPSK", "crash to desktop"
# "BPSK", "depth"
# "BPSK", "facebook"
# "BPSK", "remark"
# "BPSK", "top of file"
# "BPSK", "upload"
# "BPSK", "uplink"
# "BPSK", "upload"
# "BPSK", "Version"
# "BPSK", "XP mode"
# "Br", "Core 2"
# "Br", "feature"
# "Br", "user"
# "Br", "versus"
# "BRI", "Core 2"
# "BRI", "feature"
# "BRI", "user"
# "BRI", "versus"
# "Brouter", "bitcoin"
# "Brouter", "certificate authority"
# "Brouter", "certified"
# "Brouter", "certified"
# "Brouter", "Certified Novell Engineer"
# "Brouter", "source code"
# "Brouter", "depth"
# "Brouter", "digital-to-analog converter"
# "Brouter", "direct current"
# "Brouter", "Directory Interchange Format"
# "Brouter", "Digital Video Recorder"
# "Brouter", "feature"
# "Brouter", "Firefox"
# "Brouter", "free for all"
# "Brouter", "fractal image format"
# "Brouter", "first in, first out"
# "Brouter", "format and restore"
# "Brouter", "gigabit interface converter"
# "Brouter", "Gigahertz"
# "Brouter", "great Internet mersenne prime search"
# "Brouter", "hard drive"
# "Brouter", "Hercules graphics adapter"
# "Brouter", "hardware"
# "Brouter", "Hertz"
# "Brouter", "Internet Information Server"
# "Brouter", "integer"
# "Brouter", "list server"
# "Brouter", "memory address register"
# "Brouter", "nanometer"
# "Brouter", "no operatation"
# "Brouter", "Not-Or"
# "Brouter", "number"
# "Brouter", "original equipment manufacturer"
# "Brouter", "operator"
# "Brouter", "original poster"
# "Brouter", "operation"
# "Brouter", "parameter"
# "Brouter", "personal computer"
# "Brouter", "Portable Document Format"
# "Brouter", "Personal Electronic Transactor"
# "Brouter", "Professional Graphics Adapter"
# "Brouter", "picture"
# "Brouter", "problem in chair not in computer"
# "Brouter", "part number"
# "Brouter", "Portable operating system interface for Unix"
# "Brouter", "printer"
# "Brouter", "Personal Store"
# "Brouter", "quarter-inch cartridge"
# "Brouter", "remote access server"
# "Brouter", "raster pattern generator"
# "Brouter", "signature"
# "Brouter", "source memory address register"
# "Brouter", "service-oriented architecture"
# "Brouter", "Solitaire"
# "Brouter", "source code"
# "Brouter", "software"
# "Brouter", "terminal adapter"
# "Brouter", "teletypewriter"
# "Brouter", "virtual circuit"
# "Brouter", "virtual circuit identifier"
# "Brouter", "virtual control program interface"
# "Brouter", "Version"
# "Brouter", "Virtual Machine Manager"
# "Brouter", "Virtual Machine Monitor"
# "Brouter", "virtual private server"
# "Brouter", "Virtual YouTuber"
# "Brouter", "width"
# "Brouter", "working draft"
# "Brouter", "World of Warcraft"
# "BSB", "database"
# "BSB", "Tebi"
# "BSB", "user"
# "BSC", "bitcoin"
# "BSC", "nanosecond"
# "BSC", "user"
# "BSoD", "class ID"
# "BSoD", "nanosecond"
# "BSoD", "pseudocode"
# "BSoD", "password"
# "BSoD", "password"
# "BSoD", "user"
# "BSoD", "class ID"
# "BSoD", "nanosecond"
# "BSoD", "pseudocode"
# "BSoD", "password"
# "BSoD", "password"
# "BSoD", "user"
# "BSS", "Celsius"
# "BSS", "release"
# "BSS", "user"
# "BSS", "versus"
# "BTC", "feature"
# "BTC", "logic unit"
# "BTC", "out of office"
# "BTC", "feature"
# "BTC", "logic unit"
# "BTC", "out of office"
# "BTDT", "Balanced Technology eXtended"
# "BTDT", "database"
# "BTDT", "End-of-Text"
# "BTDT", "evaluate"
# "BTDT", "favorite"
# "BTDT", "height"
# "BTDT", "hit me up"
# "BTDT", "Java Development Kit"
# "BTDT", "kilobit"
# "BTDT", "kilobit"
# "BTDT", "kibibyte"
# "BTDT", "meta key"
# "BTDT", "megabit"
# "BTDT", "mebibyte"
# "BTDT", "not equal"
# "BTDT", "NOT NULL"
# "BTDT", "Not-Or"
# "BTDT", "NT loader"
# "BTDT", "out of office"
# "BTDT", "petabit"
# "BTDT", "petabyte"
# "BTDT", "retweet"
# "BTDT", "received data"
# "BTDT", "table data"
# "BTDT", "toolkit"
# "BTX", "feature"
# "Cab", "kibibit"
# "Cab", "mebibit"
# "Cab", "Tebi"
# "CAD", "class ID"
# "CAD", "modulo"
# "CAP", "opinion"
# "CAP", "page up"
# "CAPS", "class ID"
# "CAPS", "console"
# "CAPS", "opinion"
# "CAPS", "release"
# "CAPS", "uppercase"
# "CAPS", "versus"
# "CAPSLK", "C compiler"
# "CAPSLK", "compact disc digital audio"
# "CAPSLK", "Compact Disc file system"
# "CAPSLK", "Compact Disc-Programmable ROM"
# "CAPSLK", "Conseil Europeen pour la Recherche Nuclaire"
# "CAPSLK", "Computer Emergency Response Team"
# "CAPSLK", "CompactFlash"
# "CAPSLK", "class ID"
# "CAPSLK", "Computer Misuse Act"
# "CAPSLK", "cyan magenta yellow black"
# "CAPSLK", "Computer Output Microfilm"
# "CAPSLK", "console"
# "CAPSLK", "comprehensive Perl archive network"
# "CAPSLK", "cost per click"
# "CAPSLK", "Certificate Revocation List"
# "CAPSLK", "Computer Science Network"
# "CAPSLK", "Capture the Flag"
# "CAPSLK", "Control key"
# "CAPSLK", "Campus Wide Information System"
# "CAPSLK", "GIMP toolkit"
# "CAPSLK", "heads up display"
# "CAPSLK", "pay per click"
# "CAPSLK", "top of file"
# "CAPSLK", "upload"
# "CAPSLK", "uplink"
# "CAPSLK", "upload"
# "CAPSLK", "upper memory block"
# "CAPTCHA", "Certificate Authority Security Council"
# "CAPTCHA", "Central Africa Time"
# "CAPTCHA", "Comit Consultatif International Tlphonique et Tlgraphique"
# "CAPTCHA", "compact disc digital audio"
# "CAPTCHA", "compact disc database"
# "CAPTCHA", "Compact Disc Interactive"
# "CAPTCHA", "Cache Discovery Protocol"
# "CAPTCHA", "Columbia Data Products"
# "CAPTCHA", "continuous data protection"
# "CAPTCHA", "CD-ROM extended architecture"
# "CAPTCHA", "Compact Disc Re-Writable"
# "CAPTCHA", "Compact Disc Write Once"
# "CAPTCHA", "certified"
# "CAPTCHA", "certification"
# "CAPTCHA", "certified"
# "CAPTCHA", "certificate"
# "CAPTCHA", "CompactFlash"
# "CAPTCHA", "Computer Hope"
# "CAPTCHA", "Challenge-Handshake Authentication Protocol"
# "CAPTCHA", "character"
# "CAPTCHA", "cylinder-head-sector"
# "CAPTCHA", "compact HTML"
# "CAPTCHA", "Computer Misuse Act"
# "CAPTCHA", "computer-mediated communication"
# "CAPTCHA", "complementary metal-oxide semiconductor"
# "CAPTCHA", "Certified Network Computer Technician"
# "CAPTCHA", "Certified Network Systems Technician"
# "CAPTCHA", "Certificate of Authenticity"
# "CAPTCHA", "Cache On A STick"
# "CAPTCHA", "Computer Technology Industry Association"
# "CAPTCHA", "cost per action"
# "CAPTCHA", "cost per click"
# "CAPTCHA", "characters per inch"
# "CAPTCHA", "computer science"
# "CAPTCHA", "carrier sense multiple access/collision detection"
# "CAPTCHA", "Computer Service Technician"
# "CAPTCHA", "call to action"
# "CAPTCHA", "client-to-client protocol"
# "CAPTCHA", "Capture the Flag"
# "CAPTCHA", "depth"
# "CAPTCHA", "digital loop carrier"
# "CAPTCHA", "deathmatch"
# "CAPTCHA", "Elliptic Curve Digital Signature Algorithm"
# "CAPTCHA", "European Computer Manufacturers Association"
# "CAPTCHA", "expanded memory specification"
# "CAPTCHA", "great Internet mersenne prime search"
# "CAPTCHA", "Hypertext Transfer Protocol"
# "CAPTCHA", "Internet Relay Chat"
# "CAPTCHA", "non-printing character"
# "CAPTCHA", "non-playable character"
# "CAPTCHA", "out of office"
# "CAPTCHA", "operations research"
# "CAPTCHA", "Open Systems Interconnection"
# "CAPTCHA", "on the phone"
# "CAPTCHA", "picture"
# "CAPTCHA", "special effects"
# "CAPTCHA", "Simple Mail Transfer Protocol"
# "CAPTCHA", "Simple Network Management Protocol"
# "CAPTCHA", "Simple Object Access Protocol"
# "CAPTCHA", "specification"
# "CAPTCHA", "Spanning Tree Protocol"
# "CAPTCHA", "tape archive"
# "CAPTCHA", "team deathmatch"
# "CAPTCHA", "Tripple Data Encryption Algorithm"
# "CAPTCHA", "text-to-speech"
# "CAPTCHA", "uppercase"
# "CAPTCHA", "Valve Anti-Cheat"
# "CAPTCHA", "virtual machine"
# "CAPTCHA", "width"
# "CAPTCHA", "web application"
# "CAS", "release"
# "CAS", "user"
# "CAS", "versus"
# "CAS", "release"
# "CAS", "user"
# "CAS", "versus"
# "CASC", "class ID"
# "CASC", "console"
# "CASC", "nanosecond"
# "CASC", "user"
# "CAT", "feature"
# "CAT", "kibibit"
# "CAT", "mebibit"
# "CATV", "feature"
# "CATV", "receive"
# "CATV", "received data"
# "CATV", "feature"
# "CATV", "receive"
# "CATV", "received data"
# "CBL", "console"
# "CBL", "kibibit"
# "CBL", "level"
# "CBL", "milli"
# "CBL", "manual"
# "CBL", "mebibit"
# "CBL", "modulo"
# "CBL", "pixel"
# "CBL", "table data"
# "CBL", "table head"
# "CBL", "Tebi"
# "CBT", "certified"
# "CBT", "certified"
# "CBT", "kilobit"
# "CBT", "kilobit"
# "CBT", "kibibyte"
# "CBT", "kibibit"
# "CBT", "megabit"
# "CBT", "mebibit"
# "CBT", "mebibyte"
# "CBT", "object"
# "CBT", "petabit"
# "CBT", "table data"
# "CBT", "Tebi"
# "CCD", "class ID"
# "CCD", "modulo"
# "CCDE", "class ID"
# "CCDE", "modulo"
# "CCFL", "certified"
# "CCFL", "certified"
# "CCFL", "console"
# "CCFL", "level"
# "CCFL", "milli"
# "CCFL", "manual"
# "CCFL", "modulo"
# "CCFL", "pixel"
# "CCFL", "top of file"
# "CCITT", "feature"
# "CCITT", "kibibit"
# "CCITT", "mebibit"
# "CCNA", "console"
# "CCNA", "icon"
# "CCNA", "manual"
# "CCNA", "minimum"
# "CCNA", "opinion"
# "CCNA", "Titanium"
# "CCNP", "console"
# "CCNP", "core dump"
# "CCNP", "GNU zip"
# "CCNP", "manual"
# "CCNP", "minimum"
# "CCNP", "page up"
# "CCNP", "Titanium"
# "CCS", "release"
# "CCS", "user"
# "CCS", "versus"
# "CCS", "release"
# "CCS", "user"
# "CCS", "versus"
# "CCTV", "feature"
# "CCTV", "receive"
# "CCTV", "received data"
# "CD", "class ID"
# "CD", "modulo"
# "CD", "class ID"
# "CD", "modulo"
# "CDA", "class ID"
# "CDA", "modulo"
# "CDA", "class ID"
# "CDA", "modulo"
# "CDDA", "class ID"
# "CDDA", "modulo"
# "CDDB", "modulo"
# "CDDB", "Tebi"
# "CDDI", "class ID"
# "CDDI", "modulo"
# "CDE", "class ID"
# "CDE", "modulo"
# "CDfs", "Code Division Multiple Access"
# "CDfs", "CD-R file system"
# "CDfs", "certified"
# "CDfs", "certified"
# "CDfs", "class ID"
# "CDfs", "console"
# "CDfs", "core dump"
# "CDfs", "database"
# "CDfs", "equals"
# "CDfs", "Firefox"
# "CDfs", "half OP"
# "CDfs", "line feed"
# "CDfs", "out of office"
# "CDfs", "top of file"
# "CDfs", "VideoLAN"
# "CDfs", "width"
# "CD-i", "modulo"
# "CDMA", "form feed"
# "CDMA", "maximum"
# "CDMA", "memorandum"
# "CDMA", "minimum"
# "CDMA", "modulo"
# "CDMA", "Titanium"
# "CDMA", "XP mode"
# "CDN", "download"
# "CDN", "download"
# "CDN", "icon"
# "CDN", "modulo"
# "CDN", "opinion"
# "CDN", "VideoLAN"
# "CDN", "download"
# "CDN", "download"
# "CDN", "icon"
# "CDN", "modulo"
# "CDN", "opinion"
# "CDN", "VideoLAN"
# "CDP", "core dump"
# "CDP", "modulo"
# "CDP", "page up"
# "CDP", "core dump"
# "CDP", "modulo"
# "CDP", "page up"
# "CDP", "core dump"
# "CDP", "modulo"
# "CDP", "page up"
# "CDP", "core dump"
# "CDP", "modulo"
# "CDP", "page up"
# "CDP", "core dump"
# "CDP", "modulo"
# "CDP", "page up"
# "CDP", "core dump"
# "CDP", "modulo"
# "CDP", "page up"
# "CD-PROM", "CD-R file system"
# "CD-PROM", "Compact Disc Read-Only Memory"
# "CD-PROM", "CD-ROM extended architecture"
# "CD-PROM", "cancel entry"
# "CD-PROM", "cellular telephone"
# "CD-PROM", "Community Enterprise Operating System"
# "CD-PROM", "Computer Emergency Response Team"
# "CD-PROM", "Color Graphics Adapter"
# "CD-PROM", "computer-generated imagery"
# "CD-PROM", "change directory"
# "CD-PROM", "common Internet file system"
# "CD-PROM", "committed information rate"
# "CD-PROM", "complex instruction set computer"
# "CD-PROM", "Common Lisp object system"
# "CD-PROM", "common language runtime"
# "CD-PROM", "content management system"
# "CD-PROM", "chip on board"
# "CD-PROM", "Computer Output Microfilm"
# "CD-PROM", "comprehensive Perl archive network"
# "CD-PROM", "ceramic pin grid array"
# "CD-PROM", "carriage return"
# "CD-PROM", "continuity RIMM"
# "CD-PROM", "cryptography"
# "CD-PROM", "counter-strike"
# "CD-PROM", "code segment"
# "CD-PROM", "Computer Science Network"
# "CD-PROM", "chirp spread spectrum"
# "CD-PROM", "Content Scramble System"
# "CD-PROM", "comma-separated values"
# "CD-PROM", "click-through rate"
# "CD-PROM", "Common Unix Printing System"
# "CD-PROM", "Coordinated Universal Time"
# "CD-PROM", "Common Vulnerabilities and Exposures"
# "CD-PROM", "Concurrent Version System"
# "CD-PROM", "Campus Wide Information System"
# "CD-PROM", "digital video express"
# "CD-PROM", "DisplayPort"
# "CD-PROM", "Extended Capabilities Port"
# "CD-PROM", "Enhanced Parallel Port"
# "CD-PROM", "Ferroelectric RAM"
# "CD-PROM", "GNU image manipulation program"
# "CD-PROM", "good manners"
# "CD-PROM", "Instagram"
# "CD-PROM", "HyperTransport"
# "CD-PROM", "heads up display"
# "CD-PROM", "leadless chip carrier"
# "CD-PROM", "low-power wide-area network"
# "CD-PROM", "load-reduced dual inline memory module"
# "CD-PROM", "media access control"
# "CD-PROM", "main distribution frame"
# "CD-PROM", "Multibank DRAM"
# "CD-PROM", "Manufacturer's Suggested Retail Price"
# "CD-PROM", "NP-Complete"
# "CD-PROM", "on-screen display"
# "CD-PROM", "on-screen keyboard"
# "CD-PROM", "one-time password"
# "CD-PROM", "PCI Express"
# "CD-PROM", "Parameter RAM"
# "CD-PROM", "Quad Super Extended Graphics Array"
# "CD-PROM", "role-based access control"
# "CD-PROM", "read-eval-print loop"
# "CD-PROM", "red-green-blue"
# ...
# "SIM card", "small outline dual in-line memory module"
# "SIM card", "Solitaire"
# "SIM card", "source code"
# "SIM card", "static random access memory"
# "SIM card", "Small Scale Experimental Machine"
# "SIM card", "small-scale integration"
# "SIM card", "Space Sciences Laboratory"
# "SIM card", "storage service provider"
# "SIM card", "set user ID"
# "SIM card", "Super Video"
# "SIM card", "Unicode Transformation Format"
# "SIM card", "Urchin Tracking Module"
# "SIM card", "video cassette recorder"
# "SIMD", "source code"
# "SIMD", "set user ID"
# "SIMD", "Super Video"
# "SIMD", "XP mode"
# "SIMM", "Titanium"
# "SLA", "Solitaire"
# "SLA", "Solitaire"
# "SLI", "Solitaire"
# "SLIP", "Solitaire"
# "SLIP", "teletype"
# "Slogin", "Self-Monitoring Analysis and Reporting Technology"
# "Slogin", "Surface-mount Technology"
# "Slogin", "Solitaire"
# "Slogin", "source code"
# "Slogin", "spelling"
# "Slogin", "spam blogs"
# "Slogin", "simultaneous peripheral operatings online"
# "Slogin", "toolkit"
# "Slogin", "television"
# "Slogin", "uplink"
# "Slogin", "Version"
# "Slogin", "VideoLAN"
# "Slotket", "silicon on insulator"
# "Slotket", "Solitaire"
# "Slotket", "Scalar Processor Architecture"
# "Slotket", "Serial Presence Detection"
# "Slotket", "small-scale integration"
# "Slotket", "software"
# "Slotket", "toolkit"
# "Slotket", "teletypewriter"
# "Slotket", "teletype"
# "Slotket", "Ultra High Definition"
# "Slotket", "Ultra Large Scale Integration"
# "Slotket", "ultraviolet"
# "Slotket", "voltage direct current"
# "Slotket", "virtual reality"
# "SLSI", "Solitaire"
# "SLSI", "set user ID"
# "SLSI", "versus"
# "SMAR", "Solitaire"
# "SMAR", "Super Video"
# "SMAR", "software"
# "SMAR", "user"
# "SMART", "SmartMedia card"
# "SMART", "System Management Mode"
# "SMART", "Simple Mail Transfer Protocol"
# "SMART", "Simple Network Management Protocol"
# "SMART", "Simple Object Access Protocol"
# "SMART", "Solitaire"
# "SMART", "source code"
# "SMART", "Standard Parallel Port"
# "SMART", "static random access memory"
# "SMART", "service set identifier"
# "SMART", "Secure Socket Tunneling Protocol"
# "SMART", "set user ID"
# "SMART", "superscript"
# "SMART", "Super Video"
# "SMART", "toolkit"
# "SMB", "Tebi"
# "SMB", "Tebi"
# "SMB", "Tebi"
# "SMBus", "Solitaire"
# "SMBus", "source code"
# "SM card", "Simple Mail Interface"
# "SM card", "small outline dual in-line memory module"
# "SM card", "Solitaire"
# "SM card", "source code"
# "SM card", "static random access memory"
# "SM card", "Small Scale Experimental Machine"
# "SM card", "small-scale integration"
# "SM card", "Space Sciences Laboratory"
# "SM card", "storage service provider"
# "SM card", "set user ID"
# "SM card", "Super Video"
# "SM card", "Unicode Transformation Format"
# "SM card", "Urchin Tracking Module"
# "SM card", "video cassette recorder"
# "SMI", "Titanium"
# "SMI", "Titanium"
# "SMIL", "spelling"
# "SMIL", "voicemail"
# "SMM", "Titanium"
# "SMPS", "Simple Mail Transfer Protocol"
# "SMPS", "Simple Network Management Protocol"
# "SMPS", "Simple Object Access Protocol"
# "SMPS", "Solitaire"
# "SMPS", "source code"
# "SMRAM", "storage management subsystem"
# "SMRAM", "small outline dual in-line memory module"
# "SMRAM", "small office/home office"
# "SMRAM", "Solitaire"
# "SMRAM", "source code"
# "SMRAM", "supertwisted nematic"
# "SMRAM", "Suspend-to-RAM"
# "SMRAM", "set user ID"
# "SMRAM", "Super Video"
# "SMS", "set user ID"
# "SMS", "versus"
# "SMS", "set user ID"
# "SMS", "versus"
# "SMS", "set user ID"
# "SMS", "versus"
# "SMT", "Solitaire"
# "SMT", "software"
# "SMT", "Tantalum"
# "SMTP", "Solitaire"
# "SMTP", "source code"
# "SMTP", "Standard Parallel Port"
# "SMTP", "Source Service Access Point"
# "SMTP", "small-scale integration"
# "SMTP", "supertwisted nematic"
# "SMTP", "software test plan"
# "SMTP", "software"
# "SMTP", "teletype"
# "SMTP", "width"
# "SMTP", "write pre-comp"
# "SNA", "Titanium"
# "SNMP", "Solitaire"
# "SNMP", "source code"
# "SNMP", "Sony and Phillips Digital Interconnect Format"
# "SNMP", "Spam over Internet Telephony"
# "SNMP", "Source Service Access Point"
# "SNMP", "Titanium"
# "SNMP", "voicemail"
# "SNMP", "XP mode"
# "SO-DIMM", "Solitaire"
# "SO-DIMM", "source code"
# "SO-DIMM", "Suspend-to-RAM"
# "SONET", "spelling"
# "SONET", "software"
# "SONET", "Tantalum"
# "SONET", "Titanium"
# "Source", "set user ID"
# "Source", "versus"
# "SPARC", "specification"
# "SPARC", "Standard Parallel Port"
# "SPARC", "Space Sciences Laboratory"
# "SPARC", "supertwisted nematic"
# "SPARC", "Suspend-to-RAM"
# "SPARC", "set user ID"
# "SPARC", "superscript"
# "SPARC", "Super Video CD"
# "SPARC", "Super Video Graphics Array"
# "SPARC", "Super Video"
# "SPARC", "Super Extended Graphics Array"
# "SPARC", "Super XGA Plus"
# "SPARC", "tape archive"
# "SPARC", "top of file"
# "SPARC", "uppercase"
# "SPARC", "upload"
# "SPARC", "upload"
# "SPARC", "XP mode"
# "SPD", "set user ID"
# "SPD", "Super Video"
# "SPD", "upload"
# "SPD", "upload"
# "SPD", "XP mode"
# "S/PDIF", "shielded twisted pair"
# "S/PDIF", "upload"
# "S/PDIF", "upload"
# "S/PDIF", "XP mode"
# "Spec", "Super Video"
# "SPIM", "Super Video"
# "SPIM", "Titanium"
# "SPIM", "XP mode"
# "Spit", "Super Video"
# "Spit", "software"
# "Spit", "teletype"
# "SPL", "Super Video"
# "SPL", "top of file"
# "SPL", "upload"
# "SPL", "uplink"
# "SPL", "upload"
# "splogs", "Super Video"
# "splogs", "Super XGA Plus"
# "splogs", "uppercase"
# "splogs", "upload"
# "splogs", "uplink"
# "splogs", "upload"
# "Spool", "Super Video"
# "Spool", "top of file"
# "Spool", "upload"
# "Spool", "uplink"
# "Spool", "upload"
# "SPS", "set user ID"
# "SPS", "Super Video"
# "SPS", "uppercase"
# "SPS", "versus"
# "SRAM", "set user ID"
# "SRAM", "Titanium"
# "SRAM", "versus"
# "SSEM", "Titanium"
# "SSR", "user"
# "SSR", "versus"
# "SSTP", "set user ID"
# "Stdin", "set user ID"
# "Stdin", "software"
# "Stdin", "Version"
# "Stdin", "VideoLAN"
# "Stdin", "Window Driver Foundation"
# "Stdin", "Windows File Protection"
# "STM", "set user ID"
# "STM", "Titanium"
# "STN", "set user ID"
# "STP", "set user ID"
# "STP", "set user ID"
# "STP", "set user ID"
# "STR", "set user ID"
# "STR", "Super Video"
# "STR", "software"
# "STR", "user"
# "STS", "set user ID"
# "STS", "versus"
# "Sub", "Tebi"
# "Subnet", "table data"
# "Subnet", "toolkit"
# "Subnet", "Web-based Enterprise Management"
# "SVCD", "Super Video"
# "SVCD", "upload"
# "SVCD", "upload"
# "SVCD", "XP mode"
# "SVGA", "Super Video"
# "S-Video", "upload"
# "S-Video", "upload"
# "S-Video", "XP mode"
# "sync", "synthesizer"
# "synth", "system generation"
# "synth", "system operator"
# "synth", "width"
# "sysgen", "system log"
# "sysgen", "system operator"
# "sysgen", "system request"
# "sysgen", "Version"
# "sysgen", "VHSIC Hardware Description Language "
# "sysgen", "Website META Language"
# "sysgen", "cross-site scripting"
# "syslog", "system operator"
# "syslog", "system request"
# "syslog", "VHSIC Hardware Description Language "
# "syslog", "Website META Language"
# "sysop", "system request"
# "sysop", "Version"
# "sysrq", "Version"
# "sysrq", "very important person"
# "TA", "Tebi"
# "Ta", "Tebi"
# "TACACS", "Tebi"
# "TACACS", "Titanium"
# "TACACS", "uppercase"
# "TACACS", "versus"
# "TAPI", "Tebi"
# "TAPI", "Titanium"
# "TAPI", "top of file"
# "TAR", "Tebi"
# "TAR", "Titanium"
# "TAR", "user"
# "TAR", "versus"
# "TCO", "Tebi"
# "TCO", "Titanium"
# "TCPA", "Tebi"
# "TCPA", "Titanium"
# "TCPA", "teletype"
# "TCP/IP", "top of file"
# "TCP/IP", "technical report"
# "TCP/IP", "teletype"
# "TD", "Tebi"
# "TD", "Titanium"
# "TDD", "Tebi"
# "TDD", "Titanium"
# "TDM", "Tebi"
# "TDM", "Titanium"
# "TDM", "XP mode"
# "TDP", "Tebi"
# "TDP", "Titanium"
# "TDP", "teletype"
# "Tech", "Tebi"
# "Tech", "Titanium"
# "Telco line", "total harmonic distortion"
# "Telco line", "toolkit"
# "Telco line", "top of file"
# "Telco line", "Telecommunications Relay Service"
# "Telco line", "teletype"
# "Telco line", "television"
# "Telco line", "Video Electronics Standard Association"
# "Telco line", "VideoLAN"
# "Telco line", "voicemail"
# "Telco line", "Wireless Markup Language"
# "TERA", "Tebi"
# "TERA", "Titanium"
# "TERA", "user"
# "TERA", "versus"
# "TET", "Tebi"
# "Texel", "table head"
# "Texel", "Tebi"
# "Texel", "Titanium"
# "Texel", "top of file"
# "TFTP", "toolkit"
# "TFTP", "top of file"
# "TFTP", "technical report"
# "TFTP", "text-to-speech"
# "TFTP", "teletype"
# "TFTP", "width"
# "TH", "Tebi"
# "TH", "Titanium"
# "THD", "Tebi"
# "THD", "Titanium"
# "T&amp;L", "top of file"
# "T&amp;L", "terms of use"
# "T&amp;L", "terms of service"
# "T&amp;L", "Trusted Platform Module"
# "T&amp;L", "technical report"
# "T&amp;L", "terminate-and-stay-resident"
# "T&amp;L", "text-to-speech"
# "T&amp;L", "venture capital"
# "TLD", "teletype"
# "TLD", "television"
# "TLD", "upload"
# "TLD", "upload"
# "TLP", "teletype"
# "TLP", "television"
# "TLS", "teletype"
# "TLS", "television"
# "TLS", "versus"
# "TOPS", "uppercase"
# "TOPS", "versus"
# "Tor", "user"
# "Tor", "versus"
# "TOS", "user"
# "TOS", "versus"
# "TOS", "user"
# "TOS", "versus"
# "TOS", "user"
# "TOS", "versus"
# "TOS", "user"
# "TOS", "versus"
# "TPM", "XP mode"
# "TP-PMD", "technical report"
# "TP-PMD", "text-to-speech"
# "TP-PMD", "XP mode"
# "TR", "user"
# "TR", "versus"
# "Transistor", "Tripple Data Encryption Algorithm"
# "Transistor", "terminate-and-stay-resident"
# "Transistor", "Turing test"
# "Transistor", "transistor-transistor logic"
# "Transistor", "teletypewriter"
# "Transistor", "trasmit data"
# "Transistor", "microarchitecture"
# "Transistor", "Universal Asynchronous Receiver-Transmitter"
# "Transistor", "Universal Automatic Computer"
# "Transistor", "Uniform Resource Characteristic"
# "Transistor", "Uniform Resource Locator"
# "Transistor", "Universal Synchronous Receiver-Transmitter"
# "Transistor", "Coordinated Universal Time"
# "Transistor", "University of Washington Information Navigator"
# "Transistor", "value-added reseller"
# "Transistor", "virtual circuit identifier"
# "Transistor", "Video Graphics Adapter"
# "Transistor", "Video Home System"
# "Transistor", "very-large-scale integration"
# "Transistor", "Virtual Machine Manager"
# "Transistor", "Virtual Machine Monitor"
# "Transistor", "virtual memory system"
# "Transistor", "voicemail system"
# "Transistor", "virtual private server"
# "Transistor", "virtual reality"
# "Transistor", "Visual Studio"
# "Transistor", "Virtual YouTuber"
# "Transistor", "World Wide Web Consortium"
# "Transistor", "Warning, Advice and Reporting Point"
# "Transistor", "wireless Internet service provider"
# "Transistor", "word processor"
# "Transistor", "X Window System"
# "Transistor", "X Window System"
# "Triple DEA", "transistor-transistor logic"
# "Triple DEA", "trasmit data"
# "Triple DEA", "upload"
# "Triple DEA", "upload"
# "Triple DEA", "Urchin Tracking Module"
# "Triple DEA", "XP mode"
# "TRS", "Version"
# "TRS", "versus"
# "TSR", "television"
# "TSR", "uppercase"
# "TSR", "user"
# "TTS", "user"
# "TTS", "versus"
# "UAC", "user"
# "Uarch", "uppercase"
# "Uarch", "upload"
# "Uarch", "upload"
# "Uarch", "Urchin Tracking Module"
# "Uarch", "Version"
# "Uarch", "width"
# "UART", "user"
# "UART", "versus"
# "UBCD", "uppercase"
# "UBCD", "upload"
# "UBCD", "upload"
# "UBCD", "universal product code"
# "UBCD", "Unix-to-Unix encode"
# "UBCD", "XP mode"
# "UC", "user"
# "UCE", "user"
# "UDF", "user"
# "UDF", "user"
# "UDF", "user"
# "UDID", "upload"
# "UDID", "upload"
# "UDID", "user"
# "UDMA", "user"
# "UDMA", "XP mode"
# "UDP", "user"
# "UDSL", "upload"
# "UDSL", "upload"
# "UDSL", "universal serial bus"
# "UDSL", "user"
# "UDSL", "unshielded twisted pair cable"
# "UDSL", "very high data rate DSL"
# "UDSL", "Version"
# "UDSL", "VideoLAN"
# "UDSL", "voicemail"
# "UDSL", "width"
# "UDSL", "Wideband Code Division Multiple Access"
# "UEFI", "user"
# "UHCI", "user"
# "UHD", "upload"
# "UHD", "upload"
# "UHD", "user"
# "U/L", "uplink"
# "U/L", "upload"
# "U/L", "user"
# "UL", "user"
# "UL", "user"
# "UL", "user"
# "ULSI", "user"
# "ULSI", "versus"
# "UMA", "user"
# "UMB", "user"
# "UNIVAC", "universal product code"
# "UNIVAC", "Universal Plug and Play"
# "UNIVAC", "Uniform Resource Characteristic"
# "UNIVAC", "Uniform Resource Locator"
# "UNIVAC", "Uniform Resource Name"
# "UNIVAC", "universal serial bus"
# "UNIVAC", "Universal Synchronous Receiver-Transmitter"
# "UNIVAC", "Universal Time"
# "UNIVAC", "universal Turing machine"
# "UNIVAC", "unshielded twisted pair cable"
# "UNIVAC", "universal unique identifier"
# "UNIVAC", "University of Washington Information Navigator"
# "UPC", "user"
# "UPI", "user"
# "UPnP", "XP mode"
# "UPS", "user"
# "UPS", "versus"
# "URC", "user"
# "URC", "versus"
# "URI", "user"
# "URI", "versus"
# "URL", "user"
# "URL", "versus"
# "URN", "user"
# "URN", "Version"
# "URN", "versus"
# "USB", "user"
# "USMT", "user"
# "USMT", "Unicode Transformation Format"
# "USMT", "voicemail"
# "USMT", "XP mode"
# "USP", "user"
# "USRT", "universal unique identifier"
# "USRT", "user experience"
# "USRT", "Ultra Extended Graphics Array"
# "USWC", "user experience"
# "Uuencode", "XP mode"
# "VAC", "voicemail"
# "VAC", "versus"
# "VADSL", "version control"
# "VADSL", "very high data rate DSL"
# "VADSL", "Version"
# "VADSL", "VHSIC Hardware Description Language "
# "VADSL", "Vesa Local Bus"
# "VADSL", "Vesa Local Bus"
# "VADSL", "VideoLAN"
# "VADSL", "voicemail"
# "VADSL", "versus"
# "VADSL", "width"
# "VADSL", "Wideband Code Division Multiple Access"
# "VAN", "Version"
# "VAN", "VideoLAN"
# "VAN", "versus"
# "VAR", "Version"
# "VAR", "versus"
# "VB", "versus"
# "VBR", "versus"
# "VBScript", "video buffering verifier"
# "VBScript", "version control"
# "VBScript", "virtual circuit"
# "VBScript", "virtual control program interface"
# "VBScript", "video cassette recorder"
# "VBScript", "voltage direct current"
# "VBScript", "visual display unit"
# "VBScript", "VHSIC Hardware Description Language "
# "VBScript", "virtual host"
# "VBScript", "very important person"
# "VBScript", "very-large-scale integration"
# "VBScript", "Versa Module Eurocard bus"
# "VBScript", "virtual private server"
# "VBScript", "Web-based Enterprise Management"
# "VBScript", "working draft"
# "VBScript", "Windows metafile format"
# "VBScript", "Website META Language"
# "VBScript", "World of Warcraft"
# "VBScript", "what you see is what you print"
# "VBScript", "extended density format"
# "VBV", "versus"
# "VC", "voicemail"
# "VC", "versus"
# "VC", "voicemail"
# "VC", "versus"
# "VC", "voicemail"
# "VC", "versus"
# "VC", "voicemail"
# "VC", "versus"
# "VCEG", "voicemail"
# "VCEG", "versus"
# "VCEG", "voicemail"
# "VCEG", "versus"
# "VCI", "voicemail"
# "VCI", "versus"
# "VCPI", "voicemail"
# "VCPI", "versus"
# "VCR", "voicemail"
# "VCR", "versus"
# "VDC", "VideoLAN"
# "VDC", "versus"
# "VDD", "VideoLAN"
# "VDD", "versus"
# "VDSL", "Version"
# "VDSL", "VHSIC Hardware Description Language "
# "VDSL", "Vesa Local Bus"
# "VDSL", "Vesa Local Bus"
# "VDSL", "VideoLAN"
# "VDSL", "voicemail"
# "VDSL", "versus"
# "VDSL", "width"
# "VDSL", "Wideband Code Division Multiple Access"
# "VDU", "VideoLAN"
# "VDU", "versus"
# "Ver", "versus"
# "Veronica", "Video Electronics Standard Association"
# "Veronica", "VideoLAN"
# "Veronica", "voicemail"
# "Veronica", "virtual machine"
# "Veronica", "Virtual Network Computing"
# "Veronica", "Virtual Reality Modeling Language"
# "Veronica", "versus"
# "VESA", "versus"
# "VGA", "versus"
# "VGA", "versus"
# "VHDL", "VideoLAN"
# "VHDL", "voicemail"
# "VHDL", "voltage regulator module"
# "VHDL", "what the hell"
# "VHF", "versus"
# "Vhost", "VideoLAN"
# "Vhost", "voicemail"
# "Vhost", "versus"
# "Vhost", "virtual storage access method"
# "VHS", "versus"
# "VIM", "versus"
# "VIP", "versus"
# "VLAN", "VideoLAN"
# "VLAN", "versus"
# "VLB", "VideoLAN"
# "VLB", "versus"
# "VL Bus", "VideoLAN"
# "VL Bus", "voicemail"
# "VL Bus", "Versa Module Eurocard bus"
# "VL Bus", "versus"
# "VLC", "versus"
# "VLSI", "versus"
# "VM", "versus"
# "VM", "versus"
# "VM", "versus"
# "VMEbus", "versus"
# "VMM", "versus"
# "VMM", "versus"
# "VMS", "versus"
# "VMS", "versus"
# "VNC", "versus"
# "VOD", "versus"
# "VoIP", "versus"
# "VoMM", "versus"
# "VPN", "versus"
# "VPS", "versus"
# "VR", "versus"
# "VRAM", "versus"
# "VRLA", "versus"
# "VRM", "versus"
# "VRML", "versus"
# "VRML", "XP mode"
# "WCDMA", "Wired Equivalent Privacy"
# "WCDMA", "Wired for Management"
# "WCDMA", "Windows Pre-install Environment"
# "WCDMA", "word processing competency"
# "WCDMA", "Windows RAM"
# "Windows PE", "Windows socket"
# "Windows PE", "Windows metafile format"
# "Windows PE", "Windows Management Instrumentation"
# "Windows PE", "word of the day"
# "Windows PE", "Windows on Windows"
# "Windows PE", "WordPress"
# "Windows PE", "word processor"
# "Windows PE", "write pre-comp"
# "Windows PE", "word processing competency"
# "Windows PE", "Windows RAM"
# "Winsock", "word processor"
# "Winsock", "Windows RAM"
# "WML", "what the hell"
# "WML", "what the hell"
# "Wpcomp", "XP mode"
# "Wpcomp", "XP mode"
# "WYSIWYG", "cross-site scripting"
# "XHTML", "XP mode"
# "XML", "XP mode"
# "XMPP", "XP mode"
# "XMS", "XP mode"
# 9832 FALSE POSITIVE detections out of 1695149 created false examples

# %%
b = calc_fn(match_rating_comparison)
print(b)
# Out:
# "AA", "Anti-alias"
# ##################################
# "AAC", "Advanced Audio Coding"
# ##################################
# "AAM", "autmoatic acoustic management"
# ##################################
# "AAS", "Auto Area Segmentation"
# ##################################
# "AAS", "as a service"
# ##################################
# "ABC", "Atanasoff-Berry Computer"
# ##################################
# "ABIOS", "Advanced BIOS"
# ##################################
# "ABP", "AdBlock Plus"
# ##################################
# "AC", "anonymous coward"
# ##################################
# "AC", "Asheron's Call"
# ##################################
# "AC", "alternating current"
# ##################################
# "ACE", "access control entry"
# ##################################
# "Ack", "acknowledgment"
# ##################################
# "ACL", "access control list"
# ##################################
# "ACM", "Association for Computing Machinery"
# ##################################
# "ACPI", "Advanced Configuration and Power Interface"
# ##################################
# "ACR", "annual compliance report"
# ##################################
# "ACR", "actual cell rate"
# ##################################
# "ACR", "attenuation crosstalk ratio"
# ##################################
# "ACR", "absolute cell reference"
# ##################################
# "ACS", "access control system"
# ##################################
# "AD", "Active Directory"
# ##################################
# "ADB", "Apple Desktop Bus"
# ##################################
# "ADB", "Android Debug Bridge"
# ##################################
# "ADC", "analog-to-digital"
# ##################################
# "ADO", "ActiveX Data Object"
# ##################################
# "ADSI", "analog display service interface"
# ##################################
# "ADSI", "Active Directory Service Interface"
# ##################################
# "ADSL", "asymmetric digital subscriber line"
# ##################################
# "AE", "automatic exposure"
# ##################################
# "AE", "After Effects"
# ##################################
# "AES", "Advanced Encryption Standard"
# ##################################
# "AF", "Autofocus"
# ##################################
# "AGP", "accelerated graphics port"
# ##################################
# "AHCI", "Advanced Host Controller Interface"
# ##################################
# "AI", "artificial intelligence"
# ##################################
# "AIM", "Apple, IBM and Motorola"
# ##################################
# "AIM", "AOL Instant Messenger"
# ##################################
# "AIML", "Artificial Intelligent Markup Language"
# ##################################
# "AIMM", "AGP in-line memory module"
# ##################################
# "AIO", "All-in-One"
# ##################################
# "AIX", "advanced interactive executive"
# ##################################
# "AJAX", "Asynchronous JavaScript and XML"
# ##################################
# "AKA", "also known as"
# ##################################
# "ALU", "arithmetic logic unit"
# ##################################
# "AM", "ante meridiem"
# ##################################
# "AM", "amplitude modulation"
# ##################################
# "AMA", "ask me anything"
# ##################################
# "AMOLED", "active-matrix organic light-emitting diode"
# ##################################
# "ANI", "Automatic Number Identification"
# ##################################
# "ANSI", "American National Standards Institute"
# ##################################
# "AOP", "auto operator"
# ##################################
# "AOP", "aspect-oriented programming"
# ##################################
# "AOSP", "Android Open Source Project"
# ##################################
# "API", "application programming interface"
# ##################################
# "APIC", "Advanced Programmable Interrupt Controller"
# ##################################
# "APIPA", "Automatic Private Internet Protocol Addressing"
# ##################################
# "APK", "Android package file"
# ##################################
# "APM", "advanced power management"
# ##################################
# "App", "application"
# ##################################
# "APT", "advanced persistent threat"
# ##################################
# "APT", "advanced packaging tool"
# ##################################
# "APU", "advanced processing unit"
# ##################################
# "APU", "accelerated processing unit"
# ##################################
# "AR", "augmented reality"
# ##################################
# "ARCnet", "Attached Resource Computer network"
# ##################################
# "Arg", "argument"
# ##################################
# "ARP", "Address Resolution Protocol"
# ##################################
# "ARPA", "address and routing parameter area"
# ##################################
# "ARPA", "Advanced Research Projects Agency"
# ##################################
# "ARPANET", "Advanced Research Projects Agency Network"
# ##################################
# "ARQ", "automatic repeat request"
# ##################################
# "AS", "autonomous system"
# ##################################
# "ASAP", "as soon as possible"
# ##################################
# "ASCII", "American Standard Code for Information Interchange"
# ##################################
# "ASME", "American Society of Mechanical Engineers"
# ##################################
# "ASMR", "autonomous sensory meridian response"
# ##################################
# "ASN", "autonomous system number"
# ##################################
# "ASN.1", "abstract syntax number one"
# ##################################
# "ASP", "answer set programming"
# ##################################
# "ASP", "authorized service provider"
# ##################################
# "ASP", "application service provider"
# ##################################
# "ASP", "Active Server Pages"
# ##################################
# "ASPI", "advanced SCSI programming interface"
# ##################################
# "ASR", "automatic speech recognition"
# ##################################
# "ASR", "automated system recovery "
# ##################################
# "AT", "advanced technology"
# ##################################
# "ATA", "Advanced Technology Attachment"
# ##################################
# "ATAPI", "AT Attachment Packet Interface"
# ##################################
# "ATC", "advanced transfer cache"
# ##################################
# "ATF", "above the fold"
# ##################################
# "ATM", "automated teller machine"
# ##################################
# "ATM", "at the moment"
# ##################################
# "ATM", "ascynchronous transfer mode"
# ##################################
# "ATRAC", "Adaptive Transform Acoustic Coding"
# ##################################
# "ATX", "Advanced Technology eXtended"
# ##################################
# "AU", "arithmetic unit"
# ##################################
# "AUI", "Attachment Unit Interface"
# ##################################
# "AUP", "acceptable use policy"
# ##################################
# "Auto", "automobile"
# ##################################
# "Auto", "autonomous"
# ##################################
# "Auto", "automatic"
# ##################################
# "AV", "aperture value"
# ##################################
# "AV", "antivirus"
# ##################################
# "AVC", "Advanced Video Coding"
# ##################################
# "AVI", "Audio Video Interleaved"
# ##################################
# "AVR", "automatic voice response"
# ##################################
# "AVR", "automatic voice recognition"
# ##################################
# "AVR", "automatic voltage regulator"
# ##################################
# "AWS", "Amazon Web Services"
# ##################################
# "B2B", "business-to-business"
# ##################################
# "B2B", "business-to-consumer"
# ##################################
# "BAE", "before anyone else"
# ##################################
# "Basic", "Beginners All-purpose Symbolic Instruction Code"
# ##################################
# "BB", "broadband"
# ##################################
# "BBS", "be back shortly"
# ##################################
# "BBS", "bulletin board system"
# ##################################
# "BBS", "BIOS boot specification"
# ##################################
# "BC", "before Christ"
# ##################################
# "BCC", "blind carbon copy"
# ##################################
# "BCD", "binary-coded decimal"
# ##################################
# "BCP", "best current practices"
# ##################################
# "BCPL", "Basic Combined Programming Language"
# ##################################
# "BD", "Blu-ray disc"
# ##################################
# "BDC", "backup domain controller"
# ##################################
# "BDF", "Glyph Bitmap Distribution Format"
# ##################################
# "BDI", "bidirectional isolation"
# ##################################
# "BDO", "bidirectional override"
# ##################################
# "BER", "beyond economical repair"
# ##################################
# "BER", "bit error rate"
# ##################################
# "BERT", "bit error rate test"
# ##################################
# "BERT", "bit error rate tester"
# ##################################
# "BF", "Battlefield"
# ##################################
# "BG", "battleground"
# ##################################
# "BG", "bad game"
# ##################################
# "BG", "background"
# ##################################
# "BGA", "ball grid array"
# ##################################
# "BGMP", "Border Gateway Multicast Protocol"
# ##################################
# "BGP", "Border Gateway Protocol"
# ##################################
# "BHO", "Browser Helper Object"
# ##################################
# "Bi-di", "bidirectional"
# ##################################
# "BIND", "Berkeley Internet Name Domain"
# ##################################
# "BIO", "biography"
# ##################################
# "BIOS", "basic input/output system"
# ##################################
# "BISYNC", "BinarySynchronous Communications"
# ##################################
# "Bit", "binary digit"
# ##################################
# "BITNET", "because it's time network"
# ##################################
# "BIU", "bold, italic, underline"
# ##################################
# "BNC", "Bayonet Neill-Concelman"
# ##################################
# "BO", "back orifice"
# ##################################
# "BOFH", "Bastard Operator From Hell"
# ##################################
# "BOINC", "Berkeley Open Infrastructure for Network Computing"
# ##################################
# "BOM", "beginning of medium"
# ##################################
# "BOM", "beginning of message"
# ##################################
# "BOM", "bill of materials"
# ##################################
# "BOM", "byte order mark"
# ##################################
# "BPB", "BIOS pattern block"
# ##################################
# "BPDU", "Bridge Protocol Data Unit"
# ##################################
# "BPL", "broadband-over-powerline"
# ##################################
# "bps", "bits per second"
# ##################################
# "Bps", "bytes per second"
# ##################################
# "BPSK", "biphase shift keying"
# ##################################
# "BRI", "basic rate interface"
# ##################################
# "BSB", "back-side bus"
# ##################################
# "BSC", "Binary Synchronous Communications"
# ##################################
# "BSoD", "Blue Screen of Death"
# ##################################
# "BSoD", "Black Screen of Death"
# ##################################
# "BSS", "basic service set"
# ##################################
# "BTC", "Behavior Tech Computers"
# ##################################
# "BTDT", "been there done that"
# ##################################
# "BTX", "Balanced Technology eXtended"
# ##################################
# "C", "Celsius"
# ##################################
# "CA", "certificate authority"
# ##################################
# "Cab", "Cabinet file"
# ##################################
# "CAD", "computer-aided design"
# ##################################
# "CAP", "Competitive Access Provider"
# ##################################
# "CAPS", "CapsLock"
# ##################################
# "CAPTCHA", "Completely Automated Public Turing test to tell Computers and Humans Apart"
# ##################################
# "CAS", "column access strobe"
# ##################################
# "CAS", "column address select"
# ##################################
# "CASC", "Certificate Authority Security Council"
# ##################################
# "CAT", "Central Africa Time"
# ##################################
# "CATV", "Community Access Television"
# ##################################
# "CBL", "calculator based labs"
# ##################################
# "CBT", "computer-based training"
# ##################################
# "CC", "Cursor control"
# ##################################
# "CC", "Creative Commons"
# ##################################
# "CC", "C compiler"
# ##################################
# "CC", "carbon copy"
# ##################################
# "CCC", "Catalyst Control Center"
# ##################################
# "CCD", "charge-coupled device"
# ##################################
# "CCDE", "Cisco Certified Design Expert"
# ##################################
# "CCFL", "cold cathode fluorescent lighting"
# ##################################
# "CCIE", "Cisco Certified Internetworking Expert"
# ##################################
# "CCITT", "Comit Consultatif International Tlphonique et Tlgraphique"
# ##################################
# "CCNA", "Cisco Certified Network Associate"
# ##################################
# "CCNP", "Cisco Certified Network Professional"
# ##################################
# "CCS", "common command set"
# ##################################
# "CCS", "call-control signaling "
# ##################################
# "CCTV", "closed circuit television"
# ##################################
# "CCW", "counterclockwise"
# ##################################
# "CD", "compact disc"
# ##################################
# "CD", "change directory"
# ##################################
# "CDA", "compact audio disc"
# ##################################
# "CDA", "Communication Decency Act"
# ##################################
# "CDDA", "compact disc digital audio"
# ##################################
# "CDDB", "compact disc database"
# ##################################
# "CDDI", "Copper Distributed Data Interface"
# ##################################
# "CDE", "Common Desktop Environment"
# ##################################
# "CDfs", "Compact Disc file system"
# ##################################
# "CD-i", "Compact Disc Interactive"
# ##################################
# "CDMA", "Code Division Multiple Access"
# ##################################
# "CDN", "content distribution network"
# ##################################
# "CDN", "content delivery network"
# ##################################
# "CDP", "Cache Discovery Protocol"
# ##################################
# "CDP", "Certificate in Data Processing"
# ##################################
# "CDP", "Columbia Data Products"
# ##################################
# "CDP", "content delivery platform"
# ##################################
# "CDP", "content discovery platform, "
# ##################################
# "CDP", "continuous data protection"
# ##################################
# "CD-R", "Compact Disc Recordable"
# ##################################
# "CDRFS", "CD-R file system"
# ##################################
# "CD-ROM", "Compact Disc Read-Only Memory"
# ##################################
# "CD-RW", "Compact Disc Re-Writable"
# ##################################
# "CD-WO", "Compact Disc Write Once"
# ##################################
# "CE", "cancel entry"
# ##################################
# "CE", "consumer edition"
# ##################################
# "CE", "compact edition"
# ##################################
# "CE", "collector's edition"
# ##################################
# "CentOS", "Community Enterprise Operating System"
# ##################################
# "CEO", "chief executive officer"
# ##################################
# "CERN", "Conseil Europeen pour la Recherche Nuclaire"
# ##################################
# "CERT", "Computer Emergency Response Team"
# ##################################
# "Cert", "certification"
# ##################################
# "Cert", "certificate"
# ##################################
# "CES", "Consumer Electronics Show"
# ##################################
# "CF", "CompactFlash"
# ##################################
# "CFPM", "cubic feet per minute"
# ##################################
# "CGA", "Color Graphics Adapter"
# ##################################
# "CGI", "computer-generated imagery"
# ##################################
# "CGI", "common gateway interface"
# ##################################
# "CH", "College Humor"
# ##################################
# "CH", "Computer Hope"
# ##################################
# "CHAP", "Challenge-Handshake Authentication Protocol"
# ##################################
# "Char", "character"
# ##################################
# "chdir", "change directory"
# ##################################
# "CHS", "cylinder-head-sector"
# ##################################
# "CIDR", "classless inter-domain routing"
# ##################################
# "CIFS", "common Internet file system"
# ##################################
# "CIM", "common information model"
# ##################################
# "CIR", "committed information rate"
# ##################################
# "CISC", "complex instruction set computer"
# ##################################
# "CISSP", "certified information systems security professional"
# ##################################
# "CLCC", "ceramic leadless lead carrier"
# ##################################
# "CLI", "command-line interface"
# ##################################
# "CLNS", "connectionless network service"
# ##################################
# "CLOS", "Common Lisp object system"
# ##################################
# "CLR", "common language runtime"
# ##################################
# "CLUT", "color lookup table"
# ##################################
# "CMA", "Computer Misuse Act"
# ##################################
# "CMC", "computer-mediated communication"
# ##################################
# "CMOS", "complementary metal-oxide semiconductor"
# ##################################
# "CMS", "content management system"
# ##################################
# "CMYK", "cyan magenta yellow black"
# ##################################
# "CNE", "Certified Novell Engineer"
# ##################################
# "CNR", "Communication and Network Riser"
# ##################################
# "CNST", "Certified Network Systems Technician"
# ##################################
# "CO", "central office"
# ##################################
# "COA", "Certificate of Authenticity"
# ##################################
# "COAST", "Cache On A STick"
# ##################################
# "COB", "chip on board"
# ##################################
# "COB", "close of business"
# ##################################
# "COBOL", "Common Business Oriented Language"
# ##################################
# "Code", "source code"
# ##################################
# "Codec", "Compression / Decompression"
# ##################################
# "Codec", "COmpression / DECompression"
# ##################################
# "Coil", "electromagnetic coil"
# ##################################
# "COLA", "comp.os.linux.announce"
# ##################################
# "COM", "Computer Output Microfilm"
# ##################################
# "COM", "Component Object Model"
# ##################################
# "COMDEX", "Computer Dealers' Exhibition"
# ##################################
# "Con", "conference"
# ##################################
# "Con", "confidence"
# ##################################
# "COPPA", "Children's Online Privacy Protection Act"
# ##################################
# "COPPA", "California Online Privacy Protection Act"
# ##################################
# "Core", "core dump"
# ##################################
# "CPA", "cost per acquisition"
# ##################################
# "CPA", "cost per action"
# ##################################
# "CPAN", "comprehensive Perl archive network"
# ##################################
# "CPC", "cost per click"
# ##################################
# "CPGA", "ceramic pin grid array"
# ##################################
# "CPI", "characters per inch"
# ##################################
# "CPL", "Combined Programming Language"
# ##################################
# "CPM", "cost per mile"
# ##################################
# "CPM", "cost per thousand"
# ##################################
# "CPS", "characters per second"
# ##################################
# "CPTM", "cost per targeted thousand"
# ##################################
# "CPU", "central processing unit"
# ##################################
# "CR", "carriage return"
# ##################################
# "CRC", "cyclic redundancy check"
# ##################################
# "CREN", "Corporation for Research and Educational Networking"
# ##################################
# "CRL", "Certificate Revocation List"
# ##################################
# "CRM", "customer relationship management"
# ##################################
# "CRT", "cathode ray tube"
# ##################################
# "CS", "customer service"
# ##################################
# "CS", "computer science"
# ##################################
# "CS", "counter-strike"
# ##################################
# "CS", "cable select"
# ##################################
# "CS", "code segment"
# ##################################
# "CSMA/CD", "carrier sense multiple access/collision detection"
# ##################################
# "CSNET", "Computer Science Network"
# ##################################
# "CSS", "Cascading Style Sheets"
# ##################################
# "CSS", "chirp spread spectrum"
# ##################################
# "CSS", "Content Scramble System"
# ##################################
# "CSS", "cascading style sheets"
# ##################################
# "CST", "Computer Service Technician"
# ##################################
# "CSU/DSU", "Channel Service Unit/Data Service Unit"
# ##################################
# "CSV", "comma-separated values"
# ##################################
# "CTA", "call to action"
# ##################################
# "CTD", "crash to desktop"
# ##################################
# "CTF", "Capture the Flag"
# ##################################
# "CTO", "chief technical officer"
# ##################################
# "CTO", "chief technology officer"
# ##################################
# "CTR", "click-through rate"
# ##################################
# "Ctrl", "Control key"
# ##################################
# "CTS", "Clear to Send"
# ##################################
# "CTTY", "change teletype"
# ##################################
# "CU", "control unit"
# ##################################
# "CUI", "command-line user interface"
# ##################################
# "CUI", "character user interface"
# ##################################
# "CUPS", "Common Unix Printing System"
# ##################################
# "CUT", "Coordinated Universal Time"
# ##################################
# "CVE", "Common Vulnerabilities and Exposures"
# ##################################
# "CVS", "Concurrent Version System"
# ##################################
# "CWIS", "Campus Wide Information System"
# ##################################
# "D", "depth"
# ##################################
# "D2D", "disk-to-disk"
# ##################################
# "DAC", "discretionary access control"
# ##################################
# "DAC", "digital-to-analog converter"
# ##################################
# "DACL", "discretionary access control list"
# ##################################
# "DAE", "digital audio extraction"
# ##################################
# "DARPA", "Defense Advanced Research Projects Agency"
# ##################################
# "DART", "Data Access in Real Time"
# ##################################
# "DART", "Dynamic Analysis and Replanning Tool"
# ##################################
# "DART", "Microsoft Diagnostics and Recovery Toolset"
# ##################################
# "DASD", "direct access storage device"
# ##################################
# "DASP", "Disk Anti-Shock Protection"
# ##################################
# "DASP", "Drive Active Slave Present"
# ##################################
# "DASP", "Dynamic Adaptive Speculative Pre-Processor"
# ##################################
# "DAT", "Digital Audio Tape"
# ##################################
# "DAW", "digital audio workstation"
# ##################################
# "DB", "database"
# ##################################
# "DBA", "database analyst"
# ##################################
# "DBA", "decibels adjust"
# ##################################
# "DBA", "doing business as"
# ##################################
# "DBA", "database administrator"
# ##################################
# "DBAN", "Darik's Boot and Nuke"
# ##################################
# "DC", "domain controller"
# ##################################
# "DC", "data center"
# ##################################
# "DC", "disconnect"
# ##################################
# "DC", "direct current"
# ##################################
# "DCC", "Direct Client-to-Client"
# ##################################
# "DCE", "data circuit-terminating equipment"
# ##################################
# "DCE", "data communication equipment"
# ##################################
# "DCE", "Desktop Composting Engine"
# ##################################
# "DCE", "distributed computing environment"
# ##################################
# "DCIM", "digital camera images"
# ##################################
# "DCOM", "Distributed Component Object Model"
# ##################################
# "DD", "double density"
# ##################################
# "DDE", "Dynamic Data Exchange"
# ##################################
# "DDK", "driver development kit"
# ##################################
# "DDL", "data definition language"
# ##################################
# "DDNS", "dynamic DNS"
# ##################################
# "DDO", "disk drive overlay"
# ##################################
# "DDO", "Dungeons & Dragons Online"
# ##################################
# "DDoS", "Distributed Denial of Service"
# ##################################
# "DDP", "Datagram Delivery Protocol"
# ##################################
# "DDR", "dial-on-demand routing"
# ##################################
# "DDR", "double data rate"
# ##################################
# "DDR2", "double data rate two"
# ##################################
# "DDR3", "double data rate three"
# ##################################
# "DDR4", "double data rate four"
# ##################################
# "DDS", "Digital Data Storage"
# ##################################
# "DEA", "Data Encryption Algorithm"
# ##################################
# "DEC", "Digital Equipment Corporation"
# ##################################
# "DES", "Data Encryption Standard"
# ##################################
# "DFMC", "direct methanol fuel cell"
# ##################################
# "DHCP", "Dynamic Host Configuration Protocol"
# ##################################
# "DHTML", "dynamic Hypertext Markup Language"
# ##################################
# "DID", "direct inward dialing"
# ##################################
# "DIF", "Directory Interchange Format"
# ##################################
# "DIME", "direct Internet message encapsulation"
# ##################################
# "DIMM", "dual in-line memory module"
# ##################################
# "DIP", "dual in-line package"
# ##################################
# "DIVX", "digital video express"
# ##################################
# "DIX", "Digitial, Intel, and Xerox"
# ##################################
# "DJ", "disc jockey"
# ##################################
# "DL", "download"
# ##################################
# "D/L", "download"
# ##################################
# "DLA", "drive letter access"
# ##################################
# "DLC", "downloadable content"
# ##################################
# "DLC", "digital loop carrier"
# ##################################
# "DLC", "Data Link Control"
# ##################################
# "DLL", "dynamic-link library"
# ##################################
# "DLNA", "Digital Living Network Alliance"
# ##################################
# "DLP", "Digital Light Processing"
# ##################################
# "DLP", "discrete logarithm problem"
# ##################################
# "DLP", "data level parallelism"
# ##################################
# "DLP", "data loss prevention"
# ##################################
# "DLT", "digital linear tape"
# ##################################
# "DM", "Device Manager"
# ##################################
# "DM", "deathmatch"
# ##################################
# "DM", "direct message"
# ##################################
# "DMA", "direct memory access"
# ##################################
# "DMAC", "Direct Memory Access Control"
# ##################################
# "DMAR", "destination memory address register"
# ##################################
# "DMCA", "Digital Millennium Copyright Act"
# ##################################
# "DMI", "Desktop Management Interface"
# ##################################
# "DML", "data manipulation language"
# ##################################
# "DMZ", "demilitarized zone"
# ##################################
# "DNS", "Domain Name System"
# ##################################
# "DOA", "dead on arrival"
# ##################################
# "DoCoMo", "Do Communications Over Mobile"
# ##################################
# "DOD", "Department of Defense"
# ##################################
# "DoS", "denial of service"
# ##################################
# "DOS", "disk operating system"
# ##################################
# "DoT", "damage over time"
# ##################################
# "Double", "Double-precision floating-point"
# ##################################
# "DP", "DisplayPort"
# ##################################
# "DPI", "dots per inch"
# ##################################
# "Dpkg", "Debian package manager"
# ##################################
# "DPMI", "DOS Protected Mode Interface"
# ##################################
# "DPS", "damage per second"
# ##################################
# "DRAM", "dynamic random access memory"
# ##################################
# "DRM", "digital rights management"
# ##################################
# "Drop", "malware dropper"
# ##################################
# "DRQ", "data request"
# ##################################
# "DS", "drive select"
# ##################################
# "DSAP", "Destination Service Access Point"
# ##################################
# "DSL", "Damn Small Linux"
# ##################################
# "DSL", "digital subscriber line"
# ##################################
# "DSO", "data source object"
# ##################################
# "DSP", "drive secondary present"
# ##################################
# "DSP", "digital signal processor"
# ##################################
# "DSR", "Dynamic Source Routing"
# ##################################
# "DSR", "Dell System Restore"
# ##################################
# "DSS", "Digital Signature Standard"
# ##################################
# "DSS", "Digital Satellite Service"
# ##################################
# "DSVD", "Digital Simultaneous Voice and Data"
# ##################################
# "DTE", "data terminating equipment"
# ##################################
# "DTE", "data terminal equipment"
# ##################################
# "DTR", "Data Terminal Ready"
# ##################################
# "DTS", "data transformation services"
# ##################################
# "DTS", "Digital Theater Sound"
# ##################################
# "DTS", "digital thermal sensor"
# ##################################
# "DTX", "discontinuous transmission"
# ##################################
# "DUN", "Dial-Up Networking"
# ##################################
# "DUST", "did you see that"
# ##################################
# "DUT", "device under test"
# ##################################
# "DVD", "digital versatile disc"
# ##################################
# "DVI", "digital visual interface"
# ##################################
# "DVMT", "Dynamic Video Memory Technology"
# ##################################
# "DVR", "Digital Video Recorder"
# ##################################
# "DxDiag", "DirectX diagnostics"
# ##################################
# "E", "Enlightenment"
# ##################################
# "EA", "Electronic Arts"
# ##################################
# "EAI", "enterprise application integration"
# ##################################
# "EAP", "Extensible Authentication Protocol"
# ##################################
# "EAP-FAST", "Flexible Authentication via Secure Tunneling"
# ##################################
# "EAPROM", "Electronically Alterable Programmable Read-Only Memory"
# ##################################
# "Eb / EB", "Exabit / Exabyte"
# ##################################
# "ECC", "error-correcting code"
# ##################################
# "ECDSA", "Elliptic Curve Digital Signature Algorithm"
# ##################################
# "ECHS", "extended cylinder-head-sector"
# ##################################
# "ECMA", "European Computer Manufacturers Association"
# ##################################
# "ECP", "Extended Capabilities Port"
# ##################################
# "EDA", "electronic design automation"
# ##################################
# "EDI", "electronic data interchange"
# ##################################
# "EDIINT", "electronic data interchange-Internet integration"
# ##################################
# "EDO", "Extended Data Out"
# ##################################
# "EDP", "electronic data processing"
# ##################################
# "EDSAC", "Electronic Delay Storage Automatic Calculator"
# ##################################
# "EDVAC", "Electronic Discrete Variable Automatic Computer"
# ##################################
# "EEPROM", "electrically erasable programmable read-only memory"
# ##################################
# "EFI", "Extensible Firmware Interface"
# ##################################
# "EFS", "Encrypting File System"
# ##################################
# "EGA", "Enhanced Graphics Adapter"
# ##################################
# "eGPU", "external graphics processing unit"
# ##################################
# "EHCI", "enhanced host controller interface"
# ##################################
# "EIA", "Electronic Industries Alliance"
# ##################################
# "EIDE", "enhanced integrated drive electronics"
# ##################################
# "EIGRP", "Enhanced Interior Gateway Routing Protocol"
# ##################################
# "EISA", "Extended Industry Standard Architecture"
# ##################################
# "EISA", "Extended ISA"
# ##################################
# "EIST", "enhanced Intel SpeedStep technology"
# ##################################
# "ELD", "electroluminescent display"
# ##################################
# "ELF", "extremely low frequency"
# ##################################
# "EM", "emphasized"
# ##################################
# "EMF", "enhanced metafile"
# ##################################
# "EMF", "electromotive force"
# ##################################
# "EMI", "electromagnetic interference"
# ##################################
# "EMM", "expanded-memory manager"
# ##################################
# "EMS", "expanded memory specification"
# ##################################
# "EMS", "emergency management services "
# ##################################
# "ENIAC", "Electronic Numerical Integrator and Calculator"
# ##################################
# "EOF", "end-of-file"
# ##################################
# "EOL", "End-of-Line"
# ##################################
# "EOM", "end-of-message"
# ##################################
# "EOP", "end-of-page"
# ##################################
# "EOT", "end of topic"
# ##################################
# "EOT", "End-of-Transmission"
# ##################################
# "EOW", "end of week"
# ##################################
# "EPD", "electronic paper display"
# ##################################
# "EPIC", "Electronic Privacy Information Center"
# ##################################
# "EPP", "Enhanced Parallel Port"
# ##################################
# "EPROM", "Erasable Programmable Read-Only Memory"
# ##################################
# "EPS", "encapsulated PostScript"
# ##################################
# "ePUB", "electronic publication"
# ##################################
# "EQ", "equalizer"
# ##################################
# "EQ", "EverQuest"
# ##################################
# "ESA", "Entertainment Software Association"
# ##################################
# "ESCD", "Extended System Configuration Data"
# ##################################
# "ESD", "electrostatic discharge"
# ##################################
# "ESDI", "Enhanced Small Disk Interface"
# ##################################
# "ESI", "Enhanced Serial Interface"
# ##################################
# "ESP", "e-mail server provider"
# ##################################
# "ESRB", "Entertainment Software Rating Board"
# ##################################
# "ETA", "estimated time of arrival"
# ##################################
# "ETA-I", "Electronic Technicians Association International"
# ##################################
# "ETX", "End-of-Text"
# ##################################
# "EULA", "End-User License Agreement"
# ##################################
# "EVD", "enhanced versatile disc"
# ##################################
# "EV-DO", "Evolution-Data Only"
# ##################################
# "EVP", "enhanced virus protection"
# ##################################
# "F", "fahrenheit"
# ##################################
# "FAD", "functioning as designed"
# ##################################
# "Famicom", "family computer"
# ##################################
# "FAQ", "frequently asked questions"
# ##################################
# "FAST", "Flexible Authentication via Secure Tunneling"
# ##################################
# "FAT", "file allocation table"
# ##################################
# "FAU", "file allocation unit"
# ##################################
# "FB", "facebook"
# ##################################
# "FCC", "Federal Communications Commission"
# ##################################
# "FCIP", "Fibre Channel over IP"
# ##################################
# "FC-PGA", "flip-chip pin grid array"
# ##################################
# "FD", "floppy drive"
# ##################################
# "FDC", "Floppy Disk Controller"
# ##################################
# "FDD", "floppy disk drive"
# ##################################
# "FDDI", "Fiber Distributed Data Interface"
# ##################################
# "FDHP", "Full Duplex Handshaking Protocol"
# ##################################
# "FF", "fast forward"
# ##################################
# "FF", "form feed"
# ##################################
# "FF", "friends forever"
# ##################################
# "FF", "Firefox"
# ##################################
# "FFA", "free for all"
# ##################################
# "FFS", "freefall sensor"
# ##################################
# "FHD", "Full High Definition"
# ##################################
# "FIF", "fractal image format"
# ##################################
# "FIFO", "first in, first out"
# ##################################
# "FiOS", "Fiber Optic Service"
# ##################################
# "FIPS", "Federal Information Processing Standards"
# ##################################
# "Fixed", "fixed-point"
# ##################################
# "FLAC", "Free Lossless Audio Codec"
# ##################################
# "Float", "floating-point"
# ##################################
# "FLOPS", "Floating-Point Operation Per Second"
# ##################################
# "FM", "frequency modulation"
# ##################################
# "FMV", "full motion video"
# ##################################
# "Fn", "function"
# ##################################
# "FNBN", "for nerds by nerds"
# ##################################
# "FNEA", "full name and e-mail address"
# ##################################
# "FNR", "format and restore"
# ##################################
# "FOIA", "Freedom of Information Act"
# ##################################
# "FOIRL", "fiber-optic inter-repeater links"
# ##################################
# "FOMO", "fear of missing out"
# ##################################
# "FOSS", "free and open-source software"
# ##################################
# "FP", "FrontPage"
# ##################################
# "FP", "fast page"
# ##################################
# "FPGA", "field-programmable gate array"
# ##################################
# "FPM", "fast page mode"
# ##################################
# "FPROM", "field programmable read-only memory"
# ##################################
# "FPS", "frames per second"
# ##################################
# "FPU", "floating-point unit"
# ##################################
# "FQDN", "fully qualified domain name"
# ##################################
# "FR", "Frame Relay"
# ##################################
# "FRAM", "Ferroelectric RAM"
# ##################################
# "FRU", "field-replacable unit"
# ##################################
# "FS", "file system"
# ##################################
# "FSB", "front-side bus"
# ##################################
# "FSM", "female seeking male"
# ##################################
# "FSO", "free-space optical communication"
# ##################################
# "FSP", "File Sharing Protocol"
# ##################################
# "Fstab", "file systems table"
# ##################################
# "FSTN", "film supertwist nematic"
# ##################################
# "FTAM", "file transfer, access and management"
# ##################################
# "FTC", "Federal Trade Commission"
# ##################################
# "FTP", "File Transfer Protocol"
# ##################################
# "FUD", "fear, uncertainty, and doubt"
# ##################################
# "FWH", "Firmware Hub"
# ##################################
# "FYI", "for your information"
# ##################################
# "G+", "Google Plus"
# ##################################
# "G2G", "government to government"
# ##################################
# "GA", "general availabililty"
# ##################################
# "GaAs", "Gallium Arsenide"
# ##################################
# "Gb / GB", "gigabit / gigabyte"
# ##################################
# "GBIC", "gigabit interface converter"
# ##################################
# "Gbps", "Gigabits per second"
# ##################################
# "GCC", "GNU Compiler Collection"
# ##################################
# "GCHQ", "Government Communications Headquarters"
# ##################################
# "GCR", "group code recording"
# ##################################
# "GDDR", "graphics double data rate"
# ##################################
# "GDI", "Graphics Device Interface"
# ##################################
# "GDPR", "General Data Protection Regulation"
# ##################################
# "GE", "General Electric"
# ##################################
# "GEM", "Graphics Environment Manager"
# ##################################
# "GFM", "GitHub Flavored Markdown"
# ##################################
# "Gib / GiB", "gibibit / gibibyte"
# ##################################
# "GIGO", "&quot;garbage in, garbage out&quot;"
# ##################################
# "GIMP", "GNU image manipulation program"
# ##################################
# "GIMPS", "great Internet mersenne prime search"
# ##################################
# "GIS", "Geographic Information System"
# ##################################
# "GIYF", "Google Is Your Friend"
# ##################################
# "GKS", "Graphical Kernel System"
# ##################################
# "GM", "gold master"
# ##################################
# "GM", "golden masters"
# ##################################
# "GM", "good morning"
# ##################################
# "GM", "good manners"
# ##################################
# "GM", "game masters"
# ##################################
# "GNU", "GNU's Not Unix"
# ##################################
# "Goat", "greatest of all time"
# ##################################
# "GPF", "general protection fault"
# ##################################
# "GPG", "GNU Privacy Guard"
# ##################################
# "GPL", "general public license"
# ##################################
# "GPO", "Group Policy Object"
# ##################################
# "GPPM", "graphic pages per minute"
# ##################################
# "GPRS", "General Packet Radio Service"
# ##################################
# "GPS", "Global Positioning System"
# ##################################
# "GPT", "GUID partition table"
# ##################################
# "GPU", "graphics processing unit"
# ##################################
# "Gram", "Instagram"
# ##################################
# "GRUB", "GRand Unified Bootloader"
# ##################################
# "GSM", "Global System for Mobile communication"
# ##################################
# "GT", "Greenwich Mean Time"
# ##################################
# "GTA", "Grand Theft Auto"
# ##################################
# "GTK", "GIMP toolkit"
# ##################################
# "GUI", "graphical user interface"
# ##################################
# "GUID", "globally unique identifier"
# ##################################
# "GWAM", "gross words a minute"
# ##################################
# "H", "height"
# ##################################
# "HACMP", "high availability cluster multiprocessing"
# ##################################
# "HAL", "hardware abstraction layer"
# ##################################
# "HAN", "home area network"
# ##################################
# "HBA", "host bus adapter"
# ##################################
# "HCI", "human computer interface"
# ##################################
# "HCL", "hardware compatibility list"
# ##################################
# "HD", "high-definition"
# ##################################
# "HD", "high-density"
# ##################################
# "HD", "hard drive"
# ##################################
# "HDC", "hard disk controller"
# ##################################
# "HDCP", "High-bandwidth Digital Content Protection"
# ##################################
# "HDD", "hard disk drive"
# ##################################
# "HD DVD", "High Definition Digital Versatile Disc"
# ##################################
# "HDLC", "High-level Data Link Control"
# ##################################
# "HDMI", "High-Definition Multimedia Interface"
# ##################################
# "HDML", "handheld device markup language"
# ##################################
# "HD-ROM", "high-density read-only memory"
# ##################################
# "HDSL", "high-bit-rate digital subscriber line"
# ##################################
# "HEIF", "High Efficiency Image File format"
# ##################################
# "HES", "hypertext editing system"
# ##################################
# "HEVC", "high efficiency video coding"
# ##################################
# "HFC", "hybrid fiber coax"
# ##################################
# "HFS", "hierarchical file system"
# ##################################
# "HGA", "Hercules graphics adapter"
# ##################################
# "HID", "human interface device"
# ##################################
# "Hiew", "hacker's view"
# ##################################
# "Hi-res", "high resolution"
# ##################################
# "HIT", "human intelligence task"
# ##################################
# "HLL", "high-level language"
# ##################################
# "HMA", "high-memory area"
# ##################################
# "HMU", "hit me up"
# ##################################
# "HOPE", "hackers on planet Earth"
# ##################################
# "HoT", "Heal over Time"
# ##################################
# "HP", "Hewlett-Packard"
# ##################################
# "HPA", "high-performance addressing"
# ##################################
# "HPD", "hybrid passive display"
# ##################################
# "HPFS", "high-performance file system"
# ##################################
# "HP-UX", "Hewlett Packard UniX"
# ##################################
# "HQ", "high-quality"
# ##################################
# "HR", "Human Resources"
# ##################################
# "HREF", "Hypertext reference"
# ##################################
# "HSB", "Hue, Saturation, and Brightness"
# ##################################
# "HSF", "heat sink and fan"
# ##################################
# "HSL", "Hue, Saturation, and Lightness"
# ##################################
# "HSSI", "High-Speed Serial Interface"
# ##################################
# "HSYNC", "Horizontal Synchronization"
# ##################################
# "HT", "Hyper-Threading"
# ##################################
# "HT", "HyperTransport"
# ##################################
# "HTML", "Hypertext Markup Language"
# ##################################
# "HTPC", "home theater personal computer"
# ##################################
# "HTTP", "Hypertext Transfer Protocol"
# ##################################
# "HUD", "heads up display"
# ##################################
# "Huh", "Have you heard"
# ##################################
# "HW", "hardware"
# ##################################
# "IAB", "Internet Architecture Board"
# ...
# ##################################
# "Spit", "Spam over Internet Telephony"
# ##################################
# "SPL", "systems programming language"
# ##################################
# "Spool", "simultaneous peripheral operatings online"
# ##################################
# "SPP", "Standard Parallel Port"
# ##################################
# "SPS", "Standard Power Supply"
# ##################################
# "SQL", "Structured Query Language"
# ##################################
# "SRAM", "static random access memory"
# ##################################
# "SS", "screenshot, South Sudan"
# ##################################
# "SSAP", "Source Service Access Point"
# ##################################
# "SSD", "solid-state drive"
# ##################################
# "SSE", "Streaming SIMD Extensions"
# ##################################
# "SSEM", "Small Scale Experimental Machine"
# ##################################
# "SSI", "small-scale integration"
# ##################################
# "SSID", "service set identifier"
# ##################################
# "SSL", "Secure Sockets Layer"
# ##################################
# "SSL", "Space Sciences Laboratory"
# ##################################
# "SSP", "storage service provider"
# ##################################
# "SSR", "solid-state relay"
# ##################################
# "SSTP", "Secure Socket Tunneling Protocol"
# ##################################
# "STM", "Synchronous Transport Module"
# ##################################
# "STN", "supertwisted nematic"
# ##################################
# "STP", "software test plan"
# ##################################
# "STP", "shielded twisted pair"
# ##################################
# "STP", "Spanning Tree Protocol"
# ##################################
# "STR", "Suspend-to-RAM"
# ##################################
# "STS", "synchronous transport signal"
# ##################################
# "Sub", "subscript"
# ##################################
# "SUID", "set user ID"
# ##################################
# "Sup", "superscript"
# ##################################
# "SVCD", "Super Video CD"
# ##################################
# "SVGA", "Super Video Graphics Array"
# ##################################
# "SW", "software"
# ##################################
# "SXGA", "Super Extended Graphics Array"
# ##################################
# "SXGA+", "Super XGA Plus"
# ##################################
# "SYN", "synchronize"
# ##################################
# "TA", "terminal adapter"
# ##################################
# "Ta", "Tantalum"
# ##################################
# "TACACS", "Terminal Access Controller Access Control System"
# ##################################
# "TAPI", "Telephony Application Programming Interface"
# ##################################
# "TAR", "tape archive"
# ##################################
# "TCO", "total cost of ownership"
# ##################################
# "TCPA", "Trusted Computer Platform Alliance"
# ##################################
# "TCP/IP", "Transmission Control Protocol/Internet Protocol"
# ##################################
# "TD", "table data"
# ##################################
# "TDD", "telecommunications device for the deaf"
# ##################################
# "TDM", "team deathmatch"
# ##################################
# "TDP", "thermal design power"
# ##################################
# "Tech", "technology"
# ##################################
# "TERA", "The Exiled Ream of Arborea"
# ##################################
# "TET", "text enhancement technology"
# ##################################
# "Texel", "texture element"
# ##################################
# "TFTP", "Trivial File Transfer Protocol"
# ##################################
# "TH", "table head"
# ##################################
# "THD", "total harmonic distortion"
# ##################################
# "Ti", "Titanium"
# ##################################
# "Ti", "Textas Instruments"
# ##################################
# "TIFF", "Tagged Image File Format"
# ##################################
# "TIGA", "Texas Instruments Graphics Architecture"
# ##################################
# "Tk", "toolkit"
# ##################################
# "T&amp;L", "transform, clipping, and lighting"
# ##################################
# "TLD", "top-level domain"
# ##################################
# "TLP", "thread-level parallelism"
# ##################################
# "TLS", "Transport Layer Security"
# ##################################
# "TM", "trademark"
# ##################################
# "TN", "twisted nematic"
# ##################################
# "TOF", "top of file"
# ##################################
# "TOPS", "transparent operating system"
# ##################################
# "Tor", "The Onion Router"
# ##################################
# "TOS", "type of service"
# ##################################
# "TOS", "terms of use"
# ##################################
# "TOS", "terms of service"
# ##################################
# "TOS", "tape operating system"
# ##################################
# "TPI", "tracks per inch"
# ##################################
# "TPM", "Trusted Platform Module"
# ##################################
# "TP-PMD", "Twisted-Pair Physical Medium Dependant"
# ##################################
# "TR", "technical report"
# ##################################
# "TRS", "Telecommunications Relay Service"
# ##################################
# "TSR", "terminate-and-stay-resident"
# ##################################
# "TT", "Turing test"
# ##################################
# "TTFB", "time to first byte"
# ##################################
# "TTL", "transistor-transistor logic"
# ##################################
# "TTS", "text-to-speech"
# ##################################
# "TTY", "teletypewriter"
# ##################################
# "TTY", "teletype"
# ##################################
# "TV", "television"
# ##################################
# "TXD", "trasmit data"
# ##################################
# "UA", "user agent"
# ##################################
# "UAC", "User Account Control"
# ##################################
# "Uarch", "microarchitecture"
# ##################################
# "UART", "Universal Asynchronous Receiver-Transmitter"
# ##################################
# "UC", "uppercase"
# ##################################
# "UCE", "unsolicited commercial e-mail"
# ##################################
# "UDF", "user-defined function"
# ##################################
# "UDF", "user-defined font"
# ##################################
# "UDF", "Universal Disk Format"
# ##################################
# "UDID", "Unique Device Identification"
# ##################################
# "UDMA", "Ultra Direct Memory Access"
# ##################################
# "UDP", "User Datagram Protocol"
# ##################################
# "UEFI", "Unified Extensible Firmware Interface"
# ##################################
# "UHCI", "Universal Host Controller Interface"
# ##################################
# "UHD", "Ultra High Definition"
# ##################################
# "UI", "user interface"
# ##################################
# "UL", "uplink"
# ##################################
# "UL", "upload"
# ##################################
# "UL", "unordered list"
# ##################################
# "ULSI", "Ultra Large Scale Integration"
# ##################################
# "UMA", "Upper Memory Area"
# ##################################
# "UMB", "upper memory block"
# ##################################
# "UPC", "universal product code"
# ##################################
# "UPI", "User Program Interface"
# ##################################
# "UPnP", "Universal Plug and Play"
# ##################################
# "UPS", "uninterruptible power supply"
# ##################################
# "URC", "Uniform Resource Characteristic"
# ##################################
# "URI", "Uniform Resource Identifier"
# ##################################
# "URL", "Uniform Resource Locator"
# ##################################
# "URN", "Uniform Resource Name"
# ##################################
# "USB", "universal serial bus"
# ##################################
# "USMT", "User State Migration Tool"
# ##################################
# "USP", "unique selling point"
# ##################################
# "USRT", "Universal Synchronous Receiver-Transmitter"
# ##################################
# "USWC", "uncachable speculative write combining"
# ##################################
# "UT", "Universal Time"
# ##################################
# "UTC", "Coordinated Universal Time"
# ##################################
# "UTF", "Unicode Transformation Format"
# ##################################
# "UTM", "Urchin Tracking Module"
# ##################################
# "UTM", "universal Turing machine"
# ##################################
# "UTM", "Unified Threat Management"
# ##################################
# "UTP", "unshielded twisted pair cable"
# ##################################
# "UUID", "universal unique identifier"
# ##################################
# "UV", "ultraviolet"
# ##################################
# "UWIN", "University of Washington Information Navigator"
# ##################################
# "UX", "user experience"
# ##################################
# "UXGA", "Ultra Extended Graphics Array"
# ##################################
# "VA", "virtual address"
# ##################################
# "VAC", "Valve Anti-Cheat"
# ##################################
# "VADSL", "very high bit rate asymmetric digital subscriber line"
# ##################################
# "VAN", "value-added network"
# ##################################
# "VAR", "value-added reseller"
# ##################################
# "VB", "Visual Basic"
# ##################################
# "VBR", "variable bitrate"
# ##################################
# "VBScript", "Microsoft Visual Basic Scripting Edition"
# ##################################
# "VBV", "video buffering verifier"
# ##################################
# "VC", "version control"
# ##################################
# "VC", "virtual circuit"
# ##################################
# "VC", "videoconferencing"
# ##################################
# "VC", "venture capital"
# ##################################
# "VCEG", "Video Coding Experts Group"
# ##################################
# "VCEG", "Visual Coding Experts Group"
# ##################################
# "VCI", "virtual circuit identifier"
# ##################################
# "VCPI", "virtual control program interface"
# ##################################
# "VCR", "video cassette recorder"
# ##################################
# "VDC", "voltage direct current"
# ##################################
# "VDD", "virtual device driver, virtual disk drive"
# ##################################
# "VDU", "visual display unit"
# ##################################
# "Veronica", "Very Easy Rodent-Oriented Net-wide Index to Computer Archives"
# ##################################
# "VESA", "Video Electronics Standard Association"
# ##################################
# "VGA", "Video Graphics Array"
# ##################################
# "VGA", "Video Graphics Adapter"
# ##################################
# "VHF", "very high frequency"
# ##################################
# "VHS", "Video Home System"
# ##################################
# "VIM", "Vendor Independent Messaging"
# ##################################
# "VIP", "very important person"
# ##################################
# "VLAN", "virtual local area network"
# ##################################
# "VLB", "Vesa Local Bus"
# ##################################
# "VLSI", "very-large-scale integration"
# ##################################
# "VM", "voicemail"
# ##################################
# "VM", "virtual memory"
# ##################################
# "VM", "virtual machine"
# ##################################
# "VMM", "Virtual Machine Manager"
# ##################################
# "VMM", "Virtual Machine Monitor"
# ##################################
# "VMS", "virtual memory system"
# ##################################
# "VMS", "voicemail system"
# ##################################
# "VNC", "Virtual Network Computing"
# ##################################
# "VOD", "video on demand"
# ##################################
# "VoIP", "Voice over Internet Protocol"
# ##################################
# "VoMM", "eVade o' Matic Module"
# ##################################
# "VPN", "virtual private network"
# ##################################
# "VPS", "virtual private server"
# ##################################
# "VR", "virtual reality"
# ##################################
# "VRAM", "video random access memory"
# ##################################
# "VRLA", "valve-regulated lead-acid"
# ##################################
# "VRM", "voltage regulator module"
# ##################################
# "Vs", "Visual Studio"
# ##################################
# "VSAM", "virtual storage access method"
# ##################################
# "W", "width"
# ##################################
# "W3C", "World Wide Web Consortium"
# ##################################
# "WAIS", "Wide Area Information Server"
# ##################################
# "WAN", "wide area network"
# ##################################
# "WAP", "wireless access point"
# ##################################
# "WARP", "Warning, Advice and Reporting Point"
# ##################################
# "WBEM", "Web-based Enterprise Management"
# ##################################
# "WCDMA", "Wideband Code Division Multiple Access"
# ##################################
# "WCN", "Windows Connect Now"
# ##################################
# "WD", "working draft"
# ##################################
# "WD", "working directory"
# ##################################
# "WD", "Western Digital"
# ##################################
# "WDF", "Window Driver Foundation"
# ##################################
# "Web app", "web application"
# ##################################
# "WEP", "Wired Equivalent Privacy"
# ##################################
# "WFM", "Wired for Management"
# ##################################
# "WFP", "Windows File Protection"
# ##################################
# "WGA", "Windows Genuine Advantage"
# ##################################
# "WiMAX", "Worldwide Interoperability for Microwave Access"
# ##################################
# "WISP", "wireless Internet service provider"
# ##################################
# "WMF", "Windows metafile format"
# ##################################
# "WMI", "Windows Management Instrumentation"
# ##################################
# "WML", "Website META Language"
# ##################################
# "WML", "Wireless Markup Language"
# ##################################
# "WOL", "Wake-on-LAN"
# ##################################
# "WOTD", "word of the day"
# ##################################
# "WOW", "World of Warcraft"
# ##################################
# "WOW", "Windows on Windows"
# ##################################
# "WP", "WordPress"
# ##################################
# "WP", "word processor"
# ##################################
# "Wpcomp", "word processing competency"
# ##################################
# "WQXGA", "Wide Quad Extended Graphics Array"
# ##################################
# "WRAM", "Windows RAM"
# ##################################
# "WSXGA", "Widescreen Super eXtended Graphics Array"
# ##################################
# "WTH", "what the hell"
# ##################################
# "WWW", "World Wide Web"
# ##################################
# "WYSIWYG", "what you see is what you get"
# ##################################
# "WYSIWYP", "what you see is what you print"
# ##################################
# "X", "X Window System"
# ##################################
# "X11", "X Window System"
# ##################################
# "XDF", "extended density format"
# ##################################
# "XGA", "Extended Graphics Array"
# ##################################
# "XHTML", "Extensible Hypertext markup Language"
# ##################################
# "XML", "Extensible Markup Language"
# ##################################
# "XMPP", "Extensible Messaging and Presence Protocol"
# ##################################
# "XMS", "extended memory specification"
# ##################################
# "XSL", "Extensible Stylesheet Language"
# ##################################
# "XSLT", "Extensible Stylesheet Language Transformations"
# ##################################
# "XSS", "cross-site scripting"
# ##################################
# "XT", "extended technology"
# ##################################
# 1644 FALSE NEGATIVES. Pairs that could not be detected out of 1842 given pairs

# %%
######################### Experiments with syntactic and semantic similarity  ###################################################

# %%
def dice_coefficient(a, b):
    """dice coefficient 2nt/(na + nb)."""
    a_bigrams = set(a.lower())
    b_bigrams = set(b.lower())
    overlap = len(a_bigrams & b_bigrams)
    return overlap * 2.0 / (len(a_bigrams) + len(b_bigrams))

# %%
from random import randint
random_pairs = []
for i in range (0, 10):
    rd = randint(0, len(abbr))
    abbv = abbr[rd]
    term = long_forms[rd]
    random_pairs.append([abbv, term])

for pair in random_pairs:
    print("++++++++++++++++++++++++++++++++++++++++++")
    print("\"" + pair[0] + "\", " + "\"" + pair[1] + "\"")
    for j, measure in enumerate([jellyfish.levenshtein_distance, jellyfish.damerau_levenshtein_distance, jellyfish.hamming_distance, jellyfish.jaro_similarity, jellyfish.jaro_winkler_similarity, jellyfish.match_rating_comparison, dice_coefficient]):
        print(measure(pair[0], pair[1]))
# Out:
# ++++++++++++++++++++++++++++++++++++++++++
# "LED monitor", "light-emitting diode"
# 17
# 17
# 20
# 0.4348484848484849
# 0.4348484848484849
# True
# 0.8181818181818182
# ++++++++++++++++++++++++++++++++++++++++++
# "Int", "integer"
# 5
# 5
# 5
# 0.6507936507936508
# 0.6507936507936508
# True
# 0.6666666666666666
# ++++++++++++++++++++++++++++++++++++++++++
# "PS/2", "Personal System/2"
# 13
# 13
# 16
# 0.4362745098039216
# 0.4362745098039216
# True
# 0.4444444444444444
# ++++++++++++++++++++++++++++++++++++++++++
# "IANA", "Internet Assigned Numbers Authority"
# 31
# 31
# 34
# 0.611904761904762
# 0.611904761904762
# None
# 0.3157894736842105
# ++++++++++++++++++++++++++++++++++++++++++
# "SMM", "System Management Mode"
# 19
# 19
# 21
# 0.5858585858585859
# 0.5858585858585859
# None
# 0.3076923076923077
# ++++++++++++++++++++++++++++++++++++++++++
# "U/L", "upload"
# 6
# 6
# 6
# 0.0
# 0.0
# True
# 0.4444444444444444
# ++++++++++++++++++++++++++++++++++++++++++
# "IAP", "Internet access provider"
# 23
# 23
# 23
# 0.4583333333333333
# 0.4583333333333333
# None
# 0.375
# ++++++++++++++++++++++++++++++++++++++++++
# "CLNS", "connectionless network service"
# 30
# 30
# 30
# 0.0
# 0.0
# False
# 0.47058823529411764
# ++++++++++++++++++++++++++++++++++++++++++
# "MMC", "MultiMediaCard"
# 11
# 11
# 13
# 0.6031746031746031
# 0.6031746031746031
# None
# 0.3333333333333333
# ++++++++++++++++++++++++++++++++++++++++++
# "I/O", "input/output"
# 11
# 11
# 12
# 0.47222222222222215
# 0.47222222222222215
# None
# 0.6

# %%
########################### comparison on abbreviation level #######################################################

# %%
for k, abb in enumerate(abbr):
    abb_lower = abb.lower()
    term_lower = long_forms[k].lower()
    sanitized_abbv, sanitized_term = clear_special_characters(abb_lower, term_lower) 
    sanitized_term_without_stopswords = stop_words_handling(sanitized_term)
    initial_letters_of_tokens_of_sanitized_term_without_stopswords = ''.join([c[0] for c in sanitized_term_without_stopswords.split()])
    tmp_sum = 0
    for measure in [jellyfish.levenshtein_distance, jellyfish.damerau_levenshtein_distance, jellyfish.hamming_distance, jellyfish.jaro_similarity, jellyfish.jaro_winkler_similarity, match_rating_comparison, dice_coefficient]:
        tmp_sum = tmp_sum + measure(initial_letters_of_tokens_of_sanitized_term_without_stopswords, sanitized_abbv)
    print(tmp_sum/len(abbr))
# Out:
# 0.0036192544335866814
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.006879168605552971
# 0.00660772452303397
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005971769815418024
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.008805129000568741
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004916153938955242
# 0.0033779708046809023
# 0.0042526239594643505
# 0.002171552660152009
# 0.006659428157799494
# 0.007799493304379299
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006834358788756184
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0033779708046809023
# 0.002171552660152009
# 0.005006635299794908
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00522379056581011
# 0.011641935094703824
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005237578201747584
# 0.003450355893352636
# 0.002171552660152009
# 0.006659428157799494
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003510676800579081
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005282560363993589
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004743291453389173
# 0.0033779708046809023
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0064603691639522265
# 0.0064603691639522265
# 0.0064603691639522265
# 0.0034382917119073473
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004463747134756907
# 0.004463747134756907
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.0036192544335866814
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0052608448373920695
# 0.0038122813367113036
# 0.0038122813367113036
# 0.011455488654185724
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006514657980456026
# 0.002171552660152009
# 0.004916153938955242
# 0.004175068507316065
# 0.008203643382796477
# 0.004680902400772107
# 0.005272047291591266
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.006514657980456026
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.0031668476293883457
# 0.002171552660152009
# 0.009784912879375421
# 0.003197008083001568
# 0.002171552660152009
# 0.004175068507316065
# 0.004175068507316065
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.0033779708046809023
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004680902400772107
# 0.0038122813367113036
# 0.002171552660152009
# 0.005917480998914224
# 0.009354049256329384
# 0.008599348534201955
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003632180342278062
# 0.005609844372059355
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003920858969718904
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004217293142374575
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003920858969718904
# 0.0036011581614187474
# 0.005006635299794908
# 0.002171552660152009
# 0.002171552660152009
# 0.004403426227530462
# 0.002171552660152009
# 0.002171552660152009
# 0.0036011581614187474
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.007238508867173363
# 0.002171552660152009
# 0.005848111955603812
# 0.0042212570877066
# 0.01131154103466807
# 0.003632180342278062
# 0.005066956207021353
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.01561708288092653
# 0.006297502714440826
# 0.002171552660152009
# 0.006297502714440826
# 0.005917480998914224
# 0.002171552660152009
# 0.005917480998914224
# 0.005917480998914224
# 0.005917480998914224
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.005917480998914224
# 0.00660772452303397
# 0.00437326577391724
# 0.006336280440514969
# 0.004175068507316065
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0036373507057546146
# 0.0038122813367113036
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.006625820795201902
# 0.004175068507316065
# 0.002171552660152009
# 0.003197008083001568
# 0.004175068507316065
# 0.002171552660152009
# 0.003510676800579081
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0036819881771021834
# 0.002171552660152009
# 0.0038122813367113036
# 0.005274158523344191
# 0.00732899022801303
# 0.007202316322837496
# 0.007202316322837496
# 0.00732899022801303
# 0.0064603691639522265
# 0.002171552660152009
# 0.002171552660152009
# 0.007238508867173363
# 0.007956484340849161
# 0.004916153938955242
# 0.004916153938955242
# 0.004916153938955242
# 0.002171552660152009
# 0.002171552660152009
# 0.006243213897937026
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0033779708046809023
# 0.002171552660152009
# 0.003568843389690295
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006659428157799494
# 0.002171552660152009
# 0.004175068507316065
# 0.002171552660152009
# 0.002171552660152009
# 0.009354049256329384
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.004294848594522862
# 0.005148389431777055
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0047571652620512555
# 0.0038122813367113036
# 0.002171552660152009
# 0.005410785378212089
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.005700325732899024
# 0.002171552660152009
# 0.005139341295693088
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0100261965082812
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004463747134756907
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005112196887441187
# 0.002171552660152009
# 0.004175068507316065
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.0038122813367113036
# 0.004175068507316065
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.0036795753408131256
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003632180342278062
# 0.002171552660152009
# 0.002171552660152009
# 0.004743291453389173
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004433586681143684
# 0.002171552660152009
# 0.002171552660152009
# 0.00414404632645675
# 0.002171552660152009
# 0.003920858969718904
# 0.002171552660152009
# 0.0034654361201592473
# 0.0034654361201592473
# 0.0034654361201592473
# 0.006431122663478799
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004800036192544336
# 0.002171552660152009
# 0.004760525998311014
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005437498922840942
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.0034382917119073473
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.0036795753408131256
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.006856979128966099
# 0.00373989624803957
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.009425141754131982
# 0.0034382917119073473
# 0.002171552660152009
# 0.00489461075780294
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00732899022801303
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.0038122813367113036
# 0.0034925805284111476
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006659428157799494
# 0.00835444565086259
# 0.002171552660152009
# 0.005139341295693088
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00799596711648829
# 0.004245495124973952
# 0.008475087465315478
# 0.002171552660152009
# 0.006659428157799494
# 0.0036795753408131256
# 0.002171552660152009
# 0.005066956207021353
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00519664615755821
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004234527687296417
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005066956207021353
# 0.002171552660152009
# 0.0038122813367113036
# 0.012717657940242088
# 0.002171552660152009
# 0.0034382917119073473
# 0.00660772452303397
# 0.0035709977078055254
# 0.0038122813367113036
# 0.0038122813367113036
# 0.0036795753408131256
# 0.002171552660152009
# 0.002171552660152009
# 0.0042212570877066
# 0.004916153938955242
# 0.004916153938955242
# 0.004916153938955242
# 0.004916153938955242
# 0.0038122813367113036
# 0.004916153938955242
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0042212570877066
# 0.0035709977078055254
# 0.005066956207021353
# 0.0034382917119073473
# 0.0034382917119073473
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.004717956672354067
# 0.005917480998914224
# 0.002171552660152009
# 0.004795512124502352
# 0.004795512124502352
# 0.002171552660152009
# 0.00529979490891543
# 0.002171552660152009
# 0.002171552660152009
# 0.009552246522930562
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004916153938955242
# 0.0034382917119073473
# 0.002171552660152009
# 0.00513029315960912
# 0.00529979490891543
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0064603691639522265
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0036192544335866814
# 0.003920858969718904
# 0.003920858969718904
# 0.002171552660152009
# 0.002171552660152009
# 0.004686934491494753
# 0.004717956672354067
# 0.002171552660152009
# 0.007491856677524431
# 0.002171552660152009
# 0.007983041207796908
# 0.007491856677524431
# 0.00529979490891543
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.004717956672354067
# 0.006041138858728434
# 0.004674870310049463
# 0.010056356961894422
# 0.003709735794426348
# 0.0034382917119073473
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.0042212570877066
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.005066956207021353
# 0.0038122813367113036
# 0.002171552660152009
# 0.0038122813367113036
# 0.003632180342278062
# 0.002171552660152009
# 0.00476535167088913
# 0.002171552660152009
# 0.005148389431777055
# 0.004175068507316065
# 0.0066956207021353605
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.0034382917119073473
# 0.0032874894438412352
# 0.002171552660152009
# 0.005139341295693088
# 0.008203643382796477
# 0.004717956672354067
# 0.004717956672354067
# 0.002171552660152009
# 0.003632180342278062
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.00437326577391724
# 0.011391603329714079
# 0.005489202557606465
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00660772452303397
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006514657980456026
# 0.009681505609844371
# 0.004717956672354067
# 0.003632180342278062
# 0.0038122813367113036
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.003632180342278062
# 0.002171552660152009
# 0.005066956207021353
# 0.002171552660152009
# 0.0036819881771021834
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005297037381727936
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.006041138858728434
# 0.002171552660152009
# 0.005066956207021353
# 0.003742309084328628
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006243213897937026
# 0.007150612688071972
# 0.002171552660152009
# 0.0036795753408131256
# 0.0038122813367113036
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.0038122813367113036
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.003632180342278062
# 0.0034382917119073473
# 0.002171552660152009
# 0.005066956207021353
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0042526239594643505
# 0.006336280440514969
# 0.0034382917119073473
# 0.0034382917119073473
# 0.004717956672354067
# 0.002171552660152009
# 0.0042526239594643505
# 0.002171552660152009
# 0.0027446012788032333
# 0.0034382917119073473
# 0.0034382917119073473
# 0.003632180342278062
# 0.003632180342278062
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004281577994933044
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004916153938955242
# 0.004760525998311014
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.008207952019026939
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003632180342278062
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.005854144046326457
# 0.006798166244420316
# 0.005917480998914224
# 0.00660772452303397
# 0.00437326577391724
# 0.006188925081433225
# 0.0034382917119073473
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.011726932736704726
# 0.002171552660152009
# 0.005148389431777055
# 0.002171552660152009
# 0.003632180342278062
# 0.002171552660152009
# 0.002171552660152009
# 0.006803164262447649
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.004717956672354067
# 0.0038122813367113036
# 0.006188925081433225
# 0.0035709977078055254
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005854144046326457
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004403426227530462
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0033779708046809023
# 0.0035709977078055254
# 0.009061061992658083
# 0.002171552660152009
# 0.004175068507316065
# 0.002171552660152009
# 0.002171552660152009
# 0.00753408131258294
# 0.002171552660152009
# 0.004916153938955242
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.0038122813367113036
# 0.00476535167088913
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.01262214983713355
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.00437326577391724
# 0.004916153938955242
# 0.004916153938955242
# 0.0066956207021353605
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.0033779708046809023
# 0.002171552660152009
# 0.0048208469055374585
# 0.002171552660152009
# 0.002171552660152009
# 0.005325239364327312
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.006948968512486427
# 0.0038122813367113036
# 0.016442930938044942
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.004717956672354067
# 0.0080709373868983
# 0.004686934491494753
# 0.014185466682752241
# 0.004717956672354067
# 0.002171552660152009
# 0.0053384002895403545
# 0.011641935094703824
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.020702831370583815
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006041138858728434
# 0.0033779708046809023
# 0.0034382917119073473
# 0.002171552660152009
# 0.005311255881288455
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.006064836357995968
# 0.004463747134756907
# 0.00660772452303397
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.004916153938955242
# 0.007491856677524431
# 0.002171552660152009
# 0.0038122813367113036
# 0.004916153938955242
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0082122606552574
# 0.00888225358909398
# 0.002171552660152009
# 0.004916153938955242
# 0.004916153938955242
# 0.0034382917119073473
# 0.0034382917119073473
# 0.0034382917119073473
# 0.005971769815418024
# 0.00660772452303397
# 0.0038122813367113036
# 0.004717956672354067
# 0.004717956672354067
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.004717956672354067
# 0.0042212570877066
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004743291453389173
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.006659428157799494
# 0.006514657980456026
# 0.0038122813367113036
# 0.007763300760043433
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.005066956207021353
# 0.00437326577391724
# 0.004916153938955242
# 0.004916153938955242
# 0.002171552660152009
# 0.002171552660152009
# 0.017271002613022158
# 0.002171552660152009
# 0.002171552660152009
# 0.005519363011219689
# 0.004916153938955242
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.006406080347448425
# 0.00660772452303397
# 0.005006635299794908
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004735191217275907
# 0.002171552660152009
# 0.008755148820295402
# 0.004916153938955242
# 0.011687175775123659
# 0.007528049221860298
# 0.016459382094561246
# 0.005682229460731089
# 0.004916153938955242
# 0.006834358788756184
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.005066956207021353
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.004674870310049463
# 0.002171552660152009
# 0.0038122813367113036
# 0.004717956672354067
# 0.005360115816141875
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00476535167088913
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.0038122813367113036
# 0.006255278079382314
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.012149179087289838
# 0.0035709977078055254
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00414404632645675
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.004175068507316065
# 0.002171552660152009
# 0.0038122813367113036
# 0.005609844372059355
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004916153938955242
# 0.0070523757820174756
# 0.00825571912705463
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0053384002895403545
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.004560260586319218
# 0.00489461075780294
# 0.0034382917119073473
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006234165761853059
# 0.005139341295693088
# 0.004916153938955242
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.0038122813367113036
# 0.0038122813367113036
# 0.00437326577391724
# 0.0034382917119073473
# 0.002171552660152009
# 0.00519664615755821
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.006879168605552971
# 0.002171552660152009
# 0.002171552660152009
# 0.006188925081433225
# 0.002171552660152009
# 0.004916153938955242
# 0.006041138858728434
# 0.004717956672354067
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.004175068507316065
# 0.002171552660152009
# 0.0038122813367113036
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.004175068507316065
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.0036795753408131256
# 0.003498612619133792
# 0.003920858969718904
# 0.0034382917119073473
# 0.0034382917119073473
# 0.002171552660152009
# 0.0034382917119073473
# 0.0034382917119073473
# 0.006243213897937026
# 0.007419471588852696
# 0.007419471588852696
# 0.002171552660152009
# 0.003257328990228013
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.003632180342278062
# 0.0036795753408131256
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.004680902400772107
# 0.00437326577391724
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.005917480998914224
# 0.00414404632645675
# 0.0034382917119073473
# 0.002171552660152009
# 0.0034382917119073473
# 0.0033779708046809023
# 0.0033779708046809023
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0053384002895403545
# 0.003510676800579081
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.007491856677524431
# 0.00660772452303397
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.012995499694739652
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0063543767126829015
# 0.002171552660152009
# 0.006406080347448425
# 0.003800217155266015
# 0.004916153938955242
# 0.006865380969615498
# 0.005609844372059355
# 0.002171552660152009
# 0.0035709977078055254
# 0.0035709977078055254
# 0.002171552660152009
# 0.004735191217275907
# 0.002171552660152009
# 0.0042526239594643505
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.005066956207021353
# 0.00732899022801303
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.012561828929907103
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003197008083001568
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.004916153938955242
# 0.002171552660152009
# 0.003575823380383641
# 0.005609844372059355
# 0.002171552660152009
# 0.0038122813367113036
# 0.004916153938955242
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0036795753408131256
# 0.0048208469055374585
# 0.002171552660152009
# 0.0036192544335866814
# 0.005006635299794908
# 0.004674870310049463
# 0.002171552660152009
# 0.0034382917119073473
# 0.005066956207021353
# 0.008203643382796477
# 0.007509952949692364
# 0.005725660513934131
# 0.00979353015183634
# 0.00437326577391724
# 0.009862468331523707
# 0.0082122606552574
# 0.004175068507316065
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.0035709977078055254
# 0.0038122813367113036
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.0038122813367113036
# 0.0042212570877066
# 0.002171552660152009
# 0.002171552660152009
# 0.003197008083001568
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.00437326577391724
# 0.002171552660152009
# 0.005609844372059355
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.003450355893352636
# 0.0033779708046809023
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.008805129000568741
# 0.0035613463626492942
# 0.002171552660152009
# 0.004785367244650633
# 0.007150612688071972
# 0.002171552660152009
# 0.002171552660152009
# 0.005274158523344191
# 0.002171552660152009
# 0.0036795753408131256
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004760525998311014
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004916153938955242
# 0.004916153938955242
# 0.004717956672354067
# 0.006116539992761492
# 0.004916153938955242
# 0.004916153938955242
# 0.0053384002895403545
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.003632180342278062
# 0.01651931130758492
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.012353628998580139
# 0.002171552660152009
# 0.005066956207021353
# 0.0034382917119073473
# 0.0038122813367113036
# 0.016537208719619143
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.009009681505609844
# 0.016442930938044942
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.006659428157799494
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.0034382917119073473
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.004584388949209796
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0033779708046809023
# 0.002171552660152009
# 0.003632180342278062
# 0.002171552660152009
# 0.002171552660152009
# 0.00373989624803957
# 0.002171552660152009
# 0.00414404632645675
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.006897264877720903
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005848111955603812
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.008952353794916226
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00660772452303397
# 0.005139341295693088
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.0102976405908002
# 0.002171552660152009
# 0.013266943777258653
# 0.002171552660152009
# 0.012402409389380073
# 0.004175068507316065
# 0.008228703977889645
# 0.020702831370583815
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.004138014235734106
# 0.004138014235734106
# 0.0038122813367113036
# 0.002171552660152009
# 0.018158913110053174
# 0.004916153938955242
# 0.007940816572738398
# 0.007940816572738398
# 0.004916153938955242
# 0.008894317770539268
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.0038122813367113036
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.008173482929183256
# 0.010773744894266067
# 0.00414404632645675
# 0.002171552660152009
# 0.00529979490891543
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00520655602088827
# 0.0100261965082812
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.004686934491494753
# 0.00520655602088827
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.004175068507316065
# 0.002171552660152009
# 0.00414404632645675
# 0.002171552660152009
# 0.004916153938955242
# 0.005148389431777055
# 0.0035709977078055254
# 0.008475087465315478
# 0.0034382917119073473
# 0.005148389431777055
# 0.002171552660152009
# 0.002171552660152009
# 0.005917480998914224
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034925805284111476
# 0.0034925805284111476
# 0.002171552660152009
# 0.009173086534650052
# 0.0036647536321803417
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0036795753408131256
# 0.002171552660152009
# 0.003920858969718904
# 0.002171552660152009
# 0.002171552660152009
# 0.003920858969718904
# 0.0036011581614187474
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003920858969718904
# 0.002171552660152009
# 0.006625820795201902
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.004916153938955242
# 0.00888225358909398
# 0.003632180342278062
# 0.004916153938955242
# 0.003632180342278062
# 0.002171552660152009
# 0.008173482929183256
# 0.0034382917119073473
# 0.0034925805284111476
# 0.00489461075780294
# 0.00437326577391724
# 0.006188925081433225
# 0.007763300760043433
# 0.008483704737776399
# 0.008483704737776399
# 0.006677524429967426
# 0.006677524429967426
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.0035709977078055254
# 0.002171552660152009
# 0.002171552660152009
# 0.004204022542784757
# 0.002171552660152009
# 0.0042526239594643505
# 0.0035709977078055254
# 0.002171552660152009
# 0.005917480998914224
# 0.014857039449873327
# 0.002171552660152009
# 0.002171552660152009
# 0.006116539992761492
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.006798166244420316
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.0038122813367113036
# 0.004175068507316065
# 0.002171552660152009
# 0.0038122813367113036
# 0.004680902400772107
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0048208469055374585
# 0.002171552660152009
# 0.014338279647725901
# 0.012621453826665553
# 0.002171552660152009
# 0.00437326577391724
# 0.002171552660152009
# 0.002171552660152009
# 0.003920858969718904
# 0.005006635299794908
# 0.005006635299794908
# 0.005006635299794908
# 0.0034382917119073473
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.008414766558089034
# 0.003632180342278062
# 0.003632180342278062
# 0.0034382917119073473
# 0.002171552660152009
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.003709735794426348
# 0.002171552660152009
# 0.002171552660152009
# 0.005066956207021353
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.0034382917119073473
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.007419471588852696
# 0.002171552660152009
# 0.002171552660152009
# 0.00414404632645675
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.003632180342278062
# 0.002171552660152009
# 0.002171552660152009
# 0.004885993485342019
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.003632180342278062
# 0.011672095548317047
# 0.0036011581614187474
# 0.0034382917119073473
# 0.002171552660152009
# 0.0031668476293883457
# 0.0034925805284111476
# 0.002171552660152009
# 0.0035709977078055254
# 0.008974880982209972
# 0.0038122813367113036
# 0.0038122813367113036
# 0.002171552660152009
# 0.0035709977078055254
# 0.011823129819872491
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.006876583423814695
# 0.006930872240318494
# 0.002171552660152009
# 0.004916153938955242
# 0.005826999638074557
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00660772452303397
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.007238508867173363
# 0.00437326577391724
# 0.004795512124502352
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.00522379056581011
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.005609844372059355
# 0.002171552660152009
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.002171552660152009
# 0.00888225358909398
# 0.002171552660152009
# 0.005561587646278201
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004717956672354067
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.009552246522930562
# 0.002171552660152009
# 0.0038122813367113036
# 0.002171552660152009
# 0.002171552660152009
# 0.0036819881771021834
# 0.013548075763059476
# 0.0100261965082812
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.004916153938955242
# 0.004717956672354067
# 0.00373989624803957
# 0.002171552660152009
# 0.0034382917119073473
# 0.002171552660152009
# 0.007940816572738398
# 0.006740861382555194
# 0.0035613463626492942
# 0.005066956207021353
# 0.0035613463626492942
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.002171552660152009
# 0.00437326577391724
# 0.004620581493545663
# 0.0033779708046809023
# 0.0033779708046809023
# 0.006098443720593557
# 0.0033779708046809023
# 0.0034382917119073473
# 0.0033779708046809023
# 0.0038122813367113036
# 0.0033779708046809023
# 0.003483532392327181
# 0.004735191217275907
# 0.0031668476293883457

# %%
 for measure in [jellyfish.levenshtein_distance, jellyfish.damerau_levenshtein_distance, jellyfish.hamming_distance, jellyfish.jaro_similarity, jellyfish.jaro_winkler_similarity, match_rating_comparison, dice_coefficient, check_wether_abbv_is_proper_short_form_of_term]:
    tmp_sum = 0
    for k, abb in enumerate(abbr):
        abb_lower = abb.lower()
        term_lower = long_forms[k].lower()
        sanitized_abbv, sanitized_term = clear_special_characters(abb_lower, term_lower) 
        sanitized_term_without_stopswords = stop_words_handling(sanitized_term)
        initial_letters_of_tokens_of_sanitized_term_without_stopswords = ''.join([c[0] for c in sanitized_term_without_stopswords.split()])
        tmp_sum = tmp_sum + measure(initial_letters_of_tokens_of_sanitized_term_without_stopswords, sanitized_abbv)
    print(tmp_sum/len(abbr))
# Out:
# 0.8517915309446255
# 0.8501628664495114
# 1.1346362649294246
# 0.895096960284256
# 0.8961961651972516
# 0.9142236699239956
# 0.8650353883660081
# 0.9272529858849077
