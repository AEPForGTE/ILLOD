# %% [markdown]
# # Evaluation of the Different Approaches to AEP Detection on the Promise dataset (Section 5.5)

# %%
import pandas as pd
import Syntactic_Classifiers
import ILLOD
import Abbreviation_and_NC_Extraction

# %% [markdown]
# ## Reading the content of the PROMISE requirements. 30 abbreviations have been inserted in the texts. We want try to identify them.

# %%
requirements_data = pd.read_csv('promise_constructed.CSV', names=['text', 'set_id'], sep=';', encoding='utf8')
# print(requirements_data)

# %%
# Preparation of the data with the aim of storing it in a dictionary
data_dict = {}
for id_ in set(requirements_data["set_id"]):
    sublist = requirements_data[requirements_data["set_id"] == id_]
    data_dict[id_] = [req for req in sublist["text"]]

# %% [markdown]
# ## The following function performs a set transformation. It partitions objects of the set  𝑇  to the sets  𝑂𝑇  and  𝑇∖𝑂𝑇 according to steps (4) and (6) from section (6.2)

# %%
def determine_sets_for_term_types(set_of_abbreviations, set_of_terms):
    
    #compliant wit section 5.2: terms_that_contain_abbreviations = T \ OT
    terms_that_contain_abbreviations = set()
    
    for term in set_of_terms:
        for abb in set_of_abbreviations:
            if abb in term.split():
                terms_that_contain_abbreviations.add(term)
    
    ordinary_terms = terms - terms_that_contain_abbreviations
    
    return ordinary_terms, terms_that_contain_abbreviations

# %% [markdown]
# ## Main Program to generate AEP candidates and AEP groups. In line 29 to 32 the one can set the classifier that he wants to evaluate.

# %%
counter = 0
tuple_collection_for_evaluation = []
AEP_candidate_clusters ={}
for id_ in data_dict.keys():

    ######### Step(1) + Step(3): Extract set of Abbreviations A and set of terms T############

    terms = set()
    abbv_set = set()
    print("TUPLES FROM ReqSet: " + str(id_))
    for req in data_dict[id_]:
        terms = terms.union(Abbreviation_and_NC_Extraction.nc_detect(req))
        abbv_set = abbv_set.union(Abbreviation_and_NC_Extraction.abbv_detect(req))

    ############ step(2): Reduce extracted abbreviations set A through cmparision with #######
    ############ project resources so that only undefined abbreviations stay in A ############



    ############################ step(4): determine the sets A, OT and T\OT ##################
    ordinary_terms, terms_that_contain_abbs = determine_sets_for_term_types(abbv_set, terms)


    # For every a∈ A generate an AEP group G^{a} of possible expansions t ∈ OT via ILLOD.####
    ###################################### step(5): ##########################################
    abbreviations_with_matching_candidates = set()
    for abv in abbv_set:
        for term in ordinary_terms:
            if ILLOD.illod(abv, term):
            # if Syntactic_Classifiers.jws_classifier(abv, term):
            # if Syntactic_Classifiers.dc_classifier(abv, term):
            # if Syntactic_Classifiers.ld_classifier(abv, term):
                tuple_collection_for_evaluation.append((abv, term.lower()))
                counter += 1
                abbreviations_with_matching_candidates.add(abv)
                print(str(counter)+ ") (" + abv + ", " + term + ")")
                if id_ in AEP_candidate_clusters.keys():
                    if abv in AEP_candidate_clusters[id_]:
                        expansion_candidates_list = AEP_candidate_clusters[id_][abv]
                        expansion_candidates_list.append(term)
                        AEP_candidate_clusters[id_][abv] = expansion_candidates_list
                    else:
                        AEP_candidate_clusters[id_][abv] = [term]
                else:
                    AEP_candidate_clusters[id_] = {}

    # For every a∈ A extend its G^{a} with terms t∈ T\OT, if t contains a.####################
    ######################################### step(6): #######################################
    for abv in abbreviations_with_matching_candidates:
        for term in terms_that_contain_abbs:
            if abv in term.split() and abv != term:
                if id_ in AEP_candidate_clusters.keys():
                    if abv in AEP_candidate_clusters[id_]:
                        expansion_candidates_list = AEP_candidate_clusters[id_][abv]
                        expansion_candidates_list.append(term)
                        AEP_candidate_clusters[id_][abv] = expansion_candidates_list
                    else:
                        AEP_candidate_clusters[id_][abv] = [term]
                else:
                    AEP_candidate_clusters[id_] = {}
    print("#####################################################")

cluster_counter = 0
for id_ in AEP_candidate_clusters.keys():
    print("CLUSTERS FROM ReqSet: " + str(id_) + ":")
    for key in AEP_candidate_clusters[id_]:
        cluster_counter += 1
        print(str(cluster_counter) + ") " + "\"" + str(key)+ "\"" + " : " + str(AEP_candidate_clusters[id_][key]))
    print("#####################################################")
# Out:
# TUPLES FROM ReqSet: 1
# 1) (MDI, modification)
# 2) (MDI, modification of display)
# 3) (cT, chart)
# 4) (cT, current time)
# 5) (cT, cT.)
# 6) (PC, product)
# #####################################################
# TUPLES FROM ReqSet: 2
# 7) (CE, client)
# 8) (CMA, contact information)
# 9) (SR, seller)
# 10) (SR, search result)
# 11) (RT, realtor)
# #####################################################
# TUPLES FROM ReqSet: 3
# 12) (Dr, department)
# 13) (PoS, possibility)
# 14) (PoS, Program Administrators)
# 15) (PoS, portion of system)
# #####################################################
# TUPLES FROM ReqSet: 4
# 16) (TR, type of retrieval)
# 17) (TR, type of transaction)
# 18) (TR, transaction)
# 19) (TR, transaction and industry)
# 20) (Lab, lab)
# 21) (Lab, labs)
# 22) (RTR, retrieval)
# 23) (DS, department / section)
# 24) (DS, dispute)
# 25) (DS, Disputes System)
# 26) (DS, database)
# 27) (DS, dispute system)
# 28) (In, illness)
# 29) (In, instructor)
# 30) (In, information)
# 31) (In, interface creation)
# 32) (In, industry)
# 33) (NSM, nursing Staff member)
# 34) (ID, industry)
# 35) (E, example)
# 36) (E, exception)
# 37) (Csi, clinical site)
# 38) (DC, document)
# 39) (DC, dispute case)
# 40) (DC, documentation)
# #####################################################
# TUPLES FROM ReqSet: 5
# 41) (CE, collision estimate)
# 42) (CE, category)
# 43) (CE, claim processing)
# 44) (CE, collision estimator)
# 45) (CE, Collision Estimators)
# 46) (RF, repair facility)
# 47) (rP, recycled part)
# 48) (AR, adjuster)
# 49) (AR, appearance)
# 50) (AR, audit report)
# 51) (AR, available part)
# 52) (AR, adjuster role)
# #####################################################
# TUPLES FROM ReqSet: 6
# 53) (SP, software product)
# 54) (SP, survey respondent)
# 55) (SP, search parameter)
# 56) (SP, support)
# 57) (CD, calendar date)
# 58) (CD, cr schedule)
# 59) (HTML, html)
# 60) (MS, meeting schedule)
# 61) (CR, customer)
# 62) (CR, collaboration)
# 63) (CR, conference room)
# 64) (DBMS, dbms)
# 65) (DBMS, database management system)
# #####################################################
# TUPLES FROM ReqSet: 7
# 66) (POS, part of System)
# 67) (PF, product formula)
# 68) (PF, Product formula)
# 69) (sI, substitutionary ingredient)
# 70) (PMs, permission)
# 71) (IQA, Inventory Quantity Adjustment)
# 72) (RMS, rms system)
# 73) (It, inventory)
# 74) (It, independent audit)
# #####################################################
# TUPLES FROM ReqSet: 8
# 75) (MSN, movie description)
# 76) (Sys, system)
# 77) (IE, internet)
# 78) (IE, IzognMovies)
# 79) (IE, integrity)
# 80) (IE, infection)
# 81) (IE, information practice)
# 82) (IE, Internet)
# 83) (IE, interface)
# 84) (sMo, symbol)
# 85) (sMo, select movie)
# 86) (sMo, sale information)
# 87) (sMo, streaming movie)
# 88) (PIN, payment option)
# 89) (PIN, private information)
# 90) (CC, credit card)
# 91) (CC, compliance)
# 92) (CC, customer of change)
# 93) (PEAR, prepaid card)
# 94) (PEAR, print paper card)
# #####################################################
# TUPLES FROM ReqSet: 9
# 95) (LeSco, lead score)
# 96) (LeDA, lead datum)
# 97) (LeDA, lead data)
# 98) (WES, web service)
# 99) (WES, washing process)
# #####################################################
# TUPLES FROM ReqSet: 10
# 100) (dG, defensive grid)
# 101) (oP, other player)
# 102) (oP, offensive player)
# 103) (oP, ofeP.)
# 104) (oP, one player)
# 105) (STAT, start of turn)
# 106) (STAT, status)
# 107) (STAT, start)
# #####################################################
# TUPLES FROM ReqSet: 11
# #####################################################
# TUPLES FROM ReqSet: 12
# 108) (In, interruption)
# 109) (In, interface)
# 110) (CSR, caller and supervisor)
# #####################################################
# TUPLES FROM ReqSet: 13
# 111) (W3, w3)
# #####################################################
# TUPLES FROM ReqSet: 14
# #####################################################
# TUPLES FROM ReqSet: 15
# 112) (UAS, uas system)
# 113) (UAS, User access)
# 114) (RFS, rfs system)
# 115) (400MB, 400 mb)
# #####################################################
# CLUSTERS FROM ReqSet: 1:
# 1) "MDI" : ['modification of display', 'MDI form']
# 2) "cT" : ['chart', 'current time', 'cT.']
# 3) "PC" : ['product']
# #####################################################
# CLUSTERS FROM ReqSet: 2:
# 4) "CMA" : ['contact information', 'CMA report criterion', 'CMA report']
# 5) "SR" : ['seller', 'search result', 'property SR']
# 6) "RT" : ['realtor']
# 7) "CE" : ['Windows CE and Palm operating system']
# #####################################################
# CLUSTERS FROM ReqSet: 3:
# 8) "PoS" : ['possibility', 'Program Administrators', 'portion of system']
# 9) "Dr" : ['Dr Julie Donalek', 'Dr Susan Poslusny and Dr Julie Donalek', 'Dr Susan Poslusny and Karen Sysol', 'Dr Susan Poslusny']
# #####################################################
# CLUSTERS FROM ReqSet: 4:
# 10) "TR" : ['type of transaction', 'transaction', 'transaction and industry', 'TR request', 'part of TR creation process']
# 11) "Lab" : ['lab', 'labs', 'Clinical Lab Section']
# 12) "RTR" : ['retrieval']
# 13) "DS" : ['department / section', 'dispute', 'Disputes System', 'database', 'dispute system']
# 14) "In" : ['illness', 'instructor', 'information', 'interface creation', 'industry']
# 15) "NSM" : ['nursing Staff member', 'Program Administrators and NSM']
# 16) "ID" : ['industry', 'student ID student name']
# 17) "E" : ['example', 'exception']
# 18) "Csi" : ['clinical site']
# 19) "DC" : ['document', 'dispute case', 'documentation']
# #####################################################
# CLUSTERS FROM ReqSet: 5:
# 20) "CE" : ['category', 'claim processing', 'collision estimator', 'Collision Estimators']
# 21) "RF" : ['repair facility', 'prefer RF']
# 22) "rP" : ['recycled part', 'attempt use of rP', 'attempt use of rP and actual use', 'rp and actual use of rP']
# 23) "AR" : ['adjuster', 'appearance', 'audit report', 'available part', 'adjuster role']
# #####################################################
# CLUSTERS FROM ReqSet: 6:
# 24) "SP" : ['survey respondent', 'search parameter', 'support']
# 25) "CD" : ['calendar date', 'cr schedule']
# 26) "HTML" : ['html']
# 27) "MS" : ['meeting schedule', 'MS Access']
# 28) "CR" : ['customer', 'collaboration', 'conference room']
# 29) "DBMS" : ['dbms', 'database management system']
# #####################################################
# CLUSTERS FROM ReqSet: 7:
# 30) "PF" : ['product formula', 'Product formula', 'PF substitutionary ingredient']
# 31) "sI" : ['substitutionary ingredient']
# 32) "PMs" : ['permission', 'build PMs']
# 33) "IQA" : ['Inventory Quantity Adjustment', 'IQA document']
# 34) "RMS" : ['rms system']
# 35) "It" : ['inventory', 'independent audit']
# 36) "POS" : ['POS terminal']
# #####################################################
# CLUSTERS FROM ReqSet: 8:
# 37) "Sys" : ['system']
# 38) "IE" : ['internet', 'IzognMovies', 'integrity', 'infection', 'information practice', 'Internet', 'interface']
# 39) "sMo" : ['symbol', 'select movie', 'sale information', 'streaming movie']
# 40) "PIN" : ['payment option', 'private information', 'PIN number']
# 41) "CC" : ['credit card', 'compliance', 'customer of change']
# 42) "PEAR" : ['prepaid card', 'print paper card', 'PEAR standard']
# 43) "MSN" : ['MSN TV2']
# #####################################################
# CLUSTERS FROM ReqSet: 9:
# 44) "LeDA" : ['lead datum', 'lead data', 'LeDA parameter']
# 45) "WES" : ['web service', 'washing process']
# #####################################################
# CLUSTERS FROM ReqSet: 10:
# 46) "oP" : ['other player', 'offensive player', 'ofeP.', 'one player']
# 47) "STAT" : ['start of turn', 'status', 'start', 'STAT of defensive player']
# #####################################################
# CLUSTERS FROM ReqSet: 12:
# 48) "In" : ['interface']
# 49) "CSR" : ['caller and supervisor', 'CSR and Datastream']
# #####################################################
# CLUSTERS FROM ReqSet: 13:
# #####################################################
# CLUSTERS FROM ReqSet: 15:
# 50) "UAS" : ['User access']
# 51) "RFS" : ['rfs system', 'RFS system']
# 52) "400MB" : ['400 mb']
# #####################################################

# %% [markdown]
# ## Evaluation of AEP Detection: Counting detected AEPs

# %%
inserted_abbreviations = pd.read_csv('insertedAbbreviations.txt', names=['expansion', 'abbreviation'], sep='\t', encoding='utf8')
inserted_abbs = inserted_abbreviations["abbreviation"].tolist()
inserted_exp = inserted_abbreviations["expansion"].tolist()
inserted_abbreviations_as_tuples = [(inserted_abbs[i], inserted_exp[i]) for i in range(0, len(inserted_exp))]

def contains_exp(proper_tuple, tup):
    cont = True
    for t in proper_tuple[1].split():
        exp_candidate_lower = tup[1].lower()
        if t not in exp_candidate_lower.split():
            cont = False
    if cont:
        return True
    else:
        return False
    
matches_for_final_eval = 0
resolved_abbs = set()
for tup in tuple_collection_for_evaluation:
    for proper_tuple in inserted_abbreviations_as_tuples:
        if tup == proper_tuple and contains_exp(proper_tuple, tup):
            if tup[0] not in resolved_abbs:
                print(tup)
                resolved_abbs.add(tup[0])
                matches_for_final_eval += 1
print(matches_for_final_eval)
# Out:
# ('cT', 'current time')
# ('SR', 'search result')
# ('RT', 'realtor')
# ('DS', 'disputes system')
# ('NSM', 'nursing staff member')
# ('Csi', 'clinical site')
# ('DC', 'dispute case')
# ('CE', 'collision estimate')
# ('RF', 'repair facility')
# ('rP', 'recycled part')
# ('AR', 'audit report')
# ('SP', 'search parameter')
# ('CR', 'conference room')
# ('PF', 'product formula')
# ('sI', 'substitutionary ingredient')
# ('IQA', 'inventory quantity adjustment')
# ('Sys', 'system')
# ('sMo', 'streaming movie')
# ('CC', 'credit card')
# ('LeSco', 'lead score')
# ('LeDA', 'lead data')
# ('WES', 'web service')
# ('dG', 'defensive grid')
# ('oP', 'offensive player')
# ('STAT', 'status')
# 25
