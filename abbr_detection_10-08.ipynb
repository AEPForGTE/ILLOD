# %%
import string
import pandas as pd
import jellyfish
import random

# %% [markdown]
# # Introducing Helper Functions

# %%
def dice_coefficient(a, b):
    """dice coefficient 2nt/(na + nb)."""
    a_bigrams = set(a.lower())
    b_bigrams = set(b.lower())
    overlap = len(a_bigrams & b_bigrams)
    return overlap * 2.0 / (len(a_bigrams) + len(b_bigrams))

# %%
def clear_special_characters(s1, s2):
    invalidcharacters = set(string.punctuation)
    if any(char in invalidcharacters for char in s1):
        s1_ = s1.lower().translate(str.maketrans('', '', string.punctuation))
    else:
        s1_ = s1
    if any(char in invalidcharacters for char in s2):
        s2_ = s2.lower().translate(str.maketrans('', '', string.punctuation))
    else:
        s2_ = s2
    return s1_, s2_

# %%
def stop_words_handling(term):
    splitted_term = term.split()
    stop_words = set(["for", "and", "of", "in", "via", "be"])
    
    if splitted_term[0] in stop_words:
        stop_words = stop_words - set([splitted_term[0]])
                
    for sw in stop_words:
        while sw in splitted_term:
            splitted_term.remove(sw)
    sanitized_term = " ".join([w for w in splitted_term]) 
        
    return sanitized_term

# %%
def clean_string(s):
    s_lower = s.lower()
    invalidcharacters = set(string.punctuation)
    if any(char in invalidcharacters for char in s):
        s_ = s_lower.translate(str.maketrans('', '', string.punctuation))
    else:
        s_ = s_lower
    return s_

# %%
def clean_string_pair_and_reduce_expansion(abb, term):
    abb_lower = abb.lower()
    term_lower = term.lower()
    sanitized_abbv, sanitized_term = clear_special_characters(abb_lower, term_lower) 
    sanitized_term_without_stopswords = stop_words_handling(sanitized_term)
    initial_letters_of_tokens_of_sanitized_term_without_stopswords = ''.join([c[0] for c in sanitized_term_without_stopswords.split()])
    return sanitized_abbv, initial_letters_of_tokens_of_sanitized_term_without_stopswords

# %% [markdown]
# # Characteristics of abbreviation data

# %%
data = pd.read_csv('abbr_db.CSV', names=['abbr', 'long_forms'], sep=';', encoding='utf8')
abbr = list(data['abbr'].values)
expansions = list(data['long_forms'].values)
for i, abb in enumerate(abbr):
    print(str(i) + ": " + abb + "| " + expansions[i])
# Out:
# 0: AA| Anti-alias
# 1: AAC| Advanced Audio Coding
# 2: AAM| autmoatic acoustic management
# 3: AAS| Auto Area Segmentation
# 4: AAS| as a service
# 5: ABC| Atanasoff-Berry Computer
# 6: ABIOS| Advanced BIOS
# 7: ABP| AdBlock Plus
# 8: AC| alternating current
# 9: ACCT| account
# 10: ACE| access control entry
# 11: Ack| acknowledgment
# 12: ACL| access control list
# 13: ACM| Association for Computing Machinery
# 14: ACPI| Advanced Configuration and Power Interface
# 15: ACR| annual compliance report
# 16: ACR| actual cell rate
# 17: ACR| attenuation crosstalk ratio
# 18: ACR| absolute cell reference
# 19: ACS| access control system
# 20: AD| Active Directory
# 21: ADB| Apple Desktop Bus
# 22: ADB| Android Debug Bridge
# 23: ADC| analog-to-digital
# 24: ADO| ActiveX Data Object
# 25: ADPCM| adaptive delta pulse code modulation
# 26: ADSI| analog display service interface
# 27: ADSI| Active Directory Service Interface
# 28: ADSL| asymmetric digital subscriber line
# 29: ADSM| ADSTAR Distributed Storage Management
# 30: AE| automatic exposure
# 31: AE| After Effects
# 32: AE lock| auto exposure lock
# 33: AES| Advanced Encryption Standard
# 34: AF| Autofocus
# 35: AGP| accelerated graphics port
# 36: AHCI| Advanced Host Controller Interface
# 37: AI| artificial intelligence
# 38: AIM| Apple, IBM and Motorola
# 39: AIM| AOL Instant Messenger
# 40: AIML| Artificial Intelligent Markup Language
# 41: AIMM| AGP in-line memory module
# 42: AIO| All-in-One
# 43: AIX| advanced interactive executive
# 44: AJAX| Asynchronous JavaScript and XML
# 45: ALGOL| algorithmic language
# 46: Alpha| alphabet
# 47: ALU| arithmetic logic unit
# 48: AM| amplitude modulation
# 49: AM| ante meridiem
# 50: AMOLED| active-matrix organic light-emitting diode
# 51: Amp| ampere
# 52: ANI| Automatic Number Identification
# 53: ANSI| American National Standards Institute
# 54: AOP| auto operator
# 55: AOP| aspect-oriented programming
# 56: AOSP| Android Open Source Project
# 57: API| application programming interface
# 58: APIC| Advanced Programmable Interrupt Controller
# 59: APIPA| Automatic Private Internet Protocol Addressing
# 60: APK| Android package file
# 61: APM| advanced power management
# 62: App| application
# 63: APT| advanced persistent threat
# 64: APT| advanced packaging tool
# 65: APU| advanced processing unit
# 66: APU| accelerated processing unit
# 67: AR| augmented reality
# 68: ARCnet| Attached Resource Computer network
# 69: A record| address record
# 70: Arg| argument
# 71: ARP| Address Resolution Protocol
# 72: ARPA| address and routing parameter area
# 73: ARPA| Advanced Research Projects Agency
# 74: ARPANET| Advanced Research Projects Agency Network
# 75: ARQ| automatic repeat request
# 76: AS| autonomous system
# 77: AS/400| Application System/400
# 78: ASCII| American Standard Code for Information Interchange
# 79: ASME| American Society of Mechanical Engineers
# 80: ASMR| autonomous sensory meridian response
# 81: ASN| autonomous system number
# 82: ASN.1| abstract syntax number one
# 83: ASP| answer set programming
# 84: ASP| authorized service provider
# 85: ASP| application service provider
# 86: ASP| Active Server Pages
# 87: ASPI| advanced SCSI programming interface
# 88: ASR| automatic speech recognition
# 89: ASR| automated system recovery
# 90: AT| advanced technology
# 91: ATA| Advanced Technology Attachment
# 92: ATAPI| AT Attachment Packet Interface
# 93: ATC| advanced transfer cache
# 94: ATM| automated teller machine
# 95: ATM| at the moment
# 96: ATM| ascynchronous transfer mode
# 97: ATRAC| Adaptive Transform Acoustic Coding
# 98: ATX| Advanced Technology eXtended
# 99: AU| arithmetic unit
# 100: AUI| Attachment Unit Interface
# 101: AUP| acceptable use policy
# 102: Auto| automobile
# 103: Auto| autonomous
# 104: Auto| automatic
# 105: AV| avatar
# 106: AV| aperture value
# 107: AV| antivirus
# 108: AVC| Advanced Video Coding
# 109: AVI| Audio Video Interleaved
# 110: AVR| automatic voice response
# 111: AVR| automatic voice recognition
# 112: AVR| automatic voltage regulator
# 113: AWS| Amazon Web Services
# 114: B2B| business-to-business
# 115: B2B| business-to-consumer
# 116: Basic| Beginners All-purpose Symbolic Instruction Code
# 117: BAT| Baby AT
# 118: BB| broadband
# 119: BBS| bulletin board system
# 120: BBS| BIOS boot specification
# 121: BC| before Christ
# 122: BCC| blind carbon copy
# 123: BCD| binary-coded decimal
# 124: BCP| best current practices
# 125: BCPL| Basic Combined Programming Language
# 126: BD| Blu-ray disc
# 127: BDC| backup domain controller
# 128: BDF| Glyph Bitmap Distribution Format
# 129: BDI| bidirectional isolation
# 130: BDO| bidirectional override
# 131: BEDO DRAM| Burst EDO DRAM
# 132: BER| beyond economical repair
# 133: BER| bit error rate
# 134: BERT| bit error rate test
# 135: BERT| bit error rate tester
# 136: BF| Battlefield
# 137: BG| battleground
# 138: BG| bad game
# 139: BG| background
# 140: BGA| ball grid array
# 141: BGMP| Border Gateway Multicast Protocol
# 142: BGP| Border Gateway Protocol
# 143: BHO| Browser Helper Object
# 144: Bi-di| bidirectional
# 145: BIND| Berkeley Internet Name Domain
# 146: BIO| biography
# 147: BIOS| basic input/output system
# 148: BISYNC| BinarySynchronous Communications
# 149: Bit| binary digit
# 150: BITNET| because it's time network
# 151: BIU| bold, italic, underline
# 152: BNC| Bayonet Neill-Concelman
# 153: BO| back orifice
# 154: BOFH| Bastard Operator From Hell
# 155: BOINC| Berkeley Open Infrastructure for Network Computing
# 156: BOM| beginning of medium
# 157: BOM| beginning of message
# 158: BOM| bill of materials
# 159: BOM| byte order mark
# 160: Bool| Boolean
# 161: BPB| BIOS pattern block
# 162: BPDU| Bridge Protocol Data Unit
# 163: BPL| broadband-over-powerline
# 164: bps| bits per second
# 165: Bps| bytes per second
# 166: BPSK| biphase shift keying
# 167: Br| Break key
# 168: BRI| basic rate interface
# 169: Brouter| bridge router
# 170: BSB| back-side bus
# 171: BSC| Binary Synchronous Communications
# 172: BSoD| Blue Screen of Death
# 173: BSoD| Black Screen of Death
# 174: BSS| basic service set
# 175: BTC| Behavior Tech Computers
# 176: BTC| bitcoin
# 177: BTX| Balanced Technology eXtended
# 178: C| Celsius
# 179: C2| Core 2
# 180: CA| certificate authority
# 181: Cab| Cabinet file
# 182: CAD| computer-aided design
# 183: CAP| Competitive Access Provider
# 184: CAPS| CapsLock
# 185: CAPSLK| CapsLock
# 186: CAPTCHA| Completely Automated Public Turing test to tell Computers and Humans Apart
# 187: CAS| column access strobe
# 188: CAS| column address select
# 189: CASC| Certificate Authority Security Council
# 190: CAT| Central Africa Time
# 191: CATV| Community Access Television
# 192: CATV| Cable TV
# 193: CBL| calculator based labs
# 194: CBT| computer-based training
# 195: CC| Cursor control
# 196: CC| Creative Commons
# 197: CC| C compiler
# 198: CC| carbon copy
# 199: CCC| Catalyst Control Center
# 200: CCD| charge-coupled device
# 201: CCDE| Cisco Certified Design Expert
# 202: CCFL| cold cathode fluorescent lighting
# 203: CCIE| Cisco Certified Internetworking Expert
# 204: CCITT| Comit Consultatif International Telephonique et Telegraphique
# 205: CCNA| Cisco Certified Network Associate
# 206: CCNP| Cisco Certified Network Professional
# 207: CCS| common command set
# 208: CCS| call-control signaling
# 209: CCTV| closed circuit television
# 210: CCW| counterclockwise
# 211: CD| compact disc
# 212: CD| change directory
# 213: CDA| compact audio disc
# 214: CDA| Communication Decency Act
# 215: CDDA| compact disc digital audio
# 216: CDDB| compact disc database
# 217: CDDI| Copper Distributed Data Interface
# 218: CDE| Common Desktop Environment
# 219: CDfs| Compact Disc file system
# 220: CD-i| Compact Disc Interactive
# 221: CDMA| Code Division Multiple Access
# 222: CDN| content distribution network
# 223: CDN| content delivery network
# 224: CDP| Cache Discovery Protocol
# 225: CDP| Certificate in Data Processing
# 226: CDP| Columbia Data Products
# 227: CDP| content delivery platform
# 228: CDP| content discovery platform,
# 229: CDP| continuous data protection
# 230: CD-PROM| Compact Disc-Programmable ROM
# 231: CD-R| Compact Disc Recordable
# 232: CDRFS| CD-R file system
# 233: CD-ROM| Compact Disc Read-Only Memory
# 234: CD-ROM XA| CD-ROM extended architecture
# 235: CD-RW| Compact Disc Re-Writable
# 236: CDSL| Consumer DSL
# 237: CD-WO| Compact Disc Write Once
# 238: CE| cancel entry
# 239: CE| consumer edition
# 240: CE| compact edition
# 241: CE| collector's edition
# 242: Cell phone| cellular telephone
# 243: CentOS| Community Enterprise Operating System
# 244: CEO| chief executive officer
# 245: CERN| Conseil Europeen pour la Recherche Nuclaire
# 246: CERT| certified
# 247: CERT| Computer Emergency Response Team
# 248: Cert| certification
# 249: Cert| certified
# 250: Cert| certificate
# 251: CES| Consumer Electronics Show
# 252: CF| CompactFlash
# 253: CFPM| cubic feet per minute
# 254: CGA| Color Graphics Adapter
# 255: CGI| computer-generated imagery
# 256: CGI| common gateway interface
# 257: CH| Computer Hope
# 258: CHAP| Challenge-Handshake Authentication Protocol
# 259: Char| character
# 260: chdir| change directory
# 261: CHS| cylinder-head-sector
# 262: cHTML| compact HTML
# 263: CIDR| classless inter-domain routing
# 264: CIFS| common Internet file system
# 265: CIM| common information model
# 266: CIR| committed information rate
# 267: CISC| complex instruction set computer
# 268: CISSP| certified information systems security professional
# 269: CLCC| ceramic leadless lead carrier
# 270: CLI| command-line interface
# 271: CLNS| connectionless network service
# 272: CLOS| Common Lisp object system
# 273: CLR| common language runtime
# 274: CLSID| class ID
# 275: CLUT| color lookup table
# 276: CMA| Computer Misuse Act
# 277: CMC| computer-mediated communication
# 278: CMOS| complementary metal-oxide semiconductor
# 279: CMS| content management system
# 280: CMYK| cyan magenta yellow black
# 281: CNCT| Certified Network Computer Technician
# 282: CNE| Certified Novell Engineer
# 283: CNR| Communication and Network Riser
# 284: CNST| Certified Network Systems Technician
# 285: CO| central office
# 286: COA| Certificate of Authenticity
# 287: COAST| Cache On A STick
# 288: COB| chip on board
# 289: COB| close of business
# 290: COBOL| Common Business Oriented Language
# 291: Code| source code
# 292: Codec| Compression / Decompression
# 293: Codec| COmpression / DECompression
# 294: Coil| electromagnetic coil
# 295: COLA| comp.os.linux.announce
# 296: COM| Computer Output Microfilm
# 297: COM| Component Object Model
# 298: COMDEX| Computer Dealers' Exhibition
# 299: CompTIA| Computer Technology Industry Association
# 300: Con| conference
# 301: Con| confidence
# 302: Con| console
# 303: COPPA| Children's Online Privacy Protection Act
# 304: COPPA| California Online Privacy Protection Act
# 305: Core| core dump
# 306: CPA| cost per acquisition
# 307: CPA| cost per action
# 308: CPAN| comprehensive Perl archive network
# 309: CPC| cost per click
# 310: CPGA| ceramic pin grid array
# 311: CPI| characters per inch
# 312: CPL| Combined Programming Language
# 313: CPM| cost per mile
# 314: CPM| cost per thousand
# 315: CPS| characters per second
# 316: CPTM| cost per targeted thousand
# 317: CPU| central processing unit
# 318: CR| carriage return
# 319: CRC| cyclic redundancy check
# 320: CREN| Corporation for Research and Educational Networking
# 321: C-RIMM| continuity RIMM
# 322: CRL| Certificate Revocation List
# 323: CR/LF| carriage return/line feed
# 324: CRM| customer relationship management
# 325: CRT| cathode ray tube
# 326: Crypto| cryptography
# 327: CS| customer service
# 328: CS| computer science
# 329: CS| cable select
# 330: CS| code segment
# 331: CSMA/CD| carrier sense multiple access/collision detection
# 332: CSNET| Computer Science Network
# 333: CSS| Cascading Style Sheets
# 334: CSS| chirp spread spectrum
# 335: CSS| Content Scramble System
# 336: CSS| cascading style sheets
# 337: CST| Computer Service Technician
# 338: CSU/DSU| Channel Service Unit/Data Service Unit
# 339: CSV| comma-separated values
# 340: CTA| call to action
# 341: CTCP| client-to-client protocol
# 342: CTD| crash to desktop
# 343: CTF| Capture the Flag
# 344: CTO| chief technical officer
# 345: CTO| chief technology officer
# 346: CTR| click-through rate
# 347: Ctrl| Control key
# 348: CTS| Clear to Send
# 349: CTTY| change teletype
# 350: CU| control unit
# 351: CUI| command-line user interface
# 352: CUI| character user interface
# 353: CUPS| Common Unix Printing System
# 354: Curmbox| Current Mailbox
# 355: CUT| Coordinated Universal Time
# 356: CVE| Common Vulnerabilities and Exposures
# 357: CVS| Concurrent Version System
# 358: CWIS| Campus Wide Information System
# 359: D| depth
# 360: D2D| disk-to-disk
# 361: DAC| discretionary access control
# 362: DAC| digital-to-analog converter
# 363: DACL| discretionary access control list
# 364: DAE| digital audio extraction
# 365: DARPA| Defense Advanced Research Projects Agency
# 366: DART| Data Access in Real Time
# 367: DART| Dynamic Analysis and Replanning Tool
# 368: DART| Microsoft Diagnostics and Recovery Toolset
# 369: DASD| direct access storage device
# 370: DASP| Disk Anti-Shock Protection
# 371: DASP| Drive Active Slave Present
# 372: DASP| Dynamic Adaptive Speculative Pre-Processor
# 373: DAT| Digital Audio Tape
# 374: DAW| digital audio workstation
# 375: DB| database
# 376: DBA| database analyst
# 377: DBA| decibels adjust
# 378: DBA| database administrator
# 379: DBAN| Darik's Boot and Nuke
# 380: DBMS| database management system
# 381: DC| domain controller
# 382: DC| data center
# 383: DC| disconnect
# 384: DC| direct current
# 385: DCC| Direct Client-to-Client
# 386: DCE| data circuit-terminating equipment
# 387: DCE| data communication equipment
# 388: DCE| Desktop Composting Engine
# 389: DCE| distributed computing environment
# 390: DCIM| digital camera images
# 391: DCOM| Distributed Component Object Model
# 392: DD| double density
# 393: DDBMS| distributed database management system
# 394: DDE| Dynamic Data Exchange
# 395: DDK| driver development kit
# 396: DDL| data definition language
# 397: DDNS| dynamic DNS
# 398: DDO| disk drive overlay
# 399: DDoS| Distributed Denial of Service
# 400: DDP| Datagram Delivery Protocol
# 401: DDR| dial-on-demand routing
# 402: DDR| double data rate
# 403: DDR2| double data rate two
# 404: DDR3| double data rate three
# 405: DDR4| double data rate four
# 406: DDR SDRAM| double data rate synchronous dynamic random access memory
# 407: DDS| Digital Data Storage
# 408: DEA| Data Encryption Algorithm
# 409: DEC| Digital Equipment Corporation
# 410: DES| Data Encryption Standard
# 411: DFMC| direct methanol fuel cell
# 412: DHCP| Dynamic Host Configuration Protocol
# 413: DHTML| dynamic Hypertext Markup Language
# 414: DID| direct inward dialing
# 415: DIF| Directory Interchange Format
# 416: DIME| direct Internet message encapsulation
# 417: DIMM| dual in-line memory module
# 418: DIP| dual in-line package
# 419: DIVX| digital video express
# 420: DIX| Digitial, Intel, and Xerox
# 421: DL| download
# 422: D/L| download
# 423: DLA| drive letter access
# 424: DLC| downloadable content
# 425: DLC| digital loop carrier
# 426: DLC| Data Link Control
# 427: DLL| dynamic-link library
# 428: DLNA| Digital Living Network Alliance
# 429: DLP| Digital Light Processing
# 430: DLP| discrete logarithm problem
# 431: DLP| data level parallelism
# 432: DLP| data loss prevention
# 433: DLT| digital linear tape
# 434: DM| Device Manager
# 435: DM| direct message
# 436: DMA| direct memory access
# 437: DMAC| Direct Memory Access Control
# 438: DMAR| destination memory address register
# 439: DMCA| Digital Millennium Copyright Act
# 440: DMI| Desktop Management Interface
# 441: DML| data manipulation language
# 442: DMTF| Distributed Management Task Force
# 443: DMZ| demilitarized zone
# 444: DNS| Domain Name System
# 445: DOA| dead on arrival
# 446: DoCoMo| Do Communications Over Mobile
# 447: DOD| Department of Defense
# 448: DoS| denial of service
# 449: DOS| disk operating system
# 450: DoT| damage over time
# 451: Double| Double-precision floating-point
# 452: DP| DisplayPort
# 453: DPI| dots per inch
# 454: Dpkg| Debian package manager
# 455: DPMI| DOS Protected Mode Interface
# 456: DPMS| display power management system
# 457: DPS| damage per second
# 458: DRAM| dynamic random access memory
# 459: DRM| digital rights management
# 460: Drop| malware dropper
# 461: DRQ| data request
# 462: DS| drive select
# 463: DSAP| Destination Service Access Point
# 464: DSL| Damn Small Linux
# 465: DSL| digital subscriber line
# 466: DSO| data source object
# 467: DSP| drive secondary present
# 468: DSP| digital signal processor
# 469: DSR| Dynamic Source Routing
# 470: DSR| Dell System Restore
# 471: DSS| Digital Signature Standard
# 472: DSS| Digital Satellite Service
# 473: DSVD| Digital Simultaneous Voice and Data
# 474: DTE| data terminating equipment
# 475: DTE| data terminal equipment
# 476: DTR| Data Terminal Ready
# 477: DTS| data transformation services
# 478: DTS| Digital Theater Sound
# 479: DTS| digital thermal sensor
# 480: DTX| discontinuous transmission
# 481: DUN| Dial-Up Networking
# 482: DUT| device under test
# 483: DVD| digital versatile disc
# 484: DVI| digital visual interface
# 485: DVMT| Dynamic Video Memory Technology
# 486: DVR| Digital Video Recorder
# 487: Dword| double word
# 488: DxDiag| DirectX diagnostics
# 489: E-911| Enhanced 911
# 490: EA| Electronic Arts
# 491: EAI| enterprise application integration
# 492: EAP| Extensible Authentication Protocol
# 493: EAP-FAST| Flexible Authentication via Secure Tunneling
# 494: EAPROM| Electronically Alterable Programmable Read-Only Memory
# 495: Eb / EB| Exabit / Exabyte
# 496: EBCDIC| Extended Binary Coded Decimal Interchange Code
# 497: E-book| electronic book
# 498: ECC| error-correcting code
# 499: ECDSA| Elliptic Curve Digital Signature Algorithm
# 500: ECHS| extended cylinder-head-sector
# 501: ECMA| European Computer Manufacturers Association
# 502: ECP| Extended Capabilities Port
# 503: EDA| electronic design automation
# 504: EDI| electronic data interchange
# 505: EDIINT| electronic data interchange-Internet integration
# 506: EDO| Extended Data Out
# 507: EDP| electronic data processing
# 508: EDSAC| Electronic Delay Storage Automatic Calculator
# 509: EDVAC| Electronic Discrete Variable Automatic Computer
# 510: EEPROM| electrically erasable programmable read-only memory
# 511: EFI| Extensible Firmware Interface
# 512: EFS| Encrypting File System
# 513: EGA| Enhanced Graphics Adapter
# 514: eGPU| external graphics processing unit
# 515: EHCI| enhanced host controller interface
# 516: EIA| Electronic Industries Alliance
# 517: EIDE| enhanced integrated drive electronics
# 518: EIGRP| Enhanced Interior Gateway Routing Protocol
# 519: EISA| Extended Industry Standard Architecture
# 520: EISA| Extended ISA
# 521: EIST| enhanced Intel SpeedStep technology
# 522: ELD| electroluminescent display
# 523: E-learning| electronic learning
# 524: ELF| extremely low frequency
# 525: EM| emphasized
# 526: E-mail| electronic mail
# 527: EMF| enhanced metafile
# 528: EMF| electromotive force
# 529: EMI| electromagnetic interference
# 530: EMM| expanded-memory manager
# 531: EMS| expanded memory specification
# 532: EMS| emergency management services
# 533: ENIAC| Electronic Numerical Integrator and Calculator
# 534: EOF| end-of-file
# 535: EOL| End-of-Line
# 536: EOM| end-of-message
# 537: EOP| end-of-page
# 538: EOT| end of topic
# 539: EOT| End-of-Transmission
# 540: EOW| end of week
# 541: EPD| electronic paper display
# 542: EPIC| Electronic Privacy Information Center
# 543: EPP| Enhanced Parallel Port
# 544: EPROM| Erasable Programmable Read-Only Memory
# 545: EPS| encapsulated PostScript
# 546: ePUB| electronic publication
# 547: EQ| equalizer
# 548: EQ| equals
# 549: ESA| Entertainment Software Association
# 550: ESCD| Extended System Configuration Data
# 551: ESD| electrostatic discharge
# 552: ESDI| Enhanced Small Disk Interface
# 553: ESI| Enhanced Serial Interface
# 554: ESP| e-mail server provider
# 555: ESRB| Entertainment Software Rating Board
# 556: ETA| estimated time of arrival
# 557: ETA-I| Electronic Technicians Association International
# 558: ETX| End-of-Text
# 559: EULA| End-User License Agreement
# 560: Eval| evaluate
# 561: EVD| enhanced versatile disc
# 562: EV-DO| Evolution-Data Only
# 563: EV-DO| Evolution-Data Optimized
# 564: EVP| enhanced virus protection
# 565: exFAT| Extended File Allocation Table
# 566: F| fahrenheit
# 567: FAD| functioning as designed
# 568: Famicom| family computer
# 569: FAQ| frequently asked questions
# 570: FAST| Flexible Authentication via Secure Tunneling
# 571: FAT| file allocation table
# 572: FAU| file allocation unit
# 573: Fav| favorite
# 574: FB| facebook
# 575: FCC| Federal Communications Commission
# 576: FCIP| Fibre Channel over IP
# 577: FC-PGA| flip-chip pin grid array
# 578: FD| floppy drive
# 579: FDC| Floppy Disk Controller
# 580: FDD| floppy disk drive
# 581: FDDI| Fiber Distributed Data Interface
# 582: FDHP| Full Duplex Handshaking Protocol
# 583: Feat| feature
# 584: FF| fast forward
# 585: FF| form feed
# 586: FF| Firefox
# 587: FFA| free for all
# 588: FFS| freefall sensor
# 589: FHD| Full High Definition
# 590: FIF| fractal image format
# 591: FIFO| first in, first out
# 592: FiOS| Fiber Optic Service
# 593: FIPS| Federal Information Processing Standards
# 594: Fixed| fixed-point
# 595: FLAC| Free Lossless Audio Codec
# 596: Flash| Adobe Flash
# 597: Float| floating-point
# 598: FLOPS| Floating-Point Operation Per Second
# 599: FM| frequency modulation
# 600: FMV| full motion video
# 601: Fn| function
# 602: FNEA| full name and e-mail address
# 603: FNR| format and restore
# 604: FOIA| Freedom of Information Act
# 605: FOIRL| fiber-optic inter-repeater links
# 606: FORTRAN| Formula Translation
# 607: FOSS| free and open-source software
# 608: FP| FrontPage
# 609: FP| fast page
# 610: FPGA| field-programmable gate array
# 611: FPM| fast page mode
# 612: FPROM| field programmable read-only memory
# 613: FPS| frames per second
# 614: FPU| floating-point unit
# 615: FQDN| fully qualified domain name
# 616: FR| Frame Relay
# 617: FRAM| Ferroelectric RAM
# 618: FRU| field-replacable unit
# 619: FS| file system
# 620: FSB| front-side bus
# 621: Fsck| file system check
# 622: FSO| free-space optical communication
# 623: FSP| File Sharing Protocol
# 624: Fstab| file systems table
# 625: FSTN| film supertwist nematic
# 626: Fstype| file system type
# 627: FTAM| file transfer, access and management
# 628: FTC| Federal Trade Commission
# 629: FTP| File Transfer Protocol
# 630: FWH| Firmware Hub
# 631: FYI| for your information
# 632: G+| Google Plus
# 633: G2G| government to government
# 634: GA| general availabililty
# 635: GaAs| Gallium Arsenide
# 636: Gb / GB| gigabit / gigabyte
# 637: GBIC| gigabit interface converter
# 638: Gbps| Gigabits per second
# 639: GCC| GNU Compiler Collection
# 640: GCHQ| Government Communications Headquarters
# 641: GCR| group code recording
# 642: GDDR| graphics double data rate
# 643: GDI| Graphics Device Interface
# 644: GDPR| General Data Protection Regulation
# 645: GE| General Electric
# 646: GEM| Graphics Environment Manager
# 647: GF| GeForce
# 648: GFM| GitHub Flavored Markdown
# 649: GHz| Gigahertz
# 650: Gib / GiB| gibibit / gibibyte
# 651: GIGO| garbage in, garbage out
# 652: GIMP| GNU image manipulation program
# 653: GIMPS| great Internet mersenne prime search
# 654: GIS| Geographic Information System
# 655: GKS| Graphical Kernel System
# 656: GM| gold master
# 657: GM| game masters
# 658: Gmail| Google Mail
# 659: GNU| GNU's Not Unix
# 660: GPF| general protection fault
# 661: GPG| GNU Privacy Guard
# 662: GPL| general public license
# 663: GPO| Group Policy Object
# 664: GPPM| graphic pages per minute
# 665: GPRS| General Packet Radio Service
# 666: GPS| Global Positioning System
# 667: GPT| GUID partition table
# 668: GPU| graphics processing unit
# 669: Gravatar| globally recognized avatar
# 670: GRUB| GRand Unified Bootloader
# 671: GSM| Global System for Mobile communication
# 672: GT| Greenwich Mean Time
# 673: GTK| GIMP toolkit
# 674: GUI| graphical user interface
# 675: GUID| globally unique identifier
# 676: GWAM| gross words a minute
# 677: Gzip| GNU zip
# 678: H| height
# 679: HACMP| high availability cluster multiprocessing
# 680: HAL| hardware abstraction layer
# 681: HAN| home area network
# 682: HBA| host bus adapter
# 683: HCI| human computer interface
# 684: HCL| hardware compatibility list
# 685: HD| high-definition
# 686: HD| high-density
# 687: HD| hard drive
# 688: HDC| hard disk controller
# 689: HDCP| High-bandwidth Digital Content Protection
# 690: HDD| hard disk drive
# 691: HD DVD| High Definition Digital Versatile Disc
# 692: HDLC| High-level Data Link Control
# 693: HDMI| High-Definition Multimedia Interface
# 694: HDML| handheld device markup language
# 695: HD-ROM| high-density read-only memory
# 696: HDSL| high-bit-rate digital subscriber line
# 697: HDTV| high-definition TV
# 698: HEIF| High Efficiency Image File format
# 699: HES| hypertext editing system
# 700: HEVC| high efficiency video coding
# 701: HFC| hybrid fiber coax
# 702: HFS| hierarchical file system
# 703: HGA| Hercules graphics adapter
# 704: HID| human interface device
# 705: Hiew| hacker's view
# 706: Hi-res| high resolution
# 707: HIT| human intelligence task
# 708: HLL| high-level language
# 709: HMA| high-memory area
# 710: HOP| half OP
# 711: HoT| Heal over Time
# 712: HP| Hewlett-Packard
# 713: HPA| high-performance addressing
# 714: HPD| hybrid passive display
# 715: HPFS| high-performance file system
# 716: HPGL| Hewlett Packard Graphic Language
# 717: HP-UX| Hewlett Packard UniX
# 718: HQ| high-quality
# 719: HR| Human Resources
# 720: HREF| Hypertext reference
# 721: HSB| Hue, Saturation, and Brightness
# 722: HSF| heat sink and fan
# 723: HSL| Hue, Saturation, and Lightness
# 724: HSSI| High-Speed Serial Interface
# 725: HSYNC| Horizontal Synchronization
# 726: HT| Hyper-Threading
# 727: HT| HyperTransport
# 728: HTML| Hypertext Markup Language
# 729: HTPC| home theater personal computer
# 730: HTTP| Hypertext Transfer Protocol
# 731: HUD| heads up display
# 732: HW| hardware
# 733: Hz| Hertz
# 734: IA-32| Intel Architecture 32
# 735: IA-64| Intel Architecture 64
# 736: IAB| Internet Architecture Board
# 737: IAC| Interapplication communications
# 738: IAC| In Any Case
# 739: IAD| integrated access device
# 740: IANA| Internet Assigned Numbers Authority
# 741: IAP| Internet access provider
# 742: IBG| interblock gap
# 743: ICA| integrated communications adapter
# 744: ICA| independent computing architecture
# 745: Icacl| Integrity control access control list
# 746: ICANN| Internet Corporation for Assigned Names and Numbers
# 747: ICCCM| Inter-Client Communication Conventions Manual
# 748: ICCP| Institute for Certification of Computer Professionals
# 749: ICMP| Internet Control Message Protocol
# 750: ICO| Initial Coin Offering
# 751: ICO| icon
# 752: iCOMP| Intel comparative microprocessor performance
# 753: ICRA| Internet Content Rating Association
# 754: ICS| Internet Connection Sharing
# 755: ICT| International Computers and Tabulators
# 756: ICT| information and communications technology
# 757: ICU| interactive chart utility
# 758: ICU| ISA configuration utility
# 759: ICU| interface converter unit
# 760: ICU| instruction cache unit
# 761: IDC| insulation displacement contact
# 762: IDE| integrated development environment
# 763: IDE| integrated device electronics
# 764: IDEA| International Data Encryption Algorithm
# 765: IDMS| Integrated Database Management System
# 766: IDPS| intrusion detection prevention system
# 767: IDS| intrusion detection system
# 768: IDSL| integrated services digital network digital subscriber line
# 769: IE| Internet Explorer
# 770: IEC| International Electrotechnical Commision
# 771: IEEE| Institute of Electrical and Electronics Engineers
# 772: IEN| Image-Enabled Netware
# 773: IEN| Internet Engineering Notes
# 774: IEN| Internet Experiment Note
# 775: IETF| Internet engineering task force
# 776: IF| interactive fiction
# 777: IFIP| International Federation for Information Processing
# 778: IFTF| Interactive Fiction Technology Foundation
# 779: IGES| Initial Graphics Exchange Specification
# 780: IGMP| Internet Group Management Protocol
# 781: IGP| Interior Gateway Protocol
# 782: IHA| Intel Hub Architecture
# 783: IIL| integrated injection logic
# 784: IIS| Internet Information Server
# 785: IM| instant messaging
# 786: IM| instant messenger
# 787: IM| instant message
# 788: IMAP| Internet Message Access Protocol
# 789: IMDb| Internet Movie Database
# 790: IMEI| International Mobile Equipment Identity
# 791: IMSI| International Mobile Subscriber Identity
# 792: INC| incorporated
# 793: INCITS| International Committee for Information Technology Standards
# 794: Inetd| Internet service daemon
# 795: Info| information
# 796: Inode| index node
# 797: Int| integer
# 798: INTR| interrupt
# 799: I/O| input/output
# 800: IOC| input/output controller
# 801: IOCCC| Internet Obfuscated C Code Contest
# 802: IOPS| input/output operations per second
# 803: IOS| Input/Output Supervisor
# 804: IOS| Internetworking operating system
# 805: IP| Internet Protocol
# 806: IP| ingress protection
# 807: IP| intellectual property
# 808: IPB| illustrated parts breakdown
# 809: IPC| instructions per cycle
# 810: IPC| interprocess communication
# 811: IPD| interpupillary distance
# 812: IPF| invalid page fault
# 813: IPL| initial program load
# 814: IPng| Internet Protocol next generation
# 815: IPOS| input, processing, output, and storage
# 816: IPOS| IP over Satellite
# 817: IP Rating| Ingress Protection Rating
# 818: IPS| intrusion prevention system
# 819: IPsec| Internet Protocol security
# 820: IPTO| Information Processing Technology Office
# 821: IPTV| Internet Protocol television
# 822: IPv4| Internet Protocol version 4
# 823: IPv6| Internet Protocol version 6
# 824: IPX/SPX| Internetwork Packet Exchange/Sequenced Packet Exchange
# 825: IR| information retrieval
# 826: IR| infrared
# 827: IRC| Internet Relay Chat
# 828: IrDA| Infrared Data Association
# 829: IRG| interrecord gap
# 830: IRGB| Intensity-Red-Green-Blue
# 831: IRQ| interrupt request
# 832: IS| Information Systems
# 833: IS| Information Services
# 834: IS| image stabilization
# 835: ISA| Industry Standard Architecture
# 836: ISACA| Information System Audit and Control Association
# 837: ISAM| indexed sequential access method
# 838: ISAPI| Internet Server Application Programming Interface
# 839: ISATAP| Intra-Site Automatic Tunnel Addressing Protocol
# 840: ISBN| International Standard Book Number
# 841: ISDN| Integrated Services Digital Network
# 842: ISIS| integrated software for imagers and spectrometers
# 843: ISIS| infinitely scalable intelligent storage
# 844: ISIS| Image and Scanner Interface Specification
# 845: ISO| International Organization for Standardization
# 846: ISP| Internet service provider
# 847: ISV| independent software vendor
# 848: IT| information technology
# 849: ITC| International Typeface Corporation
# 850: ITIL| Information Technology Infrastructure Library
# 851: ITU| International Telecommunication Union
# 852: ITX| Information Technology eXtended
# 853: JAR| Java archive
# 854: Java EE| Java Platform, Enterprise Edition
# 855: JCL| job control language
# 856: JDBC| Java Database Connectivity
# 857: JDK| Java Development Kit
# 858: JEDEC| Joint Electron Device Engineering Council
# 859: JHTML| Java within HTML
# 860: JIL| Java Intermediate Language
# 861: JIT| just-in-time
# 862: JNI| Java Native Interface
# 863: JPEG| Joint Photographic Experts Group
# 864: JRE| Java Runtime Environment
# 865: JSON| JavaScript Object Notation
# 866: JSP| JavaServer Pages
# 867: JSR| jump to subroutine
# 868: JTAG| Joint Test Action Group
# 869: JVM| Java virtual machine
# 870: K| kilobit
# 871: kb / kbit| kilobit
# 872: KB| knowledge base
# 873: Kbps| kilobits per second
# 874: KDE| K Desktop Environment
# 875: kHz| kilohertz
# 876: KiB| kibibyte
# 877: Kib| kibibit
# 878: kilo| one thousand
# 879: KVM| Kernel-based Virtual Machine
# 880: KVM| keyboard, video, and mouse
# 881: L2| level 2 cache
# 882: L2P| learn to play
# 883: L2TP| Layer 2 Tunneling Protocol
# 884: LAME| LAME ain't an MP3 encoder
# 885: LAN| local area network
# 886: LAPM| Link Access Procedure for Modems
# 887: Laser| light amplification by stimulated emission of radiation
# 888: LAWN| local area wireless network
# 889: LBA| large block addressing
# 890: LBS| location-based service
# 891: LC| lowercase
# 892: LCC| leadless chip carrier
# 893: LCD| liquid crystal display
# 894: LD| laserdisc
# 895: LDAP| Lightweight Directory Access Protocol
# 896: LE| Less than or Equal to
# 897: LED| light-emitting diode
# 898: LED monitor| light-emitting diode
# 899: LF| line feed
# 900: LFAP| Light-weight Flow Admission Protocol
# 901: LFD| Login Failure Daemon
# 902: LFN| long file name
# 903: LGA| land grid array
# 904: LGPL| Lesser General Public License
# 905: LH| Loadhigh
# 906: LIFO| last in, first out
# 907: Li-ion| lithium-ion
# 908: LILO| Last In Last Out
# 909: Li-polymer| lithium-polymer
# 910: LIPS| LInux Phone Standard
# 911: LIPS| Linear Inferences Per Second
# 912: Lisp| List Processing
# 913: LISTSERV| list server
# 914: LKGC| last known good configuration
# 915: LLC| limited liability company
# 916: LLC| Logical Link Control
# 917: LMK| let me know
# 918: LMS| Learning Management System
# 919: LNP| local number portability
# 920: LOD| level of detail
# 921: LOF| loss of frame
# 922: Lo-res / low-res| low-resolution
# 923: LOS| Loss of signal
# 924: LOS| Line of Sight
# 925: LP| long play
# 926: LPD| line printer daemon
# 927: LPI| lines per inch
# 928: LPM| lines per minute
# 929: LPS| Library Programs Service
# 930: LPT| line printer terminal
# 931: LPWAN| low-power wide-area network
# 932: LPX| Low Profile eXtension
# 933: LQ| letter-quality
# 934: LRC| longitudinal redundancy check
# 935: LRDIMM| load-reduced dual inline memory module
# 936: LRU| line replaceable unit
# 937: LSB| least significant bit
# 938: LSC| least significant character
# 939: LSD| least significant digit
# 940: LSP| link state packet
# 941: LSP| Layered Service Provider
# 942: LTE| Long-Term Evolution
# 943: LU| logic unit
# 944: Luser| Local user
# 945: lvl| level
# 946: Lzone| Landing Zone
# 947: LZ| Landing Zone
# 948: m| milli
# 949: M-| meta key
# 950: MAC| media access control
# 951: MAC| Macintosh
# 952: Macro| macroinstruction
# 953: MAE| Metropolitan Area Ethernet
# 954: mAH| milliamp hour
# 955: MAN| manual
# 956: MAPI| Message Application Programming Interface
# 957: MAPS| Mail Abuse Prevention Systems
# 958: MAR| memory address register
# 959: Matlab| matrix laboratory
# 960: Matrix| Matrix code
# 961: MAU| media access unit
# 962: Max| maximize
# 963: Max| maximum
# 964: mb| motherboard
# 965: Mb| megabit
# 966: MB| megabyte
# 967: MBAM| Malwarebytes
# 968: MBean| Managed Beans
# 969: MBL| microcomputer-based labs
# 970: Mbps| megabits per second
# 971: MBps| megabytes per second
# 972: MBR| master boot record
# 973: MC| megacycle
# 974: MCA| Micro Channel Architecture
# 975: MCGA| multicolor graphics array
# 976: MCITP| Microsoft Certified IT Professional
# 977: MCSA| Microsoft Certified Systems Administrator
# 978: MCSE| Microsoft Certified System Engineer
# 979: MDA| Monochrome Display Adapter
# 980: MDBMS| Multidimensional Database Management System
# 981: MDC| modification detection code
# 982: MDF| main distribution frame
# 983: MDI| multiple-document interface
# 984: MDRAM| Multibank DRAM
# 985: Memo| memorandum
# 986: MFA| multi-factor authentication
# 987: Mflop| megaflop
# 988: MFM| Modified Frequency Modulation
# 989: MFP| multifunction printer
# 990: MFT| Master File Table
# 991: Mget| multiple get
# 992: MHz| megahertz
# 993: Mib| mebibit
# 994: MiB| mebibyte
# 995: MIB| management information base
# 996: MICR| magnetic ink character recognition
# 997: Microsoft MVP| Microsoft Most Valuable Professional
# 998: MIDI| Musical Instrument Digital Interface
# 999: MIME| Multipurpose Internet Mail Extension
# 1000: MIMO| multiple-input, multiple-output
# 1001: Min| minimum
# 1002: MIN| mobile identification number
# 1003: MIPS| millions of instructions per second
# 1004: MIR| mail in rebate
# 1005: MIS| management information system
# 1006: MIT| Massachusetts Institute of Technology
# 1007: MITMA| man-in-the-middle attack
# 1008: Mkdir| make directory
# 1009: MMC| MultiMediaCard
# 1010: MMC| Microsoft Management Console
# 1011: MMI| man machine interface
# 1012: MMORPG| massively multiplayer online role playing game
# 1013: MMS| Multimedia Message Service
# 1014: MMU| memory management unit
# 1015: MMX| MultiMedia eXtension
# 1016: MNP| Microcom Network Protocol
# 1017: Moblog| mobile blog
# 1018: Mod| modulo
# 1019: Model no.| model number
# 1020: Modem| modulator/demodulator
# 1021: MO diskette| magneto-optical diskette
# 1022: Mofo| Mozilla Foundation
# 1023: MOS| metal-oxide-semiconductor
# 1024: MOSFET| metal-oxide semiconductor field-effect transistor
# 1025: MOTD| message of the day
# 1026: MOV| Metal Oxide Varistor
# 1027: MPAA| Motion Picture Association of America
# 1028: MPC| Multimedia Personal Computer
# 1029: MPEG| Moving Picture Experts Group
# 1030: MPI| message passing interface
# 1031: MPLS| Multiprotocol Label Switching
# 1032: MPP| massively parallel processing
# 1033: Mput| multiple put
# 1034: MRP| Materials Requirement Planning
# 1035: MRU| Maximum Receive Unit
# 1036: MRUD| Most Recently Used Directory
# 1037: MS| Microsoft
# 1038: MS| memory stick
# 1039: MS| millisecond
# 1040: MSC| Most Significant Character
# 1041: MSCS| Microsoft Cluster Server
# 1042: MSD| Most Significant Digit
# 1043: MSD| Microsoft Diagnostics
# 1044: MSDN| Microsoft Developer Network
# 1045: MS-DOS| Microsoft Disk Operating System
# 1046: MSDS| material safety data sheet
# 1047: MSE| Microsoft Security Essentials
# 1048: MSN| The Microsoft Network
# 1049: MSP| Management Service Provider
# 1050: MSRP| Manufacturer's Suggested Retail Price
# 1051: MSVC| Microsoft Visual C++
# 1052: MTA| mail transfer agent
# 1053: MTBF| mean time between failure
# 1054: MTU| maximum transmission unit
# 1055: MUD| multi-user dungeon
# 1056: MUI| multi-user interface
# 1057: MUT| MultiUser Talk
# 1058: Mutex| mutual exclusion object
# 1059: MVNO| mobile virtual network operator
# 1060: MVP| most valuable player
# 1061: MVS| multiple virtual storage
# 1062: MX record| Mail eXchange record
# 1063: NAK| negative acknowledgment
# 1064: NAS| network access server
# 1065: NAS| network-attached storage
# 1066: NAT| Network Address Translation
# 1067: NCP| Network Control Protocol
# 1068: NCP| NetWare Core Protocol
# 1069: NCSA| National Center for Supercomputing Applications
# 1070: NCSC| National Cybersecurity Center
# 1071: NDA| non-disclosure agreement
# 1072: NDAS| Network Direct Attached Storage
# 1073: NDIS| network driver interface specification
# 1074: NDR| non-active, dormant, to be removed
# 1075: NDR| network data representation
# 1076: NDR| non-destructive readout
# 1077: NDRO| non-destructive readout
# 1078: ne| not equal
# 1079: NEC| Nippon Electronics Company
# 1080: NEM| New Economic Movement
# 1081: Net| network
# 1082: NetBEUI| NetBIOS Enhanced User Interface
# 1083: NetBIOS| Network Basic Input/Output System
# 1084: NFC| near-field communication
# 1085: NFR| Not For Resell
# 1086: NFS| network file system
# 1087: NG| newsgroup
# 1088: NIC| network interface card
# 1089: NIDS| network intrusion detection system
# 1090: NII| National Information Infrastructure
# 1091: NiMH| nickel-metal hydride
# 1092: Nimrod| National Institute Machine Radiating On Downs
# 1093: NIP| non-impact printer
# 1094: NIT| Network Information Table
# 1095: NLP| natural language processing
# 1096: NLQ| near letter-quality
# 1097: NLS| online system
# 1098: NLX| New Low Profile Extended
# 1099: nm| nanometer
# 1100: NMI| nonmaskable interrupt
# 1101: NMS| network management system
# 1102: NN| NOT NULL
# 1103: NNTP| Network News Transfer Protocol
# 1104: NO-OP| no operatation
# 1105: NOR| Not-Or
# 1106: NOS| network operating system
# 1107: NPAPI| Netscape Plugin Application Programming Interface
# 1108: NPC| NP-Complete
# 1109: NPC| non-printing character
# 1110: NPC| non-playable character
# 1111: NRZ| non-return-to-zero
# 1112: ns| nanosecond
# 1113: NSAP| Network Service Access Point
# 1114: NSFNET| National Science Foundation Network
# 1115: NSP| news service provider
# 1116: NSP| network service provider
# 1117: NSP| Name Server Protocol
# 1118: NSPA| Network Service Point Address
# 1119: NSSN| National Standards Systems Network
# 1120: NTFS| NTFS file system
# 1121: NTLDR| NT loader
# 1122: NTP| Network Time Protocol
# 1123: NTSC| National Television System Committee
# 1124: NTWY| noteworthy
# 1125: NUC| Next Unit of Computing
# 1126: Num| number
# 1127: NVRAM| non-volatile random-access memory
# 1128: NWAM| Network Auto Magic
# 1129: OA| office automation
# 1130: OBJ| object
# 1131: OCR| optical character recognition
# 1132: OCTAVE| operationally critical threat, asset, and vulnerability evaluation
# 1133: ODBC| Open Database Connectivity
# 1134: ODI| Open Data-Link Interface
# 1135: ODP| OverDrive Processor
# 1136: ODPR| OverDrive Processor Replacement
# 1137: OEM| original equipment manufacturer
# 1138: OHCI| Open Host Controller Inferface
# 1139: OID| object identifier
# 1140: OIN| Open Invention Network
# 1141: OLAP| online analytical processing
# 1142: OLE| Object Linking and Embedding
# 1143: OLED| organic light-emitting diode
# 1144: OLPC| one laptop per child
# 1145: OLTP| online transaction processing
# 1146: OMR| optical mark reading
# 1147: OO| object-oriented or OpenOffice
# 1148: OOF| out of office
# 1149: OOP| object-oriented programming
# 1150: OP| operator
# 1151: OP| original poster
# 1152: OP| overpowered
# 1153: OP| operation
# 1154: Open| open source
# 1155: OpenAL| Open Audio Library
# 1156: OpenGL| Open Graphics Library
# 1157: OR| operations research
# 1158: OR| OR operator
# 1159: OS| operating system
# 1160: OSD| open source definition
# 1161: OSD| object-based storage device
# 1162: OSD| on-screen display
# 1163: OSF| Open Software Foundation
# 1164: OSHA| Occupational Safety and Health Administration
# 1165: OSI| Open Systems Interconnection
# 1166: OSI| Open-Source Initiative
# 1167: OSK| on-screen keyboard
# 1168: OSPF| open shortest path first
# 1169: OSRI| operating system reinstall
# 1170: OSS| open-source software
# 1171: OTP| one-time password
# 1172: OTP| one-time programmable
# 1173: OTP| on the phone
# 1174: OVR| overtype mode
# 1175: P2W| pay-to-win
# 1176: PaaS| Platform as a Service
# 1177: PAD| packet assembler/disassembler
# 1178: PAE| Physical Address Extension
# 1179: PARC| Palo Alto Research Center
# 1180: Parm| parameter
# 1181: PATA| Parallel AT Attachment
# 1182: Pb| petabit
# 1183: PB| Packard Bell
# 1184: PB| petabyte
# 1185: PBX| private branch exchange
# 1186: PBX| private branch extension
# 1187: PC| personal computer
# 1188: PCB| printed circuit board
# 1189: PC-DOS| Personal Computer Disk operating system
# 1190: PCI| Peripheral Component Interconnect
# 1191: PCIe| PCI Express
# 1192: PCI-X| Peripheral Component Interconnect Extended
# 1193: PCL| printer command language
# 1194: PCM| pulse-code modulation
# 1195: PCMCIA| Personal Computer Memory Card International Association
# 1196: P-code| pseudocode
# 1197: P-code| packed code
# 1198: PDA| personal digital assistant
# 1199: PDC| Primary Domain Controller
# 1200: PDF| Portable Document Format
# 1201: PDL| page-description layer
# 1202: PDP| Programmed Data Processor
# 1203: PDU| protocol data unit
# 1204: PEAR| PHP Extension and Application Repository
# 1205: PEGI| Pan-European game information
# 1206: PEP| Packet Ensemble Protocol
# 1207: Permalink| permanent link
# 1208: PET| Personal Electronic Transactor
# 1209: PGA| Professional Golf Association
# 1210: PGA| Professional Graphics Adapter
# 1211: PGA| pin grid array
# 1212: Pg Dn| page down
# 1213: PGP| Pretty Good Privacy
# 1214: Pg Up| page up
# 1215: PHP| Hypertext Preprocessor
# 1216: Pic| picture
# 1217: PICO| PIne COmposer
# 1218: PICS| Platform for Internet Content Selection
# 1219: PID| product identification
# 1220: PID| process identifier
# 1221: PIF| program information file
# 1222: PII| Pentium 2
# 1223: PII| personally identifiable information
# 1224: PIIX| PCI IDE Xcelerator
# 1225: PIM| personal information management
# 1226: PIM| Protocol Independent Multicast
# 1227: PIN| personal identification number
# 1228: PIO| programmed input/output
# 1229: PL| power leveling
# 1230: PLCC| plastic leaded chip carrier
# 1231: PLED| Power LED
# 1232: Plus| Microsoft Plus!
# 1233: PM| polarization maintaining
# 1234: PM| post meridiem
# 1235: PM| preventive maintenance
# 1236: PM| Presentation Manager
# 1237: PM| personal message
# 1238: PM| power management
# 1239: PM| private message
# 1240: P-machine| pseudomachine
# 1241: PMF| polarization maintaining fiber
# 1242: PMS| Pantone Matching System
# 1243: PN| part number
# 1244: PNG| Portable Network Graphics
# 1245: PnP| Plug and Play
# 1246: POD| plain old documentation
# 1247: POE| point of entry
# 1248: POE| Power over Ethernet
# 1249: POP| Post Office Protocol
# 1250: PoS| Proof-of-Stake
# 1251: POS| packet over SONET
# 1252: POSIX| Portable operating system interface for Unix
# 1253: POST| power-on self-text
# 1254: POTS| plain old telephone system
# 1255: POV| point of view
# 1256: PoW| Proof-of-Work
# 1257: PPC| pay per click
# 1258: PPGA| Plastic Pin Grid Array
# 1259: PPI| pixels per inch
# 1260: PPM| pages per minute
# 1261: PPP| Point-to-Point Protocol
# 1262: PPPoE| Point-to-Point Protocol over Ethernet
# 1263: PPS| Privacy Policy Statement
# 1264: PPT or PP| PowerPoint
# 1265: PPTP| Point-to-Point Tunnel Protocol
# 1266: PR| press release
# 1267: PR| Pagerank
# 1268: PRAM| Parameter RAM
# 1269: Printf| print formatted
# 1270: PRISM| Synchronization
# 1271: PRISM| Planning Tool for Resource Integration,  and Management
# 1272: Privmsg| Private Message
# 1273: PRN| printer
# 1274: Proglog| progress log
# 1275: Prolog| Programming in Logic
# 1276: PROM| programmable read-only memory
# 1277: PrtScrn or Prt Scrn| Print Screen key
# 1278: PS| power supply
# 1279: PS| PowerShell
# 1280: PS| print screen
# 1281: PS/2| Personal System/2
# 1282: PS2| PlayStation 2
# 1283: PS3| PlayStation 3
# 1284: PS4| PlayStation 4
# 1285: PSAT| Preliminary Scholastic Assessment Test
# 1286: PSD| Photoshop Document
# 1287: PSoC| programmable system on a chip
# 1288: PSP| Paint Shop Pro
# 1289: PSP| Python Server Pages
# 1290: PSP| PlayStation Portable
# 1291: PSR| Problem Steps Recorder
# 1292: PST| Personal Store
# 1293: PST| Pacific Standard Time
# 1294: PSTN| public switched telephone network
# 1295: PSU| power supply unit
# 1296: PTR| Public Test Realm
# 1297: PTS| pseudoterminal slave
# 1298: PTY| pseudoterminal
# 1299: PU| physical unit
# 1300: PUBG| PlayerUnknown's Battlegrounds
# 1301: PUG| pickup group
# 1302: PVE| Player vs. Environment
# 1303: PVP| Player vs. Player
# 1304: PVR| personal video recorder
# 1305: PW| password
# 1306: PWA| progressive web application
# 1307: PWD| password
# 1308: PWD| print working directory
# 1309: PWS| Personal Web Server
# 1310: Px| pixel
# 1311: PXE| preboot execution environment
# 1312: PXI| PCI extensions for instrumentation
# 1313: Q&A| questions and answers
# 1314: QA| quality assurance
# 1315: QAM| quadrature amplitude modulation
# 1316: QBE| query by example
# 1317: QHD| Quad High Definition
# 1318: QIC| quarter-inch cartridge
# 1319: QLED| quantum-dot light emitting diode
# 1320: QMAC| Quad Media Access Controller
# 1321: QnA| questions and answers
# 1322: QoS| quality of service
# 1323: QPSK| quadrature phase shift keying
# 1324: QR Code| Quick Response Code
# 1325: QSXGA| Quad Super Extended Graphics Array
# 1326: RAD| rapid application development
# 1327: RADIUS| Remote Authentication Dial-in User Service
# 1328: RADSL| rate-adaptive DSL
# 1329: RAID| redundant array of independent disks
# 1330: RAM| random access memory
# 1331: RAMAC| random-access method of accounting and control
# 1332: RAP| Route Access Protocol
# 1333: RAR| Roshal Archive
# 1334: RARP| Reverse Address Resolution Protocol
# 1335: RAS| Remote Access Service
# 1336: RAS| row access strobe
# 1337: RAS| row address select
# 1338: RAS| remote access server
# 1339: RAT| Remote Access Trojan
# 1340: RBAC| role-based access control
# 1341: RBL| real-time blackhole list
# 1342: RC| remote connection
# 1343: RC| remote control
# 1344: RC| run commands
# 1345: RC| release candidate
# 1346: RCE| Reverse Code Engineering
# 1347: RCE| Regional Coding Enhancement
# 1348: RCE| Remote Code Execution
# 1349: RCS| revision control system
# 1350: RDBMS| relational database management system
# 1351: RDF| Resource Description Framework
# 1352: RDMS| report distribution management system
# 1353: RDP| Remote Desktop Protocol
# 1354: RDRAM| Rambus Dynamic Random Access Memory
# 1355: Rec.| receive
# 1356: REC| Record
# 1357: ReFS| Resilient File System
# 1358: Regex| regular expression
# 1359: Rel| release
# 1360: REM| remark
# 1361: REPL| read-eval-print loop
# 1362: RF| radio frequency
# 1363: RFC| Request for Comments
# 1364: RFI| request for information
# 1365: RFI| Radio Frequency Interference
# 1366: RFID| radio frequency identification
# 1367: RF shielding| radio frequency shielding
# 1368: RGB| red-green-blue
# 1369: RHCE| Red Hat Certified Engineer
# 1370: RIAA| Recording Industry Association of America
# 1371: RIP| Routing Information Protocol
# 1372: RIP| raster image process
# 1373: RIP| raster image processor
# 1374: RIPE notes| Reseaux IP Europeens notes
# 1375: RISC| reduced instruction set computer
# 1376: RJ-45| Registered Jack-45
# 1377: RLE| run-length encoding
# 1378: RLL encoding| run-length limited encoding
# 1379: RLP| resource location protocol
# 1380: RMA| return materials authorization
# 1381: RMS| root mean square
# 1382: ROM| read-only memory
# 1383: ROM BIOS| read-only memory basic input/output system
# 1384: RO terminal| read-only terminal
# 1385: RPC| remote procedure call
# 1386: RPG| raster pattern generator
# 1387: RPG| report program generator
# 1388: RPG| role playing game
# 1389: RPM| revolutions per minute
# 1390: RPM| Red Hat Package Manager
# 1391: RRAS| routing and remote access service
# 1392: RRD| removable rigid disk
# 1393: RS-449| Recommended Standard-449
# 1394: RSAC| Recreational Software Advisory Council
# 1395: RSAT| remote server administration tools
# 1396: RSAT| regulatory sequence analysis tools
# 1397: RSL| Rambus signaling level
# 1398: RSS| Relay Spam Stopper
# 1399: RSS| Really Simple Syndication
# 1400: RT| real-time
# 1401: RT| retweet
# 1402: RTC| real-time clock
# 1403: RTF| Rich Text Format
# 1404: RTOS| Real-time Operating System
# 1405: RTR| RARE technical report
# 1406: RTS| Request to Send
# 1407: RTS| real-time strategy
# 1408: RTSP| Real Time Streaming Protocol
# 1409: RTTTL| Ringing Tone Text Transfer Language
# 1410: RVR| realm vs. realm
# 1411: RWD| responsive web design
# 1412: RXD| received data
# 1413: S2R| send to receive
# 1414: SaaS| Software as a Service
# 1415: SACD| Super Audio CD
# 1416: SAN| storage area network
# 1417: SANE| Standard Apple Numeric Environment
# 1418: SAS| Standalone Server
# 1419: SAS| Serial Attached SCSI
# 1420: SATA| Serial AT Attachment
# 1421: SATAN| Security Administrator Tool for Analyzing Networks
# 1422: SBE| Small Business Edition
# 1423: SC| Supercomputing Conference
# 1424: SC| StarCraft
# 1425: SC| Service Controller
# 1426: SCA| Single Connector Attachment
# 1427: Scanf| scan formatted
# 1428: SCC| Serial Communications Controller
# 1429: SCCM| system center configuration manager
# 1430: SCOM| System Center Operations Manager
# 1431: ScrLk| Scroll Lock key
# 1432: SCSI| small computer system interface
# 1433: SD| standard definition
# 1434: SD| single-density diskette
# 1435: SD| single-sided diskette
# 1436: SD| Secure Digital
# 1437: SDDL| Security Descriptor Definition Language
# 1438: SDHC card| Secure Digital High Capacity card
# 1439: SDK| software development kit
# 1440: SDLC| synchronous data link control
# 1441: SDLC| systems development life cycle
# 1442: SDLT| super digital linear tape
# 1443: SDRAM| synchronous DRAM
# 1444: SDSL| symmetrical DSL
# 1445: SDU| service data unit
# 1446: SE| search engine
# 1447: SE| second edition
# 1448: SEA| self-extracting archive
# 1449: SECC| single edge contact cartridge
# 1450: SELinux| Security-Enhanced Linux
# 1451: SEO| search engine optimization
# 1452: Serial no.| serial number
# 1453: SERP| search engine results page
# 1454: Servlet| Java servlet
# 1455: SETI| Search for Extraterrestrial Intelligence
# 1456: Setuid| set user ID on execution
# 1457: Sexp or sexpr| s-expression
# 1458: SFF| small form factor
# 1459: SFTP| Secure File Transfer Protocol
# 1460: SFTP| SSH File Transfer Protocol
# 1461: SFW| safe for work
# 1462: SFX| sound effects
# 1463: SFX| special effects
# 1464: SGD| speech-generating device
# 1465: SGML| Standard Generalized Markup Language
# 1466: SHV connector| safe high-voltage connector
# 1467: Sig| signature
# 1468: SIGINT| signal interrupt
# 1469: SIGINT| Signals Intelligence
# 1470: Sim| simulation
# 1471: SIM card| Subscriber Identity Module card
# 1472: SIMD| single instruction, multiple data
# 1473: SIMM| single inline memory module
# 1474: SIO| super input/output
# 1475: SIP| single in-line package
# 1476: SLA| service-level agreement
# 1477: SLA| sealed lead-acid
# 1478: SLI| Scalable Link Interface
# 1479: SLIP| Serial Line Internet Protocol
# 1480: Slogin| secure login
# 1481: Slotket| socket adapter
# 1482: SLSI| super-large scale integration
# 1483: SMAR| source memory address register
# 1484: SMART| Self-Monitoring Analysis and Reporting Technology
# 1485: SMB| system management bus
# 1486: SMB| server message block
# 1487: SMBus| System Management Bus
# 1488: SM card| SmartMedia card
# 1489: SMI| Simple Mail Interface
# 1490: SMI| System Management Interrupt
# 1491: SMIL| Synchronized Multimedia Integration Language
# 1492: SMM| System Management Mode
# 1493: SMP| symmetric multiprocessing
# 1494: SMPS| switched-mode power supply
# 1495: SMRAM| System Management RAM
# 1496: SMS| system management server
# 1497: SMS| storage management subsystem
# 1498: SMS| short message service
# 1499: SMT| Surface-mount Technology
# 1500: SMTP| Simple Mail Transfer Protocol
# 1501: SNA| Systems Network Architecture
# 1502: SNMP| Simple Network Management Protocol
# 1503: SOA| service-oriented architecture
# 1504: SOA| start of authority
# 1505: SOAP| Simple Object Access Protocol
# 1506: SoC| system on a chip
# 1507: SO-DIMM| small outline dual in-line memory module
# 1508: SOHO| small office/home office
# 1509: SOI| silicon on insulator
# 1510: SOL| Solitaire
# 1511: SONET| synchronous optical networking
# 1512: SOP| super operator
# 1513: Source| source code
# 1514: SP| spelling
# 1515: SPARC| Scalar Processor Architecture
# 1516: SPD| Serial Presence Detection
# 1517: S/PDIF| Sony and Phillips Digital Interconnect Format
# 1518: Spec| specification
# 1519: SPI| system packet interface
# 1520: SPI| stateful packet inspection
# 1521: SPI| serial peripheral interface
# 1522: SPIM| spam over instant message
# 1523: Spit| Spam over Internet Telephony
# 1524: SPL| systems programming language
# 1525: splogs| spam blogs
# 1526: Spool| simultaneous peripheral operatings online
# 1527: SPP| Standard Parallel Port
# 1528: SPS| Standard Power Supply
# 1529: SQL| Structured Query Language
# 1530: SRAM| static random access memory
# 1531: SS| screenshot, South Sudan
# 1532: SSAP| Source Service Access Point
# 1533: SSD| solid-state drive
# 1534: SSE| Streaming SIMD Extensions
# 1535: SSEM| Small Scale Experimental Machine
# 1536: SSI| small-scale integration
# 1537: SSID| service set identifier
# 1538: SSL| Secure Sockets Layer
# 1539: SSL| Space Sciences Laboratory
# 1540: SSP| storage service provider
# 1541: SSR| solid-state relay
# 1542: SSTP| Secure Socket Tunneling Protocol
# 1543: Stdin| standard input
# 1544: STM| Synchronous Transport Module
# 1545: STN| supertwisted nematic
# 1546: STP| software test plan
# 1547: STP| shielded twisted pair
# 1548: STP| Spanning Tree Protocol
# 1549: STR| Suspend-to-RAM
# 1550: STS| synchronous transport signal
# 1551: Sub| subscript
# 1552: Subnet| subnetwork mask
# 1553: SUID| set user ID
# 1554: Sup| superscript
# 1555: SVCD| Super Video CD
# 1556: SVGA| Super Video Graphics Array
# 1557: S-Video| Super Video
# 1558: SW| software
# 1559: SXGA| Super Extended Graphics Array
# 1560: SXGA+| Super XGA Plus
# 1561: SYN| synchronize
# 1562: sync| synchronize
# 1563: synth| synthesizer
# 1564: sysgen| system generation
# 1565: syslog| system log
# 1566: sysop| system operator
# 1567: sysrq| system request
# 1568: TA| terminal adapter
# 1569: Ta| Tantalum
# 1570: TACACS| Terminal Access Controller Access Control System
# 1571: TAPI| Telephony Application Programming Interface
# 1572: TAR| tape archive
# 1573: TCO| total cost of ownership
# 1574: TCPA| Trusted Computer Platform Alliance
# 1575: TCP/IP| Transmission Control Protocol/Internet Protocol
# 1576: TD| table data
# 1577: TDD| telecommunications device for the deaf
# 1578: TDP| thermal design power
# 1579: Tech| technology
# 1580: Telco line| telecommunications line
# 1581: TERA| The Exiled Ream of Arborea
# 1582: TET| text enhancement technology
# 1583: Texel| texture element
# 1584: TFTP| Trivial File Transfer Protocol
# 1585: TH| table head
# 1586: THD| total harmonic distortion
# 1587: Ti| Tebi
# 1588: Ti| Titanium
# 1589: Ti| Textas Instruments
# 1590: TIFF| Tagged Image File Format
# 1591: TIGA| Texas Instruments Graphics Architecture
# 1592: Tk| toolkit
# 1593: TLD| top-level domain
# 1594: TLP| thread-level parallelism
# 1595: TLS| Transport Layer Security
# 1596: TM| trademark
# 1597: TN| twisted nematic
# 1598: TOF| top of file
# 1599: TOPS| transparent operating system
# 1600: Tor| The Onion Router
# 1601: TOS| type of service
# 1602: TOS| terms of use
# 1603: TOS| terms of service
# 1604: TOS| tape operating system
# 1605: TPI| tracks per inch
# 1606: TPM| Trusted Platform Module
# 1607: TP-PMD| Twisted-Pair Physical Medium Dependant
# 1608: TR| technical report
# 1609: Transistor| transfer resistance
# 1610: Triple DEA| Tripple Data Encryption Algorithm
# 1611: TRS| Telecommunications Relay Service
# 1612: TSR| terminate-and-stay-resident
# 1613: TT| Turing test
# 1614: TTFB| time to first byte
# 1615: TTL| transistor-transistor logic
# 1616: TTS| text-to-speech
# 1617: TTY| teletypewriter
# 1618: TTY| teletype
# 1619: TV| television
# 1620: TXD| trasmit data
# 1621: UA| user agent
# 1622: UAC| User Account Control
# 1623: Uarch| microarchitecture
# 1624: UART| Universal Asynchronous Receiver-Transmitter
# 1625: UBCD| Ultimate Boot CD
# 1626: UC| uppercase
# 1627: UCE| unsolicited commercial e-mail
# 1628: UDF| user-defined function
# 1629: UDF| user-defined font
# 1630: UDF| Universal Disk Format
# 1631: UDID| Unique Device Identification
# 1632: UDMA| Ultra Direct Memory Access
# 1633: UDP| User Datagram Protocol
# 1634: UDSL| unidirectional DSL
# 1635: UEFI| Unified Extensible Firmware Interface
# 1636: UHCI| Universal Host Controller Interface
# 1637: UHD| Ultra High Definition
# 1638: UI| user interface
# 1639: U/L| upload
# 1640: UL| uplink
# 1641: UL| upload
# 1642: UL| unordered list
# 1643: ULSI| Ultra Large Scale Integration
# 1644: UMA| Upper Memory Area
# 1645: UMB| upper memory block
# 1646: UNIVAC| Universal Automatic Computer
# 1647: UPC| universal product code
# 1648: UPI| User Program Interface
# 1649: UPnP| Universal Plug and Play
# 1650: UPS| uninterruptible power supply
# 1651: URC| Uniform Resource Characteristic
# 1652: URI| Uniform Resource Identifier
# 1653: URL| Uniform Resource Locator
# 1654: URN| Uniform Resource Name
# 1655: USB| universal serial bus
# 1656: USMT| User State Migration Tool
# 1657: USP| unique selling point
# 1658: USR| user
# 1659: USRT| Universal Synchronous Receiver-Transmitter
# 1660: USWC| uncachable speculative write combining
# 1661: UT| Universal Time
# 1662: UTC| Coordinated Universal Time
# 1663: UTF| Unicode Transformation Format
# 1664: UTM| Urchin Tracking Module
# 1665: UTM| universal Turing machine
# 1666: UTM| Unified Threat Management
# 1667: UTP| unshielded twisted pair cable
# 1668: Uuencode| Unix-to-Unix encode
# 1669: UUID| universal unique identifier
# 1670: UV| ultraviolet
# 1671: UWIN| University of Washington Information Navigator
# 1672: UX| user experience
# 1673: UXGA| Ultra Extended Graphics Array
# 1674: VA| virtual address
# 1675: VAC| Valve Anti-Cheat
# 1676: VADSL| very high bit rate asymmetric digital subscriber line
# 1677: VAN| value-added network
# 1678: VAR| value-added reseller
# 1679: VB| Visual Basic
# 1680: VBR| variable bitrate
# 1681: VBScript| Microsoft Visual Basic Scripting Edition
# 1682: VBV| video buffering verifier
# 1683: VC| version control
# 1684: VC| virtual circuit
# 1685: VC| videoconferencing
# 1686: VC| venture capital
# 1687: VCEG| Video Coding Experts Group
# 1688: VCEG| Visual Coding Experts Group
# 1689: VCI| virtual circuit identifier
# 1690: VCPI| virtual control program interface
# 1691: VCR| video cassette recorder
# 1692: VDC| voltage direct current
# 1693: VDD| virtual device driver, virtual disk drive
# 1694: VDSL| very high data rate DSL
# 1695: VDU| visual display unit
# 1696: Ver| Version
# 1697: Veronica| Very Easy Rodent-Oriented Net-wide Index to Computer Archives
# 1698: VESA| Video Electronics Standard Association
# 1699: VGA| Video Graphics Array
# 1700: VGA| Video Graphics Adapter
# 1701: VHDL| VHSIC Hardware Description Language
# 1702: VHF| very high frequency
# 1703: Vhost| virtual host
# 1704: VHS| Video Home System
# 1705: VIM| Vendor Independent Messaging
# 1706: VIP| very important person
# 1707: VLAN| virtual local area network
# 1708: VLB| Vesa Local Bus
# 1709: VL Bus| Vesa Local Bus
# 1710: VLC| VideoLAN
# 1711: VLSI| very-large-scale integration
# 1712: VM| voicemail
# 1713: VM| virtual memory
# 1714: VM| virtual machine
# 1715: VMEbus| Versa Module Eurocard bus
# 1716: VMM| Virtual Machine Manager
# 1717: VMM| Virtual Machine Monitor
# 1718: VMS| virtual memory system
# 1719: VMS| voicemail system
# 1720: VNC| Virtual Network Computing
# 1721: VOD| video on demand
# 1722: VoIP| Voice over Internet Protocol
# 1723: VoMM| eVade o' Matic Module
# 1724: VPN| virtual private network
# 1725: VPS| virtual private server
# 1726: VR| virtual reality
# 1727: VRAM| video random access memory
# 1728: VRLA| valve-regulated lead-acid
# 1729: VRM| voltage regulator module
# 1730: VRML| Virtual Reality Modeling Language
# 1731: Vs| versus
# 1732: Vs| Visual Studio
# 1733: VSAM| virtual storage access method
# 1734: VTuber| Virtual YouTuber
# 1735: W| width
# 1736: W3C| World Wide Web Consortium
# 1737: WAIS| Wide Area Information Server
# 1738: WAN| wide area network
# 1739: WAP| wireless access point
# 1740: WARP| Warning, Advice and Reporting Point
# 1741: WBEM| Web-based Enterprise Management
# 1742: WCDMA| Wideband Code Division Multiple Access
# 1743: WCN| Windows Connect Now
# 1744: WD| working draft
# 1745: WD| working directory
# 1746: WD| Western Digital
# 1747: WDF| Window Driver Foundation
# 1748: Web app| web application
# 1749: WEP| Wired Equivalent Privacy
# 1750: WFM| Wired for Management
# 1751: WFP| Windows File Protection
# 1752: WGA| Windows Genuine Advantage
# 1753: WiMAX| Worldwide Interoperability for Microwave Access
# 1754: Windows PE| Windows Pre-install Environment
# 1755: Winsock| Windows socket
# 1756: WISP| wireless Internet service provider
# 1757: WMF| Windows metafile format
# 1758: WMI| Windows Management Instrumentation
# 1759: WML| Website META Language
# 1760: WML| Wireless Markup Language
# 1761: WOL| Wake-on-LAN
# 1762: WOW| Windows on Windows
# 1763: WP| WordPress
# 1764: WP| word processor
# 1765: Wpcomp| write pre-comp
# 1766: Wpcomp| word processing competency
# 1767: WQXGA| Wide Quad Extended Graphics Array
# 1768: WRAM| Windows RAM
# 1769: WSXGA| Widescreen Super eXtended Graphics Array
# 1770: WWW| World Wide Web
# 1771: WYSIWYG| what you see is what you get
# 1772: WYSIWYP| what you see is what you print
# 1773: X| X Window System
# 1774: X11| X Window System
# 1775: XDF| extended density format
# 1776: XGA| Extended Graphics Array
# 1777: XHTML| Extensible Hypertext markup Language
# 1778: XML| Extensible Markup Language
# 1779: XMPP| Extensible Messaging and Presence Protocol
# 1780: XMS| extended memory specification
# 1781: XPM| XP mode
# 1782: XSL| Extensible Stylesheet Language
# 1783: XSLT| Extensible Stylesheet Language Transformations
# 1784: XSS| cross-site scripting
# 1785: XT| extended technology

# %%
# Average distance before pre-processing between (a,t)
similarity_measures = [jellyfish.levenshtein_distance, jellyfish.jaro_winkler_similarity, dice_coefficient]
for sim in similarity_measures:
    tmp_sim = 0
    for index, abb in enumerate(abbr):
        e = expansions[index]
        pot_abb = ''.join([c[0] for c in e.split()])
        if sim == jellyfish.levenshtein_distance:
            tmp_sim = tmp_sim + (1- (sim(abb, e))/max(len(abb), len(e)))
        else:
            tmp_sim = tmp_sim + sim(abb, e)
    print(tmp_sim/len(abbr))
# Out:
# 0.09244587264953216
# 0.3096125301007985
# 0.41868180511878067

# %%
# Average distance before pre-processing between (a^{c},t^{c})
similarity_measures = [jellyfish.levenshtein_distance, jellyfish.jaro_winkler_similarity, dice_coefficient]
for sim in similarity_measures:
    tmp_sim = 0
    for index, abb in enumerate(abbr):
        a_clean = clean_string(abb)
        t_clean = clean_string(expansions[index])
        if sim == jellyfish.levenshtein_distance:
            tmp_sim = tmp_sim + (1- (sim(a_clean, t_clean))/max(len(a_clean), len(t_clean)))
        else:
            tmp_sim = tmp_sim + sim(a_clean, t_clean)
    print(tmp_sim/len(abbr))
# Out:
# 0.18185380910770227
# 0.6364646881747009
# 0.4223538221671407

# %%
# Average distance before pre-processing between (a, â)
similarity_measures = [jellyfish.levenshtein_distance, jellyfish.jaro_winkler_similarity, dice_coefficient]
for sim in similarity_measures:
    tmp_sim = 0
    for index, abb in enumerate(abbr):
        exp = expansions[index]
        pot_abb = ''.join([c[0] for c in exp.split()])
        if sim == jellyfish.levenshtein_distance:
            tmp_sim = tmp_sim + (1- (sim(abb, pot_abb))/max(len(abb), len(pot_abb)))
        else:
            tmp_sim = tmp_sim + sim(abb, pot_abb)
    print(tmp_sim/len(abbr))
# Out:
# 0.3613525520945073
# 0.42247094680421177
# 0.8611033252550622

# %%
# Average distance after pre-processing between (a^{c}, â^{c})
similarity_measures = [jellyfish.levenshtein_distance, jellyfish.jaro_winkler_similarity, dice_coefficient]
for sim in similarity_measures:
    tmp_sim = 0
    for index, abb in enumerate(abbr):
        abb_cleaned, exp_cleaned = clean_string_pair_and_reduce_expansion(abb, expansions[index])
        if sim == jellyfish.levenshtein_distance:
            tmp_sim = tmp_sim + (1 - (sim(abb_cleaned, exp_cleaned))/max(len(abb_cleaned), len(exp_cleaned)))
        else:
            tmp_sim = tmp_sim + sim(abb_cleaned, exp_cleaned)
    print(tmp_sim/len(abbr))
# Out:
# 0.7961787056286678
# 0.8958528772830068
# 0.864156008542907

# %%
# Average length after pre-processing
tmp_len = 0
for abb in abbr:
    abb_, x = clean_string_pair_and_reduce_expansion(abb, "Platzhalter")
    tmp_len = tmp_len + len(abb_)
print(tmp_len/len(abbr))
# Out:
# 3.5498320268756998

# %%
# construction and cardinality of S:
S = set()
for i, abb in enumerate(abbr):
    for j, exp in enumerate (expansions):
        if abb != abbr[j]:
            S.add((abb, exp))
print(len(S))
# Out:
# 2710125

# %% [markdown]
# # ILLOD with its Methods

# %%
def check_initial_letters(a, t):
    initial_letters_of_tokens_of_t = ''.join([c[0] for c in t.split()])
    if initial_letters_of_tokens_of_t == a or initial_letters_of_tokens_of_t.upper() == a:
        return True

# %%
def check_length_consistency(a, t):
    length_consistency = False
    if len(t.split()) <= len(a):
        length_consistency = True
    return length_consistency

# %%
def check_order(a, t):
    abbv_reversed = a.lower()[::-1]
    term_reversed = t.lower()[::-1]
    len_of_term = len(t)
    
    pos_memory = 0
    pos_memory_list = []
    order_matching_string_rev = ""
    
    for j, char_from_abbv in enumerate(abbv_reversed):
        if j == len(abbv_reversed) - 1 and len(pos_memory_list) > 0 and pos_memory == len(term_reversed):
            break
        else:
            for i, char_from_term in enumerate(term_reversed[pos_memory:]):
                if char_from_abbv == char_from_term:
                    order_matching_string_rev = order_matching_string_rev + char_from_abbv
                    pos_memory = pos_memory + i + 1
                    pos_memory_list.append(len_of_term - pos_memory)
                    break
    if order_matching_string_rev == abbv_reversed:
        return True, pos_memory_list[::-1]
    else:
        return False, []

# %%
def check_distribution_of_matching_characters(pos_of_chars_list, t):
    term_intervals = []
    len_of_term = len(t)
    i = 0
    while i < len_of_term:
        sublist = []
        j = i
        while j < len_of_term and t[j] != " ":
            sublist.append(j)
            j = j+ 1
        i = j+1
        term_intervals.append(sublist)
        
    splitted_term = t.split()      
    
    containment_list = []
    for i, interval in enumerate(term_intervals):
        contanment_sublist = []
        for pos in pos_of_chars_list:
            if (pos in interval) and (splitted_term[i][0] == t[pos]):
                contanment_sublist.append(0)
            elif pos in interval:
                contanment_sublist.append(interval.index(pos))
        if len(contanment_sublist) == 0:
            contanment_sublist.append(-1)
        containment_list.append(contanment_sublist)
    
    result_of_distribution_check = False
    if len(containment_list) <= 1:
        result_of_distribution_check = True
    elif len (containment_list) >= 2:
        non_zero_count = 0
        for sublist in containment_list[1:]:
            if len(sublist) == 1 and 0 not in sublist:
                non_zero_count += 1
        if non_zero_count == 0:
            result_of_distribution_check = True
    
    return result_of_distribution_check

# %%
def illod(abbv, term, threshold=None):
    if (abbv[0].lower() == term[0].lower()):
        
        
        ###################################### Step (a) ##########################################
        # check wether initial letters of tokens in t match with the letters in abbreviation
        if check_initial_letters(abbv, term):
            return True
        
        
        
        ###################################### Step (b) ########################################
        # clean abbreviation and term from special characters and stopwords
        a_, t_ = clean_string_pair_and_reduce_expansion(abbv, term)
        if a_ == t_:
            return True
        
        sanitized_abbv, sanitized_term = clear_special_characters(abbv, term) 
        sanitized_term_without_stopswords = stop_words_handling(sanitized_term)
        sanitized_term_without_stopswords_splitted  = sanitized_term_without_stopswords.split()
        
        ###################################### Step (c) ##########################################
        # Sequential call of the methods that check and compare lengths, order and distribution of characters
        length_consistency = check_length_consistency(sanitized_abbv, sanitized_term_without_stopswords)
        order, pos_of_chars_list = check_order(sanitized_abbv, sanitized_term_without_stopswords)
        distribution = check_distribution_of_matching_characters(pos_of_chars_list, sanitized_term_without_stopswords)


        if length_consistency and order and distribution:
            return True
        else:
            return False

        ################################## in case nothing matches #################################
    else:
        return False

# %% [markdown]
# # Classifiers based on syntactic similarity

# %%
def dice_coefficient_on_reduction_of_expansion (a, term, threshold):
    a_, t_ = clean_string_pair_and_reduce_expansion(a, term)
    if dice_coefficient(a_, t_) >= threshold:
        return True
    else:
        return False

# %%
def levensthein_distance_on_reduction_of_expansion(a, term, threshold):
    a_, t_ = clean_string_pair_and_reduce_expansion(a, term)
    if jellyfish.levenshtein_distance(a_, t_) <= threshold:
        return True
    else:
        return False

# %%
def jaro_winkler_similarity_on_reduction_of_expansion (a, term, threshold):
    a_, t_ = clean_string_pair_and_reduce_expansion(a, term)
    if jellyfish.jaro_winkler_similarity(a_, t_) >= threshold:
        return True
    else:
        return False

# %%
def simple_jaro_winkler_similarity (a, term, threshold):
    if jellyfish.jaro_winkler_similarity(a, term) >= threshold:
        return True
    else:
        return False

# %%
def simple_dice_coefficient(a, term, threshold):
    if dice_coefficient(a, term) >= threshold:
        return True
    else:
        return False

# %% [markdown]
# # Base Algorithm

# %%
def base_algo(abbv, term, threshold = None):
    valid_order, pos_of_chars_list = check_order(abbv, term)
    return valid_order

# %% [markdown]
# # Data and Evaluation

# %%
data = pd.read_csv('abbr_db.CSV', names=['abbr', 'long_forms'], sep=';', encoding='utf8')
abbr = list(data['abbr'].values)
expansions = list(data['long_forms'].values)

# %%
def find_and_count_false_negatives(algo, threshold):
    FN = 0
    for i, abb in enumerate(abbr):
        if not algo(abb, expansions[i], threshold):
            # print("\""+abb+"\""+", "+"\""+expansions[i]+"\"")
            FN += 1
    return FN, str(FN) + " FALSE NEGATIVES. Pairs that could not be detected out of " + str(len(abbr)) + " given pairs"

# %%
def find_and_count_false_positives(algo, threshold, alpha):
    test_set = []
    while len(test_set) <= alpha * len(abbr):
        rd1 = random.randint(0, len(abbr)-1)
        rd2 = random.randint(0, len(abbr)-1)
        if abbr[rd1] != abbr[rd2]:
            test_set.append ((abbr[rd1], expansions[rd2]))
            
    count_of_false_examples = 0
    FP = 0
    for j, tup in enumerate (test_set): 
        if algo(tup[0], tup[1], threshold):
            count_of_false_examples += 1
            FP +=1
    return FP, str(FP) + " FALSE POSITIVE detections out of " +  str(len(test_set)) + " created false examples"

# %%
for alpha in [8, 16, 24, 48, 72]:
    print("alpha: " + str(alpha))
    algorithms = [dice_coefficient_on_reduction_of_expansion, jaro_winkler_similarity_on_reduction_of_expansion]
    for algo in algorithms:
        max_f1 = 0
        best_values = []
        for th in range(0,101):
            th_ = th/100
            result_on_L = find_and_count_false_negatives(algo, th_)
            result_on_S = find_and_count_false_positives(algo, th_, alpha)
            FN = result_on_L[0]
            FP = result_on_S[0]
            TP = len(abbr) - FN
            precision = TP/(TP + FP)
            recall = TP/(TP + FN)
            f1 = (2*precision*recall)/(precision+recall)
            if f1 > max_f1:
                best_values = [th_, precision, recall, f1]
                max_f1 = f1
        print(best_values)
    print("#########################################################")
# Out:
# alpha: 8
# [0.67, 0.9251837007348029, 0.7754759238521837, 0.8437404812671337]
# [0.75, 0.9021932424422051, 0.8521836506159015, 0.8764756694500432]
# #########################################################
# alpha: 16
# [0.71, 0.8491722869405273, 0.7754759238521837, 0.8106526192566579]
# [0.79, 0.9346049046321526, 0.7681970884658454, 0.8432698217578366]
# #########################################################
# alpha: 24
# [0.76, 0.8085867620751341, 0.7592385218365062, 0.7831360092405428]
# [0.79, 0.9014454664914586, 0.7681970884658454, 0.8295042321644497]
# #########################################################
# alpha: 48
# [0.84, 0.8721017202692596, 0.6528555431131019, 0.7467178994556517]
# [0.83, 0.8560460652591171, 0.7491601343784995, 0.7990444908928038]
# #########################################################
# alpha: 72
# [0.82, 0.805939226519337, 0.6534154535274356, 0.7217068645640075]
# [0.84, 0.9012527634487841, 0.6847704367301232, 0.7782373528475979]
# #########################################################

# %%
for alpha in [8, 16, 24, 48, 72]:
    print("alpha: " + str(alpha))
    max_f1 = 0
    best_values = []
    for th_ in range(0,4):
        result_on_L = find_and_count_false_negatives(levensthein_distance_on_reduction_of_expansion, th_)
        result_on_S = find_and_count_false_positives(levensthein_distance_on_reduction_of_expansion, th_, alpha)
        FN = result_on_L[0]
        FP = result_on_S[0]
        TP = len(abbr) - FN
        precision = TP/(TP + FP)
        recall = TP/(TP + FN)
        f1 = (2*precision*recall)/(precision+recall)
        if f1 > max_f1:
            best_values = [th_, precision, recall, f1]
            max_f1 = f1
    print(best_values)
print("#########################################################")
# Out:
# alpha: 8
# [1, 0.9177295918367347, 0.8057110862262038, 0.8580799045915325]
# alpha: 16
# [1, 0.8251146788990825, 0.8057110862262038, 0.8152974504249291]
# alpha: 24
# [1, 0.7638004246284501, 0.8057110862262038, 0.7841961852861035]
# alpha: 48
# [0, 0.9900891972249752, 0.5593505039193729, 0.7148479427549195]
# alpha: 72
# [0, 0.9794117647058823, 0.5593505039193729, 0.7120456165359944]
# #########################################################

# %%
for alpha in [8, 16, 24, 48, 72]:
    print("alpha: " + str(alpha))
    algorithms = [illod, base_algo]
    for algo in algorithms:
        th_ = 0
        result_on_L = find_and_count_false_negatives(algo, th_)
        result_on_S = find_and_count_false_positives(algo, th_, alpha)
        FN = result_on_L[0]
        FP = result_on_S[0]
        TP = len(abbr) - FN
        if FP == 0:
            FP = 1
        if TP == 0:
            TP = 1
        if FN == 0:
            FN = 1
        precision = TP/(TP + FP)
        recall = TP/(TP + FN)
        f1 = (2*precision*recall)/(precision+recall)
        evaluation_values = [precision, recall, f1]
        print(evaluation_values)
# Out:
# alpha: 8
# [0.9810975609756097, 0.9008958566629339, 0.9392877991827202]
# [0.5913194444444444, 0.9535274356103024, 0.7299614230604372]
# alpha: 16
# [0.9722054380664653, 0.9008958566629339, 0.9351932577739029]
# [0.4117504835589942, 0.9535274356103024, 0.5751435325903411]
# alpha: 24
# [0.9617453676031081, 0.9008958566629339, 0.9303266840127203]
# [0.3227212431305666, 0.9535274356103024, 0.4822313464533484]
# alpha: 48
# [0.9305957200694043, 0.9008958566629339, 0.9155049786628735]
# [0.19057743957027753, 0.9535274356103024, 0.3176646148106696]
# alpha: 72
# [0.8998881431767338, 0.9008958566629339, 0.9003917179630666]
# [0.13878249531415532, 0.9535274356103024, 0.2422992103578288]

# %%
for alpha in [8, 16, 24, 48, 72]:
    print("alpha: " + str(alpha))
    algorithms = [simple_dice_coefficient, simple_jaro_winkler_similarity]
    for algo in algorithms:
        max_f1 = 0
        best_values = []
        for th in range(0,101):
            th_ = th/100
            result_on_L = find_and_count_false_negatives(algo, th_)
            result_on_S = find_and_count_false_positives(algo, th_, alpha)
            FN = result_on_L[0]
            FP = result_on_S[0]
            TP = len(abbr) - FN
            if FP == 0:
                FP = 1
            if TP == 0:
                TP = 1
            if FN == 0:
                FN = 1
            precision = TP/(TP + FP)
            recall = TP/(TP + FN)
            f1 = (2*precision*recall)/(precision+recall)
            if f1 > max_f1:
                best_values = [th_, precision, recall, f1]
                max_f1 = f1
        print(best_values)
    print("#########################################################")
# Out:
# alpha: 8
# [0.36, 0.32583957812933667, 0.6573348264277715, 0.43570235665244017]
# [0.52, 0.6700091157702825, 0.41153415453527437, 0.509885535900104]
# #########################################################
# alpha: 16
# [0.37, 0.19894086496028243, 0.6310190369540873, 0.302509730237552]
# [0.52, 0.49528301886792453, 0.41153415453527437, 0.44954128440366975]
# #########################################################
# alpha: 24
# [0.38, 0.14744370054777844, 0.5425531914893617, 0.23187365398420673]
# [0.55, 0.5366269165247018, 0.3527435610302352, 0.4256756756756757]
# #########################################################
# alpha: 48
# [0.41, 0.08602778102019376, 0.41265397536394177, 0.14237419105573262]
# [0.57, 0.40355677154582764, 0.3303471444568869, 0.36330049261083747]
# #########################################################
# alpha: 72
# [0.61, 0.14925373134328357, 0.08958566629339305, 0.1119664100769769]
# [0.58, 0.36629526462395545, 0.2945128779395297, 0.32650527622594666]
# #########################################################

# %% [markdown]
# # Characteristics of requirements data

# %%
nlp = spacy.load("en_core_web_sm")

# %%
pure_data = pd.read_csv('pure_data.CSV', names=["dataset", "id", "req_texts"], sep='\t', encoding='utf8')
ids = list(pure_data['id'].values)
reqs = list(pure_data['req_texts'].values)
dataset = list(pure_data['dataset'].values)

# %%
def upper_ratio(w):
    upper_cases = ''.join([c for c in w if c.isupper()])
    return len(upper_cases)/len(w)

# %%
abbv_set = set()
ordinary_terms = set()
for req in reqs:
    doc = nlp(req)
    for chunk in doc.noun_chunks:
        term = chunk.text
        term_splitted = term.split()
        abbreviation_in_term = False
        for word in term_splitted:
            if len(word) <= 8 and upper_ratio(word) >= 0.33:
                abbv_set.add(word)
            else:
                ordinary_terms.add(term)
print(len(ordinary_terms))
print(len(abbv_set))
print(len(ordinary_terms)/len(abbv_set))

# %%
print(abbv_set)

# %%
def strict_base_algo(SF, LF):
    lIndex = len(LF)-1
    for sIndex in range (len(SF)-1, 0, -1):
        currCharr = SF[sIndex].lower()
        if not currCharr.isalnum():
            continue
        while (lIndex >= 0 and LF[lIndex].lower() != currCharr) or ((sIndex == 0) and (lIndex>0) and LF[lIndex-1].isalnum()):
            lIndex = lIndex - 1
        if(lIndex < 0):
            return False
        lIndex = lIndex -1
        
    lIndex = LF[:lIndex].rfind(" ")+1
    return LF[lIndex:]

# %%
# some testing of order matching

# %%
def check_order_old_version(a, t):
    abbv_reversed = a.lower()[::-1]
    term_reversed = t.lower()[::-1]
    len_of_term = len(t)
    
    pos_memory = 0
    pos_memory_list = []
    order_matching_string_rev = ""
    
    for j, char_from_abbv in enumerate(abbv_reversed):
        if j == len(abbv_reversed) - 1:
            if char_from_abbv == term_reversed[-1]:
                order_matching_string_rev = order_matching_string_rev + char_from_abbv
                pos_memory_list.append(0)
        else:
            for i, char_from_term in enumerate(term_reversed[pos_memory:]):
                if char_from_abbv == char_from_term:
                    order_matching_string_rev = order_matching_string_rev + char_from_abbv
                    pos_memory = pos_memory + i + 1
                    pos_memory_list.append(len_of_term - pos_memory)
                    break
    if order_matching_string_rev == abbv_reversed:
        return True, pos_memory_list[::-1], order_matching_string_rev
    else:
        return False, [], order_matching_string_rev

# %%
def check_order_new_version(a, t):
    abbv_reversed = a.lower()[::-1]
    term_reversed = t.lower()[::-1]
    len_of_term = len(t)
    
    pos_memory = 0
    pos_memory_list = []
    order_matching_string_rev = ""
    
    for j, char_from_abbv in enumerate(abbv_reversed):
        if j == len(abbv_reversed) - 1:
            print(j)
            if len(pos_memory_list) > 0 and pos_memory == len(term_reversed)-1:
                order_matching_string_rev = order_matching_string_rev + char_from_abbv
                pos_memory_list.append(0)
                break
        else:
            for i, char_from_term in enumerate(term_reversed[pos_memory:]):
                if char_from_abbv == char_from_term:
                    order_matching_string_rev = order_matching_string_rev + char_from_abbv
                    pos_memory = pos_memory + i + 1
                    pos_memory_list.append(len_of_term - pos_memory)
                    print(pos_memory_list)
                    break
    if order_matching_string_rev == abbv_reversed:
        return True, pos_memory_list[::-1], order_matching_string_rev
    else:
        return False, [], order_matching_string_rev

# %%
def check_order_new_version(a, t):
    abbv_reversed = a.lower()[::-1]
    term_reversed = t.lower()[::-1]
    len_of_term = len(t)
    
    pos_memory = 0
    pos_memory_list = []
    order_matching_string_rev = ""
    
    for j, char_from_abbv in enumerate(abbv_reversed):
        # print("j = " +str(j))
        if j == len(abbv_reversed) - 1 and len(pos_memory_list) > 0 and pos_memory == len(term_reversed):
            break
        else:
            for i, char_from_term in enumerate(term_reversed[pos_memory:]):
                # print("i = " +str(i))
                if char_from_abbv == char_from_term:
                    order_matching_string_rev = order_matching_string_rev + char_from_abbv
                    pos_memory = pos_memory + i + 1
                    pos_memory_list.append(len_of_term - pos_memory)
                    break
    if order_matching_string_rev == abbv_reversed:
        return True, pos_memory_list[::-1], order_matching_string_rev
    else:
        return False, [], order_matching_string_rev

# %%
print(check_order_old_version("AA", "Anti ant"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1585f437226d> in <module>
# ----> 1 print(check_order_old_version("AA", "Anti ant"))
#
# NameError: name 'check_order_old_version' is not defined

# %%
print(check_order_old_version("AA", "Anti"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f8e3923a226b> in <module>
# ----> 1 print(check_order_old_version("AA", "Anti"))
#
# NameError: name 'check_order_old_version' is not defined

# %%
print(check_order_new_version("AA", "Anti ant"))
# Out:
# j = 0
# i = 0
# i = 1
# i = 2
# j = 1
# i = 0
# i = 1
# i = 2
# i = 3
# i = 4
# (True, [0, 5], 'aa')

# %%
print(check_order_new_version("AA", "Anti"))
# Out:
# j = 0
# i = 0
# i = 1
# i = 2
# i = 3
# j = 1
# (False, [], 'a')

# %%
count = 0
for i, abb in enumerate(abbr):
    # print(abb + "; " + expansions[i])
    if not check_order_new_version(abb, expansions[i])[0]:
        count += 1
        print(abb + "; " + expansions[i])
        print("new_version: FALSE!")
        print(count)
        print("##############################################")
# Out:
# ADC; analog-to-digital
# new_version: FALSE!
# 1
# ##############################################
# ASN.1; abstract syntax number one
# new_version: FALSE!
# 2
# ##############################################
# B2B; business-to-business
# new_version: FALSE!
# 3
# ##############################################
# B2B; business-to-consumer
# new_version: FALSE!
# 4
# ##############################################
# Bi-di; bidirectional
# new_version: FALSE!
# 5
# ##############################################
# CDA; compact audio disc
# new_version: FALSE!
# 6
# ##############################################
# CD-i; Compact Disc Interactive
# new_version: FALSE!
# 7
# ##############################################
# CD-R; Compact Disc Recordable
# new_version: FALSE!
# 8
# ##############################################
# CD-ROM; Compact Disc Read-Only Memory
# new_version: FALSE!
# 9
# ##############################################
# CD-RW; Compact Disc Re-Writable
# new_version: FALSE!
# 10
# ##############################################
# CD-WO; Compact Disc Write Once
# new_version: FALSE!
# 11
# ##############################################
# CLCC; ceramic leadless lead carrier
# new_version: FALSE!
# 12
# ##############################################
# CPM; cost per thousand
# new_version: FALSE!
# 13
# ##############################################
# CPTM; cost per targeted thousand
# new_version: FALSE!
# 14
# ##############################################
# C-RIMM; continuity RIMM
# new_version: FALSE!
# 15
# ##############################################
# D2D; disk-to-disk
# new_version: FALSE!
# 16
# ##############################################
# DDR2; double data rate two
# new_version: FALSE!
# 17
# ##############################################
# DDR3; double data rate three
# new_version: FALSE!
# 18
# ##############################################
# DDR4; double data rate four
# new_version: FALSE!
# 19
# ##############################################
# DFMC; direct methanol fuel cell
# new_version: FALSE!
# 20
# ##############################################
# D/L; download
# new_version: FALSE!
# 21
# ##############################################
# DTX; discontinuous transmission
# new_version: FALSE!
# 22
# ##############################################
# E-911; Enhanced 911
# new_version: FALSE!
# 23
# ##############################################
# EAP-FAST; Flexible Authentication via Secure Tunneling
# new_version: FALSE!
# 24
# ##############################################
# E-book; electronic book
# new_version: FALSE!
# 25
# ##############################################
# E-learning; electronic learning
# new_version: FALSE!
# 26
# ##############################################
# E-mail; electronic mail
# new_version: FALSE!
# 27
# ##############################################
# ETA-I; Electronic Technicians Association International
# new_version: FALSE!
# 28
# ##############################################
# FC-PGA; flip-chip pin grid array
# new_version: FALSE!
# 29
# ##############################################
# G+; Google Plus
# new_version: FALSE!
# 30
# ##############################################
# G2G; government to government
# new_version: FALSE!
# 31
# ##############################################
# HD-ROM; high-density read-only memory
# new_version: FALSE!
# 32
# ##############################################
# Hi-res; high resolution
# new_version: FALSE!
# 33
# ##############################################
# HP-UX; Hewlett Packard UniX
# new_version: FALSE!
# 34
# ##############################################
# IA-32; Intel Architecture 32
# new_version: FALSE!
# 35
# ##############################################
# IA-64; Intel Architecture 64
# new_version: FALSE!
# 36
# ##############################################
# kb / kbit; kilobit
# new_version: FALSE!
# 37
# ##############################################
# kilo; one thousand
# new_version: FALSE!
# 38
# ##############################################
# L2P; learn to play
# new_version: FALSE!
# 39
# ##############################################
# LED monitor; light-emitting diode
# new_version: FALSE!
# 40
# ##############################################
# Lo-res / low-res; low-resolution
# new_version: FALSE!
# 41
# ##############################################
# M-; meta key
# new_version: FALSE!
# 42
# ##############################################
# MBAM; Malwarebytes
# new_version: FALSE!
# 43
# ##############################################
# Model no.; model number
# new_version: FALSE!
# 44
# ##############################################
# MS-DOS; Microsoft Disk Operating System
# new_version: FALSE!
# 45
# ##############################################
# NO-OP; no operatation
# new_version: FALSE!
# 46
# ##############################################
# P2W; pay-to-win
# new_version: FALSE!
# 47
# ##############################################
# PC-DOS; Personal Computer Disk operating system
# new_version: FALSE!
# 48
# ##############################################
# PCI-X; Peripheral Component Interconnect Extended
# new_version: FALSE!
# 49
# ##############################################
# P-code; pseudocode
# new_version: FALSE!
# 50
# ##############################################
# P-code; packed code
# new_version: FALSE!
# 51
# ##############################################
# PHP; Hypertext Preprocessor
# new_version: FALSE!
# 52
# ##############################################
# PII; Pentium 2
# new_version: FALSE!
# 53
# ##############################################
# P-machine; pseudomachine
# new_version: FALSE!
# 54
# ##############################################
# PPT or PP; PowerPoint
# new_version: FALSE!
# 55
# ##############################################
# PRISM; Synchronization
# new_version: FALSE!
# 56
# ##############################################
# PRISM; Planning Tool for Resource Integration,  and Management
# new_version: FALSE!
# 57
# ##############################################
# PrtScrn or Prt Scrn; Print Screen key
# new_version: FALSE!
# 58
# ##############################################
# PTY; pseudoterminal
# new_version: FALSE!
# 59
# ##############################################
# Q&A; questions and answers
# new_version: FALSE!
# 60
# ##############################################
# Rec.; receive
# new_version: FALSE!
# 61
# ##############################################
# RXD; received data
# new_version: FALSE!
# 62
# ##############################################
# S2R; send to receive
# new_version: FALSE!
# 63
# ##############################################
# Serial no.; serial number
# new_version: FALSE!
# 64
# ##############################################
# Sexp or sexpr; s-expression
# new_version: FALSE!
# 65
# ##############################################
# SFX; sound effects
# new_version: FALSE!
# 66
# ##############################################
# SFX; special effects
# new_version: FALSE!
# 67
# ##############################################
# Slotket; socket adapter
# new_version: FALSE!
# 68
# ##############################################
# SO-DIMM; small outline dual in-line memory module
# new_version: FALSE!
# 69
# ##############################################
# S/PDIF; Sony and Phillips Digital Interconnect Format
# new_version: FALSE!
# 70
# ##############################################
# S-Video; Super Video
# new_version: FALSE!
# 71
# ##############################################
# SXGA+; Super XGA Plus
# new_version: FALSE!
# 72
# ##############################################
# TP-PMD; Twisted-Pair Physical Medium Dependant
# new_version: FALSE!
# 73
# ##############################################
# Transistor; transfer resistance
# new_version: FALSE!
# 74
# ##############################################
# TXD; trasmit data
# new_version: FALSE!
# 75
# ##############################################
# Uarch; microarchitecture
# new_version: FALSE!
# 76
# ##############################################
# U/L; upload
# new_version: FALSE!
# 77
# ##############################################
# UTC; Coordinated Universal Time
# new_version: FALSE!
# 78
# ##############################################
# VLC; VideoLAN
# new_version: FALSE!
# 79
# ##############################################
# W3C; World Wide Web Consortium
# new_version: FALSE!
# 80
# ##############################################
# WiMAX; Worldwide Interoperability for Microwave Access
# new_version: FALSE!
# 81
# ##############################################
# X11; X Window System
# new_version: FALSE!
# 82
# ##############################################
# XSS; cross-site scripting
# new_version: FALSE!
# 83
# ##############################################
